# %% [markdown]
# # Notebook para desenvolvimento de um agente que escaneia notícias sobre o Bitcoin (news_scanner)
#
# - Agente usa a biblioteca Tavily para escanear notícias sobre o Bitcoin.
# - Eu vou ter dois agentes de noticias, um para coletar notícias diretamente relacionadas ao Bitcoin
# - Outro para coletar notícias relacionadas a criptomoedas e noticias sobre a economia mundial que podem impactar o preço do Bitcoin.

# %% [markdown]
# ### Tavily news:

# %%
from tavily import TavilyClient
from dotenv import load_dotenv
_ = load_dotenv()

tavily_client = TavilyClient()

# %%
search_response_news = tavily_client.search(query="Bitcoin", topic="news", time_range="day", max_results=2)
search_response_finance = tavily_client.search(query="Bitcoin", topic="finance", time_range="day", max_results=2)
print("News Search Results:")
print(search_response_news)
print("\n\n")
print("Finance Search Results:")
print(search_response_finance)
# Out:
# News Search Results:
# {'query': 'Bitcoin', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://longportapp.com/en/news/242305766', 'title': 'At the Bitcoin conference, VanS stated: Bitcoin is a part of the mainstream economy in the United States, and stablecoins will not threaten the US dollar - longportapp.com', 'score': 0.43568602, 'published_date': 'Thu, 29 May 2025 02:37:43 GMT', 'content': 'On May 28, local time, at this year\'s Bitcoin 2025 conference, U.S. Vice President JD Vance emphasized that cryptocurrency (especially Bitcoin) has become a part of the mainstream U.S. economy and "will be here to stay": David Sacks, a top cryptocurrency and AI advisor to the Trump administration, revealed to the media that there are over $200 billion in unregulated stablecoins in the market, and a legal framework "could create trillions of dollars in demand for U.S. Treasury bonds almost overnight." Reports indicate that Trump himself holds $2.9 billion in cryptocurrency assets, and his Trump Media and Technology Group has just announced raising $2.5 billion to invest in Bitcoin.'}, {'url': 'https://www.kitco.com/news/article/2025-05-29/bitcoin-may-29-daily-chart-alert-bulls-remain-firm-control', 'title': 'Bitcoin May 29 daily chart alert - Bulls remain in firm control - KITCO', 'score': 0.30925363, 'published_date': 'Thu, 29 May 2025 12:18:53 GMT', 'content': 'Bitcoin May 29 daily chart alert - Bulls remain in firm control | Kitco News Kitco News Kitco NEWS has a diverse team of journalists reporting on the economy, stock markets, commodities, cryptocurrencies, mining and metals with accuracy and objectivity. (Kitco News) - Thursday, May 29—June bitcoin futures prices are higher in early U.S. trading Thursday. Follow Jim daily on Kitco.com as he provides both AM and PM roundups and a daily Technical Special. ### Whether 145% or 10%, tariff uncertainty is enough to stop U.S. gold and silver imports, distort the metals market at all levels – Experts May 14, 2025 - 4:34 PM ### Bitcoin analysts target $120k as crypto market gains momentum after correction Nov 27, 2024 - 11:09 AM'}], 'response_time': 0.36}
#
#
#
# Finance Search Results:
# {'query': 'Bitcoin', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'title': 'Latest Bitcoin 2025 Twist is Turning Small Firms Into Crypto ...', 'url': 'https://www.bloomberg.com/news/newsletters/2025-05-29/latest-bitcoin-2025-twist-is-turning-small-firms-into-crypto-juggernauts', 'content': "Hi, it's Matt Monks in Las Vegas with a rundown on the Bitcoin 2025 conference that drew a lot of bankers. In other M&A news, Hailey Bieber sells her beauty brand to a publicly traded", 'score': 0.17813979, 'raw_content': None}, {'title': "Bitmain's New Antminer Launch Signals Profound Shift for Bitcoin Miners ...", 'url': 'https://sg.finance.yahoo.com/news/bitmains-antminer-launch-signals-profound-150340588.html', 'content': "The new rig delivers sub-10 J/TH efficiency, but miners face tighter margins despite Bitcoin's price surge.", 'score': 0.13738221, 'raw_content': None}], 'response_time': 2.06}

# %%
search_response_news['results'][0].keys()
# Out:
# dict_keys(['url', 'title', 'score', 'published_date', 'content'])

# %%
search_response_finance['results'][0].keys()
# Out:
# dict_keys(['title', 'url', 'content', 'score', 'raw_content'])

# %%
querie = "Bitcoin price analysis"
search_response_finance = tavily_client.search(query=querie, topic="news", time_range="day", max_results=2)

print("Finance Search Results:")
print(search_response_finance)
# Out:
# Finance Search Results:
# {'query': 'Bitcoin price analysis', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.kitco.com/news/article/2025-05-29/bitcoin-may-29-daily-chart-alert-bulls-remain-firm-control', 'title': 'Bitcoin May 29 daily chart alert - Bulls remain in firm control - KITCO', 'score': 0.42133808, 'published_date': 'Thu, 29 May 2025 12:18:53 GMT', 'content': 'Bitcoin May 29 daily chart alert - Bulls remain in firm control | Kitco News Kitco News Kitco NEWS has a diverse team of journalists reporting on the economy, stock markets, commodities, cryptocurrencies, mining and metals with accuracy and objectivity. (Kitco News) - Thursday, May 29—June bitcoin futures prices are higher in early U.S. trading Thursday. Follow Jim daily on Kitco.com as he provides both AM and PM roundups and a daily Technical Special. ### Whether 145% or 10%, tariff uncertainty is enough to stop U.S. gold and silver imports, distort the metals market at all levels – Experts May 14, 2025 - 4:34 PM ### Bitcoin analysts target $120k as crypto market gains momentum after correction Nov 27, 2024 - 11:09 AM'}, {'url': 'https://www.marketscreener.com/quote/stock/NORDSON-CORPORATION-10175/news/Nordson-Contract-Manufacturing-Sites-in-Ireland-Mexico-to-Be-Acquired-by-Quasar-Medical-50102108/', 'title': 'Nordson Contract Manufacturing Sites in Ireland, Mexico to Be Acquired by Quasar Medical - marketscreener.com', 'score': 0.22505063, 'published_date': 'Thu, 29 May 2025 12:41:44 GMT', 'content': 'ELI LILLY AND COMPANY Indices Homepage Rankings Europe America Asia Africa Index Analysis Indexes News S&P 500 DOW JONES NASDAQ 100 TSX COMP FTSE 100 DAX CAC 40 EURO STOXX 50 Currency / Forex Homepage Rankings Currency Cross Rate Currency Converter Forex Analysis Currencies News USD / EUR USD / CAD USD / MXN USD / BRL USD / INR Commodities Homepage Energy Precious metals Agriculture Industrial Metals Livestock and Cattle GOLD CRUDE OIL (WTI) CRUDE OIL (BRENT) SILVER PLATINUM Cryptocurrencies Homepage Rankings Charts Analysis News BITCOIN ETHEREUM BINANCE COIN SOLANA CARDANO CHAINLINK Interest Rates Homepage Yield Curve Developed Nations Emerging Countries ETF Summary Screener Analysis News '}], 'response_time': 0.46}

# %%
extract = tavily_client.extract(urls=["https://www.binance.com/en/square/news/bitcoin-news"])
extract
# Out:
# {'results': [{'url': 'https://www.binance.com/en/square/news/bitcoin-news',
#    'raw_content': "Top Bitcoin News News Today | Binance Square\n===============\n\nLogin\nSign Up\nHomeNotificationProfileTrending ArticlesNewsBookmarked and LikedHistoryCreator CenterSettings\nNews\nMay 28 Wed\nOnly Display Breaking News\nAllBinance NewsMarket NewsBitcoin NewsBNB NewsEthereum NewsAI NewsMeme NewsWhale AlertDeFi NewsGameFi NewsWeb3 NewsSolana NewsXRP NewsDOGE NewsSHIB NewsPEPE NewsRegulation NewsNFT NewsEditor's Pick\nLatest Bitcoin news, price updates, and market trends\n5m\n### Meta Urged to Consider Bitcoin for Corporate Strategy According to Odaily, Strive CEO Matt Cole has urged Mark Zuckerberg's Meta to purchase Bitcoin and incorporate it into the company's balance sheet. Cole emphasized that Bitcoin could be beneficial for businesses.\nBTC-2.60%\n0\n0\n2h\n### U.S. Vice President Vance Affirms Continued Bitcoin Holdings According to BlockBeats, U.S. Vice President Vance revealed during his speech at the Bitcoin 2025 Conference that he still holds a significant amount of Bitcoin. His statement underscores the ongoing interest and investment in cryptocurrency by high-profile political figures.\nBTC-2.60%\n7\n3\n4h\n### Bitcoin Price Falls Below $108,000 Amid Fed Rate Cut Expectations According to Odaily, Bitcoin's price has dropped below $108,000, potentially influenced by diminished expectations for a Federal Reserve rate cut. Ahead of the Fed's May meeting minutes release, the sentiment in risk asset markets remains cautious. The CME FedWatch tool indicates that the market now anticipates the first rate cut by the Federal Reserve might be postponed until September, with the expected number of rate cuts for 2025 reduced from four to two. Trader TheKingfisher noted that further declines in Bitcoin's price could trigger additional short covering. QCP Capital previously stated that the current market lacks catalysts to drive price fluctuations, resulting in a continued decrease in overall volatility.\nBTC-2.60%\n16\n2\n5h\n### Bitcoin Users Recognize National Debt Issues Early, Says CEO According to Foresight News, Anthony Pompliano, founder and CEO of Professional Capital Management, stated that Bitcoin users have been quicker than most to recognize the challenges posed by national debt. He noted that these individuals understand how to allocate capital effectively to benefit from the inevitable depreciation of currency. Pompliano expressed that history will favor those who foresee future trends and take early action.\nBTC-2.60%\n9\n1\n5h\n### Bitcoin(BTC) Drops Below 108,000 USDT with a 2.00% Decrease in 24 Hours On May 28, 2025, 14:10 PM(UTC). According to Binance Market Data, Bitcoin has dropped below 108,000 USDT and is now trading at 107,950 USDT, with a narrowed 2.00% decrease in 24 hours.\nBTC-2.60%\n5\n1\n6h\n### K33 Secures $6.23 Million for Bitcoin Treasury Strategy According to Odaily, K33 has entered into an investment agreement with its shareholders, including Klein Group (via Aurora 3 AS), Middelborg Invest AS, Tigergutt Invest AS, and Modiola AS. The agreement aims to raise a total of 60 million Swedish kronor, approximately $6.23 million, to support the company's new Bitcoin treasury strategy. The net proceeds from this investment will be entirely allocated to purchasing Bitcoin.\nBTC-2.60%\n6\n1\n7h\n### Bitcoin Funding Rates Turn Negative Amid Market Shifts According to Foresight News, recent data from Glassnode indicates that Bitcoin's funding rates have shifted to negative. This change suggests a growing presence of short positions among the top ten cryptocurrencies by market capitalization. Both Binance Coin (BNB) and Cardano (ADA) are showing signs of pressure in the market. Additionally, Solana's funding rate is currently ranked as the sixth lowest among all assets tracked by Glassnode Studio.\n5\n0\n7h\n### GameStop Announces First Bitcoin Acquisition Amid Rising Share Prices According to Cointelegraph, GameStop, a prominent U.S. video game and consumer electronics retailer, has of ...
#    'images': []}],
#  'failed_results': [],
#  'response_time': 0.01}

# %%
print(extract['results'][0]['raw_content'])
# Out:
# Top Bitcoin News News Today | Binance Square
# ===============
#
# Login
# Sign Up
# HomeNotificationProfileTrending ArticlesNewsBookmarked and LikedHistoryCreator CenterSettings
# News
# May 28 Wed
# Only Display Breaking News
# AllBinance NewsMarket NewsBitcoin NewsBNB NewsEthereum NewsAI NewsMeme NewsWhale AlertDeFi NewsGameFi NewsWeb3 NewsSolana NewsXRP NewsDOGE NewsSHIB NewsPEPE NewsRegulation NewsNFT NewsEditor's Pick
# Latest Bitcoin news, price updates, and market trends
# 5m
# ### Meta Urged to Consider Bitcoin for Corporate Strategy According to Odaily, Strive CEO Matt Cole has urged Mark Zuckerberg's Meta to purchase Bitcoin and incorporate it into the company's balance sheet. Cole emphasized that Bitcoin could be beneficial for businesses.
# BTC-2.60%
# 0
# 0
# 2h
# ### U.S. Vice President Vance Affirms Continued Bitcoin Holdings According to BlockBeats, U.S. Vice President Vance revealed during his speech at the Bitcoin 2025 Conference that he still holds a significant amount of Bitcoin. His statement underscores the ongoing interest and investment in cryptocurrency by high-profile political figures.
# BTC-2.60%
# 7
# 3
# 4h
# ### Bitcoin Price Falls Below $108,000 Amid Fed Rate Cut Expectations According to Odaily, Bitcoin's price has dropped below $108,000, potentially influenced by diminished expectations for a Federal Reserve rate cut. Ahead of the Fed's May meeting minutes release, the sentiment in risk asset markets remains cautious. The CME FedWatch tool indicates that the market now anticipates the first rate cut by the Federal Reserve might be postponed until September, with the expected number of rate cuts for 2025 reduced from four to two. Trader TheKingfisher noted that further declines in Bitcoin's price could trigger additional short covering. QCP Capital previously stated that the current market lacks catalysts to drive price fluctuations, resulting in a continued decrease in overall volatility.
# BTC-2.60%
# 16
# 2
# 5h
# ### Bitcoin Users Recognize National Debt Issues Early, Says CEO According to Foresight News, Anthony Pompliano, founder and CEO of Professional Capital Management, stated that Bitcoin users have been quicker than most to recognize the challenges posed by national debt. He noted that these individuals understand how to allocate capital effectively to benefit from the inevitable depreciation of currency. Pompliano expressed that history will favor those who foresee future trends and take early action.
# BTC-2.60%
# 9
# 1
# 5h
# ### Bitcoin(BTC) Drops Below 108,000 USDT with a 2.00% Decrease in 24 Hours On May 28, 2025, 14:10 PM(UTC). According to Binance Market Data, Bitcoin has dropped below 108,000 USDT and is now trading at 107,950 USDT, with a narrowed 2.00% decrease in 24 hours.
# BTC-2.60%
# 5
# 1
# 6h
# ### K33 Secures $6.23 Million for Bitcoin Treasury Strategy According to Odaily, K33 has entered into an investment agreement with its shareholders, including Klein Group (via Aurora 3 AS), Middelborg Invest AS, Tigergutt Invest AS, and Modiola AS. The agreement aims to raise a total of 60 million Swedish kronor, approximately $6.23 million, to support the company's new Bitcoin treasury strategy. The net proceeds from this investment will be entirely allocated to purchasing Bitcoin.
# BTC-2.60%
# 6
# 1
# 7h
# ### Bitcoin Funding Rates Turn Negative Amid Market Shifts According to Foresight News, recent data from Glassnode indicates that Bitcoin's funding rates have shifted to negative. This change suggests a growing presence of short positions among the top ten cryptocurrencies by market capitalization. Both Binance Coin (BNB) and Cardano (ADA) are showing signs of pressure in the market. Additionally, Solana's funding rate is currently ranked as the sixth lowest among all assets tracked by Glassnode Studio.
# 5
# 0
# 7h
# ### GameStop Announces First Bitcoin Acquisition Amid Rising Share Prices According to Cointelegraph, GameStop, a prominent U.S. video game and consumer electronics retailer, has officially confirmed its initial foray into Bitcoin investment. The company announced the purchase of 4,710 Bitcoin (BTC) in a brief statement shared on X on May 28, marking a significant milestone in its investment strategy.This announcement follows GameStop's earlier disclosure in March 2025, where it revealed plans to venture into Bitcoin investments. At that time, the company indicated its intention to fund the acquisition through debt financing, launching a $1.3 billion convertible notes offering. The decision to invest in Bitcoin comes after months of speculation and reports suggesting GameStop's interest in diversifying into alternative asset classes, including cryptocurrencies, which first emerged in February 2025.The news of GameStop's Bitcoin purchase has had a notable impact on its stock performance. In March, when the company's Bitcoin investment plans were initially reported, GameStop shares experienced a significant surge, increasing by 12%. Earlier speculation regarding Bitcoin investments had already contributed to an 18% rise in the company's stock value. As of May 27, GameStop shares closed at $35, and by the time of publication, they had risen to $36.3 in pre-market trading. Over the past 30 days, the stock has seen an approximate 30% increase, with year-to-date gains of around 10%.This development is part of an ongoing story, and additional details will be provided as they become available. The move by GameStop into Bitcoin investment reflects a broader trend among companies seeking to explore the potential of cryptocurrencies as part of their financial strategies.
# BTC-2.60%
# 8
# 0
# 8h
# ### Bitcoin's Influence on U.S. Capital Markets Grows According to Foresight News, Ki Young Ju, the founder of CryptoQuant, recently commented on the impact of Michael Saylor's strategies on the U.S. capital markets. Ju noted that Saylor has effectively redirected market liquidity towards Bitcoin, creating a perpetual motion effect among companies with convertible bond operations and Bitcoin reserves. This mechanism continues to be fueled by market volatility, raising questions about when it might cease. The notion of Bitcoin's perpetual rise, once considered a meme, is now gaining traction among long-term Bitcoin advocates.
# BTC-2.60%
# 2
# 0
# 8h
# ### Traders Anticipate Bitcoin Volatility Ahead of Upcoming Conference According to Odaily, macro researcher Adam from Greeks.live shared insights in an English community briefing, highlighting a prevalent bearish sentiment among traders. Most expect a significant downturn, particularly before the upcoming Bitcoin conference scheduled from May 27 to 29. There is a notable divide between bearish traders anticipating a sharp decline and a bullish trader who predicts the SPX will reach 6650 by the end of July, with Bitcoin potentially hitting $120,000 before correcting to $102,000.Despite the ongoing upward price momentum, the majority of active traders are heavily invested in bearish options spread positions. They plan to increase these positions ahead of the Bitcoin conference, anticipating that the event will lead to a repricing of volatility.
# BTC-2.60%
# 3
# 0
# 8h
# ### GameStop Shares Rise Following Bitcoin Purchase According to BlockBeats, GameStop Corp. (GME) experienced a 3.68% increase in pre-market trading, with shares currently priced at $36.5. This rise is attributed to the news of a purchase of 4,710 BTC.
# BTC-2.60%
# 8
# 0
# 9h
# ### Strategy Slows Bitcoin Accumulation Amid Competitive Market According to BlockBeats, Strategy, formerly known as MicroStrategy, has recently slowed its pace of Bitcoin accumulation compared to its peak in November last year. K33 Research Director Vetle Lunde highlighted two main reasons for this slowdown in a report released on Tuesday. Firstly, the premium of Strategy's Class A common stock, MSTR, relative to its Bitcoin holdings has decreased. Secondly, the competition among companies to hoard Bitcoin has intensified.Between May 19 and May 25, Strategy purchased 4,020 Bitcoins at an average price of $106,237, totaling approximately $427.1 million. Of this amount, $348.7 million was financed through its latest $21 billion at-the-market (ATM) offering plan, a significant reduction from the previous week's $705.7 million and the $1.31 billion from May 5 to 11.Lunde noted that the utilization rate of the new $21 billion ATM plan is much lower than the first $21 billion plan. From November 4 to December 16 last year, MSTR raised an average of $2.13 billion per week through ATM financing, whereas the recent three-week average is only $788 million. The emergence of other companies adopting Bitcoin reserves has provided more options for investors, potentially diverting some demand away from MSTR.Additionally, as Strategy's Bitcoin holdings appreciate, maintaining the previous 2x net asset premium requires stronger buying support. Last week, particularly on Friday, the premium of MSTR relative to its Bitcoin holdings dropped sharply from 185% to 163%, marking a new low since April 8. Lunde added that aggressive issuance has accelerated the premium contraction, which may force MSTR to slow down its ATM financing pace. The scenario of last November, where large issuances could still boost the premium, may not be replicable.
# BTC-2.60%
# 4
# 1
# 11h
# ### Bitcoin(BTC) Surpasses 109,000 USDT with a Narrowed 0.53% Decrease in 24 Hours On May 28, 2025, 08:39 AM(UTC). According to Binance Market Data, Bitcoin has crossed the 109,000 USDT benchmark and is now trading at 109,057.828125 USDT, with a narrowed narrowed 0.53% decrease in 24 hours.
# BTC-2.60%
# 4
# 0
# 11h
# ### Bitcoin Holders Increase Activity, Reaching New Transfer Peaks According to PANews, recent data from Glassnode indicates a significant rise in activity among long-term Bitcoin holders, with the total transfer volume for those holding Bitcoin for 1-5 years reaching $4.02 billion, marking the highest level since February this year. Within this group, holders of 3-5 years contributed $2.16 billion, the second-highest in this cycle, following the $6 billion peak in March 2024. Meanwhile, the 2-3 year holders transferred $1.41 billion, and the 1-2 year holders moved $450 million. This recent transfer activity among the 1-5 year holding group represents the fifth-largest peak in this cycle, primarily driven by long-term holders. Reviewing other peaks in this cycle, October 2024 saw $9.25 billion dominated by the 1-2 year group, March 2024 had $6.11 billion led by the 2-3 year group, February 2025 recorded $5.42 billion also led by the 2-3 year group, and November 2024 saw $4.39 billion dominated by the 3-5 year group. The current activity suggests that long-term holders are accelerating the release of their Bitcoin holdings.
# BTC-2.60%
# 2
# 1
# 11h
# ### Metaplanet Raises $50 Million in Zero-Interest Bonds to Boost Bitcoin Holdings According to Cointelegraph, Japanese investment firm Metaplanet is actively pursuing an increase in its Bitcoin exposure by raising $50 million through a private placement of zero-interest bonds. Announced on May 28, these bonds are issued in denominations of $1.25 million and do not offer regular interest payments. Instead, any potential profit for investors is anticipated to come from the bond's redemption value. Evo Fund, an investment firm based in the Cayman Islands, will be the sole bondholder. Evo Fund has been a consistent supporter of Metaplanet's Bitcoin acquisition strategy, participating in multiple rounds of zero-interest bonds to provide capital for Metaplanet's Bitcoin purchases. Metaplanet's bonds are unsecured and unguaranteed, lacking both a bond administrator and collateral, which indicates a significant level of trust between Metaplanet and Evo Fund. This move also underscores confidence in Bitcoin's long-term potential as Metaplanet continues to expand its holdings. The company has stated that the bond issuance is expected to have minimal impact on its financial results for 2025, though it will provide updates if necessary. This strategy reflects a broader trend among companies seeking alternatives to traditional fiat-based treasury strategies. Metaplanet's recent activities include its second-largest Bitcoin purchase, acquiring 1,004 Bitcoin valued at over $100 million, which increased its total Bitcoin holdings to 7,800 BTC, worth over $800 million. According to BitcoinTreasuries.NET, Metaplanet's Bitcoin investments have appreciated by nearly 20%. This aggressive Bitcoin strategy has also positively impacted Metaplanet's stock prices. On May 27, 10x Research reported that Metaplanet's stock is trading as if Bitcoin were valued at five times its actual price, suggesting that investors might be overpaying for their Bitcoin exposure through the company. The rising stock prices of companies with significant Bitcoin holdings have attracted criticism from notable investors like Jim Chanos. Speaking at the Sohn Investment Conference in New York, Chanos revealed that he is selling MicroStrategy stock to purchase Bitcoin directly. His decision is based on the belief that investors are overpaying for Bitcoin exposure through corporate entities like MicroStrategy, and that direct Bitcoin purchases would be more advantageous. This perspective highlights the ongoing debate over the best methods for gaining Bitcoin exposure in the investment community.
# BTC-2.60%
# 2
# 2
# 13h
# ### U.S. Government Explores Bitcoin Acquisition Options According to PANews, David Sacks, the head of artificial intelligence and cryptocurrency affairs at the U.S. White House, discussed potential government strategies for acquiring more Bitcoin at the Bitcoin 2025 conference. Sacks emphasized that while he cannot make any promises, there are avenues for the U.S. government to purchase additional Bitcoin. He noted that if the acquisition could be funded in a 'budget-neutral' manner, without imposing taxes or increasing the national debt, it would be feasible for the government to proceed with such purchases. Sacks highlighted the importance of gaining the interest of the Treasury or Commerce Department in this initiative. He stated that if these departments become enthusiastic about the idea and can devise a funding strategy, they would effectively have the authorization from U.S. President Donald Trump to move forward with the acquisition.
# BTC-2.60%
# 10
# 3
# 16h
# ### Bitcoin Spot ETFs Experience Significant Net Inflows and Outflows According to PANews, data from SoSoValue indicates that on May 27, Bitcoin spot ETFs saw a total net inflow of $385 million. The largest single-day net inflow was recorded by Blackrock's ETF IBIT, which received $409 million, bringing its historical total net inflow to $48.394 billion. Grayscale's Bitcoin Mini Trust ETF BTC followed with a single-day net inflow of $36.029 million, accumulating a historical total net inflow of $1.414 billion. Conversely, the Bitcoin spot ETF with the largest single-day net outflow was Ark Invest and 21Shares' ETF ARKB, which saw an outflow of $38.335 million. ARKB's historical total net inflow currently stands at $2.687 billion. As of the latest report, the total net asset value of Bitcoin spot ETFs is $132.895 billion, with an ETF net asset ratio of 6.1% compared to Bitcoin's total market value. The historical cumulative net inflow has reached $44.911 billion.
# BTC-2.60%
# 6
# 2
# 16h
# ### BlackRock Executive Recommends Bitcoin Allocation at Conference According to Odaily, a spokesperson from BlackRock, the world's largest asset management firm overseeing $11 trillion, suggested at the Bitcoin 2025 Conference that investors allocate 2% of their portfolios to Bitcoin. This recommendation highlights the growing acceptance of cryptocurrency in traditional investment strategies.
# BTC-2.60%
# 7
# 2
# 17h
# ### Bitcoin's Potential Growth Surpasses Gold, Says BlackRock Executive According to BlockBeats, Robert Mitchnick, the head of digital assets at BlackRock, stated at the Bitcoin 2025 conference that Bitcoin has a significantly higher potential for growth compared to gold. Mitchnick's remarks highlight the increasing interest and optimism surrounding Bitcoin's future prospects in the financial markets.
# BTC-2.60%
# 12
# 1
# 18h
# ### Bitcoin's Potential Surge to $1 Million with Wall Street Investment According to PANews, Michael Saylor, Chairman of the Board at Strategy (formerly MicroStrategy), stated at the Bitcoin 2025 Conference that Bitcoin's price could reach $1 million if Wall Street holds 10% of the cryptocurrency. Saylor's remarks highlight the potential impact of institutional investment on Bitcoin's market value.
# BTC-2.60%
# 10
# 0
# Explore the latest crypto news
# ⚡️ Be a part of the latests discussions in crypto
# 💬 Interact with your favorite creators
# 👍 Enjoy content that interests you
# Email / Phone number
# Sign Up
# Login
# Relevant Creator
#
# Binance News
# @Binance_News
# Follow
# Trending Topics
# BinanceHODLerSOPH 1.3M views 3,298 DiscussingBitcoin2025 6.9M views 12,995 DiscussingTrumpMediaBitcoinTreasury 2.5M views 4,697 DiscussingView More
# Fear & Greed Index ------------------Trade Now
# 68 Greed
# How do you feel about BTC today？
# Bearish Bullish
# Most Searched (6H)
# USDT
#  A Rapid Riser 0.739 -5.24% SOPH Rapid Riser 0.06452 +115.07% TON Rapid Riser 3.403 +13.43%
# Suggested Creators
#
# Binance Risk Sniper
# Stay ahead on risk warnings, risk sniping, and shared risk knowledge with the official Binance Risk team. Follow us for updates!
# Follow
#
# Binance Research
# Binance Research provides institutional-grade analysis, in-depth insights, and unbiased information to all participants in the digital asset industry.
# Follow
#
# Yi He
# Co-Founder & Chief Customer Service Officer in @Binance /Holder of #BNB
# Follow
#
# Binance Square Official
# Follow Binance Square's Official Account for the latest updates!
# Follow
#
# Binance Angels
#
# Official Account of @Binance Angel Program. Join a selected group of international volunteers who are passionate about Binance, and help make the difference!
# Follow
# View More
# Trending Articles
# 🚨 BREAKING: Fed Minutes Released! 🚨 📰 Key Highlights: 🟡
# Mafi VIP SIGNAL
# Russia escalates public spat with US president Trump with World War III threats
# Cryptopolitan
# BLACKROCK JUST SHOCKED EVERYONE! 😱 Ripple’s CTO Breaks the Silence — Is India Making a Crypto Comeb
# Rehan malik awan
# Ethereum Investors Are in Big Trouble — One More Dip Could Put $123 Billion At Risk
# Coinpedia
# Satoshi Nakamoto hasn’t moved a single coin in 15 years. No
# Big dog127
# View More
# SitemapCookie PreferencesPlatform T&Cs
# Sitemap
# Platform T&Cs
# Cookie Preferences
#
# Privacy Preference Center
# When you visit any website, it may store or retrieve information on your browser, mostly in the form of cookies. This information might be about you, your preferences or your device and is mostly used to make the site work as you expect it to. The information does not usually directly identify you, but it can give you a more personalized web experience. Because we respect your right to privacy, you can choose not to allow some types of cookies. Click on the different category headings to find out more and change our default settings. However, blocking some types of cookies may impact your experience of the site and the services we are able to offer.
# Cookie Policy
# Allow All
# Manage Consent Preferences
# Strictly Necessary Cookies
# Always Active
# These cookies are necessary for the website to function and cannot be switched off in our systems. They are usually only set in response to actions made by you which amount to a request for services, such as setting your privacy preferences, logging in or filling in forms. You can set your browser to block or alert you about these cookies, but some parts of the site will not then work. These cookies do not store any personally identifiable information.
# Cookies Details‎
# Functional Cookies
#
# [x] Functional Cookies
#
# These cookies enable the website to provide enhanced functionality and personalisation. They may be set by us or by third party providers whose services we have added to our pages. If you do not allow these cookies then some or all of these services may not function properly.
# Cookies Details‎
# Targeting Cookies
#
# [x] Targeting Cookies
#
# Targeting cookies may be set through our site by ourselves and our advertising partners. First parties and third parties will use them to build a profile of your interests based on the browsing information they collect from you, which includes uniquely identifying your browser and terminal equipment. If you do not allow these cookies you will still see basic advertising on your browser that is generic and not based on your interests
# Cookies Details‎
# Performance Cookies
#
# [x] Performance Cookies
#
# These cookies allow us to count visits and traffic sources so we can measure and improve the performance of our site. They help us to know which pages are the most and least popular and see how visitors move around the site. All information these cookies collect is aggregated and therefore anonymous. If you do not allow these cookies we will not know when you have visited our site, and will not be able to monitor its performance.
# Cookies Details‎
# Cookie List
# Clear
#
# [x] checkbox label label
#
# Apply Cancel
# Consent Leg.Interest
#
#
# [x] checkbox label label
#
#
# [x] checkbox label label
#
#
# [x] checkbox label label
#
#
# Reject All Confirm My Choices

# %%
extract2 = tavily_client.extract(urls=["https://www.coindesk.com/search"], extract_depth='advanced')
extract2

# %% [markdown]
# ### Função que coleta as notícias (modo news):

# %%
import asyncio
from tavily import AsyncTavilyClient

tavily_client = AsyncTavilyClient()

async def fetch_and_extract():
    # Define the queries with search_depth and max_results inside the query dictionary
    queries = [
        {"query": "Bitcoin", "topic": "news", "search_depth": "advanced", "time_range": "day","max_results": 2},
        {"query": "Bitcoin price analysis", "topic": "news", "search_depth": "advanced", "time_range": "day", "max_results": 2},
        {"query": "Bitcoin Fear & Greed Index", "topic": "news", "search_depth": "advanced", "time_range": "week", "max_results": 2},
    ]

    # Perform the search queries concurrently, passing the entire query dictionary
    responses = await asyncio.gather(*[tavily_client.search(**q) for q in queries])

    # Retorna o resultado:
    return responses

# Função que formata as respostas em um novo dicionario estruturado:
def format_search_news(responses):

    search_response = responses
    list_dict_news = []

    for response in search_response:
        for item in response.get('results', []):
            list_dict_news.append({
                'titulo': item.get('title'),
                'url': item.get('url'),
                'data': item.get('published_date'),
                'conteudo': item.get('content'),
                'score': item.get('score'),
            })
    return list_dict_news

# %%
resultado = await fetch_and_extract()
print(resultado)

# %%
result_formatado = format_search_news(resultado)
result_formatado

# %% [markdown]
# ### Função que coleta e extrai as notícias (modo finance e extract):

# %%
import asyncio
from tavily import AsyncTavilyClient

tavily_client = AsyncTavilyClient()

async def fetch_and_extract():
    # Define the queries with search_depth and max_results inside the query dictionary
    queries = [
        {"query": "Bitcoin", "topic": "finance", "search_depth": "advanced", "time_range": "week", "max_results": 3},
    ]

    # Perform the search queries concurrently, passing the entire query dictionary
    responses = await asyncio.gather(*[tavily_client.search(**q) for q in queries])

    return responses

# Função que recebe a lista de dicionários formatado (com todas as repostas) filtra os scores maiores que 0.5, extrai o conteudo(com tavily_client.extract) e formata o resultado em uma nova lista de dicionarios:
async def filter_and_extract(responses):

    noticias_filtradas = []
    for response in responses:
        for result in response.get('results', []):
            if result.get('score', 0) > 0.5:
                noticias_filtradas.append(result)

    # Para cada uma das notícias filtradas, pegar a url e extrair o conteúdo usando tavily_client.extract, em seguida adicionar a chave 'raw_content' ao dicionário de notícias filtradas... 




# Função que formata as respostas em um novo dicionario estruturado:
def format_search_finance(responses):

    search_response = responses
    list_dict_news = []

    for response in search_response:
        for item in response.get('results', []):
            list_dict_news.append({
                'titulo': item.get('title'),
                'url': item.get('url'),
                'conteudo': item.get('raw_content'),
                'score': item.get('score'),
            })
    return list_dict_news

# %%
# Função de formatação
def formatar_resposta(resposta):
    linhas = []
    for idx, item in enumerate(resposta, start=1):
        title = item.get('title', '').strip()
        url = item.get('url', '').strip()
        date = item.get('published_date', '').strip()
        content = item.get('content', '').strip()

        linhas.append(f"Notícia {idx}:")
        linhas.append(f"Título: {title}")
        linhas.append(f"URL: {url}")
        linhas.append(f"Data de publicação: {date}")
        linhas.append(f"Conteúdo: {content}")
        linhas.append("")  # linha em branco entre notícias

    return "\n".join(linhas)

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# ### Função de coleta de noticias da Openai

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

# Obter a data atual
today = datetime.now().strftime("%m/%d/%Y")


instruction = """
You are a professional news assistant about Bitcoin.
You are expert in analyzing news and information from the internet to extract the most relevant and up-to-date information.
"""

input_messages = [
    {
        "role": "user", 
        "content": f"""Give me recent Bitcoin news (05/16/2025) based on the following aspects:
        1. Bitcoin price {today}
        2. Bitcoin price action “support” and “resistance” daily analysis {today}.
        3. Bitcoin market sentiment “Crypto Fear and Greed Index” {today} .
        4. Impact of macroeconomic events on Bitcoin price {today}.
        5. Bitcoin buy and sell signals moving average crossover RSI MACD forecast {today}.
        """
    },

]

# %%
from openai import OpenAI
client = OpenAI()
from datetime import datetime
from dateutil.relativedelta import relativedelta


def news_openai():

    today = datetime.now().strftime("%m/%d/%Y")
    this_week = (datetime.now() - relativedelta(weeks=1)).strftime("%m/%d/%Y")
    instruction = """
    You are a professional news assistant about Bitcoin.
    You are expert in analyzing news and information from the internet to extract the most relevant and up-to-date information.
    """

    input_messages = [
        {
            "role": "user", 
            "content": f"""Give me recent Bitcoin news (05/16/2025) based on the following aspects:
            1. Bitcoin price analysis {today}
            2. Bitcoin market sentiment “Crypto Fear and Greed Index” {this_week} - {today}.
            3. Important events that impact Bitcoin price this week {this_week} - {today}.
            4. Macroeconomic outlook May 2025.
            5. Macroeconomic events impact on Bitcoin price {today}.
            6. Bitcoin buy and sell signals {today}.
            """
        },
    ]

    # Create a response using the OpenAI client
    response = client.responses.create(
        model="gpt-4.1",
        instructions=instruction,
        tools=[{
            "type": "web_search_preview",
            "search_context_size": "medium",
        }],
        input=input_messages,
        tool_choice={"type": "web_search_preview"},
    )

    return response

# %%
print(response.model_dump_json(indent=2))

# %%
print(response.output_text)

# %%
def mostra_urls_usadas(response):
    print("URLs citadas:")
    for block in response.output:
        if not hasattr(block, 'content'):
            continue
        for content_item in block.content:
            if not hasattr(content_item, 'annotations'):
                continue
            for annotation in content_item.annotations:
                if annotation.type == "url_citation":
                    print(f"- {annotation.title}: {annotation.url}")

# %% [markdown]
# ### Teste taapio:

# %%
# Import the requests library 
import requests 
import os
import json

# Define indicator
indicator = "sma"
# Define endpoint 
endpoint = f"https://api.taapi.io/{indicator}"
# Define a parameters dict for the parameters to be sent to the API 
parameters = {
    'secret': os.getenv('TAAPI_IO_API_KEY'),
    'exchange': 'binance',
    'symbol': 'BTC/USDT',
    'interval': '1d',
    'period': '20',
    }  
# Send get request and save the response as response object 
response = requests.get(url = endpoint, params = parameters)
# Extract data in json format 
result = response.json() 
# Print result
print(result)

# %%
# Define indicator
indicator = "sma"
# Define endpoint 
endpoint = f"https://api.taapi.io/{indicator}"
# Define a parameters dict for the parameters to be sent to the API 
parameters = {
    'secret': os.getenv('TAAPI_IO_API_KEY'),
    'exchange': 'binance',
    'symbol': 'BTC/USDT',
    'interval': '1h',
    'period': '20',
    }  
# Send get request and save the response as response object 
response = requests.get(url = endpoint, params = parameters)
# Extract data in json format 
result = response.json() 
# Print result
print(result)

# %%
# Import the requests library 
import requests 
import os
import json

url = "https://api.taapi.io/bulk"
  
# Define a parameters dict for the parameters to be sent to the API 
payload = {
	"secret": os.getenv('TAAPI_IO_API_KEY'),
	"construct": [
		{
			"exchange": "binance",
			"symbol": "BTC/USDT",
			"interval": "1h",
			"indicators": [
				{
					"indicator": "sma",
					"period": 50
				}
			]
		},
		{
			"exchange": "binance",
			"symbol": "BTC/USDT",
			"interval": "4h",
			"indicators": [
				{
					"indicator": "sma",
					"period": 50
				}
			]
		},
		{
			"exchange": "binance",
			"symbol": "BTC/USDT",
			"interval": "1d",
			"indicators": [
				{
					"indicator": "sma",
					"period": 50
				}
			]
		},
        {
			"exchange": "binance",
			"symbol": "BTC/USDT",
			"interval": "1d",
			"indicators": [
				{
					"indicator": "rsi",
					"period": 14
				}
			]
		},
        {
			"exchange": "binance",
			"symbol": "BTC/USDT",
			"interval": "1d",
			"indicators": [
				{
					"indicator": "bbands",
					"period": 20
				}
			]
		}
	]
}
  
headers = {"Content-Type": "application/json"}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)

# %%
def indicadores_tecnicos_taapi_io(indicador: str, intervalo: str, periodo: int):
    # Define endpoint 
    endpoint = f"https://api.taapi.io/{indicador}"
    # Define a parameters dict for the parameters to be sent to the API 
    parameters = {
        'secret': os.getenv('TAAPI_IO_API_KEY'),
        'exchange': 'binance',
        'symbol': 'BTC/USDT',
        'interval': intervalo,
        'period': periodo,
        }  
    # Send get request and save the response as response object 
    response = requests.get(url = endpoint, params = parameters)
    # Extract data in json format 
    result = response.json() 
    # Print result
    print(result)

# %%
import time
sma_periods = [20, 50, 100, 200]
for period in sma_periods:
    sma = indicadores_tecnicos_taapi_io("sma", "1h", period)
    time.sleep(15)

# %% [markdown]
# ### Coindesk api news: ✅

# %%
import requests 

response = requests.get('https://data-api.coindesk.com/news/v1/article/list',
    params={"lang":"EN", "limit":10, "categories":"BTC,MARKET", "api_key":"fd8a81d53ce5de8a8cb711d0c99896fe94879d0f4870da333592d712241fb30d"},
    headers={"Content-type":"application/json; charset=UTF-8"}
)

json_response = response.json()

# %%
json_response
# Out:
# {'Data': [{'TYPE': '121',
#    'ID': 45263761,
#    'GUID': 'https://ambcrypto.com/?p=496298',
#    'PUBLISHED_ON': 1748559614,
#    'IMAGE_URL': 'https://images.cryptocompare.com/news/default/ambcrypto.png',
#    'TITLE': 'HYPE’s fate tied to Bitcoin? What whale positions on Hyperliquid say',
#    'SUBTITLE': None,
#    'AUTHORS': 'Olayiwola Dolapo',
#    'URL': 'https://ambcrypto.com/hypes-fate-tied-to-bitcoin-what-whale-positions-on-hyperliquid-say/',
#    'SOURCE_ID': 32,
#    'BODY': 'Could this liquidity flood pull HYPE back into rally mode?',
#    'KEYWORDS': 'Altcoin|News|News 1|Social|Trading View',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEUTRAL',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748559623,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 32,
#     'SOURCE_KEY': 'ambcrypto',
#     'NAME': 'AMB Crypto',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/ambcrypto.png',
#     'URL': 'https://ambcrypto.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558383,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1674467937},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 5,
#      'NAME': 'ALTCOIN',
#      'CATEGORY': 'ALTCOIN'},
#     {'TYPE': '122', 'ID': 14, 'NAME': 'BTC', 'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'}]},
#   {'TYPE': '121',
#    'ID': 45263878,
#    'GUID': 'https://www.cryptopolitan.com/?p=737264',
#    'PUBLISHED_ON': 1748559600,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/43/45263878.jpeg',
#    'TITLE': 'AVAX May Hit $35 Soon, But Ruvi AI (RUVI) Could Deliver 13,233% Returns for Early Investors',
#    'SUBTITLE': None,
#    'AUTHORS': 'Cryptopolitan Media',
#    'URL': 'https://www.cryptopolitan.com/avax-may-hit-35-soon-but-ruvi-ai-ruvi-could-deliver-13233-returns-for-early-investors/',
#    'SOURCE_ID': 43,
#    'BODY': 'While Avalanche (AVAX) is going to $35, it’s Ruvi AI (RUVI) that’s got the crypto world buzzing with 13,233% returns. With investors looking for exponential growth, Ruvi AI is the game-changer in the blockchain and AI space for those ready to grab the next big opportunity. Avalanche (AVAX): $35 Avalanche has been touted as one of the most scalable and efficient blockchain platforms out there. 4,500 transactions per second and low fees has made it a hub for dApps and DeFi projects. AVAX to $35 is backed by its growing adoption and strong performance in the market. But as a more mature project, Avalanche’s growth potential is now relatively small compared to emerging projects with groundbreaking innovation and early stage returns. Ruvi AI: A Disruptor at the intersection of AI and Blockchain Ruvi AI is boldly going where no one has gone before by combining blockchain with AI. This platform enables decentralized content creation, allowing users to generate AI driven text, images, videos and audio assets for entertainment, marketing and business automation. What sets Ruvi AI apart is its utility. Unlike Avalanche’s large dApp ecosystem which often focuses on niche applications, Ruvi AI is solving immediate high demand business needs. The $RUVI token is at the heart of its offerings, a gateway to premium AI features, governance and staking rewards. With its practical approach to blockchain innovation, Ruvi AI is leading the charge for real world change, making it an attractive opportunity for investors. A Hot Presale Defining 2025 Ruvi AI’s presale has already made waves in the investor community. Phase 1 launched at $0.010 per token and sold out in 2 weeks. Phase 2 is now live at $0.015 and early backers have already seen 50% returns.The project has 1,400+ holders and is gaining momentum with its achievements. It has listed its token and partnered with a major exchange, Ruvi AI is committed to growth and long term success. More announcements to come and the project will only get stronger and more investor confidence. 13,233% Returns Why are analysts projecting such huge returns for Ruvi AI? It’s all about the technology, community and partnerships. Technology : By combining AI with blockchain, Ruvi AI provides solutions that resonate across industries, adoption beyond early adopters. Expanding Investor Base : 1,400+ holders is strong market confidence in Ruvi AI. Strategic Partnerships and Visibility : Exchanges and listings will increase Ruvi AI’s visibility and market presence. Exponential Growth Potential : Unlike Avalanche, Ruvi AI is in its infancy, early backers have huge upside. At $0.015 per token, the project is still accessible to a broader range of investors who will benefit from its growth. Given its disruption potential, Ruvi AI is an opportunity to change your life. Investment Scenarios with Ruvi AI Ruvi AI has different investment tiers through its VIP presale model. Here’s how the returns look like for the three VIP tiers based on its listing price of $0.07 and the predicted $1 price post listing. VIP 2 Threshold : 50,000 $RUVI ($750 at $0.015/token) Bonus : 40% (+20,000 tokens) Total Tokens : 70,000 Value at Listing Price ($0.07) : $4,900 Value at Predicted Price ($1) : $70,000 VIP 3 Threshold : 100,000 $RUVI ($1,500 at $0.015/token) Bonus : 60% (+60,000 tokens) Total Tokens : 160,000 Value at Listing Price ($0.07) : $11,200 Value at Predicted Price ($1) : $160,000 VIP 5 Threshold : 500,000 $RUVI ($7,500 at $0.015/token) Bonus : 100% (+500,000 tokens) Total Tokens : 1,000,000 Value at Listing Price ($0.07) : $70,000 Value at Predicted Price ($1) : $1,000,000 These numbers are mind blowing and Ruvi AI is an opportunity like no other for those who want to get in on the presale. Now or Never AVAX is great and all but Ruvi AI offers early stage growth and disruption. For those who want exponential returns, Ruvi AI’s presale is the moment to get in on a project that will change the future of decentralized i ...
#    'KEYWORDS': 'Press Release',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748559846,
#    'UPDATED_ON': 1748559846,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 43,
#     'SOURCE_KEY': 'cryptopolitan',
#     'NAME': 'Cryptopolitan',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cryptopolitan.png',
#     'URL': 'https://www.cryptopolitan.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558399,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1681205909},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 8,
#      'NAME': 'AVAX',
#      'CATEGORY': 'AVAX'},
#     {'TYPE': '122', 'ID': 13, 'NAME': 'BLOCKCHAIN', 'CATEGORY': 'BLOCKCHAIN'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'}]},
#   {'TYPE': '121',
#    'ID': 45263705,
#    'GUID': 'https://en.coinotag.com/cantor-fitzgerald-introduces-bitcoin-fund-with-gold-backed-downside-protection-for-risk-averse-investors/',
#    'PUBLISHED_ON': 1748559440,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/45263705.jpeg',
#    'TITLE': 'Cantor Fitzgerald Introduces Bitcoin Fund with Gold-Backed Downside Protection for Risk-Averse Investors',
#    'SUBTITLE': None,
#    'AUTHORS': 'Marisol Navaro',
#    'URL': 'https://en.coinotag.com/cantor-fitzgerald-introduces-bitcoin-fund-with-gold-backed-downside-protection-for-risk-averse-investors/',
#    'SOURCE_ID': 77,
#    'BODY': 'Cantor Fitzgerald is set to launch a revolutionary Bitcoin fund that offers downside protection by linking its performance to gold prices. This novel approach aims to alleviate investors’ concerns regarding',
#    'KEYWORDS': 'News|BTC',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748559509,
#    'UPDATED_ON': 1748559510,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558403,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 26, 'NAME': 'FIAT', 'CATEGORY': 'FIAT'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'}]},
#   {'TYPE': '121',
#    'ID': 45263604,
#    'GUID': 'https://decrypt.co/?p=322870',
#    'PUBLISHED_ON': 1748559188,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/44/45263604.jpeg',
#    'TITLE': 'Cantor to Unveil a New Bitcoin Product—With a Little Gold Insurance',
#    'SUBTITLE': None,
#    'AUTHORS': 'Mathew Di Salvo',
#    'URL': 'https://decrypt.co/322870/cantor-debut-bitcoin-gold-fund-aimed-investors-scared-crypto',
#    'SOURCE_ID': 44,
#    'BODY': "The firm will protect investors against Bitcoin's volatility with gold.",
#    'KEYWORDS': 'Markets',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748559304,
#    'UPDATED_ON': 1748559304,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 44,
#     'SOURCE_KEY': 'decrypt',
#     'NAME': 'Decrypt',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/decrypt.png',
#     'URL': 'https://decrypt.co/feed',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': 1521331200,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 57,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558371,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1711620560},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 26, 'NAME': 'FIAT', 'CATEGORY': 'FIAT'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'}]},
#   {'TYPE': '121',
#    'ID': 45263225,
#    'GUID': 'https://cointelegraph.com/news/solana-price-drops-as-memecoins-fade-and-sol-unlock-concerns-emerge',
#    'PUBLISHED_ON': 1748558355,
#    'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cointelegraph.png',
#    'TITLE': 'Solana price drops as memecoins fade and SOL unlock concerns emerge',
#    'SUBTITLE': None,
#    'AUTHORS': 'Cointelegraph by Marcel Pechman',
#    'URL': 'https://cointelegraph.com/news/solana-price-drops-as-memecoins-fade-and-sol-unlock-concerns-emerge?utm_source=rss_feed&utm_medium=rss&utm_campaign=rss_partner_inbound',
#    'SOURCE_ID': 16,
#    'BODY': 'Trader’s interest in Solana is strong, but declining memecoin prices and SOL token unlocks have put a cap on the altcoin’s rally.',
#    'KEYWORDS': '',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748558568,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 16,
#     'SOURCE_KEY': 'cointelegraph',
#     'NAME': 'CoinTelegraph',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cointelegraph.png',
#     'URL': 'https://cointelegraph.com/rss',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': 1382227200,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 66,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558360,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1711620813},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 5,
#      'NAME': 'ALTCOIN',
#      'CATEGORY': 'ALTCOIN'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 46, 'NAME': 'SOL', 'CATEGORY': 'SOL'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'}]},
#   {'TYPE': '121',
#    'ID': 45263046,
#    'GUID': 'https://en.coinotag.com/pi-network-faces-increased-selling-pressure-as-bearish-indicators-suggest-potential-downtrend-continuation/',
#    'PUBLISHED_ON': 1748558086,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/45263046.jpeg',
#    'TITLE': 'Pi Network Faces Increased Selling Pressure as Bearish Indicators Suggest Potential Downtrend Continuation',
#    'SUBTITLE': None,
#    'AUTHORS': 'Marisol Navaro',
#    'URL': 'https://en.coinotag.com/pi-network-faces-increased-selling-pressure-as-bearish-indicators-suggest-potential-downtrend-continuation/',
#    'SOURCE_ID': 77,
#    'BODY': 'Pi Network (PI) has experienced a significant decline of nearly 15% over the past week, with technical indicators confirming a bearish trend fueled by increasing selling pressure. As the Chaikin',
#    'KEYWORDS': 'Analysis|News|FLOW',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748558167,
#    'UPDATED_ON': 1748558167,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558403,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 37,
#      'NAME': 'MARKET',
#      'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'},
#     {'TYPE': '122', 'ID': 125, 'NAME': 'FLOW', 'CATEGORY': 'FLOW'}]},
#   {'TYPE': '121',
#    'ID': 45262880,
#    'GUID': 'https://decrypt.co/?p=322869',
#    'PUBLISHED_ON': 1748557750,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/44/45262880.jpeg',
#    'TITLE': 'Congress Rolls Out New Crypto Market Structure Bill—What Does It Actually Do?',
#    'SUBTITLE': None,
#    'AUTHORS': 'Sander Lutz',
#    'URL': 'https://decrypt.co/322869/congress-new-crypto-market-structure-bill',
#    'SOURCE_ID': 44,
#    'BODY': 'A House bill formally introduced Thursday would end SEC oversight over the crypto industry. It will be debated by lawmakers in the coming weeks.',
#    'KEYWORDS': '||Law and Order',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEUTRAL',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748557848,
#    'UPDATED_ON': 1748557848,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 44,
#     'SOURCE_KEY': 'decrypt',
#     'NAME': 'Decrypt',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/decrypt.png',
#     'URL': 'https://decrypt.co/feed',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': 1521331200,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 57,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558371,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1711620560},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 37,
#      'NAME': 'MARKET',
#      'CATEGORY': 'MARKET'},
#     {'TYPE': '122',
#      'ID': 41,
#      'NAME': 'REGULATION',
#      'CATEGORY': 'REGULATION'}]},
#   {'TYPE': '121',
#    'ID': 45262801,
#    'GUID': 'https://en.coinotag.com/potential-securities-implications-for-bitcoin-transactions-highlighted-by-secs-hester-peirce-at-bitcoin-2025-conference/',
#    'PUBLISHED_ON': 1748557664,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#    'TITLE': 'Potential Securities Implications for Bitcoin Transactions Highlighted by SEC’s Hester Peirce at Bitcoin 2025 Conference',
#    'SUBTITLE': None,
#    'AUTHORS': 'Jocelyn Blake',
#    'URL': 'https://en.coinotag.com/potential-securities-implications-for-bitcoin-transactions-highlighted-by-secs-hester-peirce-at-bitcoin-2025-conference/',
#    'SOURCE_ID': 77,
#    'BODY': 'Hester Peirce, head of the SEC’s crypto task force, recently emphasized the importance of transaction context in determining if digital asset transfer qualifies as a securities transaction. This perspective highlights',
#    'KEYWORDS': 'News',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEUTRAL',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748557669,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558403,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122',
#      'ID': 41,
#      'NAME': 'REGULATION',
#      'CATEGORY': 'REGULATION'}]},
#   {'TYPE': '121',
#    'ID': 45262752,
#    'GUID': 'https://www.cryptopolitan.com/?p=737499',
#    'PUBLISHED_ON': 1748557246,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/43/45262752.jpeg',
#    'TITLE': 'Ethereum researcher raise concerns about Bitcoin potential security problem due to its low fees',
#    'SUBTITLE': None,
#    'AUTHORS': 'Cryptopolitan News',
#    'URL': 'https://www.cryptopolitan.com/ethereum-foundation-developer-warns-bitcoin-security-is-a-disaster-waiting-to-happen/',
#    'SOURCE_ID': 43,
#    'BODY': 'Ethereum Foundation researcher Justin Drake has warned about the security of the Bitcoin Network. Drake shared his view on X, noting that the Bitcoin Proof of Work (PoW) consensus mechanism is a ticking time bomb. The blockchain security expert, one of the masterminds behind the Merge, i.e., Ethereum transition from PoW to Proof of Stake (PoS), identified Bitcoin’s low fees as the major risk to its security. According to Drake , Bitcoin fees have fallen for 13 years, with miners generating less than 10 BTC in daily fees. He believes that this low fee represents a disincentive for most miners who are the ones securing the network and could eventually affect the network, a contagion risk for the whole crypto industry. He said: “Bitcoin’s security model is broken. If Bitcoin gets taken over, the fallout could take the entire crypto ecosystem. The systemic risks can’t be ignored.” The researcher noted that Bitcoin fees have constantly declined for over a decade despite halving and reducing the issuance rate. In fact, the fees are falling faster than the issuance rate on the network, with a 30-day moving average (MA) of Bitcoin transaction fees currently at 6.5 BTC per day. Bitcoin Transaction Fees.(Source: X/Drake) This meant that fees only account for around 1% of miners’ revenue over the years, and Bitcoin miners could see a 100% decline in their revenue once the complete 21 million BTC have been mined. However, Category Labs researcher Kushal Babel disagreed with the argument, noting that denominating fees in BTC to say it is at an all-time low is wrong. According to him, the whole argument might change if BTC fees are denominated in US Dollars. Babel argued that Drake’s opinion that the ratio of BTC market cap to the amount securing it makes the network vulnerable to a 51% attack is a weak argument at best, and the focus should be on the cost of an attack in dollars. Higher prices may not save the Bitcoin network from attack Meanwhile, Drake added that a rise in Bitcoin prices could be inimical to network security because it would make it harder to sustain the BTC-denominated fees. In order to explain this, he described a scenario where Bitcoin price increases but fees stay unchanged, noting that fees at the time will only cover around 10% of the security cost for the network. He said: “Let’s be optimistic and say BTC rises to $1M, and today’s 6.5 BTC/day in fees is maintained: $6.5M/day in fees, 10% of today’s security budget. Bitcoin would be a $20T asset secured by 1/10th of today’s hashing infrastructure.” Thus, he believes that the cost of attacking the Bitcoin network will not increase even as the price of BTC increases. This could make it possible for a 51% attack on the Bitcoin network to cost as little as $20 billion, even if the network has a market cap of $200 trillion tokens. Drake further debunked the presumption that Bitcoin fees will increase, noting that this has not happened in the last 13 years. He added that all previous attempts to boost Bitcoin fees by increasing its utility as a transaction layer have failed to achieve sustainable long-term gains, with projects such as Ordinals, Liquid, Omni, Babylon, and others only creating short-term spikes. Potential solutions to Bitcoin’s fragile security With Drake highlighting Bitcoin’s risks, he proposed two solutions that could work for the network if fees do not increase. According to him, the solution is for Bitcoin to expand the total supply beyond the 21 million cap or for the network to switch to Proof of Stake. Unsurprisingly, he acknowledged that these two proposed solutions are unlikely to be implemented, given that they are completely against the conventional ethos of the Bitcoin community. However, he insisted that creating a Bitcoin Virtual Machine or Proof of Authority, where the major mining pools will secure the network, is unlikely to work. Still, he called on anyone who could explain how the PoA will function to do so. Interestingly, o ...
#    'KEYWORDS': 'News|Bitcoin|BTC',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748557567,
#    'UPDATED_ON': 1748559845,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 43,
#     'SOURCE_KEY': 'cryptopolitan',
#     'NAME': 'Cryptopolitan',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cryptopolitan.png',
#     'URL': 'https://www.cryptopolitan.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558399,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1681205909},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 24, 'NAME': 'ETH', 'CATEGORY': 'ETH'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 39, 'NAME': 'MINING', 'CATEGORY': 'MINING'}]},
#   {'TYPE': '121',
#    'ID': 45263528,
#    'GUID': '65469750-590a-4d9f-9477-a2a09050eeb1',
#    'PUBLISHED_ON': 1748557121,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/5/45263528.jpeg',
#    'TITLE': 'Suspects in Manhattan Crypto Kidnapping, Torture Case Plead Not Guilty as Investigation Widens',
#    'SUBTITLE': 'William Duplessie, 33, and John Woeltz, 37, have been accused of holding a 28-year-old Italian man hostage for over two weeks and torturing him in an attempt to steal his bitcoin.',
#    'AUTHORS': 'Nikhilesh De,Cheyenne Ligon',
#    'URL': 'https://www.coindesk.com/policy/2025/05/29/suspects-in-manhattan-crypto-kidnapping-torture-case-plead-not-guilty-as-investigation-widens',
#    'SOURCE_ID': 5,
#    'BODY': 'Two men suspected in the kidnapping and torture of a 28-year-old Italian cryptocurrency investor have pleaded not guilty, while the investigation into their case appears to have expanded to the New York Police Department itself. New York police had previously arrested William Duplessie , 33, and John Woeltz , 37, on the charges, as well as a third individual, Beatrice Folchi, 24, though her prosecution is being deferred. The victim has not been publicly named. The men are accused of kidnapping the victim and holding him hostage in a luxury townhouse in Manhattan’s ritzy SoHo neighborhood for more than two weeks. During that time, New York City police say the trio tortured the man, forcing him to take drugs, dangling him from a ledge, urinating on him and electrocuting him in an effort to force him to hand over the private keys to his bitcoin. The alleged perpetrators are accused of making t-shirts of the victim with a crack pipe in his mouth and taking Polaroids of the victim with a gun to his head. The victim escaped last Friday, grabbing his laptop and getting out of the townhouse and then seeking help from a traffic officer. Duplessie entered a not-guilty plea to five different charges, including kidnapping with an intent to collect a ransom, kidnapping and causing a physical injury, criminal possession of a loaded firearm, assault with an intent to cause a physical injury with a weapon and unlawful imprisonment, according to the court docket. Woeltz was charged with kidnapping, assault, unlawful imprisonment and criminal possession of a firearm, and he also pleaded not guilty, according to his court docket. Two NYPD officers, including a detective assigned to Mayor Eric Adams\' protection detail, worked for both Duplessie and Woeltz in their off-duty hours and have now been placed on modified duty, Bloomberg reported Thursday. A source familiar told CoinDesk that the two officers are not believed to be part of the kidnapping, but rather did security work for the defendants. They may have driven the victim from an airport to the townhouse, but have not been tied to his torture, the source said. A spokesperson for the NYPD said the matter was "under internal review." A spokesperson for the mayor\'s office said in a statement that, "Every city employee is expected to follow the law, including our officers, both on and off duty. We are disturbed by these allegations, and as soon as it came to our attention, the officers were placed on modified duty. The investigation is ongoing." UPDATE (May 29, 2025, 22:27 UTC): Adds additional detail.',
#    'KEYWORDS': 'Policy|NYPD|News',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1748559186,
#    'UPDATED_ON': 1748559187,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 5,
#     'SOURCE_KEY': 'coindesk',
#     'NAME': 'CoinDesk',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/5/default.png',
#     'URL': 'https://www.coindesk.com/arc/outboundfeeds/rss/?outputType=xml',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': 1367884800,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 71,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1748558359,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1744296800},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122',
#      'ID': 41,
#      'NAME': 'REGULATION',
#      'CATEGORY': 'REGULATION'}]}],
#  'Err': {}}

# %%
json_response.keys()
# Out:
# dict_keys(['Data', 'Err'])

# %%
noticias_coindesk = []
for item in json_response['Data']:
    noticias_coindesk.append({
        'titulo': item.get('TITLE'),
        'url': item.get('URL'),
        'palavras_chave': item.get('KEYWORDS'),
        'sentimento': item.get('SENTIMENT'),
        'data': item.get('PUBLISHED_ON'),
        'conteudo': item.get('BODY'),
    })

# %%
from datetime import datetime
import pytz

def parse_iso8601(date_str):
    """
    Converte string ISO 8601 (UTC) para datetime c/ tzinfo UTC.
    """
    dt = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")
    return dt.replace(tzinfo=pytz.UTC)


def format_datetime(dt, fmt="%d/%m/%Y %H:%M:%S %Z"):  
    """
    Formata datetime em string legível.
    """
    return dt.strftime(fmt)

def extract_unix_api_items(api_response, local_tz=None, output_fmt="%d/%m/%Y %H:%M:%S %Z"):
    """
    Extrai campos (TITLE, URL, KEYWORDS, SENTIMENT, PUBLISHED_ON, BODY) da segunda API.
    Converte PUBLISHED_ON (timestamp UTC em segundos) para formato legível.
    """
    extracted = []
    for entry in api_response['Data']:
        raw_ts = entry.get('PUBLISHED_ON')
        # Converte timestamp UTC em seconds para datetime
        dt = datetime.fromtimestamp(raw_ts, tz=pytz.UTC) if raw_ts else None
        if dt and local_tz:
            dt = dt.astimezone(local_tz)
        formatted = format_datetime(dt, output_fmt) if dt else None

        extracted.append({
            'TITLE': entry.get('TITLE'),
            'URL': entry.get('URL'),
            'KEYWORDS': entry.get('KEYWORDS'),
            'SENTIMENT': entry.get('SENTIMENT'),
            'PUBLISHED_ON': formatted,
            'BODY': entry.get('BODY')
        })
    return extracted

# %%
sp_tz = pytz.timezone('America/Sao_Paulo')
result = extract_unix_api_items(json_response, local_tz=sp_tz)

# %%
result
# Out:
# [{'TITLE': 'HYPE’s fate tied to Bitcoin? What whale positions on Hyperliquid say',
#   'URL': 'https://ambcrypto.com/hypes-fate-tied-to-bitcoin-what-whale-positions-on-hyperliquid-say/',
#   'KEYWORDS': 'Altcoin|News|News 1|Social|Trading View',
#   'SENTIMENT': 'NEUTRAL',
#   'PUBLISHED_ON': '29/05/2025 20:00:14 -03',
#   'BODY': 'Could this liquidity flood pull HYPE back into rally mode?'},
#  {'TITLE': 'AVAX May Hit $35 Soon, But Ruvi AI (RUVI) Could Deliver 13,233% Returns for Early Investors',
#   'URL': 'https://www.cryptopolitan.com/avax-may-hit-35-soon-but-ruvi-ai-ruvi-could-deliver-13233-returns-for-early-investors/',
#   'KEYWORDS': 'Press Release',
#   'SENTIMENT': 'POSITIVE',
#   'PUBLISHED_ON': '29/05/2025 20:00:00 -03',
#   'BODY': 'While Avalanche (AVAX) is going to $35, it’s Ruvi AI (RUVI) that’s got the crypto world buzzing with 13,233% returns. With investors looking for exponential growth, Ruvi AI is the game-changer in the blockchain and AI space for those ready to grab the next big opportunity. Avalanche (AVAX): $35 Avalanche has been touted as one of the most scalable and efficient blockchain platforms out there. 4,500 transactions per second and low fees has made it a hub for dApps and DeFi projects. AVAX to $35 is backed by its growing adoption and strong performance in the market. But as a more mature project, Avalanche’s growth potential is now relatively small compared to emerging projects with groundbreaking innovation and early stage returns. Ruvi AI: A Disruptor at the intersection of AI and Blockchain Ruvi AI is boldly going where no one has gone before by combining blockchain with AI. This platform enables decentralized content creation, allowing users to generate AI driven text, images, videos and audio assets for entertainment, marketing and business automation. What sets Ruvi AI apart is its utility. Unlike Avalanche’s large dApp ecosystem which often focuses on niche applications, Ruvi AI is solving immediate high demand business needs. The $RUVI token is at the heart of its offerings, a gateway to premium AI features, governance and staking rewards. With its practical approach to blockchain innovation, Ruvi AI is leading the charge for real world change, making it an attractive opportunity for investors. A Hot Presale Defining 2025 Ruvi AI’s presale has already made waves in the investor community. Phase 1 launched at $0.010 per token and sold out in 2 weeks. Phase 2 is now live at $0.015 and early backers have already seen 50% returns.The project has 1,400+ holders and is gaining momentum with its achievements. It has listed its token and partnered with a major exchange, Ruvi AI is committed to growth and long term success. More announcements to come and the project will only get stronger and more investor confidence. 13,233% Returns Why are analysts projecting such huge returns for Ruvi AI? It’s all about the technology, community and partnerships. Technology : By combining AI with blockchain, Ruvi AI provides solutions that resonate across industries, adoption beyond early adopters. Expanding Investor Base : 1,400+ holders is strong market confidence in Ruvi AI. Strategic Partnerships and Visibility : Exchanges and listings will increase Ruvi AI’s visibility and market presence. Exponential Growth Potential : Unlike Avalanche, Ruvi AI is in its infancy, early backers have huge upside. At $0.015 per token, the project is still accessible to a broader range of investors who will benefit from its growth. Given its disruption potential, Ruvi AI is an opportunity to change your life. Investment Scenarios with Ruvi AI Ruvi AI has different investment tiers through its VIP presale model. Here’s how the returns look like for the three VIP tiers based on its listing price of $0.07 and the predicted $1 price post listing. VIP 2 Threshold : 50,000 $RUVI ($750 at $0.015/token) Bonus : 40% (+20,000 tokens) Total Tokens : 70,000 Value at Listing Price ($0.07) : $4,900 Value at Predicted Price ($1) : $70,000 VIP 3 Threshold : 100,000 $RUVI ($1,500 at $0.015/token) Bonus : 60% (+60,000 tokens) Total Tokens : 160,000 Value at Listing Price ($0.07) : $11,200 Value at Predicted Price ($1) : $160,000 VIP 5 Threshold : 500,000 $RUVI ($7,500 at $0.015/token) Bonus : 100% (+500,000 tokens) Total Tokens : 1,000,000 Value at Listing Price ($0.07) : $70,000 Value at Predicted Price ($1) : $1,000,000 These numbers are mind blowing and Ruvi AI is an opportunity like no other for those who want to get in on the presale. Now or Never AVAX is great and all but Ruvi AI offers early stage growth and disruption. For those who want exponential returns, Ruvi AI’s presale is the moment to get in on a project that will change the future of decentralized in ...
#  {'TITLE': 'Cantor Fitzgerald Introduces Bitcoin Fund with Gold-Backed Downside Protection for Risk-Averse Investors',
#   'URL': 'https://en.coinotag.com/cantor-fitzgerald-introduces-bitcoin-fund-with-gold-backed-downside-protection-for-risk-averse-investors/',
#   'KEYWORDS': 'News|BTC',
#   'SENTIMENT': 'POSITIVE',
#   'PUBLISHED_ON': '29/05/2025 19:57:20 -03',
#   'BODY': 'Cantor Fitzgerald is set to launch a revolutionary Bitcoin fund that offers downside protection by linking its performance to gold prices. This novel approach aims to alleviate investors’ concerns regarding'},
#  {'TITLE': 'Cantor to Unveil a New Bitcoin Product—With a Little Gold Insurance',
#   'URL': 'https://decrypt.co/322870/cantor-debut-bitcoin-gold-fund-aimed-investors-scared-crypto',
#   'KEYWORDS': 'Markets',
#   'SENTIMENT': 'POSITIVE',
#   'PUBLISHED_ON': '29/05/2025 19:53:08 -03',
#   'BODY': "The firm will protect investors against Bitcoin's volatility with gold."},
#  {'TITLE': 'Solana price drops as memecoins fade and SOL unlock concerns emerge',
#   'URL': 'https://cointelegraph.com/news/solana-price-drops-as-memecoins-fade-and-sol-unlock-concerns-emerge?utm_source=rss_feed&utm_medium=rss&utm_campaign=rss_partner_inbound',
#   'KEYWORDS': '',
#   'SENTIMENT': 'NEGATIVE',
#   'PUBLISHED_ON': '29/05/2025 19:39:15 -03',
#   'BODY': 'Trader’s interest in Solana is strong, but declining memecoin prices and SOL token unlocks have put a cap on the altcoin’s rally.'},
#  {'TITLE': 'Pi Network Faces Increased Selling Pressure as Bearish Indicators Suggest Potential Downtrend Continuation',
#   'URL': 'https://en.coinotag.com/pi-network-faces-increased-selling-pressure-as-bearish-indicators-suggest-potential-downtrend-continuation/',
#   'KEYWORDS': 'Analysis|News|FLOW',
#   'SENTIMENT': 'NEGATIVE',
#   'PUBLISHED_ON': '29/05/2025 19:34:46 -03',
#   'BODY': 'Pi Network (PI) has experienced a significant decline of nearly 15% over the past week, with technical indicators confirming a bearish trend fueled by increasing selling pressure. As the Chaikin'},
#  {'TITLE': 'Congress Rolls Out New Crypto Market Structure Bill—What Does It Actually Do?',
#   'URL': 'https://decrypt.co/322869/congress-new-crypto-market-structure-bill',
#   'KEYWORDS': '||Law and Order',
#   'SENTIMENT': 'NEUTRAL',
#   'PUBLISHED_ON': '29/05/2025 19:29:10 -03',
#   'BODY': 'A House bill formally introduced Thursday would end SEC oversight over the crypto industry. It will be debated by lawmakers in the coming weeks.'},
#  {'TITLE': 'Potential Securities Implications for Bitcoin Transactions Highlighted by SEC’s Hester Peirce at Bitcoin 2025 Conference',
#   'URL': 'https://en.coinotag.com/potential-securities-implications-for-bitcoin-transactions-highlighted-by-secs-hester-peirce-at-bitcoin-2025-conference/',
#   'KEYWORDS': 'News',
#   'SENTIMENT': 'NEUTRAL',
#   'PUBLISHED_ON': '29/05/2025 19:27:44 -03',
#   'BODY': 'Hester Peirce, head of the SEC’s crypto task force, recently emphasized the importance of transaction context in determining if digital asset transfer qualifies as a securities transaction. This perspective highlights'},
#  {'TITLE': 'Ethereum researcher raise concerns about Bitcoin potential security problem due to its low fees',
#   'URL': 'https://www.cryptopolitan.com/ethereum-foundation-developer-warns-bitcoin-security-is-a-disaster-waiting-to-happen/',
#   'KEYWORDS': 'News|Bitcoin|BTC',
#   'SENTIMENT': 'NEGATIVE',
#   'PUBLISHED_ON': '29/05/2025 19:20:46 -03',
#   'BODY': 'Ethereum Foundation researcher Justin Drake has warned about the security of the Bitcoin Network. Drake shared his view on X, noting that the Bitcoin Proof of Work (PoW) consensus mechanism is a ticking time bomb. The blockchain security expert, one of the masterminds behind the Merge, i.e., Ethereum transition from PoW to Proof of Stake (PoS), identified Bitcoin’s low fees as the major risk to its security. According to Drake , Bitcoin fees have fallen for 13 years, with miners generating less than 10 BTC in daily fees. He believes that this low fee represents a disincentive for most miners who are the ones securing the network and could eventually affect the network, a contagion risk for the whole crypto industry. He said: “Bitcoin’s security model is broken. If Bitcoin gets taken over, the fallout could take the entire crypto ecosystem. The systemic risks can’t be ignored.” The researcher noted that Bitcoin fees have constantly declined for over a decade despite halving and reducing the issuance rate. In fact, the fees are falling faster than the issuance rate on the network, with a 30-day moving average (MA) of Bitcoin transaction fees currently at 6.5 BTC per day. Bitcoin Transaction Fees.(Source: X/Drake) This meant that fees only account for around 1% of miners’ revenue over the years, and Bitcoin miners could see a 100% decline in their revenue once the complete 21 million BTC have been mined. However, Category Labs researcher Kushal Babel disagreed with the argument, noting that denominating fees in BTC to say it is at an all-time low is wrong. According to him, the whole argument might change if BTC fees are denominated in US Dollars. Babel argued that Drake’s opinion that the ratio of BTC market cap to the amount securing it makes the network vulnerable to a 51% attack is a weak argument at best, and the focus should be on the cost of an attack in dollars. Higher prices may not save the Bitcoin network from attack Meanwhile, Drake added that a rise in Bitcoin prices could be inimical to network security because it would make it harder to sustain the BTC-denominated fees. In order to explain this, he described a scenario where Bitcoin price increases but fees stay unchanged, noting that fees at the time will only cover around 10% of the security cost for the network. He said: “Let’s be optimistic and say BTC rises to $1M, and today’s 6.5 BTC/day in fees is maintained: $6.5M/day in fees, 10% of today’s security budget. Bitcoin would be a $20T asset secured by 1/10th of today’s hashing infrastructure.” Thus, he believes that the cost of attacking the Bitcoin network will not increase even as the price of BTC increases. This could make it possible for a 51% attack on the Bitcoin network to cost as little as $20 billion, even if the network has a market cap of $200 trillion tokens. Drake further debunked the presumption that Bitcoin fees will increase, noting that this has not happened in the last 13 years. He added that all previous attempts to boost Bitcoin fees by increasing its utility as a transaction layer have failed to achieve sustainable long-term gains, with projects such as Ordinals, Liquid, Omni, Babylon, and others only creating short-term spikes. Potential solutions to Bitcoin’s fragile security With Drake highlighting Bitcoin’s risks, he proposed two solutions that could work for the network if fees do not increase. According to him, the solution is for Bitcoin to expand the total supply beyond the 21 million cap or for the network to switch to Proof of Stake. Unsurprisingly, he acknowledged that these two proposed solutions are unlikely to be implemented, given that they are completely against the conventional ethos of the Bitcoin community. However, he insisted that creating a Bitcoin Virtual Machine or Proof of Authority, where the major mining pools will secure the network, is unlikely to work. Still, he called on anyone who could explain how the PoA will function to do so. Interestingly, ot ...
#  {'TITLE': 'Suspects in Manhattan Crypto Kidnapping, Torture Case Plead Not Guilty as Investigation Widens',
#   'URL': 'https://www.coindesk.com/policy/2025/05/29/suspects-in-manhattan-crypto-kidnapping-torture-case-plead-not-guilty-as-investigation-widens',
#   'KEYWORDS': 'Policy|NYPD|News',
#   'SENTIMENT': 'NEGATIVE',
#   'PUBLISHED_ON': '29/05/2025 19:18:41 -03',
#   'BODY': 'Two men suspected in the kidnapping and torture of a 28-year-old Italian cryptocurrency investor have pleaded not guilty, while the investigation into their case appears to have expanded to the New York Police Department itself. New York police had previously arrested William Duplessie , 33, and John Woeltz , 37, on the charges, as well as a third individual, Beatrice Folchi, 24, though her prosecution is being deferred. The victim has not been publicly named. The men are accused of kidnapping the victim and holding him hostage in a luxury townhouse in Manhattan’s ritzy SoHo neighborhood for more than two weeks. During that time, New York City police say the trio tortured the man, forcing him to take drugs, dangling him from a ledge, urinating on him and electrocuting him in an effort to force him to hand over the private keys to his bitcoin. The alleged perpetrators are accused of making t-shirts of the victim with a crack pipe in his mouth and taking Polaroids of the victim with a gun to his head. The victim escaped last Friday, grabbing his laptop and getting out of the townhouse and then seeking help from a traffic officer. Duplessie entered a not-guilty plea to five different charges, including kidnapping with an intent to collect a ransom, kidnapping and causing a physical injury, criminal possession of a loaded firearm, assault with an intent to cause a physical injury with a weapon and unlawful imprisonment, according to the court docket. Woeltz was charged with kidnapping, assault, unlawful imprisonment and criminal possession of a firearm, and he also pleaded not guilty, according to his court docket. Two NYPD officers, including a detective assigned to Mayor Eric Adams\' protection detail, worked for both Duplessie and Woeltz in their off-duty hours and have now been placed on modified duty, Bloomberg reported Thursday. A source familiar told CoinDesk that the two officers are not believed to be part of the kidnapping, but rather did security work for the defendants. They may have driven the victim from an airport to the townhouse, but have not been tied to his torture, the source said. A spokesperson for the NYPD said the matter was "under internal review." A spokesperson for the mayor\'s office said in a statement that, "Every city employee is expected to follow the law, including our officers, both on and off duty. We are disturbed by these allegations, and as soon as it came to our attention, the officers were placed on modified duty. The investigation is ongoing." UPDATE (May 29, 2025, 22:27 UTC): Adds additional detail.'}]

# %% [markdown]
# ### Coindesk OHLCV:

# %%
import requests
import pandas as pd
#import pandas_ta as ta
import os
from dotenv import load_dotenv
import json

# Carregar variáveis de ambiente do arquivo .env
load_dotenv()


def fetch_coindesk_ohlcv(api_key: str, instrument: str = "BTC-USD", limit: int = 250) -> dict | None:
    """
    Busca dados históricos OHLCV da API CoinDesk.

    Args:
        api_key (str): Sua chave de API da CoinDesk.
        instrument (str): O instrumento a ser buscado (ex: "BTC-USD").
        limit (int): O número de dias de dados a serem retornados.
                     Para indicadores como SMA de 200 dias, um limite de pelo menos 200-250 é recomendado.

    Returns:
        dict | None: A resposta JSON da API ou None em caso de erro.
    """
    url = 'https://data-api.coindesk.com/index/cc/v1/historical/days'
    params = {
        "market": "cadli",  # Este mercado parece específico, verifique se é o desejado para BTC-USD geral
        "instrument": instrument,
        "aggregate": 1,
        "fill": "true",
        "apply_mapping": "true",
        "response_format": "JSON",
        "limit": limit,
        "groups": "OHLC,VOLUME", # Garante que estamos pegando OHLC e o campo VOLUME principal
        "api_key": api_key
    }
    headers = {
        "Content-type": "application/json; charset=UTF-8"
    }

    try:
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status()  # Levanta um erro HTTP para respostas ruins (4xx ou 5xx)
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Erro ao buscar dados da API CoinDesk: {e}")
        return None

# %%
teste = fetch_coindesk_ohlcv(os.getenv('COINDESK_API_KEY'), instrument="BTC-USD", limit=250)

# %%
teste
# Out:
# {'Data': [{'UNIT': 'DAY',
#    'TIMESTAMP': 1727568000,
#    'OPEN': 65887.2135773289,
#    'HIGH': 66083.01348839,
#    'LOW': 65465.0294142081,
#    'CLOSE': 65626.5046907249,
#    'VOLUME': 118592.273372256,
#    'QUOTE_VOLUME': 7797769947.47553,
#    'VOLUME_TOP_TIER': 62938.5640529879,
#    'QUOTE_VOLUME_TOP_TIER': 4138370535.90633,
#    'VOLUME_DIRECT': 15161.901458264,
#    'QUOTE_VOLUME_DIRECT': 997024754.124539,
#    'VOLUME_TOP_TIER_DIRECT': 11633.57350217,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 764945057.404365},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1727654400,
#    'OPEN': 65626.5046907249,
#    'HIGH': 65634.6632562962,
#    'LOW': 62894.9934452219,
#    'CLOSE': 63332.7776140374,
#    'VOLUME': 383332.54931369,
#    'QUOTE_VOLUME': 24530931549.7999,
#    'VOLUME_TOP_TIER': 214559.188914789,
#    'QUOTE_VOLUME_TOP_TIER': 13726628873.9195,
#    'VOLUME_DIRECT': 55085.865351886,
#    'QUOTE_VOLUME_DIRECT': 3524434485.35093,
#    'VOLUME_TOP_TIER_DIRECT': 43065.34437998,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2754835142.43758},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1727740800,
#    'OPEN': 63332.7776140374,
#    'HIGH': 64126.3450296224,
#    'LOW': 60203.8620421962,
#    'CLOSE': 60826.6276746958,
#    'VOLUME': 553425.687392482,
#    'QUOTE_VOLUME': 34519454354.5085,
#    'VOLUME_TOP_TIER': 330537.621472764,
#    'QUOTE_VOLUME_TOP_TIER': 20590888730.9895,
#    'VOLUME_DIRECT': 81231.4830898378,
#    'QUOTE_VOLUME_DIRECT': 5058977951.98905,
#    'VOLUME_TOP_TIER_DIRECT': 68383.88527637,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4255409157.83714},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1727827200,
#    'OPEN': 60826.6276746958,
#    'HIGH': 62364.8614998385,
#    'LOW': 60015.5830813617,
#    'CLOSE': 60662.2329218135,
#    'VOLUME': 449231.827388045,
#    'QUOTE_VOLUME': 27490586460.3678,
#    'VOLUME_TOP_TIER': 263805.087011652,
#    'QUOTE_VOLUME_TOP_TIER': 16138585820.5077,
#    'VOLUME_DIRECT': 68978.066048387,
#    'QUOTE_VOLUME_DIRECT': 4217932825.7002,
#    'VOLUME_TOP_TIER_DIRECT': 56647.35582373,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3462950760.09266},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1727913600,
#    'OPEN': 60662.2329218135,
#    'HIGH': 61482.7898825813,
#    'LOW': 59899.7956322606,
#    'CLOSE': 60768.6760074744,
#    'VOLUME': 405576.995461709,
#    'QUOTE_VOLUME': 24608753927.7064,
#    'VOLUME_TOP_TIER': 246220.166125473,
#    'QUOTE_VOLUME_TOP_TIER': 14934234438.355,
#    'VOLUME_DIRECT': 60600.806886018,
#    'QUOTE_VOLUME_DIRECT': 3674598136.59717,
#    'VOLUME_TOP_TIER_DIRECT': 51142.44090382,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3100054857.56821},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728000000,
#    'OPEN': 60768.6760074744,
#    'HIGH': 62480.791886014,
#    'LOW': 60483.5022024609,
#    'CLOSE': 62097.1099705322,
#    'VOLUME': 320033.727195165,
#    'QUOTE_VOLUME': 19709725870.8046,
#    'VOLUME_TOP_TIER': 194414.958811024,
#    'QUOTE_VOLUME_TOP_TIER': 11972507876.7445,
#    'VOLUME_DIRECT': 48083.75667045,
#    'QUOTE_VOLUME_DIRECT': 2960853135.77231,
#    'VOLUME_TOP_TIER_DIRECT': 39581.15670314,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2436950078.45757},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728086400,
#    'OPEN': 62097.1099705322,
#    'HIGH': 62380.8400096376,
#    'LOW': 61712.1306050395,
#    'CLOSE': 62073.0157519238,
#    'VOLUME': 122013.790193855,
#    'QUOTE_VOLUME': 7573746878.69597,
#    'VOLUME_TOP_TIER': 67287.9910017696,
#    'QUOTE_VOLUME_TOP_TIER': 4175995801.57564,
#    'VOLUME_DIRECT': 13592.20824613,
#    'QUOTE_VOLUME_DIRECT': 843431593.845601,
#    'VOLUME_TOP_TIER_DIRECT': 10253.91954248,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 636076649.178981},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728172800,
#    'OPEN': 62073.0157519238,
#    'HIGH': 62962.9847402468,
#    'LOW': 61828.8109924387,
#    'CLOSE': 62828.358701696,
#    'VOLUME': 133119.921764546,
#    'QUOTE_VOLUME': 8308673421.27975,
#    'VOLUME_TOP_TIER': 75896.0506057392,
#    'QUOTE_VOLUME_TOP_TIER': 4738023639.24536,
#    'VOLUME_DIRECT': 17440.21334772,
#    'QUOTE_VOLUME_DIRECT': 1089449530.82396,
#    'VOLUME_TOP_TIER_DIRECT': 13666.37300796,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 853870124.40473},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728259200,
#    'OPEN': 62828.358701696,
#    'HIGH': 64427.6040547436,
#    'LOW': 62173.3169379203,
#    'CLOSE': 62230.4625084833,
#    'VOLUME': 352230.718182244,
#    'QUOTE_VOLUME': 22329051579.6041,
#    'VOLUME_TOP_TIER': 209095.914514712,
#    'QUOTE_VOLUME_TOP_TIER': 13253196737.8117,
#    'VOLUME_DIRECT': 51593.061066364,
#    'QUOTE_VOLUME_DIRECT': 3270833443.94969,
#    'VOLUME_TOP_TIER_DIRECT': 41929.10482834,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2657732018.59461},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728345600,
#    'OPEN': 62230.4625084833,
#    'HIGH': 63173.7662621025,
#    'LOW': 61859.5681372391,
#    'CLOSE': 62141.647102476,
#    'VOLUME': 286759.003037121,
#    'QUOTE_VOLUME': 17898211685.7763,
#    'VOLUME_TOP_TIER': 173411.174243871,
#    'QUOTE_VOLUME_TOP_TIER': 10822338262.8939,
#    'VOLUME_DIRECT': 41908.51880539,
#    'QUOTE_VOLUME_DIRECT': 2615661513.68025,
#    'VOLUME_TOP_TIER_DIRECT': 34273.9843972,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2138712473.61109},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728432000,
#    'OPEN': 62141.647102476,
#    'HIGH': 62519.4834716067,
#    'LOW': 60308.8589626368,
#    'CLOSE': 60602.0586200711,
#    'VOLUME': 286318.048091879,
#    'QUOTE_VOLUME': 17668272104.2318,
#    'VOLUME_TOP_TIER': 170498.11945229,
#    'QUOTE_VOLUME_TOP_TIER': 10518234828.5296,
#    'VOLUME_DIRECT': 46136.598305159,
#    'QUOTE_VOLUME_DIRECT': 2843038357.50433,
#    'VOLUME_TOP_TIER_DIRECT': 38307.4858797,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2359312403.65402},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728518400,
#    'OPEN': 60602.0586200711,
#    'HIGH': 61257.6452048336,
#    'LOW': 58910.2671194159,
#    'CLOSE': 60291.8230408993,
#    'VOLUME': 316253.461180801,
#    'QUOTE_VOLUME': 19077992459.0705,
#    'VOLUME_TOP_TIER': 181764.166874359,
#    'QUOTE_VOLUME_TOP_TIER': 10959414063.7348,
#    'VOLUME_DIRECT': 52480.309628354,
#    'QUOTE_VOLUME_DIRECT': 3162195707.3205,
#    'VOLUME_TOP_TIER_DIRECT': 43416.82350174,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2614693445.60865},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728604800,
#    'OPEN': 60291.8230408993,
#    'HIGH': 63390.5947191873,
#    'LOW': 60052.3010990007,
#    'CLOSE': 62515.8763316225,
#    'VOLUME': 309234.18087792,
#    'QUOTE_VOLUME': 19109979263.8139,
#    'VOLUME_TOP_TIER': 173277.310936433,
#    'QUOTE_VOLUME_TOP_TIER': 10712523868.7844,
#    'VOLUME_DIRECT': 46332.346468566,
#    'QUOTE_VOLUME_DIRECT': 2868735160.65479,
#    'VOLUME_TOP_TIER_DIRECT': 36943.85441969,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2288006387.19917},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728691200,
#    'OPEN': 62515.8763316225,
#    'HIGH': 63464.4203171775,
#    'LOW': 62480.8123902975,
#    'CLOSE': 63221.9295438542,
#    'VOLUME': 150528.308841463,
#    'QUOTE_VOLUME': 9478435074.60424,
#    'VOLUME_TOP_TIER': 81074.2683639217,
#    'QUOTE_VOLUME_TOP_TIER': 5105720103.00485,
#    'VOLUME_DIRECT': 20355.836448754,
#    'QUOTE_VOLUME_DIRECT': 1282365829.80419,
#    'VOLUME_TOP_TIER_DIRECT': 15893.7824984,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1001295105.40753},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728777600,
#    'OPEN': 63221.9295438542,
#    'HIGH': 63303.2322932345,
#    'LOW': 62059.3667994464,
#    'CLOSE': 62871.9480057892,
#    'VOLUME': 166830.988200688,
#    'QUOTE_VOLUME': 10459385319.5697,
#    'VOLUME_TOP_TIER': 90234.6983350476,
#    'QUOTE_VOLUME_TOP_TIER': 5656529895.31007,
#    'VOLUME_DIRECT': 21767.38069718,
#    'QUOTE_VOLUME_DIRECT': 1364401199.20431,
#    'VOLUME_TOP_TIER_DIRECT': 16896.73639054,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1058907540.08412},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728864000,
#    'OPEN': 62871.9480057892,
#    'HIGH': 66454.0941459396,
#    'LOW': 62461.9682063243,
#    'CLOSE': 66052.4764903993,
#    'VOLUME': 424493.026768188,
#    'QUOTE_VOLUME': 27582697772.6231,
#    'VOLUME_TOP_TIER': 234031.063067122,
#    'QUOTE_VOLUME_TOP_TIER': 15211559471.5613,
#    'VOLUME_DIRECT': 64664.10540237,
#    'QUOTE_VOLUME_DIRECT': 4208555714.76139,
#    'VOLUME_TOP_TIER_DIRECT': 51043.62779337,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3322293706.44698},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1728950400,
#    'OPEN': 66052.4764903993,
#    'HIGH': 67855.9095319163,
#    'LOW': 64832.7907203237,
#    'CLOSE': 67050.4491516615,
#    'VOLUME': 452608.776698969,
#    'QUOTE_VOLUME': 29972982374.5341,
#    'VOLUME_TOP_TIER': 255672.003261326,
#    'QUOTE_VOLUME_TOP_TIER': 16936732526.0898,
#    'VOLUME_DIRECT': 65140.945972455,
#    'QUOTE_VOLUME_DIRECT': 4319394643.61978,
#    'VOLUME_TOP_TIER_DIRECT': 52935.8272052,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3510530398.55659},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729036800,
#    'OPEN': 67050.4491516615,
#    'HIGH': 68375.2431669292,
#    'LOW': 66745.4241641731,
#    'CLOSE': 67608.9554372881,
#    'VOLUME': 351445.627098057,
#    'QUOTE_VOLUME': 23749618415.5977,
#    'VOLUME_TOP_TIER': 198298.604494781,
#    'QUOTE_VOLUME_TOP_TIER': 13402399391.1873,
#    'VOLUME_DIRECT': 54246.985181249,
#    'QUOTE_VOLUME_DIRECT': 3667658681.88998,
#    'VOLUME_TOP_TIER_DIRECT': 43042.33680275,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2909892132.50765},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729123200,
#    'OPEN': 67608.9554372881,
#    'HIGH': 67919.3970261853,
#    'LOW': 66651.5562182071,
#    'CLOSE': 67395.2215125504,
#    'VOLUME': 298560.128689724,
#    'QUOTE_VOLUME': 20061432080.6322,
#    'VOLUME_TOP_TIER': 163109.300164062,
#    'QUOTE_VOLUME_TOP_TIER': 10959039793.0563,
#    'VOLUME_DIRECT': 42716.017519673,
#    'QUOTE_VOLUME_DIRECT': 2870470594.92348,
#    'VOLUME_TOP_TIER_DIRECT': 32770.35932073,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2201788145.63485},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729209600,
#    'OPEN': 67395.2215125504,
#    'HIGH': 68983.1978759721,
#    'LOW': 67165.226660124,
#    'CLOSE': 68421.8208316511,
#    'VOLUME': 330620.573408691,
#    'QUOTE_VOLUME': 22543580325.5849,
#    'VOLUME_TOP_TIER': 180648.771253597,
#    'QUOTE_VOLUME_TOP_TIER': 12319587118.0577,
#    'VOLUME_DIRECT': 48575.077079364,
#    'QUOTE_VOLUME_DIRECT': 3315003437.13146,
#    'VOLUME_TOP_TIER_DIRECT': 37736.55260567,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2575537219.66657},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729296000,
#    'OPEN': 68421.8208316511,
#    'HIGH': 68674.9279570562,
#    'LOW': 68024.1069214103,
#    'CLOSE': 68370.4988843752,
#    'VOLUME': 109267.643327387,
#    'QUOTE_VOLUME': 7462364225.3134,
#    'VOLUME_TOP_TIER': 51682.079206138,
#    'QUOTE_VOLUME_TOP_TIER': 3529553073.27015,
#    'VOLUME_DIRECT': 11138.62839466,
#    'QUOTE_VOLUME_DIRECT': 760817654.126212,
#    'VOLUME_TOP_TIER_DIRECT': 7780.80891223,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 531427788.079485},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729382400,
#    'OPEN': 68370.4988843752,
#    'HIGH': 69369.0314060122,
#    'LOW': 67946.8314768704,
#    'CLOSE': 69020.5399560581,
#    'VOLUME': 141551.262279764,
#    'QUOTE_VOLUME': 9712707915.13144,
#    'VOLUME_TOP_TIER': 69950.5509727304,
#    'QUOTE_VOLUME_TOP_TIER': 4801147010.17972,
#    'VOLUME_DIRECT': 17105.076279069,
#    'QUOTE_VOLUME_DIRECT': 1174861471.16723,
#    'VOLUME_TOP_TIER_DIRECT': 12112.74796005,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 832129620.423991},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729468800,
#    'OPEN': 69020.5399560581,
#    'HIGH': 69472.4379373916,
#    'LOW': 66828.7556296073,
#    'CLOSE': 67349.4984218654,
#    'VOLUME': 341884.44102115,
#    'QUOTE_VOLUME': 23230112066.6167,
#    'VOLUME_TOP_TIER': 182205.814530156,
#    'QUOTE_VOLUME_TOP_TIER': 12376094535.7452,
#    'VOLUME_DIRECT': 49544.06901536,
#    'QUOTE_VOLUME_DIRECT': 3364030183.27416,
#    'VOLUME_TOP_TIER_DIRECT': 37663.28553874,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2556649348.81916},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729555200,
#    'OPEN': 67349.4984218654,
#    'HIGH': 67783.4538555604,
#    'LOW': 66589.5947334582,
#    'CLOSE': 67395.6874685028,
#    'VOLUME': 287673.581278062,
#    'QUOTE_VOLUME': 19342084285.8922,
#    'VOLUME_TOP_TIER': 158036.573335765,
#    'QUOTE_VOLUME_TOP_TIER': 10625014708.7148,
#    'VOLUME_DIRECT': 42779.32368677,
#    'QUOTE_VOLUME_DIRECT': 2877047512.02337,
#    'VOLUME_TOP_TIER_DIRECT': 33275.75562935,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2237624864.23208},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729641600,
#    'OPEN': 67395.6874685028,
#    'HIGH': 67413.7007527587,
#    'LOW': 65202.0937854378,
#    'CLOSE': 66595.1575370042,
#    'VOLUME': 305974.205950342,
#    'QUOTE_VOLUME': 20308469487.9532,
#    'VOLUME_TOP_TIER': 172679.529475527,
#    'QUOTE_VOLUME_TOP_TIER': 11458856014.3337,
#    'VOLUME_DIRECT': 43648.27008593,
#    'QUOTE_VOLUME_DIRECT': 2895365037.86642,
#    'VOLUME_TOP_TIER_DIRECT': 33487.77258686,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2220722286.07199},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729728000,
#    'OPEN': 66595.1575370042,
#    'HIGH': 68798.7899967317,
#    'LOW': 66452.0865313455,
#    'CLOSE': 68164.8279907969,
#    'VOLUME': 284306.01614709,
#    'QUOTE_VOLUME': 19202052741.3557,
#    'VOLUME_TOP_TIER': 159469.357548777,
#    'QUOTE_VOLUME_TOP_TIER': 10771056519.5573,
#    'VOLUME_DIRECT': 41177.05553162,
#    'QUOTE_VOLUME_DIRECT': 2784208431.41083,
#    'VOLUME_TOP_TIER_DIRECT': 32467.42257564,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2195211218.10186},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729814400,
#    'OPEN': 68164.8279907969,
#    'HIGH': 68719.7997052664,
#    'LOW': 65634.8724584663,
#    'CLOSE': 66608.8588016777,
#    'VOLUME': 377887.372335262,
#    'QUOTE_VOLUME': 25460260770.0967,
#    'VOLUME_TOP_TIER': 220139.019155807,
#    'QUOTE_VOLUME_TOP_TIER': 14825528687.1897,
#    'VOLUME_DIRECT': 56158.75684426,
#    'QUOTE_VOLUME_DIRECT': 3785449406.94201,
#    'VOLUME_TOP_TIER_DIRECT': 44991.851016,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3031465497.44428},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729900800,
#    'OPEN': 66608.8588016777,
#    'HIGH': 67355.2483774178,
#    'LOW': 66381.3315781647,
#    'CLOSE': 67025.6278144203,
#    'VOLUME': 161728.895412342,
#    'QUOTE_VOLUME': 10817790320.6812,
#    'VOLUME_TOP_TIER': 89842.6253521775,
#    'QUOTE_VOLUME_TOP_TIER': 6008288102.21839,
#    'VOLUME_DIRECT': 19075.50071306,
#    'QUOTE_VOLUME_DIRECT': 1275734606.62486,
#    'VOLUME_TOP_TIER_DIRECT': 14287.08009406,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 955000700.049589},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1729987200,
#    'OPEN': 67025.6278144203,
#    'HIGH': 68249.6005764028,
#    'LOW': 66867.2036403921,
#    'CLOSE': 67960.7870584741,
#    'VOLUME': 131352.228945225,
#    'QUOTE_VOLUME': 8871917209.91429,
#    'VOLUME_TOP_TIER': 75947.1306060834,
#    'QUOTE_VOLUME_TOP_TIER': 5130839971.77372,
#    'VOLUME_DIRECT': 15775.35535467,
#    'QUOTE_VOLUME_DIRECT': 1066768694.73677,
#    'VOLUME_TOP_TIER_DIRECT': 12218.23274774,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 826238543.600163},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730073600,
#    'OPEN': 67960.7870584741,
#    'HIGH': 70204.2983517315,
#    'LOW': 67567.5120465036,
#    'CLOSE': 69931.1218734847,
#    'VOLUME': 346088.254924601,
#    'QUOTE_VOLUME': 23839639653.2235,
#    'VOLUME_TOP_TIER': 198578.738900769,
#    'QUOTE_VOLUME_TOP_TIER': 13679483106.1933,
#    'VOLUME_DIRECT': 54346.31892385,
#    'QUOTE_VOLUME_DIRECT': 3748631046.50685,
#    'VOLUME_TOP_TIER_DIRECT': 43263.54368463,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2983850743.13528},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730160000,
#    'OPEN': 69931.1218734847,
#    'HIGH': 73565.4936382496,
#    'LOW': 69735.7799342236,
#    'CLOSE': 72716.9139244938,
#    'VOLUME': 498617.464855358,
#    'QUOTE_VOLUME': 35818675448.0672,
#    'VOLUME_TOP_TIER': 273044.999406508,
#    'QUOTE_VOLUME_TOP_TIER': 19628100746.4703,
#    'VOLUME_DIRECT': 76695.49588968,
#    'QUOTE_VOLUME_DIRECT': 5517004314.2144,
#    'VOLUME_TOP_TIER_DIRECT': 59815.66553276,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4304506149.89778},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730246400,
#    'OPEN': 72716.9139244938,
#    'HIGH': 72921.2009337958,
#    'LOW': 71447.4789909563,
#    'CLOSE': 72347.5952043618,
#    'VOLUME': 338604.095441546,
#    'QUOTE_VOLUME': 24440790562.3386,
#    'VOLUME_TOP_TIER': 193740.855372224,
#    'QUOTE_VOLUME_TOP_TIER': 13981379604.6594,
#    'VOLUME_DIRECT': 49730.16667622,
#    'QUOTE_VOLUME_DIRECT': 3588454821.53052,
#    'VOLUME_TOP_TIER_DIRECT': 39695.41094289,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2863485501.60353},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730332800,
#    'OPEN': 72347.5952043618,
#    'HIGH': 72675.3912125001,
#    'LOW': 69626.5754212057,
#    'CLOSE': 70239.8161326723,
#    'VOLUME': 339188.592494718,
#    'QUOTE_VOLUME': 24161748081.0094,
#    'VOLUME_TOP_TIER': 187258.560182419,
#    'QUOTE_VOLUME_TOP_TIER': 13326949568.1498,
#    'VOLUME_DIRECT': 50379.72861522,
#    'QUOTE_VOLUME_DIRECT': 3580465683.4197,
#    'VOLUME_TOP_TIER_DIRECT': 40576.86172159,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2881256751.90469},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730419200,
#    'OPEN': 70239.8161326723,
#    'HIGH': 71603.2555447057,
#    'LOW': 68827.8995808763,
#    'CLOSE': 69499.8990526099,
#    'VOLUME': 427630.308335649,
#    'QUOTE_VOLUME': 29886542174.8476,
#    'VOLUME_TOP_TIER': 237583.141696024,
#    'QUOTE_VOLUME_TOP_TIER': 16604627569.6583,
#    'VOLUME_DIRECT': 63723.11459875,
#    'QUOTE_VOLUME_DIRECT': 4457023076.60385,
#    'VOLUME_TOP_TIER_DIRECT': 50291.92511807,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3517614207.57641},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730505600,
#    'OPEN': 69499.8990526099,
#    'HIGH': 69906.1956365661,
#    'LOW': 69046.0203450696,
#    'CLOSE': 69349.1039939168,
#    'VOLUME': 138484.797667479,
#    'QUOTE_VOLUME': 9626520683.57186,
#    'VOLUME_TOP_TIER': 70425.9782090937,
#    'QUOTE_VOLUME_TOP_TIER': 4894430898.28453,
#    'VOLUME_DIRECT': 15224.54084657,
#    'QUOTE_VOLUME_DIRECT': 1057600543.17715,
#    'VOLUME_TOP_TIER_DIRECT': 10885.77154787,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 755911415.370548},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730592000,
#    'OPEN': 69349.1039939168,
#    'HIGH': 69376.7123985593,
#    'LOW': 67510.5387819435,
#    'CLOSE': 68782.5710242388,
#    'VOLUME': 291714.056905673,
#    'QUOTE_VOLUME': 19957258721.1543,
#    'VOLUME_TOP_TIER': 159324.908115935,
#    'QUOTE_VOLUME_TOP_TIER': 10897906503.4985,
#    'VOLUME_DIRECT': 39693.17381868,
#    'QUOTE_VOLUME_DIRECT': 2714332882.16581,
#    'VOLUME_TOP_TIER_DIRECT': 29961.68022139,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2048344621.40641},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730678400,
#    'OPEN': 68782.5710242388,
#    'HIGH': 69489.6484691297,
#    'LOW': 66829.1467610505,
#    'CLOSE': 67839.6651434504,
#    'VOLUME': 365286.072518402,
#    'QUOTE_VOLUME': 24945919312.2133,
#    'VOLUME_TOP_TIER': 210689.037734869,
#    'QUOTE_VOLUME_TOP_TIER': 14379182600.3371,
#    'VOLUME_DIRECT': 55796.95901426,
#    'QUOTE_VOLUME_DIRECT': 3803494490.50253,
#    'VOLUME_TOP_TIER_DIRECT': 44514.9872336,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3032631833.62369},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730764800,
#    'OPEN': 67839.6651434504,
#    'HIGH': 70489.1565250943,
#    'LOW': 67468.2533099102,
#    'CLOSE': 69391.5345696399,
#    'VOLUME': 396813.660885695,
#    'QUOTE_VOLUME': 27476959279.1723,
#    'VOLUME_TOP_TIER': 230089.343764792,
#    'QUOTE_VOLUME_TOP_TIER': 15939356902.3916,
#    'VOLUME_DIRECT': 60602.99808266,
#    'QUOTE_VOLUME_DIRECT': 4201912428.32956,
#    'VOLUME_TOP_TIER_DIRECT': 48928.74404636,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3393638225.54478},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730851200,
#    'OPEN': 69391.5345696399,
#    'HIGH': 76396.9483939753,
#    'LOW': 69324.8332776382,
#    'CLOSE': 75596.3997543213,
#    'VOLUME': 1003622.35339263,
#    'QUOTE_VOLUME': 74248446131.1542,
#    'VOLUME_TOP_TIER': 545570.442908949,
#    'QUOTE_VOLUME_TOP_TIER': 40334343959.6647,
#    'VOLUME_DIRECT': 152378.31442322,
#    'QUOTE_VOLUME_DIRECT': 11279460312.191,
#    'VOLUME_TOP_TIER_DIRECT': 119234.6559025,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 8825212135.02021},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1730937600,
#    'OPEN': 75596.3997543213,
#    'HIGH': 76905.4482652172,
#    'LOW': 74455.3755000087,
#    'CLOSE': 75901.9931706196,
#    'VOLUME': 510449.296230174,
#    'QUOTE_VOLUME': 38591439550.4239,
#    'VOLUME_TOP_TIER': 268869.948323175,
#    'QUOTE_VOLUME_TOP_TIER': 20336824380.6715,
#    'VOLUME_DIRECT': 76569.19848604,
#    'QUOTE_VOLUME_DIRECT': 5800033476.91392,
#    'VOLUME_TOP_TIER_DIRECT': 59574.53065637,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4515214937.4308},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731024000,
#    'OPEN': 75901.9931706196,
#    'HIGH': 77240.0954608893,
#    'LOW': 75650.8044684099,
#    'CLOSE': 76552.8549931562,
#    'VOLUME': 433003.466166704,
#    'QUOTE_VOLUME': 33032652514.924,
#    'VOLUME_TOP_TIER': 227880.584323747,
#    'QUOTE_VOLUME_TOP_TIER': 17388252390.0636,
#    'VOLUME_DIRECT': 63320.73169625,
#    'QUOTE_VOLUME_DIRECT': 4834951362.63229,
#    'VOLUME_TOP_TIER_DIRECT': 49798.79681642,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3803689078.60495},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731110400,
#    'OPEN': 76552.8549931562,
#    'HIGH': 76934.8053027748,
#    'LOW': 75761.712889609,
#    'CLOSE': 76715.8795017437,
#    'VOLUME': 202508.789994867,
#    'QUOTE_VOLUME': 15479557286.3744,
#    'VOLUME_TOP_TIER': 98391.0315203813,
#    'QUOTE_VOLUME_TOP_TIER': 7519982797.02772,
#    'VOLUME_DIRECT': 22819.77882684,
#    'QUOTE_VOLUME_DIRECT': 1744063484.13552,
#    'VOLUME_TOP_TIER_DIRECT': 16163.53388909,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1235291192.97101},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731196800,
#    'OPEN': 76715.8795017437,
#    'HIGH': 81369.5893280528,
#    'LOW': 76561.4448605417,
#    'CLOSE': 80406.6501624955,
#    'VOLUME': 549373.490137066,
#    'QUOTE_VOLUME': 43580607880.2027,
#    'VOLUME_TOP_TIER': 299259.9689523,
#    'QUOTE_VOLUME_TOP_TIER': 23744867532.8641,
#    'VOLUME_DIRECT': 76167.02876758,
#    'QUOTE_VOLUME_DIRECT': 6045530542.93163,
#    'VOLUME_TOP_TIER_DIRECT': 58549.54345578,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4648627612.95088},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731283200,
#    'OPEN': 80406.6501624955,
#    'HIGH': 89583.6860825148,
#    'LOW': 80265.4884454702,
#    'CLOSE': 88728.9508391651,
#    'VOLUME': 805361.953570754,
#    'QUOTE_VOLUME': 67889246225.7454,
#    'VOLUME_TOP_TIER': 473003.528471455,
#    'QUOTE_VOLUME_TOP_TIER': 39922600455.4,
#    'VOLUME_DIRECT': 127696.9376146,
#    'QUOTE_VOLUME_DIRECT': 10803713155.4081,
#    'VOLUME_TOP_TIER_DIRECT': 105984.98684686,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 8978717750.04984},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731369600,
#    'OPEN': 88728.9508391651,
#    'HIGH': 89992.7276452079,
#    'LOW': 85182.0494384673,
#    'CLOSE': 88056.9520854703,
#    'VOLUME': 878950.701190278,
#    'QUOTE_VOLUME': 77249742025.4881,
#    'VOLUME_TOP_TIER': 525428.754571064,
#    'QUOTE_VOLUME_TOP_TIER': 46139082824.6421,
#    'VOLUME_DIRECT': 133274.01366163,
#    'QUOTE_VOLUME_DIRECT': 11712490958.4755,
#    'VOLUME_TOP_TIER_DIRECT': 119388.66690596,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 10483509767.1026},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731456000,
#    'OPEN': 88056.9520854703,
#    'HIGH': 93408.2569524473,
#    'LOW': 86285.2443459286,
#    'CLOSE': 90511.4218833129,
#    'VOLUME': 809682.661582748,
#    'QUOTE_VOLUME': 72746242190.983,
#    'VOLUME_TOP_TIER': 486294.866167365,
#    'QUOTE_VOLUME_TOP_TIER': 43748859551.4441,
#    'VOLUME_DIRECT': 145537.34684964,
#    'QUOTE_VOLUME_DIRECT': 13109708318.5851,
#    'VOLUME_TOP_TIER_DIRECT': 127275.74899089,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 11477267753.4144},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731542400,
#    'OPEN': 90511.4218833129,
#    'HIGH': 91802.1155669152,
#    'LOW': 86716.7205862663,
#    'CLOSE': 87344.1898531065,
#    'VOLUME': 576762.19360372,
#    'QUOTE_VOLUME': 51626903376.229,
#    'VOLUME_TOP_TIER': 337870.493728906,
#    'QUOTE_VOLUME_TOP_TIER': 30220571590.3165,
#    'VOLUME_DIRECT': 99760.0806856127,
#    'QUOTE_VOLUME_DIRECT': 8911651050.14013,
#    'VOLUME_TOP_TIER_DIRECT': 83998.76474218,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 7501835278.95028},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731628800,
#    'OPEN': 87344.1898531065,
#    'HIGH': 91875.5564928485,
#    'LOW': 87157.6497119319,
#    'CLOSE': 91076.8119424913,
#    'VOLUME': 494933.828136558,
#    'QUOTE_VOLUME': 44199794615.9865,
#    'VOLUME_TOP_TIER': 279974.228578608,
#    'QUOTE_VOLUME_TOP_TIER': 25008785482.9261,
#    'VOLUME_DIRECT': 88245.25706769,
#    'QUOTE_VOLUME_DIRECT': 7889229136.29827,
#    'VOLUME_TOP_TIER_DIRECT': 72761.84371576,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6506846011.29227},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731715200,
#    'OPEN': 91076.8119424913,
#    'HIGH': 91789.3880470043,
#    'LOW': 90109.7796043353,
#    'CLOSE': 90584.2911636323,
#    'VOLUME': 251539.572049573,
#    'QUOTE_VOLUME': 22905681706.7486,
#    'VOLUME_TOP_TIER': 131078.726414655,
#    'QUOTE_VOLUME_TOP_TIER': 11932602145.5337,
#    'VOLUME_DIRECT': 35575.60923698,
#    'QUOTE_VOLUME_DIRECT': 3238183054.32794,
#    'VOLUME_TOP_TIER_DIRECT': 27781.85783514,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2528276577.32331},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731801600,
#    'OPEN': 90584.2911636323,
#    'HIGH': 91441.8563315991,
#    'LOW': 88798.4913148752,
#    'CLOSE': 89875.5646640815,
#    'VOLUME': 270720.125242577,
#    'QUOTE_VOLUME': 24437200615.59,
#    'VOLUME_TOP_TIER': 150471.500253444,
#    'QUOTE_VOLUME_TOP_TIER': 13578169250.8373,
#    'VOLUME_DIRECT': 39787.60576463,
#    'QUOTE_VOLUME_DIRECT': 3587792752.76539,
#    'VOLUME_TOP_TIER_DIRECT': 31420.98141335,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2832167231.45812},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731888000,
#    'OPEN': 89875.5646640815,
#    'HIGH': 92585.1563828683,
#    'LOW': 89182.5142797818,
#    'CLOSE': 90534.6457249376,
#    'VOLUME': 461749.644797978,
#    'QUOTE_VOLUME': 42044157090.9888,
#    'VOLUME_TOP_TIER': 273473.810096513,
#    'QUOTE_VOLUME_TOP_TIER': 24897308840.6573,
#    'VOLUME_DIRECT': 81326.14366345,
#    'QUOTE_VOLUME_DIRECT': 7401408092.85985,
#    'VOLUME_TOP_TIER_DIRECT': 67936.72802023,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6182227079.56425},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1731974400,
#    'OPEN': 90534.6457249376,
#    'HIGH': 93990.7500828168,
#    'LOW': 90436.9109078325,
#    'CLOSE': 92393.0854652586,
#    'VOLUME': 458491.243367917,
#    'QUOTE_VOLUME': 42292419155.716,
#    'VOLUME_TOP_TIER': 269007.058570426,
#    'QUOTE_VOLUME_TOP_TIER': 24821652818.8701,
#    'VOLUME_DIRECT': 81672.42967409,
#    'QUOTE_VOLUME_DIRECT': 7540948567.42707,
#    'VOLUME_TOP_TIER_DIRECT': 66405.57379285,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6133417771.46755},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732060800,
#    'OPEN': 92393.0854652586,
#    'HIGH': 94910.1798173257,
#    'LOW': 91632.4826468961,
#    'CLOSE': 94369.3365827971,
#    'VOLUME': 424125.764965134,
#    'QUOTE_VOLUME': 39716868942.3548,
#    'VOLUME_TOP_TIER': 265247.744305282,
#    'QUOTE_VOLUME_TOP_TIER': 24852744938.0156,
#    'VOLUME_DIRECT': 85537.53306873,
#    'QUOTE_VOLUME_DIRECT': 8016513228.76005,
#    'VOLUME_TOP_TIER_DIRECT': 71838.86368041,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6735426250.95911},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732147200,
#    'OPEN': 94369.3365827971,
#    'HIGH': 98977.8400237093,
#    'LOW': 94161.5602509987,
#    'CLOSE': 98402.1949920443,
#    'VOLUME': 580727.649983617,
#    'QUOTE_VOLUME': 56427810562.4421,
#    'VOLUME_TOP_TIER': 356081.719787714,
#    'QUOTE_VOLUME_TOP_TIER': 34602373781.2512,
#    'VOLUME_DIRECT': 112229.11063362,
#    'QUOTE_VOLUME_DIRECT': 10911197328.506,
#    'VOLUME_TOP_TIER_DIRECT': 91326.03819453,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 8881134376.39415},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732233600,
#    'OPEN': 98402.1949920443,
#    'HIGH': 99639.3382545678,
#    'LOW': 97187.432972889,
#    'CLOSE': 98943.4977548279,
#    'VOLUME': 434976.091216109,
#    'QUOTE_VOLUME': 42927517993.6963,
#    'VOLUME_TOP_TIER': 270578.362626669,
#    'QUOTE_VOLUME_TOP_TIER': 26699588187.7631,
#    'VOLUME_DIRECT': 90775.52969694,
#    'QUOTE_VOLUME_DIRECT': 8965112484.10139,
#    'VOLUME_TOP_TIER_DIRECT': 76161.66239902,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 7522541778.80796},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732320000,
#    'OPEN': 98943.4977548279,
#    'HIGH': 98944.034328803,
#    'LOW': 97209.5328863943,
#    'CLOSE': 97724.4950610056,
#    'VOLUME': 219905.659661735,
#    'QUOTE_VOLUME': 21612593286.6705,
#    'VOLUME_TOP_TIER': 128412.215127724,
#    'QUOTE_VOLUME_TOP_TIER': 12618480326.3567,
#    'VOLUME_DIRECT': 36143.34179036,
#    'QUOTE_VOLUME_DIRECT': 3553786543.76444,
#    'VOLUME_TOP_TIER_DIRECT': 29434.53333019,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2894576140.07837},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732406400,
#    'OPEN': 97724.4950610056,
#    'HIGH': 98605.730043346,
#    'LOW': 95780.2761065909,
#    'CLOSE': 97967.2951372954,
#    'VOLUME': 260559.195352845,
#    'QUOTE_VOLUME': 25349238358.0354,
#    'VOLUME_TOP_TIER': 157096.852978468,
#    'QUOTE_VOLUME_TOP_TIER': 15273967131.1022,
#    'VOLUME_DIRECT': 39928.41652037,
#    'QUOTE_VOLUME_DIRECT': 3880890859.42568,
#    'VOLUME_TOP_TIER_DIRECT': 30848.85633742,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2996771363.42239},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732492800,
#    'OPEN': 97967.2951372954,
#    'HIGH': 98877.9197437827,
#    'LOW': 92684.2619953663,
#    'CLOSE': 93025.1292956724,
#    'VOLUME': 431859.241774272,
#    'QUOTE_VOLUME': 41504948599.4465,
#    'VOLUME_TOP_TIER': 292826.559131232,
#    'QUOTE_VOLUME_TOP_TIER': 28116262573.4173,
#    'VOLUME_DIRECT': 82465.10311655,
#    'QUOTE_VOLUME_DIRECT': 7900245764.78174,
#    'VOLUME_TOP_TIER_DIRECT': 69781.58427115,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6679507703.93847},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732579200,
#    'OPEN': 93025.1292956724,
#    'HIGH': 95002.0885966689,
#    'LOW': 90799.7751550477,
#    'CLOSE': 91940.193000198,
#    'VOLUME': 486566.735382776,
#    'QUOTE_VOLUME': 45180721595.1262,
#    'VOLUME_TOP_TIER': 330670.526934969,
#    'QUOTE_VOLUME_TOP_TIER': 30699858060.5676,
#    'VOLUME_DIRECT': 93475.18780426,
#    'QUOTE_VOLUME_DIRECT': 8672889317.18463,
#    'VOLUME_TOP_TIER_DIRECT': 78691.43016803,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 7299188836.8373},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732665600,
#    'OPEN': 91940.193000198,
#    'HIGH': 97336.3587020162,
#    'LOW': 91780.4766726778,
#    'CLOSE': 95947.0830989849,
#    'VOLUME': 398260.872853311,
#    'QUOTE_VOLUME': 37673863820.9864,
#    'VOLUME_TOP_TIER': 234419.335610435,
#    'QUOTE_VOLUME_TOP_TIER': 22180109491.8091,
#    'VOLUME_DIRECT': 62872.68583454,
#    'QUOTE_VOLUME_DIRECT': 5962344387.68283,
#    'VOLUME_TOP_TIER_DIRECT': 48962.77411151,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4647209664.30852},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732752000,
#    'OPEN': 95947.0830989849,
#    'HIGH': 96643.1883917306,
#    'LOW': 94681.7421365357,
#    'CLOSE': 95666.2193195659,
#    'VOLUME': 279123.450365353,
#    'QUOTE_VOLUME': 26651739433.483,
#    'VOLUME_TOP_TIER': 154556.613792476,
#    'QUOTE_VOLUME_TOP_TIER': 14755333535.6971,
#    'VOLUME_DIRECT': 35162.73951167,
#    'QUOTE_VOLUME_DIRECT': 3356898771.88117,
#    'VOLUME_TOP_TIER_DIRECT': 24699.62422295,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2358230251.26969},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732838400,
#    'OPEN': 95666.2193195659,
#    'HIGH': 98693.2388446259,
#    'LOW': 95404.761788695,
#    'CLOSE': 97490.1520025695,
#    'VOLUME': 300723.544769699,
#    'QUOTE_VOLUME': 29199236173.7971,
#    'VOLUME_TOP_TIER': 175532.976460928,
#    'QUOTE_VOLUME_TOP_TIER': 17049735479.3155,
#    'VOLUME_DIRECT': 49969.98310538,
#    'QUOTE_VOLUME_DIRECT': 4861687875.31194,
#    'VOLUME_TOP_TIER_DIRECT': 40729.12997404,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3965357599.0536},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1732924800,
#    'OPEN': 97490.1520025695,
#    'HIGH': 97490.8043937339,
#    'LOW': 96145.6722461059,
#    'CLOSE': 96479.2439359753,
#    'VOLUME': 153386.821626767,
#    'QUOTE_VOLUME': 14839390323.9965,
#    'VOLUME_TOP_TIER': 84722.6619767123,
#    'QUOTE_VOLUME_TOP_TIER': 8196285797.27102,
#    'VOLUME_DIRECT': 18011.68666325,
#    'QUOTE_VOLUME_DIRECT': 1742533924.58171,
#    'VOLUME_TOP_TIER_DIRECT': 12697.90822209,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1228726483.4418},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733011200,
#    'OPEN': 96479.2439359753,
#    'HIGH': 97844.9691545753,
#    'LOW': 95789.931352868,
#    'CLOSE': 97240.3353955653,
#    'VOLUME': 183848.389669403,
#    'QUOTE_VOLUME': 17820627596.6557,
#    'VOLUME_TOP_TIER': 102299.745220943,
#    'QUOTE_VOLUME_TOP_TIER': 9916258013.83478,
#    'VOLUME_DIRECT': 23414.30556484,
#    'QUOTE_VOLUME_DIRECT': 2269723188.41113,
#    'VOLUME_TOP_TIER_DIRECT': 17333.53104788,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1680519209.03854},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733097600,
#    'OPEN': 97240.3353955653,
#    'HIGH': 98152.6880351147,
#    'LOW': 94526.7040304943,
#    'CLOSE': 95862.9439884694,
#    'VOLUME': 390919.635704981,
#    'QUOTE_VOLUME': 37560957351.814,
#    'VOLUME_TOP_TIER': 240041.499024408,
#    'QUOTE_VOLUME_TOP_TIER': 23065468684.8719,
#    'VOLUME_DIRECT': 62498.35388292,
#    'QUOTE_VOLUME_DIRECT': 6005148133.67993,
#    'VOLUME_TOP_TIER_DIRECT': 53707.56692293,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5160976556.85354},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733184000,
#    'OPEN': 95862.9439884694,
#    'HIGH': 96284.4749978801,
#    'LOW': 93688.7783942233,
#    'CLOSE': 95871.9335129261,
#    'VOLUME': 364999.981569621,
#    'QUOTE_VOLUME': 34794154341.2232,
#    'VOLUME_TOP_TIER': 217981.709367573,
#    'QUOTE_VOLUME_TOP_TIER': 20772044801.9754,
#    'VOLUME_DIRECT': 63014.97379029,
#    'QUOTE_VOLUME_DIRECT': 6010395347.46775,
#    'VOLUME_TOP_TIER_DIRECT': 53973.13043085,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5147144782.38023},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733270400,
#    'OPEN': 95871.9335129261,
#    'HIGH': 99177.5161838037,
#    'LOW': 94690.9338945262,
#    'CLOSE': 98734.3200545731,
#    'VOLUME': 438631.68841798,
#    'QUOTE_VOLUME': 42454708965.2337,
#    'VOLUME_TOP_TIER': 252191.39864331,
#    'QUOTE_VOLUME_TOP_TIER': 24414266948.3174,
#    'VOLUME_DIRECT': 71358.46029068,
#    'QUOTE_VOLUME_DIRECT': 6914450742.45144,
#    'VOLUME_TOP_TIER_DIRECT': 60922.67999608,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5904675007.41047},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733356800,
#    'OPEN': 98734.3200545731,
#    'HIGH': 103713.667072889,
#    'LOW': 93468.3399145307,
#    'CLOSE': 97050.027060881,
#    'VOLUME': 853862.849119906,
#    'QUOTE_VOLUME': 85955503865.1295,
#    'VOLUME_TOP_TIER': 497658.858857842,
#    'QUOTE_VOLUME_TOP_TIER': 50022258006.8094,
#    'VOLUME_DIRECT': 142755.20806224,
#    'QUOTE_VOLUME_DIRECT': 14356218298.8255,
#    'VOLUME_TOP_TIER_DIRECT': 122375.85672756,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 12293536050.975},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733443200,
#    'OPEN': 97050.027060881,
#    'HIGH': 102006.430175579,
#    'LOW': 96475.2097358183,
#    'CLOSE': 99866.4510373869,
#    'VOLUME': 680775.148988338,
#    'QUOTE_VOLUME': 67519116866.2171,
#    'VOLUME_TOP_TIER': 369562.130996997,
#    'QUOTE_VOLUME_TOP_TIER': 36671281131.8572,
#    'VOLUME_DIRECT': 72102.75462646,
#    'QUOTE_VOLUME_DIRECT': 7158974410.40959,
#    'VOLUME_TOP_TIER_DIRECT': 58136.69689764,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5777219083.80945},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733529600,
#    'OPEN': 99866.4510373869,
#    'HIGH': 100533.36537904,
#    'LOW': 99063.0738728127,
#    'CLOSE': 99921.2160409421,
#    'VOLUME': 265996.93214222,
#    'QUOTE_VOLUME': 26539614525.5782,
#    'VOLUME_TOP_TIER': 94546.7592982945,
#    'QUOTE_VOLUME_TOP_TIER': 9431952790.33444,
#    'VOLUME_DIRECT': 23377.14015482,
#    'QUOTE_VOLUME_DIRECT': 2333174347.42237,
#    'VOLUME_TOP_TIER_DIRECT': 17490.4546615,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1746425916.75409},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733616000,
#    'OPEN': 99921.2160409421,
#    'HIGH': 101375.618684987,
#    'LOW': 98768.1275538834,
#    'CLOSE': 101164.789500775,
#    'VOLUME': 269700.684689133,
#    'QUOTE_VOLUME': 26943607530.7203,
#    'VOLUME_TOP_TIER': 94759.0667528678,
#    'QUOTE_VOLUME_TOP_TIER': 9468773151.82132,
#    'VOLUME_DIRECT': 23736.59085363,
#    'QUOTE_VOLUME_DIRECT': 2373074065.74949,
#    'VOLUME_TOP_TIER_DIRECT': 18049.48160984,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1804827512.42868},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733702400,
#    'OPEN': 101164.789500775,
#    'HIGH': 101246.071997686,
#    'LOW': 94915.2173590384,
#    'CLOSE': 97406.9715880375,
#    'VOLUME': 705343.787243298,
#    'QUOTE_VOLUME': 69238069182.0378,
#    'VOLUME_TOP_TIER': 298904.484732016,
#    'QUOTE_VOLUME_TOP_TIER': 29288833202.4092,
#    'VOLUME_DIRECT': 83982.15326398,
#    'QUOTE_VOLUME_DIRECT': 8225520951.83647,
#    'VOLUME_TOP_TIER_DIRECT': 71295.32824235,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6976887358.56353},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733788800,
#    'OPEN': 97406.9715880375,
#    'HIGH': 98267.2163788997,
#    'LOW': 94334.3496925922,
#    'CLOSE': 96657.0407188012,
#    'VOLUME': 660407.437723984,
#    'QUOTE_VOLUME': 63840482230.305,
#    'VOLUME_TOP_TIER': 300516.928732513,
#    'QUOTE_VOLUME_TOP_TIER': 29012030516.4296,
#    'VOLUME_DIRECT': 81136.37648809,
#    'QUOTE_VOLUME_DIRECT': 7828918078.54689,
#    'VOLUME_TOP_TIER_DIRECT': 70333.00176016,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6783162153.42485},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733875200,
#    'OPEN': 96657.0407188012,
#    'HIGH': 101904.036375275,
#    'LOW': 95738.7160288452,
#    'CLOSE': 101169.668463919,
#    'VOLUME': 537052.852463069,
#    'QUOTE_VOLUME': 53268974413.9667,
#    'VOLUME_TOP_TIER': 224469.480603111,
#    'QUOTE_VOLUME_TOP_TIER': 22290124572.348,
#    'VOLUME_DIRECT': 67277.76205597,
#    'QUOTE_VOLUME_DIRECT': 6696566844.63716,
#    'VOLUME_TOP_TIER_DIRECT': 56327.60524508,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5609250782.52734},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1733961600,
#    'OPEN': 101169.668463919,
#    'HIGH': 102508.508795843,
#    'LOW': 99349.3764472432,
#    'CLOSE': 100028.919617953,
#    'VOLUME': 461069.063867661,
#    'QUOTE_VOLUME': 46511298395.5622,
#    'VOLUME_TOP_TIER': 207447.695715618,
#    'QUOTE_VOLUME_TOP_TIER': 20931129664.4115,
#    'VOLUME_DIRECT': 56436.69297024,
#    'QUOTE_VOLUME_DIRECT': 5696979811.11228,
#    'VOLUME_TOP_TIER_DIRECT': 48386.0154634,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4885045435.98421},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734048000,
#    'OPEN': 100028.919617953,
#    'HIGH': 101880.782062637,
#    'LOW': 99238.2950231363,
#    'CLOSE': 101446.437188656,
#    'VOLUME': 363103.843805038,
#    'QUOTE_VOLUME': 36530267256.6078,
#    'VOLUME_TOP_TIER': 154954.815666648,
#    'QUOTE_VOLUME_TOP_TIER': 15597126060.5204,
#    'VOLUME_DIRECT': 43003.41643534,
#    'QUOTE_VOLUME_DIRECT': 4333914533.82848,
#    'VOLUME_TOP_TIER_DIRECT': 35663.57607721,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3595208198.93417},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734134400,
#    'OPEN': 101446.437188656,
#    'HIGH': 102620.103495946,
#    'LOW': 100622.654450547,
#    'CLOSE': 101400.839850663,
#    'VOLUME': 249690.231004717,
#    'QUOTE_VOLUME': 25350638514.923,
#    'VOLUME_TOP_TIER': 95360.6707534155,
#    'QUOTE_VOLUME_TOP_TIER': 9684041845.82956,
#    'VOLUME_DIRECT': 22033.24998221,
#    'QUOTE_VOLUME_DIRECT': 2237872189.47279,
#    'VOLUME_TOP_TIER_DIRECT': 16906.77007022,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1717139019.60595},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734220800,
#    'OPEN': 101400.839850663,
#    'HIGH': 105017.711899901,
#    'LOW': 101229.961786872,
#    'CLOSE': 104389.474858669,
#    'VOLUME': 296809.242070003,
#    'QUOTE_VOLUME': 30528796220.9553,
#    'VOLUME_TOP_TIER': 123374.949093023,
#    'QUOTE_VOLUME_TOP_TIER': 12705432502.3239,
#    'VOLUME_DIRECT': 32785.52617467,
#    'QUOTE_VOLUME_DIRECT': 3379357888.17528,
#    'VOLUME_TOP_TIER_DIRECT': 25267.77214519,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2606286414.11833},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734307200,
#    'OPEN': 104389.474858669,
#    'HIGH': 107778.433989127,
#    'LOW': 103349.102019496,
#    'CLOSE': 106079.090411121,
#    'VOLUME': 528048.394267647,
#    'QUOTE_VOLUME': 55755887277.7364,
#    'VOLUME_TOP_TIER': 239527.02736922,
#    'QUOTE_VOLUME_TOP_TIER': 25316545755.1105,
#    'VOLUME_DIRECT': 73611.24047837,
#    'QUOTE_VOLUME_DIRECT': 7788845862.16529,
#    'VOLUME_TOP_TIER_DIRECT': 61616.0998305,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 6522918403.04826},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734393600,
#    'OPEN': 106079.090411121,
#    'HIGH': 108266.707517594,
#    'LOW': 105395.742955253,
#    'CLOSE': 106168.858284328,
#    'VOLUME': 389520.134215259,
#    'QUOTE_VOLUME': 41595223499.0026,
#    'VOLUME_TOP_TIER': 187583.629470135,
#    'QUOTE_VOLUME_TOP_TIER': 20032375062.2526,
#    'VOLUME_DIRECT': 49272.45986934,
#    'QUOTE_VOLUME_DIRECT': 5261709424.37329,
#    'VOLUME_TOP_TIER_DIRECT': 41837.41202505,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4467808636.03112},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734480000,
#    'OPEN': 106168.858284328,
#    'HIGH': 106498.308435072,
#    'LOW': 100052.350506188,
#    'CLOSE': 100187.26575458,
#    'VOLUME': 555456.007380732,
#    'QUOTE_VOLUME': 57458110210.164,
#    'VOLUME_TOP_TIER': 311424.935859884,
#    'QUOTE_VOLUME_TOP_TIER': 32155057902.834,
#    'VOLUME_DIRECT': 86584.63763417,
#    'QUOTE_VOLUME_DIRECT': 8917231543.24354,
#    'VOLUME_TOP_TIER_DIRECT': 76698.32192777,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 7893631767.28491},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734566400,
#    'OPEN': 100187.26575458,
#    'HIGH': 102780.741548511,
#    'LOW': 95633.8465368784,
#    'CLOSE': 97472.6550452805,
#    'VOLUME': 596072.32231823,
#    'QUOTE_VOLUME': 59310291022.9078,
#    'VOLUME_TOP_TIER': 345812.806751006,
#    'QUOTE_VOLUME_TOP_TIER': 34325655224.9037,
#    'VOLUME_DIRECT': 94102.60786173,
#    'QUOTE_VOLUME_DIRECT': 9320795307.56019,
#    'VOLUME_TOP_TIER_DIRECT': 82852.80350391,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 8197951081.39118},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734652800,
#    'OPEN': 97472.6550452805,
#    'HIGH': 98133.7617107355,
#    'LOW': 92263.6027950042,
#    'CLOSE': 97868.8217768341,
#    'VOLUME': 655726.780604918,
#    'QUOTE_VOLUME': 62940682628.9479,
#    'VOLUME_TOP_TIER': 372826.676973407,
#    'QUOTE_VOLUME_TOP_TIER': 35750114674.8132,
#    'VOLUME_DIRECT': 98347.52945144,
#    'QUOTE_VOLUME_DIRECT': 9426613721.91614,
#    'VOLUME_TOP_TIER_DIRECT': 86769.78533984,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 8314446050.05637},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734739200,
#    'OPEN': 97868.8217768341,
#    'HIGH': 99581.0300283164,
#    'LOW': 96491.8897813078,
#    'CLOSE': 97234.4605283882,
#    'VOLUME': 321770.605732535,
#    'QUOTE_VOLUME': 31438215239.6994,
#    'VOLUME_TOP_TIER': 148315.242792255,
#    'QUOTE_VOLUME_TOP_TIER': 14491315958.032,
#    'VOLUME_DIRECT': 36092.5424673,
#    'QUOTE_VOLUME_DIRECT': 3523219668.04012,
#    'VOLUME_TOP_TIER_DIRECT': 30127.78974613,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2939617694.88296},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734825600,
#    'OPEN': 97234.4605283882,
#    'HIGH': 97381.7331501215,
#    'LOW': 94228.1268303623,
#    'CLOSE': 95112.7522534299,
#    'VOLUME': 277949.718188278,
#    'QUOTE_VOLUME': 26691622766.2663,
#    'VOLUME_TOP_TIER': 135203.166958794,
#    'QUOTE_VOLUME_TOP_TIER': 12973607563.8026,
#    'VOLUME_DIRECT': 35014.56844742,
#    'QUOTE_VOLUME_DIRECT': 3356303982.3294,
#    'VOLUME_TOP_TIER_DIRECT': 29949.29945786,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2869827409.51023},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734912000,
#    'OPEN': 95112.7522534299,
#    'HIGH': 96464.1028668923,
#    'LOW': 92475.9774987538,
#    'CLOSE': 94812.1850603651,
#    'VOLUME': 430316.998821292,
#    'QUOTE_VOLUME': 40625895882.7179,
#    'VOLUME_TOP_TIER': 237353.396655926,
#    'QUOTE_VOLUME_TOP_TIER': 22387153185.9684,
#    'VOLUME_DIRECT': 68067.54212866,
#    'QUOTE_VOLUME_DIRECT': 6407205280.16846,
#    'VOLUME_TOP_TIER_DIRECT': 59337.27953996,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5581926220.27687},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1734998400,
#    'OPEN': 94812.1850603651,
#    'HIGH': 99443.9037446732,
#    'LOW': 93498.5336163978,
#    'CLOSE': 98646.2398597345,
#    'VOLUME': 288729.79565812,
#    'QUOTE_VOLUME': 27821492457.1204,
#    'VOLUME_TOP_TIER': 177729.342930183,
#    'QUOTE_VOLUME_TOP_TIER': 17169177659.6201,
#    'VOLUME_DIRECT': 48424.12259918,
#    'QUOTE_VOLUME_DIRECT': 4690269357.2038,
#    'VOLUME_TOP_TIER_DIRECT': 42183.26068599,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4087053874.03982},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735084800,
#    'OPEN': 98646.2398597345,
#    'HIGH': 99517.2078790577,
#    'LOW': 97671.9997509019,
#    'CLOSE': 99390.0555088638,
#    'VOLUME': 197189.077589724,
#    'QUOTE_VOLUME': 19424122254.6578,
#    'VOLUME_TOP_TIER': 116716.177178235,
#    'QUOTE_VOLUME_TOP_TIER': 11497141633.8213,
#    'VOLUME_DIRECT': 26137.57177034,
#    'QUOTE_VOLUME_DIRECT': 2574432974.62787,
#    'VOLUME_TOP_TIER_DIRECT': 22160.89678082,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2182455694.71303},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735171200,
#    'OPEN': 99390.0555088638,
#    'HIGH': 99923.3439217042,
#    'LOW': 95169.2240138869,
#    'CLOSE': 95736.3243416497,
#    'VOLUME': 283769.442860161,
#    'QUOTE_VOLUME': 27404917490.0914,
#    'VOLUME_TOP_TIER': 167930.48055161,
#    'QUOTE_VOLUME_TOP_TIER': 16212135699.4989,
#    'VOLUME_DIRECT': 45688.01522737,
#    'QUOTE_VOLUME_DIRECT': 4404660434.80141,
#    'VOLUME_TOP_TIER_DIRECT': 40031.05358544,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3857372865.95822},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735257600,
#    'OPEN': 95736.3243416497,
#    'HIGH': 97199.8198313911,
#    'LOW': 93393.6349617642,
#    'CLOSE': 94209.4541683634,
#    'VOLUME': 318470.000605941,
#    'QUOTE_VOLUME': 30355206094.0039,
#    'VOLUME_TOP_TIER': 188697.386932101,
#    'QUOTE_VOLUME_TOP_TIER': 17972767077.5391,
#    'VOLUME_DIRECT': 55750.76343563,
#    'QUOTE_VOLUME_DIRECT': 5299965650.16827,
#    'VOLUME_TOP_TIER_DIRECT': 48996.4762138,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4655398465.44482},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735344000,
#    'OPEN': 94209.4541683634,
#    'HIGH': 95515.1802753732,
#    'LOW': 94048.4897973533,
#    'CLOSE': 95157.2883658672,
#    'VOLUME': 138112.743011363,
#    'QUOTE_VOLUME': 13070453428.8946,
#    'VOLUME_TOP_TIER': 73795.4718440228,
#    'QUOTE_VOLUME_TOP_TIER': 6984277062.18372,
#    'VOLUME_DIRECT': 16738.81617501,
#    'QUOTE_VOLUME_DIRECT': 1584236568.88164,
#    'VOLUME_TOP_TIER_DIRECT': 14385.71100554,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1361147515.36817},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735430400,
#    'OPEN': 95157.2883658672,
#    'HIGH': 95186.1179484234,
#    'LOW': 92919.1020467299,
#    'CLOSE': 93615.04302023,
#    'VOLUME': 172671.240735563,
#    'QUOTE_VOLUME': 16254412554.5803,
#    'VOLUME_TOP_TIER': 94416.1376201723,
#    'QUOTE_VOLUME_TOP_TIER': 8883044288.96566,
#    'VOLUME_DIRECT': 21888.31968393,
#    'QUOTE_VOLUME_DIRECT': 2057795114.71392,
#    'VOLUME_TOP_TIER_DIRECT': 18212.51966187,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1711439161.42153},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735516800,
#    'OPEN': 93615.04302023,
#    'HIGH': 94923.5931730324,
#    'LOW': 91374.9607524214,
#    'CLOSE': 92671.5245019799,
#    'VOLUME': 378011.14933075,
#    'QUOTE_VOLUME': 35198880042.1904,
#    'VOLUME_TOP_TIER': 221294.052886983,
#    'QUOTE_VOLUME_TOP_TIER': 20601034109.144,
#    'VOLUME_DIRECT': 65218.0047861,
#    'QUOTE_VOLUME_DIRECT': 6067656774.97316,
#    'VOLUME_TOP_TIER_DIRECT': 58262.26418799,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 5419258623.39421},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735603200,
#    'OPEN': 92671.5245019799,
#    'HIGH': 96133.5486794865,
#    'LOW': 91932.8732527472,
#    'CLOSE': 93441.6983892194,
#    'VOLUME': 284228.313447607,
#    'QUOTE_VOLUME': 26711551882.5478,
#    'VOLUME_TOP_TIER': 164825.411663487,
#    'QUOTE_VOLUME_TOP_TIER': 15503401175.409,
#    'VOLUME_DIRECT': 45497.12849513,
#    'QUOTE_VOLUME_DIRECT': 4281170710.56407,
#    'VOLUME_TOP_TIER_DIRECT': 40317.30276531,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3793662951.0065},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735689600,
#    'OPEN': 93441.6983892194,
#    'HIGH': 94979.0979452426,
#    'LOW': 92848.1136284567,
#    'CLOSE': 94451.9403687362,
#    'VOLUME': 152845.673685992,
#    'QUOTE_VOLUME': 14353936248.2457,
#    'VOLUME_TOP_TIER': 84097.4349950047,
#    'QUOTE_VOLUME_TOP_TIER': 7898309557.37268,
#    'VOLUME_DIRECT': 20942.81423996,
#    'QUOTE_VOLUME_DIRECT': 1966553883.74378,
#    'VOLUME_TOP_TIER_DIRECT': 19736.11110354,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1852863695.24573},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735776000,
#    'OPEN': 94451.9403687362,
#    'HIGH': 97755.6136668064,
#    'LOW': 94260.086766928,
#    'CLOSE': 96919.3484077694,
#    'VOLUME': 288813.824744512,
#    'QUOTE_VOLUME': 27832622662.4158,
#    'VOLUME_TOP_TIER': 172911.794885292,
#    'QUOTE_VOLUME_TOP_TIER': 16670340080.9989,
#    'VOLUME_DIRECT': 44997.15235083,
#    'QUOTE_VOLUME_DIRECT': 4341531067.57958,
#    'VOLUME_TOP_TIER_DIRECT': 39297.38448295,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 3791784502.70658},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735862400,
#    'OPEN': 96919.3484077694,
#    'HIGH': 98944.6015893314,
#    'LOW': 96044.9817768415,
#    'CLOSE': 98141.0286082368,
#    'VOLUME': 222855.456509767,
#    'QUOTE_VOLUME': 21706556722.9287,
#    'VOLUME_TOP_TIER': 130130.00048246,
#    'QUOTE_VOLUME_TOP_TIER': 12681618238.1178,
#    'VOLUME_DIRECT': 33224.81555943,
#    'QUOTE_VOLUME_DIRECT': 3240994512.65588,
#    'VOLUME_TOP_TIER_DIRECT': 29229.67377284,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2851623195.011},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1735948800,
# ...
#    'VOLUME_DIRECT': 13780.57259253,
#    'QUOTE_VOLUME_DIRECT': 1315218176.16707,
#    'VOLUME_TOP_TIER_DIRECT': 11125.5332682,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1061709667.67747},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746403200,
#    'OPEN': 94478.6878332568,
#    'HIGH': 95321.3869119287,
#    'LOW': 93818.7132889248,
#    'CLOSE': 94862.0086638579,
#    'VOLUME': 174268.587189472,
#    'QUOTE_VOLUME': 16467859092.0838,
#    'VOLUME_TOP_TIER': 92973.940821454,
#    'QUOTE_VOLUME_TOP_TIER': 8782986103.02535,
#    'VOLUME_DIRECT': 22151.63188827,
#    'QUOTE_VOLUME_DIRECT': 2089077080.61768,
#    'VOLUME_TOP_TIER_DIRECT': 18067.6515694,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1703815456.18944},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746489600,
#    'OPEN': 94862.0086638579,
#    'HIGH': 96943.8284636517,
#    'LOW': 93460.7152709229,
#    'CLOSE': 96866.2202845,
#    'VOLUME': 173642.623254888,
#    'QUOTE_VOLUME': 16450680524.8003,
#    'VOLUME_TOP_TIER': 96055.90766371,
#    'QUOTE_VOLUME_TOP_TIER': 9102303891.8992,
#    'VOLUME_DIRECT': 22784.56150312,
#    'QUOTE_VOLUME_DIRECT': 2157436860.46694,
#    'VOLUME_TOP_TIER_DIRECT': 18978.82412861,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1796990613.02405},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746576000,
#    'OPEN': 96866.2202845,
#    'HIGH': 97708.0555103223,
#    'LOW': 95848.2644735249,
#    'CLOSE': 97073.3755116741,
#    'VOLUME': 182380.131449399,
#    'QUOTE_VOLUME': 17664205916.1507,
#    'VOLUME_TOP_TIER': 96504.8167209236,
#    'QUOTE_VOLUME_TOP_TIER': 9345806545.22967,
#    'VOLUME_DIRECT': 24380.49234397,
#    'QUOTE_VOLUME_DIRECT': 2360429537.82949,
#    'VOLUME_TOP_TIER_DIRECT': 20481.54322928,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1982805437.97878},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746662400,
#    'OPEN': 97073.3755116741,
#    'HIGH': 103765.101628915,
#    'LOW': 96938.1820369386,
#    'CLOSE': 103264.778625663,
#    'VOLUME': 338904.324908567,
#    'QUOTE_VOLUME': 34035599539.3945,
#    'VOLUME_TOP_TIER': 193446.466396149,
#    'QUOTE_VOLUME_TOP_TIER': 19447973057.6842,
#    'VOLUME_DIRECT': 48869.54769389,
#    'QUOTE_VOLUME_DIRECT': 4915117377.35078,
#    'VOLUME_TOP_TIER_DIRECT': 41515.00863623,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4177233852.16844},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746748800,
#    'OPEN': 103264.778625663,
#    'HIGH': 104266.41492874,
#    'LOW': 102361.032397427,
#    'CLOSE': 102981.796358804,
#    'VOLUME': 255001.821879362,
#    'QUOTE_VOLUME': 26282671361.5572,
#    'VOLUME_TOP_TIER': 134826.396549143,
#    'QUOTE_VOLUME_TOP_TIER': 13896013288.3775,
#    'VOLUME_DIRECT': 29110.73104291,
#    'QUOTE_VOLUME_DIRECT': 3000310769.38511,
#    'VOLUME_TOP_TIER_DIRECT': 23272.91685195,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2398414152.87628},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746835200,
#    'OPEN': 102981.796358804,
#    'HIGH': 104899.035355261,
#    'LOW': 102843.308377896,
#    'CLOSE': 104783.621919911,
#    'VOLUME': 139260.08447705,
#    'QUOTE_VOLUME': 14425355337.7847,
#    'VOLUME_TOP_TIER': 64642.1036273338,
#    'QUOTE_VOLUME_TOP_TIER': 6697834682.71817,
#    'VOLUME_DIRECT': 12772.95850121,
#    'QUOTE_VOLUME_DIRECT': 1323899876.237,
#    'VOLUME_TOP_TIER_DIRECT': 9318.91966756,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 965969335.331447},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1746921600,
#    'OPEN': 104783.621919911,
#    'HIGH': 104926.844151172,
#    'LOW': 103361.440427744,
#    'CLOSE': 104139.253887922,
#    'VOLUME': 164292.606383846,
#    'QUOTE_VOLUME': 17113381847.3516,
#    'VOLUME_TOP_TIER': 79056.4773988555,
#    'QUOTE_VOLUME_TOP_TIER': 8234878200.9289,
#    'VOLUME_DIRECT': 15403.48008487,
#    'QUOTE_VOLUME_DIRECT': 1604850827.21986,
#    'VOLUME_TOP_TIER_DIRECT': 11183.75241671,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1165266769.61432},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747008000,
#    'OPEN': 104139.253887922,
#    'HIGH': 105638.069433991,
#    'LOW': 100876.743667623,
#    'CLOSE': 102801.528591045,
#    'VOLUME': 278866.720766263,
#    'QUOTE_VOLUME': 28883425097.4572,
#    'VOLUME_TOP_TIER': 151692.157050031,
#    'QUOTE_VOLUME_TOP_TIER': 15705468378.9616,
#    'VOLUME_DIRECT': 34530.45227858,
#    'QUOTE_VOLUME_DIRECT': 3572410397.35139,
#    'VOLUME_TOP_TIER_DIRECT': 28395.57804377,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2936453123.60731},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747094400,
#    'OPEN': 102801.528591045,
#    'HIGH': 104972.901637968,
#    'LOW': 101483.838702781,
#    'CLOSE': 104119.197357816,
#    'VOLUME': 217821.58743646,
#    'QUOTE_VOLUME': 22523287996.7243,
#    'VOLUME_TOP_TIER': 108306.608587146,
#    'QUOTE_VOLUME_TOP_TIER': 11201834786.0701,
#    'VOLUME_DIRECT': 25902.9968974,
#    'QUOTE_VOLUME_DIRECT': 2682767951.19714,
#    'VOLUME_TOP_TIER_DIRECT': 20963.95542769,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2172031189.81358},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747180800,
#    'OPEN': 104119.197357816,
#    'HIGH': 104324.918562028,
#    'LOW': 102643.002875117,
#    'CLOSE': 103525.737928456,
#    'VOLUME': 175852.917185274,
#    'QUOTE_VOLUME': 18216814795.7288,
#    'VOLUME_TOP_TIER': 90595.8533222871,
#    'QUOTE_VOLUME_TOP_TIER': 9382515603.46129,
#    'VOLUME_DIRECT': 20746.79392432,
#    'QUOTE_VOLUME_DIRECT': 2148749355.21486,
#    'VOLUME_TOP_TIER_DIRECT': 16920.80482653,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1752259468.1626},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747267200,
#    'OPEN': 103525.737928456,
#    'HIGH': 104181.3370969,
#    'LOW': 101471.099793643,
#    'CLOSE': 103789.638422078,
#    'VOLUME': 203139.658619083,
#    'QUOTE_VOLUME': 20888950760.0391,
#    'VOLUME_TOP_TIER': 103041.635247607,
#    'QUOTE_VOLUME_TOP_TIER': 10594148261.7264,
#    'VOLUME_DIRECT': 22391.66626377,
#    'QUOTE_VOLUME_DIRECT': 2303018778.58684,
#    'VOLUME_TOP_TIER_DIRECT': 18288.28379181,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1881042527.36589},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747353600,
#    'OPEN': 103789.638422078,
#    'HIGH': 104567.242638633,
#    'LOW': 103162.146455743,
#    'CLOSE': 103511.805578656,
#    'VOLUME': 163865.168701458,
#    'QUOTE_VOLUME': 17022784480.1035,
#    'VOLUME_TOP_TIER': 83820.1255608438,
#    'QUOTE_VOLUME_TOP_TIER': 8708325287.64097,
#    'VOLUME_DIRECT': 18529.56507928,
#    'QUOTE_VOLUME_DIRECT': 1925038645.11139,
#    'VOLUME_TOP_TIER_DIRECT': 14847.28945489,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1542563619.2518},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747440000,
#    'OPEN': 103511.805578656,
#    'HIGH': 103744.692387111,
#    'LOW': 102677.702653236,
#    'CLOSE': 103154.345299531,
#    'VOLUME': 116572.309605509,
#    'QUOTE_VOLUME': 12027867232.0656,
#    'VOLUME_TOP_TIER': 51672.9492442432,
#    'QUOTE_VOLUME_TOP_TIER': 5331520913.84691,
#    'VOLUME_DIRECT': 8649.42009543,
#    'QUOTE_VOLUME_DIRECT': 892223276.594449,
#    'VOLUME_TOP_TIER_DIRECT': 6035.93123341,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 622605079.958466},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747526400,
#    'OPEN': 103154.345299531,
#    'HIGH': 106634.57061978,
#    'LOW': 103145.239142946,
#    'CLOSE': 106505.0154357,
#    'VOLUME': 178608.372460785,
#    'QUOTE_VOLUME': 18694877952.6371,
#    'VOLUME_TOP_TIER': 87899.6875854209,
#    'QUOTE_VOLUME_TOP_TIER': 9205380720.71823,
#    'VOLUME_DIRECT': 18191.45852446,
#    'QUOTE_VOLUME_DIRECT': 1906404778.5118,
#    'VOLUME_TOP_TIER_DIRECT': 13315.17403317,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1395403822.803},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747612800,
#    'OPEN': 106505.0154357,
#    'HIGH': 107058.090336459,
#    'LOW': 102141.715368668,
#    'CLOSE': 105604.642906113,
#    'VOLUME': 273240.194094944,
#    'QUOTE_VOLUME': 28469115058.0882,
#    'VOLUME_TOP_TIER': 140693.258925849,
#    'QUOTE_VOLUME_TOP_TIER': 14665010523.3875,
#    'VOLUME_DIRECT': 31480.52138703,
#    'QUOTE_VOLUME_DIRECT': 3284954399.46239,
#    'VOLUME_TOP_TIER_DIRECT': 24326.30457689,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2539902369.63981},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747699200,
#    'OPEN': 105604.642906113,
#    'HIGH': 107306.994693904,
#    'LOW': 104221.945237207,
#    'CLOSE': 106869.555658958,
#    'VOLUME': 229592.514653948,
#    'QUOTE_VOLUME': 24303560073.4184,
#    'VOLUME_TOP_TIER': 117141.267307617,
#    'QUOTE_VOLUME_TOP_TIER': 12404335130.143,
#    'VOLUME_DIRECT': 25697.94468012,
#    'QUOTE_VOLUME_DIRECT': 2722463907.17696,
#    'VOLUME_TOP_TIER_DIRECT': 19999.53092403,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2119215541.38854},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747785600,
#    'OPEN': 106869.555658958,
#    'HIGH': 110682.242526308,
#    'LOW': 106152.486018174,
#    'CLOSE': 109686.515398019,
#    'VOLUME': 370153.662892409,
#    'QUOTE_VOLUME': 39930337746.676,
#    'VOLUME_TOP_TIER': 204536.969153595,
#    'QUOTE_VOLUME_TOP_TIER': 22074746046.6181,
#    'VOLUME_DIRECT': 49016.3127832,
#    'QUOTE_VOLUME_DIRECT': 5293330879.62344,
#    'VOLUME_TOP_TIER_DIRECT': 39417.52322308,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 4257352064.43404},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747872000,
#    'OPEN': 109686.515398019,
#    'HIGH': 111960.503547811,
#    'LOW': 109309.133851695,
#    'CLOSE': 111695.395495789,
#    'VOLUME': 289605.923147551,
#    'QUOTE_VOLUME': 32146737342.597,
#    'VOLUME_TOP_TIER': 146947.58314193,
#    'QUOTE_VOLUME_TOP_TIER': 16312899400.5591,
#    'VOLUME_DIRECT': 33686.72205177,
#    'QUOTE_VOLUME_DIRECT': 3740670564.72236,
#    'VOLUME_TOP_TIER_DIRECT': 26236.71633869,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2914020449.33877},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1747958400,
#    'OPEN': 111695.395495789,
#    'HIGH': 111768.216390219,
#    'LOW': 106875.221354395,
#    'CLOSE': 107355.200436426,
#    'VOLUME': 277454.099880957,
#    'QUOTE_VOLUME': 30384177590.0337,
#    'VOLUME_TOP_TIER': 149776.912523808,
#    'QUOTE_VOLUME_TOP_TIER': 16384023810.295,
#    'VOLUME_DIRECT': 32800.6205527,
#    'QUOTE_VOLUME_DIRECT': 3585877097.6055,
#    'VOLUME_TOP_TIER_DIRECT': 26236.57897217,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2867507131.21707},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748044800,
#    'OPEN': 107355.200436426,
#    'HIGH': 109531.501000777,
#    'LOW': 106947.030288999,
#    'CLOSE': 107679.52734887,
#    'VOLUME': 148320.254721078,
#    'QUOTE_VOLUME': 16081064645.3242,
#    'VOLUME_TOP_TIER': 68573.684151564,
#    'QUOTE_VOLUME_TOP_TIER': 7432581763.74055,
#    'VOLUME_DIRECT': 13190.09343457,
#    'QUOTE_VOLUME_DIRECT': 1429223598.67822,
#    'VOLUME_TOP_TIER_DIRECT': 9189.90999559,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 995383458.926782},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748131200,
#    'OPEN': 107679.52734887,
#    'HIGH': 109287.388282741,
#    'LOW': 106625.841979859,
#    'CLOSE': 109005.415876225,
#    'VOLUME': 158583.432708853,
#    'QUOTE_VOLUME': 17054300722.9139,
#    'VOLUME_TOP_TIER': 77667.1317383037,
#    'QUOTE_VOLUME_TOP_TIER': 8354869731.82669,
#    'VOLUME_DIRECT': 14418.20245961,
#    'QUOTE_VOLUME_DIRECT': 1552456285.6605,
#    'VOLUME_TOP_TIER_DIRECT': 10251.96235225,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1104358962.9613},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748217600,
#    'OPEN': 109005.415876225,
#    'HIGH': 110438.102472575,
#    'LOW': 108703.976657596,
#    'CLOSE': 109483.495424922,
#    'VOLUME': 159508.508959346,
#    'QUOTE_VOLUME': 17483705111.6127,
#    'VOLUME_TOP_TIER': 85847.661555881,
#    'QUOTE_VOLUME_TOP_TIER': 9409239466.0317,
#    'VOLUME_DIRECT': 18025.95616135,
#    'QUOTE_VOLUME_DIRECT': 1975798739.89569,
#    'VOLUME_TOP_TIER_DIRECT': 14536.77702281,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1593329075.59235},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748304000,
#    'OPEN': 109483.495424922,
#    'HIGH': 110744.512010695,
#    'LOW': 107604.040287938,
#    'CLOSE': 108968.503052516,
#    'VOLUME': 217230.239084136,
#    'QUOTE_VOLUME': 23783153378.4607,
#    'VOLUME_TOP_TIER': 123548.446866439,
#    'QUOTE_VOLUME_TOP_TIER': 13528449913.2682,
#    'VOLUME_DIRECT': 28650.12010807,
#    'QUOTE_VOLUME_DIRECT': 3139754438.64334,
#    'VOLUME_TOP_TIER_DIRECT': 23719.12878038,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2600178531.85148},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748390400,
#    'OPEN': 108968.503052516,
#    'HIGH': 109290.046934971,
#    'LOW': 106834.230235048,
#    'CLOSE': 107818.812865523,
#    'VOLUME': 170468.096240946,
#    'QUOTE_VOLUME': 18433781299.6642,
#    'VOLUME_TOP_TIER': 93538.7606004859,
#    'QUOTE_VOLUME_TOP_TIER': 10111653324.3973,
#    'VOLUME_DIRECT': 22996.29168085,
#    'QUOTE_VOLUME_DIRECT': 2484408889.91076,
#    'VOLUME_TOP_TIER_DIRECT': 19236.15219919,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2078058330.85206},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748476800,
#    'OPEN': 107818.812865523,
#    'HIGH': 108927.254127896,
#    'LOW': 105408.536787501,
#    'CLOSE': 105609.901855557,
#    'VOLUME': 229055.186725995,
#    'QUOTE_VOLUME': 24585844717.4459,
#    'VOLUME_TOP_TIER': 132517.258685982,
#    'QUOTE_VOLUME_TOP_TIER': 14215569548.3801,
#    'VOLUME_DIRECT': 29923.86699464,
#    'QUOTE_VOLUME_DIRECT': 3205911501.77055,
#    'VOLUME_TOP_TIER_DIRECT': 25254.44039686,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2704707768.69438},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748563200,
#    'OPEN': 105609.901855557,
#    'HIGH': 106345.864964101,
#    'LOW': 103705.313630095,
#    'CLOSE': 104041.544897185,
#    'VOLUME': 240851.334156804,
#    'QUOTE_VOLUME': 25342705763.6738,
#    'VOLUME_TOP_TIER': 130757.497695215,
#    'QUOTE_VOLUME_TOP_TIER': 13753202798.7948,
#    'VOLUME_DIRECT': 29540.64045342,
#    'QUOTE_VOLUME_DIRECT': 3104571899.7912,
#    'VOLUME_TOP_TIER_DIRECT': 24281.39242363,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2551259677.5789},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748649600,
#    'OPEN': 104041.544897185,
#    'HIGH': 104926.600815016,
#    'LOW': 103156.40517335,
#    'CLOSE': 104627.888470108,
#    'VOLUME': 122770.865184851,
#    'QUOTE_VOLUME': 12775877360.1041,
#    'VOLUME_TOP_TIER': 60396.9404431796,
#    'QUOTE_VOLUME_TOP_TIER': 6285418197.72683,
#    'VOLUME_DIRECT': 11520.47940411,
#    'QUOTE_VOLUME_DIRECT': 1198852937.81676,
#    'VOLUME_TOP_TIER_DIRECT': 8914.15258613,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 927738575.850016},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748736000,
#    'OPEN': 104627.888470108,
#    'HIGH': 105884.016456929,
#    'LOW': 103811.7763836,
#    'CLOSE': 105674.332934938,
#    'VOLUME': 100791.381971296,
#    'QUOTE_VOLUME': 10550985228.4996,
#    'VOLUME_TOP_TIER': 51369.6185423724,
#    'QUOTE_VOLUME_TOP_TIER': 5377401103.39489,
#    'VOLUME_DIRECT': 10088.70340412,
#    'QUOTE_VOLUME_DIRECT': 1057182506.22111,
#    'VOLUME_TOP_TIER_DIRECT': 7795.78573275,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 817162877.562845},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748822400,
#    'OPEN': 105674.332934938,
#    'HIGH': 105987.941670626,
#    'LOW': 103748.484642856,
#    'CLOSE': 105910.305712728,
#    'VOLUME': 164482.200932084,
#    'QUOTE_VOLUME': 17233101942.5303,
#    'VOLUME_TOP_TIER': 93015.1820388473,
#    'QUOTE_VOLUME_TOP_TIER': 9742724715.71236,
#    'VOLUME_DIRECT': 18857.22098712,
#    'QUOTE_VOLUME_DIRECT': 1974945141.75941,
#    'VOLUME_TOP_TIER_DIRECT': 15664.20407467,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1640499593.85822},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748908800,
#    'OPEN': 105910.305712728,
#    'HIGH': 106839.767296522,
#    'LOW': 104942.487873616,
#    'CLOSE': 105443.377497846,
#    'VOLUME': 161757.900295597,
#    'QUOTE_VOLUME': 17123164828.6954,
#    'VOLUME_TOP_TIER': 87198.2131963963,
#    'QUOTE_VOLUME_TOP_TIER': 9234133116.78789,
#    'VOLUME_DIRECT': 19228.75175966,
#    'QUOTE_VOLUME_DIRECT': 2036636549.7162,
#    'VOLUME_TOP_TIER_DIRECT': 16064.56731332,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1701900918.59803},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1748995200,
#    'OPEN': 105443.377497846,
#    'HIGH': 106036.16345245,
#    'LOW': 104269.244471979,
#    'CLOSE': 104729.848933543,
#    'VOLUME': 159918.206914073,
#    'QUOTE_VOLUME': 16832695204.4505,
#    'VOLUME_TOP_TIER': 79922.1343374266,
#    'QUOTE_VOLUME_TOP_TIER': 8409889732.28188,
#    'VOLUME_DIRECT': 16406.71158009,
#    'QUOTE_VOLUME_DIRECT': 1725468040.80811,
#    'VOLUME_TOP_TIER_DIRECT': 13060.59173253,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 1373281095.96196},
#   {'UNIT': 'DAY',
#    'TIMESTAMP': 1749081600,
#    'OPEN': 104729.848933543,
#    'HIGH': 105961.673176329,
#    'LOW': 100548.945911112,
#    'CLOSE': 101673.351608268,
#    'VOLUME': 223939.121413658,
#    'QUOTE_VOLUME': 23189055220.3945,
#    'VOLUME_TOP_TIER': 133259.427285906,
#    'QUOTE_VOLUME_TOP_TIER': 13786289675.0897,
#    'VOLUME_DIRECT': 30624.70338426,
#    'QUOTE_VOLUME_DIRECT': 3163868619.86717,
#    'VOLUME_TOP_TIER_DIRECT': 26361.59330064,
#    'QUOTE_VOLUME_TOP_TIER_DIRECT': 2722497992.36198}],
#  'Err': {}}

# %%
def parse_coindesk_response_to_dataframe(json_response: dict) -> pd.DataFrame | None:
    """
    Converte a resposta JSON da CoinDesk em um DataFrame do Pandas.

    Args:
        json_response (dict): A resposta JSON da função fetch_coindesk_ohlcv.

    Returns:
        pd.DataFrame | None: Um DataFrame com colunas 'timestamp', 'open', 'high', 'low', 'close', 'volume'
                              e 'timestamp' como índice, ou None se a entrada for inválida.
    """
    if not json_response or 'Data' not in json_response or not json_response['Data']:
        print("Resposta JSON inválida ou sem dados.")
        return None

    data = json_response['Data']
    df = pd.DataFrame(data)

    # Renomear colunas para o padrão (minúsculas) e selecionar as principais
    # A API parece retornar em maiúsculas: OPEN, HIGH, LOW, CLOSE, VOLUME
    column_mapping = {
        'TIMESTAMP': 'timestamp',
        'OPEN': 'open',
        'HIGH': 'high',
        'LOW': 'low',
        'CLOSE': 'close',
        'VOLUME': 'volume' # Usando o campo 'VOLUME' principal conforme discutido
    }
    
    # Filtrar para manter apenas as colunas que existem e que queremos mapear
    existing_columns_to_rename = {k: v for k, v in column_mapping.items() if k in df.columns}
    df = df.rename(columns=existing_columns_to_rename)
    
    # Manter apenas as colunas renomeadas que são relevantes
    final_columns = [col for col in column_mapping.values() if col in df.columns]
    df = df[final_columns]

    if 'timestamp' not in df.columns:
        print("Coluna 'TIMESTAMP' não encontrada nos dados.")
        return None

    # Converter timestamp Unix (em segundos) para datetime e definir como índice
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
    df = df.set_index('timestamp')
    
    # Converter colunas OHLCV para numérico, caso não estejam
    for col in ['open', 'high', 'low', 'close', 'volume']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # Ordenar pelo índice de tempo, do mais antigo para o mais novo, importante para TA
    df = df.sort_index(ascending=True)
            
    return df

# %%
dataframe = parse_coindesk_response_to_dataframe(teste)
dataframe

# %%
def calculate_technical_indicators_v2(df: pd.DataFrame, 
                                     sma_periods: list = [20, 30, 50, 200], 
                                     ema_periods: list = [20], 
                                     rsi_period: int = 14, 
                                     macd_fast: int = 12, 
                                     macd_slow: int = 26, 
                                     macd_signal: int = 9) -> pd.DataFrame | None:
    """
    Calcula indicadores técnicos (SMAs, EMAs, RSI, MACD) usando pandas_ta
    e retorna um NOVO DataFrame contendo apenas esses indicadores.

    Args:
        df (pd.DataFrame): DataFrame com colunas 'open', 'high', 'low', 'close', 'volume'.
                           Deve ter um DatetimeIndex.
        sma_periods (list): Lista de períodos para SMAs.
        ema_periods (list): Lista de períodos para EMAs.
        rsi_period (int): Período para o RSI.
        macd_fast (int): Período rápido para o MACD.
        macd_slow (int): Período lento para o MACD.
        macd_signal (int): Período do sinal para o MACD.

    Returns:
        pd.DataFrame | None: Um novo DataFrame contendo apenas as colunas dos indicadores calculados,
                              compartilhando o mesmo índice do DataFrame de entrada. Retorna None se a entrada for inválida.
    """
    if df is None or df.empty:
        print("DataFrame de entrada (OHLCV) está vazio ou é None.")
        return None
    
    if not isinstance(df.index, pd.DatetimeIndex):
        print("O DataFrame de entrada (OHLCV) deve ter um DatetimeIndex.")
        return None

    # Lista para armazenar todas as séries/dataframes de indicadores
    all_indicators = []

    # Calcular SMAs
    for period in sma_periods:
        sma = df.ta.sma(length=period) # Retorna uma Série, nomeada automaticamente (ex: SMA_50)
        all_indicators.append(sma)

    # Calcular EMAs
    for period in ema_periods:
        ema = df.ta.ema(length=period) # Retorna uma Série, nomeada automaticamente (ex: EMA_20)
        all_indicators.append(ema)

    # Calcular RSI
    rsi = df.ta.rsi(length=rsi_period) # Retorna uma Série, nomeada automaticamente (ex: RSI_14)
    all_indicators.append(rsi)

    # Calcular MACD
    # df.ta.macd() retorna um DataFrame com 3 colunas: MACD_fast_slow_signal, MACDh_..., MACDs_...
    macd_df = df.ta.macd(fast=macd_fast, slow=macd_slow, signal=macd_signal, append=False)
    if macd_df is not None and not macd_df.empty:
        all_indicators.append(macd_df)
    
    # Concatenar todas as séries/dataframes de indicadores em um único DataFrame
    if not all_indicators:
        print("Nenhum indicador foi calculado.")
        return pd.DataFrame(index=df.index) # Retorna DF vazio com o mesmo índice

    indicators_df = pd.concat(all_indicators, axis=1)

    # Remover as linhas com NaN
    indicators_df = indicators_df.dropna()
    
    return indicators_df

# %%
calculos = calculate_technical_indicators_v2(dataframe,
                                          sma_periods=[20, 30, 50, 200], 
                                          ema_periods=[20], 
                                          rsi_period=14, 
                                          macd_fast=12, 
                                          macd_slow=26, 
                                          macd_signal=9)

# %%
calculos

# %%
dataframe

# %%
import pandas_ta as ta

help(ta.bbands)

# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta


ohlc_df = yf.Ticker('BTC-USD').history(period="3mo", interval="1h")
ohlc_df

# %%
ohlc_df.columns

# %%
ohlc_df_copy = ohlc_df.copy()

# %%
rsi14_4h = ta.rsi(ohlc_df_copy['Close'], length=4)
rsi14_4h

# %%
MyStrategy = ta.Strategy(
    name="MyStrategy",
    ta=[
        {"kind": "sma", "length": 20},
        {"kind": "sma", "length": 30},
        {"kind": "sma", "length": 50},
        {"kind": "sma", "length": 200},
        {"kind": "ema", "length": 20},
        {"kind": "ema", "length": 30},
        {"kind": "ema", "length": 50},
        {"kind": "ema", "length": 200},
        {"kind": "rsi", "length": 14},
        {"kind": "macd", "fast": 12, "slow": 26, "signal": 9},
        {"kind": "bbands", "length": 20, "std": 2},
        {"kind": "adx", "length": 14},
        {"kind": "atr", "length": 14},
        {"kind": "obv"},
    ]
)

# %%
ohlc_df.ta.strategy(MyStrategy)

# %%
ohlc_df.columns

# %%
teste_df = yf.Ticker('BTC-USD').history(period="1mo", interval="4h")

# %%
rsi14_4h = ta.rsi(teste_df['Close'], length=14)
rsi14_4h

# %% [markdown]
# ### Coleta noticias yfinance: ✅

# %%
import yfinance as yf

# %%
symbol = 'BTC-USD'
ticker = yf.Ticker(symbol)
# Obtendo noticias recentes
news = ticker.get_news()

# %%
news[0].keys()
# Out:
# dict_keys(['id', 'content'])

# %%
news[0]['content'].keys()
# Out:
# dict_keys(['id', 'contentType', 'title', 'description', 'summary', 'pubDate', 'displayTime', 'isHosted', 'bypassModal', 'previewUrl', 'thumbnail', 'provider', 'canonicalUrl', 'clickThroughUrl', 'metadata', 'finance', 'storyline'])

# %%
from datetime import datetime
import pytz

def parse_iso8601(date_str):
    # Formato ISO 8601 com 'Z' indicando UTC
    dt = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")
    # Atribui timezone UTC
    return dt.replace(tzinfo=pytz.UTC)

def format_datetime(dt, fmt="%d/%m/%Y %H:%M:%S %Z"):  # exemplo: '28/05/2025 13:39:31 UTC'
    return dt.strftime(fmt)

# %%
def extract_api_items(api_response, local_tz=None, output_fmt="%d/%m/%Y %H:%M:%S %Z"):
    """
    Extrai de uma lista de respostas de API os campos: title, summary, pubDate e canonicalUrl.

    Args:
        api_response (list): Lista de dicionários retornada pela API.

    Returns:
        list: Lista de dicionários contendo apenas os campos desejados.
    """
    extracted = []
    for entry in api_response:
        content = entry.get('content', {})
        raw_date = content.get('pubDate')
        dt = parse_iso8601(raw_date) if raw_date else None
        # Converte para timezone local se fornecido
        if dt and local_tz is not None:
            dt = dt.astimezone(local_tz)
        formatted = format_datetime(dt, output_fmt) if dt else None

        item = {
            'title': content.get('title'),
            'summary': content.get('summary'),
            'pubDate': formatted,
            'canonicalUrl': content.get('canonicalUrl', {}).get('url')
        }
        extracted.append(item)
    return extracted

# %%
extract_api_items(news)
# Out:
# [{'title': 'How bitcoin miners are powering the AI boom',
#   'summary': "Some bitcoin (BTC-USD) miners are pivoting to artificial intelligence (AI) as the rapidly evolving tech's data center and power demands expand. BitFarms (BITF) CEO Ben Gagnon joins Catalysts with Madison Mills and Interactive Brokers chief strategist Steve Sosnick to dive into the phenomenon. To watch more expert insights and analysis on the latest market action, check out more Catalysts here.",
#   'pubDate': '29/05/2025 11:30:45 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/bitcoin-miners-powering-ai-boom-113045424.html'},
#  {'title': "The real winner in GameStop's bitcoin pivot is Strategy",
#   'summary': 'For a certain class of GameStop investor, chasing improbable upside is entirely the point.',
#   'pubDate': '29/05/2025 10:00:51 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/news/the-real-winner-in-gamestops-bitcoin-pivot-is-strategy-100051206.html'},
#  {'title': 'Bitcoin Price Falls. Key Crypto Conference Fails to Lift Digital Coins.',
#   'summary': 'Bitcoin’s  price edged down despite a flurry of crypto news, including an endorsement by Vice President JD Vance in a speech at the 2025 Bitcoin Conference under way in Las Vegas.  In his speech at the Las Vegas conference, Vance said Bitcoin represented “genuine, ground-up innovation” while adding he believed the number of Americans holding Bitcoin would double “before too long.”',
#   'pubDate': '28/05/2025 17:55:00 UTC',
#   'canonicalUrl': 'https://www.barrons.com/articles/bitcoin-price-falls-key-crypto-conference-fails-to-lift-digital-coins-edeaf1c8?siteid=yhoof2&yptr=yahoo'},
#  {'title': 'Bitcoin conference: DJT, GameStop, & more race to buy bitcoin',
#   'summary': "The 2025 annual bitcoin (BTC-USD) conference is underway, with US Vice President JD Vance and Donald Trump Jr. in attendance. BitcoinIRA COO and co-founder Chris Kline joins Wealth from the conference to discuss sentiment at the event, Trump Media & Technology Group's (DJT) and GameStop's (GME) bitcoin plays, and the changing culture of the crypto space. To watch more expert insights and analysis on the latest market action, check out more Wealth here.",
#   'pubDate': '28/05/2025 16:12:25 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/bitcoin-conference-djt-gamestop-more-161225855.html'},
#  {'title': "Okta guidance, GameStop purchases bitcoin, Macy's Q1 results",
#   'summary': "Yahoo Finance host&nbsp;Madison Mills tracks today's top moving stocks and biggest market stories in this Market Minute, including Okta (OKTA) shares falling after disappointing investors with its latest guidance, GameStop (GME) purchases 4,710 bitcoin (BTC-USD), and department store Macy's (M) trimming its outlook after beating first quarter earnings estimates. Stay up to date on the latest market action, minute-by-minute, with&nbsp;Yahoo Finance's Market Minute.",
#   'pubDate': '28/05/2025 15:09:37 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/okta-guidance-gamestop-purchases-bitcoin-150937890.html'},
#  {'title': "How Trump's crypto push complicates stablecoin regulation",
#   'summary': "US President Trump's crypto ties may have helped legitimize the asset class to hesitant investors, but they also raise ethical concerns and slow down regulation, Axios crypto reporter Brady Dale tells Madison Mills and Brad Smith on Morning Brief. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here.",
#   'pubDate': '28/05/2025 14:49:00 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/trumps-crypto-push-complicates-stablecoin-144900577.html'},
#  {'title': 'Abercrombie, GameStop & bitcoin, Capri: Trending Tickers',
#   'summary': "Abercrombie (ANF) stock is skyrocketing after the retailer reported an earnings beat and lifted its full-year outlook. GameStop (GME) announced that it has purchased bitcoin (BTC-USD) valued at more than $500 million. Coach's parent company, Capri Holdings (CPRI), is in focus after cutting its fiscal 2026 outlook and posting fourth quarter results that highlighted the potential impact of tariffs. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here.",
#   'pubDate': '28/05/2025 13:39:31 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/abercrombie-gamestop-bitcoin-capri-trending-133931758.html'},
#  {'title': 'DJT & bitcoin, Wingstop upgrade, Salesforce–Informatica deal',
#   'summary': "Market Domination co-host Josh Lipton tracks today's top moving stocks and biggest market stories in this Market Minute. Trump Media & Technology Group (DJT) stock falls as the company announces plans to build one of the largest bitcoin (BTC-USD) treasuries. Wingstop (WING) stock rises after Truist upgraded the stock to Buy from Hold and raised its price target to $400 from $274. Meanwhile, Informatica (INFA) also pops as Salesforce (CRM) unveils an $8 billion acquisition to boost its data capabilities. Stay up to date on the latest market action, minute-by-minute, with Yahoo Finance's Market Minute.",
#   'pubDate': '27/05/2025 17:15:45 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/djt-bitcoin-wingstop-upgrade-salesforce-171545867.html'},
#  {'title': 'Trump Media to raise $2.5 billion to buy bitcoin',
#   'summary': 'Trump Media & Technology Group is making a push into cryptocurrency with a $2.5 billion funding deal to build what it has called one of the largest bitcoin treasuries held by a public company.',
#   'pubDate': '27/05/2025 14:29:42 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/news/trump-media-to-raise-25-billion-to-buy-bitcoin-142942484.html'},
#  {'title': 'Bull flags, gold, bitcoin: What to watch on Wall Street today',
#   'summary': 'There are a few things Wall Street is watching in the markets on Tuesday, May 27, including yields (^TYX), gold (GC=F), and bitcoin (BTC-USD). Yahoo Finance Markets and Data Editor Jared Blikre breaks it all down in the video above. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here.',
#   'pubDate': '27/05/2025 13:57:49 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/bull-flags-gold-bitcoin-watch-135749917.html'},
#  {'title': 'Salesforce–Informatica deal, DJT & bitcoin, PDD: Trending Tickers',
#   'summary': "Salesforce (CRM) is set to acquire Informatica (INFA) in an $8 billion deal, just ahead of the customer relationship management company's earnings. Trump Media & Technology Group (DJT) announces plans to raise $2.5 billion to create a bitcoin (BTC=F) treasury. Chinese online retailer, PDD Holdings (PDD), shares plunge after reporting an earnings miss as the US–China trade war weighs on the company. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here.",
#   'pubDate': '27/05/2025 13:47:51 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/salesforce-informatica-deal-djt-bitcoin-134751841.html'},
#  {'title': 'Bitcoin Price Jumps.\xa0Why Cryptos Are Loving Life Under Trump.',
#   'summary': "Trump Media revealed plans to raise $2.5 billion to invest in the world's largest cryptocurrency.",
#   'pubDate': '27/05/2025 13:37:00 UTC',
#   'canonicalUrl': 'https://www.barrons.com/articles/bitcoin-price-rises-djt-trump-media-5db65c2b?siteid=yhoof2&yptr=yahoo'},
#  {'title': 'Trending tickers: Tesla, Nvidia, GameStop, Palantir and Whitbread',
#   'summary': 'The latest investor updates on stocks that are trending on Tuesday',
#   'pubDate': '27/05/2025 08:39:56 UTC',
#   'canonicalUrl': 'https://uk.finance.yahoo.com/news/trending-tickers-tesla-nvidia-gamestop-palantir-and-whitbread-083956951.html'},
#  {'title': 'The Weekend: A blow to the US economy takes the shine off a UK-EU trade deal',
#   'summary': 'Key moments from the last seven days, plus a glimpse at the week ahead',
#   'pubDate': '24/05/2025 10:08:55 UTC',
#   'canonicalUrl': 'https://uk.finance.yahoo.com/news/weekend-us-credit-downgrade-uk-eu-trade-deal-100855218.html'},
#  {'title': 'Trading week, Treasury yields, gold & bitcoin: Market Takeaways',
#   'summary': 'US stocks (^DJI, ^IXIC, ^GSPC) cap off this trading week in negative territory after the recent market rally seemingly stalls and President Trump threatens new tariffs against the European Union (EU). Yahoo Finance markets and data editor Jared Blikre shares his market trend insights, noting the worst trading week since Trump\'s "Liberation Day" in April, the moves in US Treasury yields (^TYX, ^TNX, ^FVX) To watch more expert insights and analysis on the latest market action, check out more Asking for a Trend&nbsp;here.',
#   'pubDate': '23/05/2025 21:15:00 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/trading-week-treasury-yields-gold-211500814.html'},
#  {'title': 'Bitcoin retreats, Nippon Steel–US Steel deal in limbo, Volvo Cars',
#   'summary': "Market Domination co-host Josh Lipton tracks today's top stories and stocks in this Market Minute. Bitcoin (BTC-USD) pulls back from recent highs above $111,900 amid the market downturn. Nippon Steel's (NPSCY) planned acquisition of US Steel (X) continues to hang in the balance, though the company's talks with the US government are reportedly in the final stage. Meanwhile, Volvo Cars (VOLCAR-B.ST) stock falls after the automaker warned that customers may bear the brunt of looming tariff-related cost hikes. Stay up to date on the latest market action, minute-by-minute, with Yahoo Finance's Market Minute.",
#   'pubDate': '23/05/2025 17:26:59 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/bitcoin-retreats-nippon-steel-us-172659604.html'},
#  {'title': "Is bitcoin a 'superior gold substitute'?",
#   'summary': 'Bitcoin (BTC-USD) is surging past $111,000 has some of the ultra-wealthy taking notice. Michael Sonnenfeldt, founder and chairman of TIGER 21, explains how high-net-worth investors are thinking about crypto as a long-term store of value, sometimes even over gold. To watch more expert insights and analysis on the latest market action, check out more Wealth&nbsp;here.',
#   'pubDate': '23/05/2025 10:30:56 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/bitcoin-superior-gold-substitute-103056129.html'},
#  {'title': 'Trending tickers: GameStop, Advance Auto Parts, Autodesk, Target and International Paper',
#   'summary': 'The latest investor updates on stocks that are trending on Friday',
#   'pubDate': '23/05/2025 09:13:55 UTC',
#   'canonicalUrl': 'https://uk.finance.yahoo.com/news/gamestop-advance-auto-parts-autodesk-target-international-paper-trending-tickers-091355579.html'},
#  {'title': "Bitcoin soars, Fannie Mae & Freddie Mac, Novo's GLP-1 discount",
#   'summary': "Market Domination co-host Josh Lipton tracks today's top stories and stocks in this Market Minute. Bitcoin (BTC-USD) continues its rally, soaring past $111,000 as rising bond yields (^TYX,&nbsp;^TNX,&nbsp;^FVX) drive investors toward alternative assets. Over-the-counter shares of Fannie Mae (FNMA) and Freddie Mac (FMCC) skyrocket after President Trump signals he's considering taking the firms public. Meanwhile, Novo Nordisk (NVO) offers a one-month discount on its GLP-1 weight loss drug to attract new users. Stay up to date on the latest market action, minute-by-minute, with Yahoo Finance's Market Minute.",
#   'pubDate': '22/05/2025 17:16:51 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/video/bitcoin-soars-fannie-mae-freddie-171651387.html'},
#  {'title': 'Bitcoin hovers near $111,000 as crypto momentum grows',
#   'summary': 'Bitcoin hovered near an all-time high again on Thursday thanks to a combination of US debt concerns and looser regulations.',
#   'pubDate': '22/05/2025 16:51:43 UTC',
#   'canonicalUrl': 'https://finance.yahoo.com/news/bitcoin-hovers-near-111000-as-crypto-momentum-grows-165143182.html'}]
