# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta

# %%
from openai import OpenAI
client = OpenAI()

# %% [markdown]
# ## Agente de Análises:

# %% [markdown]
# ## Agente de indicadores técnicos:

# %%
from coleta_dados_coindesk import fetch_last_3_months_hourly, converte_ohlcv_para_df

# %%
import requests
import pandas as pd
import pandas_ta as ta
import os
from dotenv import load_dotenv
import json

# %%
dados_coindesk = fetch_last_3_months_hourly()
dados_coindesk['Data']
# Out:
# [{'UNIT': 'HOUR',
#   'TIMESTAMP': 1742050800,
#   'OPEN': 84156.4,
#   'HIGH': 84408.31,
#   'LOW': 84156.4,
#   'CLOSE': 84351.8,
#   'VOLUME': 2.19683322,
#   'QUOTE_VOLUME': 185139.431000613,
#   'VOLUME_BUY': 0.94882201,
#   'QUOTE_VOLUME_BUY': 79964.3284352862,
#   'VOLUME_SELL': 1.24801121,
#   'QUOTE_VOLUME_SELL': 105175.102565327,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742054400,
#   'OPEN': 84351.8,
#   'HIGH': 84480.03,
#   'LOW': 84179.07,
#   'CLOSE': 84348.92,
#   'VOLUME': 4.10877429,
#   'QUOTE_VOLUME': 346589.066428744,
#   'VOLUME_BUY': 1.97943798,
#   'QUOTE_VOLUME_BUY': 166947.785376924,
#   'VOLUME_SELL': 2.12933631,
#   'QUOTE_VOLUME_SELL': 179641.281051815,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742058000,
#   'OPEN': 84348.92,
#   'HIGH': 84477.57,
#   'LOW': 84272.12,
#   'CLOSE': 84371.66,
#   'VOLUME': 4.10876242,
#   'QUOTE_VOLUME': 346696.263293632,
#   'VOLUME_BUY': 1.55547244,
#   'QUOTE_VOLUME_BUY': 131229.698672665,
#   'VOLUME_SELL': 2.55328998,
#   'QUOTE_VOLUME_SELL': 215466.564620969,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742061600,
#   'OPEN': 84371.66,
#   'HIGH': 84467.67,
#   'LOW': 84144,
#   'CLOSE': 84209.78,
#   'VOLUME': 1.22050801,
#   'QUOTE_VOLUME': 102841.805446585,
#   'VOLUME_BUY': 0.7331552,
#   'QUOTE_VOLUME_BUY': 61779.4078263659,
#   'VOLUME_SELL': 0.48735281,
#   'QUOTE_VOLUME_SELL': 41062.3976202194,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742065200,
#   'OPEN': 84209.78,
#   'HIGH': 84318.53,
#   'LOW': 84104.26,
#   'CLOSE': 84289,
#   'VOLUME': 2.12842766,
#   'QUOTE_VOLUME': 179269.010356731,
#   'VOLUME_BUY': 0.81287795,
#   'QUOTE_VOLUME_BUY': 68450.0676608942,
#   'VOLUME_SELL': 1.31554971,
#   'QUOTE_VOLUME_SELL': 110818.942695841,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742068800,
#   'OPEN': 84289,
#   'HIGH': 84442.65,
#   'LOW': 84289,
#   'CLOSE': 84364.39,
#   'VOLUME': 1.61330532,
#   'QUOTE_VOLUME': 136163.379672587,
#   'VOLUME_BUY': 0.75480146,
#   'QUOTE_VOLUME_BUY': 63701.7526909718,
#   'VOLUME_SELL': 0.85850386,
#   'QUOTE_VOLUME_SELL': 72461.6269816171,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742072400,
#   'OPEN': 84364.39,
#   'HIGH': 84474.04,
#   'LOW': 84236.37,
#   'CLOSE': 84384.95,
#   'VOLUME': 2.22802078,
#   'QUOTE_VOLUME': 188013.066489126,
#   'VOLUME_BUY': 0.93716371,
#   'QUOTE_VOLUME_BUY': 79076.5666545323,
#   'VOLUME_SELL': 1.29085707,
#   'QUOTE_VOLUME_SELL': 108936.499834593,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742076000,
#   'OPEN': 84384.95,
#   'HIGH': 84449.6,
#   'LOW': 84328.02,
#   'CLOSE': 84375.53,
#   'VOLUME': 2.34846359,
#   'QUOTE_VOLUME': 198202.638507028,
#   'VOLUME_BUY': 1.17862673,
#   'QUOTE_VOLUME_BUY': 99465.097548615,
#   'VOLUME_SELL': 1.16983686,
#   'QUOTE_VOLUME_SELL': 98737.5409584146,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742079600,
#   'OPEN': 84375.53,
#   'HIGH': 84390.69,
#   'LOW': 84275.35,
#   'CLOSE': 84355.54,
#   'VOLUME': 2.07731717,
#   'QUOTE_VOLUME': 175153.406107915,
#   'VOLUME_BUY': 0.97410287,
#   'QUOTE_VOLUME_BUY': 82125.2550568122,
#   'VOLUME_SELL': 1.1032143,
#   'QUOTE_VOLUME_SELL': 93028.151051099,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742083200,
#   'OPEN': 84355.54,
#   'HIGH': 84366.78,
#   'LOW': 84207.23,
#   'CLOSE': 84257.04,
#   'VOLUME': 4.83254351,
#   'QUOTE_VOLUME': 407307.361850951,
#   'VOLUME_BUY': 2.80596193,
#   'QUOTE_VOLUME_BUY': 236492.465627304,
#   'VOLUME_SELL': 2.02658158,
#   'QUOTE_VOLUME_SELL': 170814.896223647,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742086800,
#   'OPEN': 84257.04,
#   'HIGH': 84272.26,
#   'LOW': 83829.07,
#   'CLOSE': 83869.27,
#   'VOLUME': 6.44252121,
#   'QUOTE_VOLUME': 541316.075134207,
#   'VOLUME_BUY': 2.31987559,
#   'QUOTE_VOLUME_BUY': 194915.604154672,
#   'VOLUME_SELL': 4.12264562,
#   'QUOTE_VOLUME_SELL': 346400.470979532,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742090400,
#   'OPEN': 83869.27,
#   'HIGH': 84120.19,
#   'LOW': 83737.44,
#   'CLOSE': 83977.66,
#   'VOLUME': 4.43904132,
#   'QUOTE_VOLUME': 372451.080077076,
#   'VOLUME_BUY': 2.09295994,
#   'QUOTE_VOLUME_BUY': 175598.278625354,
#   'VOLUME_SELL': 2.34608138,
#   'QUOTE_VOLUME_SELL': 196852.801451714,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742094000,
#   'OPEN': 83977.66,
#   'HIGH': 84377.72,
#   'LOW': 83910.87,
#   'CLOSE': 84325.62,
#   'VOLUME': 4.37682151,
#   'QUOTE_VOLUME': 368611.304463654,
#   'VOLUME_BUY': 2.3809112,
#   'QUOTE_VOLUME_BUY': 200470.628313543,
#   'VOLUME_SELL': 1.99591031,
#   'QUOTE_VOLUME_SELL': 168140.676150114,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742097600,
#   'OPEN': 84325.62,
#   'HIGH': 84423.43,
#   'LOW': 84247.38,
#   'CLOSE': 84396.96,
#   'VOLUME': 4.33267904,
#   'QUOTE_VOLUME': 365440.447060024,
#   'VOLUME_BUY': 2.19889571,
#   'QUOTE_VOLUME_BUY': 185449.30618493,
#   'VOLUME_SELL': 2.13378333,
#   'QUOTE_VOLUME_SELL': 179991.140875094,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742101200,
#   'OPEN': 84396.96,
#   'HIGH': 84409.54,
#   'LOW': 84305.88,
#   'CLOSE': 84397.89,
#   'VOLUME': 3.7737102,
#   'QUOTE_VOLUME': 318360.470974065,
#   'VOLUME_BUY': 1.89616222,
#   'QUOTE_VOLUME_BUY': 159939.863208904,
#   'VOLUME_SELL': 1.87754798,
#   'QUOTE_VOLUME_SELL': 158420.607765157,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742104800,
#   'OPEN': 84397.89,
#   'HIGH': 84402.95,
#   'LOW': 84230.4,
#   'CLOSE': 84235.44,
#   'VOLUME': 4.6589616,
#   'QUOTE_VOLUME': 392890.131191445,
#   'VOLUME_BUY': 2.08317198,
#   'QUOTE_VOLUME_BUY': 175659.131684132,
#   'VOLUME_SELL': 2.57578962,
#   'QUOTE_VOLUME_SELL': 217230.99950731,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742108400,
#   'OPEN': 84235.44,
#   'HIGH': 84371.04,
#   'LOW': 83984.6,
#   'CLOSE': 84262.11,
#   'VOLUME': 6.19522708,
#   'QUOTE_VOLUME': 521649.880230761,
#   'VOLUME_BUY': 2.99727548,
#   'QUOTE_VOLUME_BUY': 252360.208918133,
#   'VOLUME_SELL': 3.1979516,
#   'QUOTE_VOLUME_SELL': 269289.67131263,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742112000,
#   'OPEN': 84262.11,
#   'HIGH': 84333.54,
#   'LOW': 84162.35,
#   'CLOSE': 84288.36,
#   'VOLUME': 2.90103797,
#   'QUOTE_VOLUME': 244396.846292977,
#   'VOLUME_BUY': 1.53255859,
#   'QUOTE_VOLUME_BUY': 129089.515115433,
#   'VOLUME_SELL': 1.36847938,
#   'QUOTE_VOLUME_SELL': 115307.331177543,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742115600,
#   'OPEN': 84288.36,
#   'HIGH': 84288.36,
#   'LOW': 83814.07,
#   'CLOSE': 83874.08,
#   'VOLUME': 4.42139628,
#   'QUOTE_VOLUME': 371479.140854497,
#   'VOLUME_BUY': 1.99988862,
#   'QUOTE_VOLUME_BUY': 168055.553658523,
#   'VOLUME_SELL': 2.42150766,
#   'QUOTE_VOLUME_SELL': 203423.587195975,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742119200,
#   'OPEN': 83874.08,
#   'HIGH': 84048.72,
#   'LOW': 83617.11,
#   'CLOSE': 83665.93,
#   'VOLUME': 9.02007616,
#   'QUOTE_VOLUME': 755873.564693284,
#   'VOLUME_BUY': 4.58912204,
#   'QUOTE_VOLUME_BUY': 384649.36971192,
#   'VOLUME_SELL': 4.43095412,
#   'QUOTE_VOLUME_SELL': 371224.194981353,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742122800,
#   'OPEN': 83665.93,
#   'HIGH': 83696.11,
#   'LOW': 82364.46,
#   'CLOSE': 82407.99,
#   'VOLUME': 20.10883458,
#   'QUOTE_VOLUME': 1666767.64037757,
#   'VOLUME_BUY': 8.91719279,
#   'QUOTE_VOLUME_BUY': 739185.028474405,
#   'VOLUME_SELL': 11.19164179,
#   'QUOTE_VOLUME_SELL': 927582.611903133,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742126400,
#   'OPEN': 82407.99,
#   'HIGH': 82918.53,
#   'LOW': 82400.24,
#   'CLOSE': 82762.72,
#   'VOLUME': 9.12007071,
#   'QUOTE_VOLUME': 753866.417469553,
#   'VOLUME_BUY': 5.34325462,
#   'QUOTE_VOLUME_BUY': 441687.992877512,
#   'VOLUME_SELL': 3.77681609,
#   'QUOTE_VOLUME_SELL': 312178.424592042,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742130000,
#   'OPEN': 82762.72,
#   'HIGH': 83133.44,
#   'LOW': 82500,
#   'CLOSE': 82598.87,
#   'VOLUME': 8.60379178,
#   'QUOTE_VOLUME': 713068.953462051,
#   'VOLUME_BUY': 4.21167989,
#   'QUOTE_VOLUME_BUY': 349058.39921278,
#   'VOLUME_SELL': 4.39211189,
#   'QUOTE_VOLUME_SELL': 364010.55424927,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742133600,
#   'OPEN': 82598.87,
#   'HIGH': 83374.46,
#   'LOW': 82581.68,
#   'CLOSE': 83367.17,
#   'VOLUME': 8.03566396,
#   'QUOTE_VOLUME': 666861.517323997,
#   'VOLUME_BUY': 4.63705546,
#   'QUOTE_VOLUME_BUY': 384873.024616333,
#   'VOLUME_SELL': 3.3986085,
#   'QUOTE_VOLUME_SELL': 281988.492707665,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742137200,
#   'OPEN': 83367.17,
#   'HIGH': 83485.35,
#   'LOW': 82965.64,
#   'CLOSE': 83304.06,
#   'VOLUME': 10.13463377,
#   'QUOTE_VOLUME': 843623.695610775,
#   'VOLUME_BUY': 5.31844495,
#   'QUOTE_VOLUME_BUY': 442684.226576237,
#   'VOLUME_SELL': 4.81618882,
#   'QUOTE_VOLUME_SELL': 400939.469034541,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742140800,
#   'OPEN': 83304.06,
#   'HIGH': 85129.34,
#   'LOW': 83281.81,
#   'CLOSE': 83633.38,
#   'VOLUME': 57.92917323,
#   'QUOTE_VOLUME': 4881863.71622513,
#   'VOLUME_BUY': 29.92345269,
#   'QUOTE_VOLUME_BUY': 2521901.2526591,
#   'VOLUME_SELL': 28.00572054,
#   'QUOTE_VOLUME_SELL': 2359962.46356608,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742144400,
#   'OPEN': 83633.38,
#   'HIGH': 84102.05,
#   'LOW': 83480.89,
#   'CLOSE': 83911.69,
#   'VOLUME': 10.08386732,
#   'QUOTE_VOLUME': 844821.610536024,
#   'VOLUME_BUY': 4.60902046,
#   'QUOTE_VOLUME_BUY': 386079.023890381,
#   'VOLUME_SELL': 5.47484686,
#   'QUOTE_VOLUME_SELL': 458742.586645648,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742148000,
#   'OPEN': 83911.69,
#   'HIGH': 84090.11,
#   'LOW': 83626.9,
#   'CLOSE': 83700.31,
#   'VOLUME': 12.48909183,
#   'QUOTE_VOLUME': 1046604.27061068,
#   'VOLUME_BUY': 4.14260962,
#   'QUOTE_VOLUME_BUY': 347124.76962214,
#   'VOLUME_SELL': 8.34648221,
#   'QUOTE_VOLUME_SELL': 699479.500988542,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742151600,
#   'OPEN': 83700.31,
#   'HIGH': 83726.8,
#   'LOW': 82562.73,
#   'CLOSE': 83086.5,
#   'VOLUME': 32.01335535,
#   'QUOTE_VOLUME': 2659988.00349644,
#   'VOLUME_BUY': 14.15775768,
#   'QUOTE_VOLUME_BUY': 1175428.39358165,
#   'VOLUME_SELL': 17.85559767,
#   'QUOTE_VOLUME_SELL': 1484559.60991476,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742155200,
#   'OPEN': 83086.5,
#   'HIGH': 83451.58,
#   'LOW': 82911.25,
#   'CLOSE': 83194.87,
#   'VOLUME': 7.5399154,
#   'QUOTE_VOLUME': 627060.832554051,
#   'VOLUME_BUY': 3.43010441,
#   'QUOTE_VOLUME_BUY': 285349.991758553,
#   'VOLUME_SELL': 4.10981099,
#   'QUOTE_VOLUME_SELL': 341710.840795503,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742158800,
#   'OPEN': 83194.87,
#   'HIGH': 83210.09,
#   'LOW': 82672.94,
#   'CLOSE': 82717.87,
#   'VOLUME': 6.89849563,
#   'QUOTE_VOLUME': 571869.536908519,
#   'VOLUME_BUY': 3.38987442,
#   'QUOTE_VOLUME_BUY': 281020.561533575,
#   'VOLUME_SELL': 3.50862121,
#   'QUOTE_VOLUME_SELL': 290848.975374943,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742162400,
#   'OPEN': 82717.87,
#   'HIGH': 82840.95,
#   'LOW': 82087.27,
#   'CLOSE': 82096.1,
#   'VOLUME': 14.10337182,
#   'QUOTE_VOLUME': 1161585.02700247,
#   'VOLUME_BUY': 6.64512346,
#   'QUOTE_VOLUME_BUY': 547274.498302169,
#   'VOLUME_SELL': 7.45824836,
#   'QUOTE_VOLUME_SELL': 614310.528700251,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742166000,
#   'OPEN': 82096.1,
#   'HIGH': 82632.16,
#   'LOW': 81993.8,
#   'CLOSE': 82576.04,
#   'VOLUME': 8.74533096,
#   'QUOTE_VOLUME': 720427.152744124,
#   'VOLUME_BUY': 5.01591807,
#   'QUOTE_VOLUME_BUY': 413294.600337601,
#   'VOLUME_SELL': 3.72941289,
#   'QUOTE_VOLUME_SELL': 307132.552406523,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742169600,
#   'OPEN': 82576.04,
#   'HIGH': 83142.5,
#   'LOW': 82553.94,
#   'CLOSE': 83043.15,
#   'VOLUME': 4.94853824,
#   'QUOTE_VOLUME': 410119.842432999,
#   'VOLUME_BUY': 2.5026163,
#   'QUOTE_VOLUME_BUY': 207401.580553557,
#   'VOLUME_SELL': 2.44592194,
#   'QUOTE_VOLUME_SELL': 202718.261879443,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742173200,
#   'OPEN': 83043.15,
#   'HIGH': 83375.79,
#   'LOW': 82827.63,
#   'CLOSE': 83204.6,
#   'VOLUME': 5.18251365,
#   'QUOTE_VOLUME': 431044.923648841,
#   'VOLUME_BUY': 2.57589705,
#   'QUOTE_VOLUME_BUY': 214329.48935214,
#   'VOLUME_SELL': 2.6066166,
#   'QUOTE_VOLUME_SELL': 216715.434296696,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742176800,
#   'OPEN': 83204.6,
#   'HIGH': 83351.8,
#   'LOW': 82973.28,
#   'CLOSE': 83279.67,
#   'VOLUME': 3.65477008,
#   'QUOTE_VOLUME': 303945.465750026,
#   'VOLUME_BUY': 1.53725742,
#   'QUOTE_VOLUME_BUY': 127848.640383014,
#   'VOLUME_SELL': 2.11751266,
#   'QUOTE_VOLUME_SELL': 176096.825367012,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742180400,
#   'OPEN': 83279.67,
#   'HIGH': 83707.66,
#   'LOW': 83215.06,
#   'CLOSE': 83671.16,
#   'VOLUME': 7.54057316,
#   'QUOTE_VOLUME': 629669.078841308,
#   'VOLUME_BUY': 3.38813797,
#   'QUOTE_VOLUME_BUY': 282945.033527822,
#   'VOLUME_SELL': 4.15243519,
#   'QUOTE_VOLUME_SELL': 346724.045313485,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742184000,
#   'OPEN': 83671.16,
#   'HIGH': 83864.5,
#   'LOW': 83538.57,
#   'CLOSE': 83608.56,
#   'VOLUME': 4.5436504,
#   'QUOTE_VOLUME': 380414.366971594,
#   'VOLUME_BUY': 2.45307332,
#   'QUOTE_VOLUME_BUY': 205373.307733929,
#   'VOLUME_SELL': 2.09057708,
#   'QUOTE_VOLUME_SELL': 175041.059237667,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742187600,
#   'OPEN': 83608.56,
#   'HIGH': 83608.56,
#   'LOW': 83117.75,
#   'CLOSE': 83117.75,
#   'VOLUME': 5.01844869,
#   'QUOTE_VOLUME': 417974.10295535,
#   'VOLUME_BUY': 2.07767149,
#   'QUOTE_VOLUME_BUY': 172992.359926552,
#   'VOLUME_SELL': 2.9407772,
#   'QUOTE_VOLUME_SELL': 244981.7430288,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742191200,
#   'OPEN': 83117.75,
#   'HIGH': 83283.66,
#   'LOW': 82673.23,
#   'CLOSE': 83215.45,
#   'VOLUME': 3.34034153,
#   'QUOTE_VOLUME': 277437.984611014,
#   'VOLUME_BUY': 1.49165248,
#   'QUOTE_VOLUME_BUY': 123904.549892241,
#   'VOLUME_SELL': 1.84868905,
#   'QUOTE_VOLUME_SELL': 153533.434718772,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742194800,
#   'OPEN': 83215.45,
#   'HIGH': 83629.46,
#   'LOW': 83213.04,
#   'CLOSE': 83518.68,
#   'VOLUME': 6.16495918,
#   'QUOTE_VOLUME': 514385.637065332,
#   'VOLUME_BUY': 3.81133524,
#   'QUOTE_VOLUME_BUY': 317976.759722357,
#   'VOLUME_SELL': 2.35362394,
#   'QUOTE_VOLUME_SELL': 196408.877342978,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742198400,
#   'OPEN': 83518.68,
#   'HIGH': 83704.95,
#   'LOW': 83200.9,
#   'CLOSE': 83537.74,
#   'VOLUME': 4.40043036,
#   'QUOTE_VOLUME': 367292.688410468,
#   'VOLUME_BUY': 2.19625574,
#   'QUOTE_VOLUME_BUY': 183334.487242167,
#   'VOLUME_SELL': 2.20417462,
#   'QUOTE_VOLUME_SELL': 183958.201168295,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742202000,
#   'OPEN': 83537.74,
#   'HIGH': 83761.45,
#   'LOW': 83436,
#   'CLOSE': 83657.25,
#   'VOLUME': 5.024027,
#   'QUOTE_VOLUME': 420133.017970378,
#   'VOLUME_BUY': 2.35014681,
#   'QUOTE_VOLUME_BUY': 196529.769866154,
#   'VOLUME_SELL': 2.67388019,
#   'QUOTE_VOLUME_SELL': 223603.248104227,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742205600,
#   'OPEN': 83657.25,
#   'HIGH': 83677.21,
#   'LOW': 83255.27,
#   'CLOSE': 83306.23,
#   'VOLUME': 3.8301342,
#   'QUOTE_VOLUME': 319556.112560629,
#   'VOLUME_BUY': 1.58210514,
#   'QUOTE_VOLUME_BUY': 132044.662279111,
#   'VOLUME_SELL': 2.24802906,
#   'QUOTE_VOLUME_SELL': 187511.450281516,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742209200,
#   'OPEN': 83306.23,
#   'HIGH': 83648.34,
#   'LOW': 83232.77,
#   'CLOSE': 83528.13,
#   'VOLUME': 5.65636507,
#   'QUOTE_VOLUME': 472310.193975971,
#   'VOLUME_BUY': 2.14151045,
#   'QUOTE_VOLUME_BUY': 178824.372769352,
#   'VOLUME_SELL': 3.51485462,
#   'QUOTE_VOLUME_SELL': 293485.82120662,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742212800,
#   'OPEN': 83528.13,
#   'HIGH': 84005.82,
#   'LOW': 82990.32,
#   'CLOSE': 83129.27,
#   'VOLUME': 50.65330554,
#   'QUOTE_VOLUME': 4226916.35117953,
#   'VOLUME_BUY': 25.41031734,
#   'QUOTE_VOLUME_BUY': 2119502.88749893,
#   'VOLUME_SELL': 25.2429882,
#   'QUOTE_VOLUME_SELL': 2107413.46368072,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742216400,
#   'OPEN': 83129.27,
#   'HIGH': 83724.78,
#   'LOW': 82812.68,
#   'CLOSE': 83070.44,
#   'VOLUME': 16.20779837,
#   'QUOTE_VOLUME': 1348523.44164395,
#   'VOLUME_BUY': 8.35820002,
#   'QUOTE_VOLUME_BUY': 695218.803413421,
#   'VOLUME_SELL': 7.84959835,
#   'QUOTE_VOLUME_SELL': 653304.638230551,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742220000,
#   'OPEN': 83070.44,
#   'HIGH': 83348.24,
#   'LOW': 82460.67,
#   'CLOSE': 82912.21,
#   'VOLUME': 26.98165683,
#   'QUOTE_VOLUME': 2233594.98606912,
#   'VOLUME_BUY': 14.13771734,
#   'QUOTE_VOLUME_BUY': 1170234.81690542,
#   'VOLUME_SELL': 12.84393949,
#   'QUOTE_VOLUME_SELL': 1063360.16916366,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742223600,
#   'OPEN': 82912.21,
#   'HIGH': 83713.32,
#   'LOW': 82740.75,
#   'CLOSE': 83537.73,
#   'VOLUME': 17.21523467,
#   'QUOTE_VOLUME': 1435481.51721466,
#   'VOLUME_BUY': 7.97060644,
#   'QUOTE_VOLUME_BUY': 664376.831012424,
#   'VOLUME_SELL': 9.24462823,
#   'QUOTE_VOLUME_SELL': 771104.686202258,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742227200,
#   'OPEN': 83537.73,
#   'HIGH': 83877.05,
#   'LOW': 83115.12,
#   'CLOSE': 83443.84,
#   'VOLUME': 14.79834276,
#   'QUOTE_VOLUME': 1235694.53067701,
#   'VOLUME_BUY': 8.1809077,
#   'QUOTE_VOLUME_BUY': 683233.490643501,
#   'VOLUME_SELL': 6.61743506,
#   'QUOTE_VOLUME_SELL': 552461.040033492,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742230800,
#   'OPEN': 83443.84,
#   'HIGH': 84341.18,
#   'LOW': 83372.23,
#   'CLOSE': 84202.73,
#   'VOLUME': 12.16588117,
#   'QUOTE_VOLUME': 1022417.29554961,
#   'VOLUME_BUY': 6.09153278,
#   'QUOTE_VOLUME_BUY': 511916.175272201,
#   'VOLUME_SELL': 6.07434839,
#   'QUOTE_VOLUME_SELL': 510501.120277419,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742234400,
#   'OPEN': 84202.73,
#   'HIGH': 84605.76,
#   'LOW': 84002.65,
#   'CLOSE': 84500.91,
#   'VOLUME': 26.74394738,
#   'QUOTE_VOLUME': 2253974.94579436,
#   'VOLUME_BUY': 10.16397076,
#   'QUOTE_VOLUME_BUY': 856933.905135286,
#   'VOLUME_SELL': 16.57997662,
#   'QUOTE_VOLUME_SELL': 1397041.04065909,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742238000,
#   'OPEN': 84500.91,
#   'HIGH': 84754.78,
#   'LOW': 84362.61,
#   'CLOSE': 84494.88,
#   'VOLUME': 13.16511014,
#   'QUOTE_VOLUME': 1112836.18484199,
#   'VOLUME_BUY': 6.42028232,
#   'QUOTE_VOLUME_BUY': 542684.227683566,
#   'VOLUME_SELL': 6.74482782,
#   'QUOTE_VOLUME_SELL': 570151.957158409,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742241600,
#   'OPEN': 84494.88,
#   'HIGH': 84507,
#   'LOW': 83853.66,
#   'CLOSE': 83963.76,
#   'VOLUME': 11.48464826,
#   'QUOTE_VOLUME': 966669.221779741,
#   'VOLUME_BUY': 4.68398442,
#   'QUOTE_VOLUME_BUY': 394072.782200506,
#   'VOLUME_SELL': 6.80066384,
#   'QUOTE_VOLUME_SELL': 572596.439579234,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742245200,
#   'OPEN': 83963.76,
#   'HIGH': 84201.69,
#   'LOW': 83882.03,
#   'CLOSE': 84140.01,
#   'VOLUME': 4.9830604,
#   'QUOTE_VOLUME': 418697.986671882,
#   'VOLUME_BUY': 2.1298192,
#   'QUOTE_VOLUME_BUY': 178976.448343109,
#   'VOLUME_SELL': 2.8532412,
#   'QUOTE_VOLUME_SELL': 239721.538328776,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742248800,
#   'OPEN': 84140.01,
#   'HIGH': 84237.52,
#   'LOW': 84009.8,
#   'CLOSE': 84081.66,
#   'VOLUME': 1.66862771,
#   'QUOTE_VOLUME': 140384.567993849,
#   'VOLUME_BUY': 0.7534928,
#   'QUOTE_VOLUME_BUY': 63383.3391085708,
#   'VOLUME_SELL': 0.91513491,
#   'QUOTE_VOLUME_SELL': 77001.2288852788,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742252400,
#   'OPEN': 84081.66,
#   'HIGH': 84121.74,
#   'LOW': 83757.5,
#   'CLOSE': 84039.85,
#   'VOLUME': 5.87208969,
#   'QUOTE_VOLUME': 493352.842087606,
#   'VOLUME_BUY': 1.54217231,
#   'QUOTE_VOLUME_BUY': 129490.65624832,
#   'VOLUME_SELL': 4.32991738,
#   'QUOTE_VOLUME_SELL': 363862.185839285,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742256000,
#   'OPEN': 84039.85,
#   'HIGH': 84039.85,
#   'LOW': 83721,
#   'CLOSE': 83783.63,
#   'VOLUME': 4.30152973,
#   'QUOTE_VOLUME': 360642.302919979,
#   'VOLUME_BUY': 2.1270776,
#   'QUOTE_VOLUME_BUY': 178353.159669209,
#   'VOLUME_SELL': 2.17445213,
#   'QUOTE_VOLUME_SELL': 182289.143250769,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742259600,
#   'OPEN': 83783.63,
#   'HIGH': 83913.74,
#   'LOW': 83014.62,
#   'CLOSE': 83161.6,
#   'VOLUME': 12.12516493,
#   'QUOTE_VOLUME': 1010396.18076915,
#   'VOLUME_BUY': 5.92556289,
#   'QUOTE_VOLUME_BUY': 493656.08598771,
#   'VOLUME_SELL': 6.19960204,
#   'QUOTE_VOLUME_SELL': 516740.094781447,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742263200,
#   'OPEN': 83161.6,
#   'HIGH': 83517.09,
#   'LOW': 83087.04,
#   'CLOSE': 83377.91,
#   'VOLUME': 4.0865059,
#   'QUOTE_VOLUME': 340723.809250909,
#   'VOLUME_BUY': 2.25979446,
#   'QUOTE_VOLUME_BUY': 188457.168385206,
#   'VOLUME_SELL': 1.82671144,
#   'QUOTE_VOLUME_SELL': 152266.640865705,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742266800,
#   'OPEN': 83377.91,
#   'HIGH': 83377.91,
#   'LOW': 82955.43,
#   'CLOSE': 83140.47,
#   'VOLUME': 6.83422305,
#   'QUOTE_VOLUME': 567999.503921125,
#   'VOLUME_BUY': 2.20228622,
#   'QUOTE_VOLUME_BUY': 183034.564279012,
#   'VOLUME_SELL': 4.63193683,
#   'QUOTE_VOLUME_SELL': 384964.939642112,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742270400,
#   'OPEN': 83140.47,
#   'HIGH': 83211.55,
#   'LOW': 82851.1,
#   'CLOSE': 82973.65,
#   'VOLUME': 9.13786564,
#   'QUOTE_VOLUME': 758747.848777636,
#   'VOLUME_BUY': 4.6150406,
#   'QUOTE_VOLUME_BUY': 383162.3146804,
#   'VOLUME_SELL': 4.52282504,
#   'QUOTE_VOLUME_SELL': 375585.534097239,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742274000,
#   'OPEN': 82973.65,
#   'HIGH': 83131.89,
#   'LOW': 82900.75,
#   'CLOSE': 83015.71,
#   'VOLUME': 5.85114868,
#   'QUOTE_VOLUME': 485623.919835451,
#   'VOLUME_BUY': 2.25750661,
#   'QUOTE_VOLUME_BUY': 187337.915428696,
#   'VOLUME_SELL': 3.59364207,
#   'QUOTE_VOLUME_SELL': 298286.004406757,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742277600,
#   'OPEN': 83015.71,
#   'HIGH': 83015.71,
#   'LOW': 82250.82,
#   'CLOSE': 82480.71,
#   'VOLUME': 15.28584484,
#   'QUOTE_VOLUME': 1261068.90596195,
#   'VOLUME_BUY': 7.90435495,
#   'QUOTE_VOLUME_BUY': 652098.336432462,
#   'VOLUME_SELL': 7.38148989,
#   'QUOTE_VOLUME_SELL': 608970.569529491,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742281200,
#   'OPEN': 82480.71,
#   'HIGH': 83282.21,
#   'LOW': 82370.84,
#   'CLOSE': 83153.08,
#   'VOLUME': 17.68095922,
#   'QUOTE_VOLUME': 1466853.52154938,
#   'VOLUME_BUY': 10.96722955,
#   'QUOTE_VOLUME_BUY': 909768.113757369,
#   'VOLUME_SELL': 6.71372967,
#   'QUOTE_VOLUME_SELL': 557085.407791998,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742284800,
#   'OPEN': 83153.08,
#   'HIGH': 83452.06,
#   'LOW': 83056.88,
#   'CLOSE': 83252.01,
#   'VOLUME': 6.39843686,
#   'QUOTE_VOLUME': 532849.103242457,
#   'VOLUME_BUY': 2.99770337,
#   'QUOTE_VOLUME_BUY': 249651.343823188,
#   'VOLUME_SELL': 3.40073349,
#   'QUOTE_VOLUME_SELL': 283197.759419268,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742288400,
#   'OPEN': 83252.01,
#   'HIGH': 83339.07,
#   'LOW': 82801.39,
#   'CLOSE': 82810.96,
#   'VOLUME': 4.99564123,
#   'QUOTE_VOLUME': 415410.257398892,
#   'VOLUME_BUY': 2.38093581,
#   'QUOTE_VOLUME_BUY': 197974.0406389,
#   'VOLUME_SELL': 2.61470542,
#   'QUOTE_VOLUME_SELL': 217436.216759995,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742292000,
#   'OPEN': 82810.96,
#   'HIGH': 82924.21,
#   'LOW': 82592.84,
#   'CLOSE': 82818.94,
#   'VOLUME': 7.28851915,
#   'QUOTE_VOLUME': 603066.973505262,
#   'VOLUME_BUY': 3.74172594,
#   'QUOTE_VOLUME_BUY': 309634.423797933,
#   'VOLUME_SELL': 3.54679321,
#   'QUOTE_VOLUME_SELL': 293432.549707328,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742295600,
#   'OPEN': 82818.94,
#   'HIGH': 82845.47,
#   'LOW': 82497.17,
#   'CLOSE': 82588.67,
#   'VOLUME': 3.16854069,
#   'QUOTE_VOLUME': 261861.213637257,
#   'VOLUME_BUY': 1.1683238,
#   'QUOTE_VOLUME_BUY': 96559.763499398,
#   'VOLUME_SELL': 2.00021689,
#   'QUOTE_VOLUME_SELL': 165301.450137857,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742299200,
#   'OPEN': 82588.67,
#   'HIGH': 82833.31,
#   'LOW': 82338.06,
#   'CLOSE': 82389.51,
#   'VOLUME': 7.3918952,
#   'QUOTE_VOLUME': 610162.119013134,
#   'VOLUME_BUY': 4.02036389,
#   'QUOTE_VOLUME_BUY': 331841.15341669,
#   'VOLUME_SELL': 3.37153131,
#   'QUOTE_VOLUME_SELL': 278320.965596444,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742302800,
#   'OPEN': 82389.51,
#   'HIGH': 82444.89,
#   'LOW': 81154.91,
#   'CLOSE': 81368.79,
#   'VOLUME': 34.44465156,
#   'QUOTE_VOLUME': 2814788.91404899,
#   'VOLUME_BUY': 17.67988028,
#   'QUOTE_VOLUME_BUY': 1444129.96831108,
#   'VOLUME_SELL': 16.76477128,
#   'QUOTE_VOLUME_SELL': 1370658.94573785,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742306400,
#   'OPEN': 81368.79,
#   'HIGH': 81961.04,
#   'LOW': 81150,
#   'CLOSE': 81841.29,
#   'VOLUME': 31.19872269,
#   'QUOTE_VOLUME': 2541807.86074509,
#   'VOLUME_BUY': 16.51080231,
#   'QUOTE_VOLUME_BUY': 1345261.84191757,
#   'VOLUME_SELL': 14.68792038,
#   'QUOTE_VOLUME_SELL': 1196546.01882741,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742310000,
#   'OPEN': 81841.29,
#   'HIGH': 82181.86,
#   'LOW': 81527.64,
#   'CLOSE': 81575.92,
#   'VOLUME': 12.59172662,
#   'QUOTE_VOLUME': 1029642.59767207,
#   'VOLUME_BUY': 6.68833082,
#   'QUOTE_VOLUME_BUY': 546776.614081889,
#   'VOLUME_SELL': 5.9033958,
#   'QUOTE_VOLUME_SELL': 482865.983590216,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742313600,
#   'OPEN': 81575.92,
#   'HIGH': 82150.75,
#   'LOW': 81552.17,
#   'CLOSE': 81871.53,
#   'VOLUME': 7.53902392,
#   'QUOTE_VOLUME': 616534.690787082,
#   'VOLUME_BUY': 3.84233815,
#   'QUOTE_VOLUME_BUY': 314255.499250189,
#   'VOLUME_SELL': 3.69668577,
#   'QUOTE_VOLUME_SELL': 302279.191536894,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742317200,
#   'OPEN': 81871.53,
#   'HIGH': 81979.76,
#   'LOW': 81332.17,
#   'CLOSE': 81457.49,
#   'VOLUME': 16.77899063,
#   'QUOTE_VOLUME': 1369162.96647647,
#   'VOLUME_BUY': 8.44458647,
#   'QUOTE_VOLUME_BUY': 689081.652415352,
#   'VOLUME_SELL': 8.33440416,
#   'QUOTE_VOLUME_SELL': 680081.314061083,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742320800,
#   'OPEN': 81457.49,
#   'HIGH': 81943.27,
#   'LOW': 81246.54,
#   'CLOSE': 81826.12,
#   'VOLUME': 11.4551657,
#   'QUOTE_VOLUME': 935031.155715604,
#   'VOLUME_BUY': 5.58402696,
#   'QUOTE_VOLUME_BUY': 455789.420400297,
#   'VOLUME_SELL': 5.87113874,
#   'QUOTE_VOLUME_SELL': 479241.735315316,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742324400,
#   'OPEN': 81826.12,
#   'HIGH': 82493.03,
#   'LOW': 81775.36,
#   'CLOSE': 82330.26,
#   'VOLUME': 16.64078775,
#   'QUOTE_VOLUME': 1366639.66482629,
#   'VOLUME_BUY': 8.45203816,
#   'QUOTE_VOLUME_BUY': 694212.471391591,
#   'VOLUME_SELL': 8.18874959,
#   'QUOTE_VOLUME_SELL': 672427.193434648,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742328000,
#   'OPEN': 82330.26,
#   'HIGH': 82369.49,
#   'LOW': 81877.86,
#   'CLOSE': 82059.55,
#   'VOLUME': 6.36671719,
#   'QUOTE_VOLUME': 522683.682824682,
#   'VOLUME_BUY': 3.30682299,
#   'QUOTE_VOLUME_BUY': 271580.421479412,
#   'VOLUME_SELL': 3.0598942,
#   'QUOTE_VOLUME_SELL': 251103.261345275,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742331600,
#   'OPEN': 82059.55,
#   'HIGH': 82214.52,
#   'LOW': 81934.53,
#   'CLOSE': 82060.42,
#   'VOLUME': 2.74150026,
#   'QUOTE_VOLUME': 224976.077347266,
#   'VOLUME_BUY': 0.99891525,
#   'QUOTE_VOLUME_BUY': 81962.5901825502,
#   'VOLUME_SELL': 1.74258501,
#   'QUOTE_VOLUME_SELL': 143013.487164713,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742335200,
#   'OPEN': 82060.42,
#   'HIGH': 82567.34,
#   'LOW': 81993.98,
#   'CLOSE': 82389.31,
#   'VOLUME': 6.95483008,
#   'QUOTE_VOLUME': 572354.996880142,
#   'VOLUME_BUY': 3.57463567,
#   'QUOTE_VOLUME_BUY': 294122.391996852,
#   'VOLUME_SELL': 3.38019441,
#   'QUOTE_VOLUME_SELL': 278232.604883291,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742338800,
#   'OPEN': 82389.31,
#   'HIGH': 82813.3,
#   'LOW': 82389.31,
#   'CLOSE': 82733.09,
#   'VOLUME': 9.06765384,
#   'QUOTE_VOLUME': 749444.055080575,
#   'VOLUME_BUY': 3.96753933,
#   'QUOTE_VOLUME_BUY': 327958.378302653,
#   'VOLUME_SELL': 5.10011451,
#   'QUOTE_VOLUME_SELL': 421485.676777929,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742342400,
#   'OPEN': 82733.09,
#   'HIGH': 83248,
#   'LOW': 82610.64,
#   'CLOSE': 83120.13,
#   'VOLUME': 7.00582373,
#   'QUOTE_VOLUME': 581581.822477908,
#   'VOLUME_BUY': 3.64068491,
#   'QUOTE_VOLUME_BUY': 302155.534262803,
#   'VOLUME_SELL': 3.36513882,
#   'QUOTE_VOLUME_SELL': 279426.288215111,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742346000,
#   'OPEN': 83120.13,
#   'HIGH': 83164.84,
#   'LOW': 82613.62,
#   'CLOSE': 82613.62,
#   'VOLUME': 6.28417667,
#   'QUOTE_VOLUME': 521072.479220914,
#   'VOLUME_BUY': 2.83908228,
#   'QUOTE_VOLUME_BUY': 235367.791249639,
#   'VOLUME_SELL': 3.44509439,
#   'QUOTE_VOLUME_SELL': 285704.687971273,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742349600,
#   'OPEN': 82613.62,
#   'HIGH': 82903.86,
#   'LOW': 82565.26,
#   'CLOSE': 82903.86,
#   'VOLUME': 4.4230842,
#   'QUOTE_VOLUME': 366032.542531123,
#   'VOLUME_BUY': 2.34090443,
#   'QUOTE_VOLUME_BUY': 193711.164670245,
#   'VOLUME_SELL': 2.08217977,
#   'QUOTE_VOLUME_SELL': 172321.377860881,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742353200,
#   'OPEN': 82903.86,
#   'HIGH': 83092.26,
#   'LOW': 82747.4,
#   'CLOSE': 83039.71,
#   'VOLUME': 3.93990719,
#   'QUOTE_VOLUME': 326752.904931745,
#   'VOLUME_BUY': 1.98233917,
#   'QUOTE_VOLUME_BUY': 164395.599330699,
#   'VOLUME_SELL': 1.95756802,
#   'QUOTE_VOLUME_SELL': 162357.305601042,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742356800,
#   'OPEN': 83039.71,
#   'HIGH': 83083.95,
#   'LOW': 82788.43,
#   'CLOSE': 82957.34,
#   'VOLUME': 8.68302756,
#   'QUOTE_VOLUME': 720303.776928363,
#   'VOLUME_BUY': 3.82962304,
#   'QUOTE_VOLUME_BUY': 317681.788004052,
#   'VOLUME_SELL': 4.85340452,
#   'QUOTE_VOLUME_SELL': 402621.988924311,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742360400,
#   'OPEN': 82957.34,
#   'HIGH': 83330.58,
#   'LOW': 82911.3,
#   'CLOSE': 83260.65,
#   'VOLUME': 16.01586455,
#   'QUOTE_VOLUME': 1331861.94633401,
#   'VOLUME_BUY': 8.30978782,
#   'QUOTE_VOLUME_BUY': 690869.843693057,
#   'VOLUME_SELL': 7.70607673,
#   'QUOTE_VOLUME_SELL': 640992.102641014,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742364000,
#   'OPEN': 83260.65,
#   'HIGH': 83347.18,
#   'LOW': 83115.89,
#   'CLOSE': 83207.89,
#   'VOLUME': 11.59167307,
#   'QUOTE_VOLUME': 964612.89376777,
#   'VOLUME_BUY': 6.13686688,
#   'QUOTE_VOLUME_BUY': 510673.339655335,
#   'VOLUME_SELL': 5.45480619,
#   'QUOTE_VOLUME_SELL': 453939.554112429,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742367600,
#   'OPEN': 83207.89,
#   'HIGH': 83375.26,
#   'LOW': 83046.41,
#   'CLOSE': 83179.18,
#   'VOLUME': 19.67046203,
#   'QUOTE_VOLUME': 1636264.77922948,
#   'VOLUME_BUY': 9.67030108,
#   'QUOTE_VOLUME_BUY': 804361.189874122,
#   'VOLUME_SELL': 10.00016095,
#   'QUOTE_VOLUME_SELL': 831903.589355228,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742371200,
#   'OPEN': 83179.18,
#   'HIGH': 83512.55,
#   'LOW': 83179.18,
#   'CLOSE': 83426.04,
#   'VOLUME': 8.86229841,
#   'QUOTE_VOLUME': 738747.109116588,
#   'VOLUME_BUY': 4.75429003,
#   'QUOTE_VOLUME_BUY': 396345.584185647,
#   'VOLUME_SELL': 4.10800838,
#   'QUOTE_VOLUME_SELL': 342401.524930941,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742374800,
#   'OPEN': 83426.04,
#   'HIGH': 83605.34,
#   'LOW': 83368.76,
#   'CLOSE': 83530.57,
#   'VOLUME': 5.684449,
#   'QUOTE_VOLUME': 474648.513140263,
#   'VOLUME_BUY': 2.3114833,
#   'QUOTE_VOLUME_BUY': 192977.139694178,
#   'VOLUME_SELL': 3.3729657,
#   'QUOTE_VOLUME_SELL': 281671.373446087,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742378400,
#   'OPEN': 83530.57,
#   'HIGH': 83841.22,
#   'LOW': 83461.75,
#   'CLOSE': 83491.15,
#   'VOLUME': 13.93489682,
#   'QUOTE_VOLUME': 1165633.89457998,
#   'VOLUME_BUY': 6.64015428,
#   'QUOTE_VOLUME_BUY': 555532.883652163,
#   'VOLUME_SELL': 7.29474254,
#   'QUOTE_VOLUME_SELL': 610101.010927821,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742382000,
#   'OPEN': 83491.15,
#   'HIGH': 84099.27,
#   'LOW': 83396.56,
#   'CLOSE': 83882.71,
#   'VOLUME': 13.86890649,
#   'QUOTE_VOLUME': 1162757.28716445,
#   'VOLUME_BUY': 6.16765288,
#   'QUOTE_VOLUME_BUY': 516951.427919305,
#   'VOLUME_SELL': 7.70125361,
#   'QUOTE_VOLUME_SELL': 645805.859245167,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742385600,
#   'OPEN': 83882.71,
#   'HIGH': 83917.18,
#   'LOW': 83518.74,
#   'CLOSE': 83760.84,
#   'VOLUME': 4.76967522,
#   'QUOTE_VOLUME': 399167.508609217,
#   'VOLUME_BUY': 2.34564735,
#   'QUOTE_VOLUME_BUY': 196311.162672127,
#   'VOLUME_SELL': 2.42402787,
#   'QUOTE_VOLUME_SELL': 202856.34593709,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742389200,
#   'OPEN': 83760.84,
#   'HIGH': 84335.87,
#   'LOW': 83627.93,
#   'CLOSE': 84089.18,
#   'VOLUME': 34.79593756,
#   'QUOTE_VOLUME': 2924603.03947472,
#   'VOLUME_BUY': 17.44053748,
#   'QUOTE_VOLUME_BUY': 1465721.3087873,
#   'VOLUME_SELL': 17.35540008,
#   'QUOTE_VOLUME_SELL': 1458881.73068731,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742392800,
#   'OPEN': 84089.18,
#   'HIGH': 84403.12,
#   'LOW': 83884.71,
#   'CLOSE': 84282.92,
#   'VOLUME': 21.59449317,
#   'QUOTE_VOLUME': 1818506.02703183,
#   'VOLUME_BUY': 9.04872228,
#   'QUOTE_VOLUME_BUY': 761884.269471706,
#   'VOLUME_SELL': 12.54577089,
#   'QUOTE_VOLUME_SELL': 1056621.75756012,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742396400,
#   'OPEN': 84282.92,
#   'HIGH': 84889.96,
#   'LOW': 84115.89,
#   'CLOSE': 84747.07,
#   'VOLUME': 15.49172733,
#   'QUOTE_VOLUME': 1309131.19796937,
#   'VOLUME_BUY': 7.76069562,
#   'QUOTE_VOLUME_BUY': 655771.363972594,
#   'VOLUME_SELL': 7.73103171,
#   'QUOTE_VOLUME_SELL': 653359.833996788,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742400000,
#   'OPEN': 84747.07,
#   'HIGH': 84826.7,
#   'LOW': 84438.9,
#   'CLOSE': 84575.87,
#   'VOLUME': 16.71317273,
#   'QUOTE_VOLUME': 1413810.47581074,
#   'VOLUME_BUY': 8.69342051,
#   'QUOTE_VOLUME_BUY': 735352.127121286,
#   'VOLUME_SELL': 8.01975222,
#   'QUOTE_VOLUME_SELL': 678458.348689405,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742403600,
#   'OPEN': 84575.87,
#   'HIGH': 84710.64,
#   'LOW': 83795.13,
#   'CLOSE': 84264.48,
#   'VOLUME': 44.26838598,
#   'QUOTE_VOLUME': 3732056.95603003,
#   'VOLUME_BUY': 24.96738717,
#   'QUOTE_VOLUME_BUY': 2104515.08306743,
#   'VOLUME_SELL': 19.30099881,
#   'QUOTE_VOLUME_SELL': 1627541.87296267,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742407200,
#   'OPEN': 84264.48,
#   'HIGH': 85894.98,
#   'LOW': 83587.39,
#   'CLOSE': 85623.19,
#   'VOLUME': 94.51939009,
#   'QUOTE_VOLUME': 7997698.88267966,
#   'VOLUME_BUY': 48.3204242,
#   'QUOTE_VOLUME_BUY': 4089095.28055251,
#   'VOLUME_SELL': 46.19896589,
#   'QUOTE_VOLUME_SELL': 3908603.60212703,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742410800,
#   'OPEN': 85623.19,
#   'HIGH': 85946.76,
#   'LOW': 84943.55,
#   'CLOSE': 85433.65,
#   'VOLUME': 70.78717437,
#   'QUOTE_VOLUME': 6049326.90165246,
#   'VOLUME_BUY': 35.71286908,
#   'QUOTE_VOLUME_BUY': 3052017.58795268,
#   'VOLUME_SELL': 35.07430529,
#   'QUOTE_VOLUME_SELL': 2997309.31369967,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742414400,
#   'OPEN': 85433.65,
#   'HIGH': 85857.66,
#   'LOW': 85217.89,
#   'CLOSE': 85363.81,
#   'VOLUME': 15.84705681,
#   'QUOTE_VOLUME': 1356187.67151002,
#   'VOLUME_BUY': 8.98273569,
#   'QUOTE_VOLUME_BUY': 768729.587633121,
#   'VOLUME_SELL': 6.86432112,
#   'QUOTE_VOLUME_SELL': 587458.083876796,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742418000,
#   'OPEN': 85363.81,
#   'HIGH': 85925.1,
#   'LOW': 85347.7,
#   'CLOSE': 85647.85,
#   'VOLUME': 7.26473121,
#   'QUOTE_VOLUME': 622166.009518603,
#   'VOLUME_BUY': 2.92424654,
#   'QUOTE_VOLUME_BUY': 250472.454519366,
#   'VOLUME_SELL': 4.34048467,
#   'QUOTE_VOLUME_SELL': 371693.554999237,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742421600,
#   'OPEN': 85647.85,
#   'HIGH': 86520.69,
#   'LOW': 85647.85,
#   'CLOSE': 86166.38,
#   'VOLUME': 13.49371484,
#   'QUOTE_VOLUME': 1161618.53288878,
#   'VOLUME_BUY': 7.31510011,
#   'QUOTE_VOLUME_BUY': 629724.269211219,
#   'VOLUME_SELL': 6.17861473,
#   'QUOTE_VOLUME_SELL': 531894.263677531,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742425200,
#   'OPEN': 86166.38,
#   'HIGH': 87009.98,
#   'LOW': 86166.38,
#   'CLOSE': 86837.21,
#   'VOLUME': 14.98884931,
#   'QUOTE_VOLUME': 1298830.54429944,
#   'VOLUME_BUY': 8.36861038,
#   'QUOTE_VOLUME_BUY': 725172.530958571,
#   'VOLUME_SELL': 6.62023893,
#   'QUOTE_VOLUME_SELL': 573658.013340898,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742428800,
#   'OPEN': 86837.21,
#   'HIGH': 87466.44,
#   'LOW': 85960.18,
#   'CLOSE': 86027.95,
#   'VOLUME': 34.48744474,
#   'QUOTE_VOLUME': 2989753.49126282,
#   'VOLUME_BUY': 14.87841103,
#   'QUOTE_VOLUME_BUY': 1290471.93796644,
#   'VOLUME_SELL': 19.60903371,
#   'QUOTE_VOLUME_SELL': 1699281.55329632,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742432400,
#   'OPEN': 86027.95,
#   'HIGH': 86363.16,
#   'LOW': 85730.64,
#   'CLOSE': 85839.29,
#   'VOLUME': 15.02723619,
#   'QUOTE_VOLUME': 1292261.74803821,
#   'VOLUME_BUY': 7.27487835,
#   'QUOTE_VOLUME_BUY': 625616.923735186,
#   'VOLUME_SELL': 7.75235784,
#   'QUOTE_VOLUME_SELL': 666644.824303031,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742436000,
#   'OPEN': 85839.29,
#   'HIGH': 86117.38,
#   'LOW': 85634.97,
#   'CLOSE': 86071.38,
#   'VOLUME': 8.81182258,
#   'QUOTE_VOLUME': 756666.913570596,
#   'VOLUME_BUY': 4.40184406,
#   'QUOTE_VOLUME_BUY': 378066.086889244,
#   'VOLUME_SELL': 4.40997852,
#   'QUOTE_VOLUME_SELL': 378600.826681351,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742439600,
#   'OPEN': 86071.38,
#   'HIGH': 86133.59,
#   'LOW': 85828.93,
#   'CLOSE': 85877.52,
#   'VOLUME': 3.95823124,
#   'QUOTE_VOLUME': 340265.72179417,
#   'VOLUME_BUY': 1.68730013,
#   'QUOTE_VOLUME_BUY': 145046.587449567,
#   'VOLUME_SELL': 2.27093111,
#   'QUOTE_VOLUME_SELL': 195219.134344602,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742443200,
#   'OPEN': 85877.52,
#   'HIGH': 85924.14,
#   'LOW': 85434.15,
#   'CLOSE': 85672.82,
#   'VOLUME': 5.26487609,
#   'QUOTE_VOLUME': 450953.216259401,
#   'VOLUME_BUY': 2.59677267,
#   'QUOTE_VOLUME_BUY': 222430.951022265,
#   'VOLUME_SELL': 2.66810342,
#   'QUOTE_VOLUME_SELL': 228522.265237141,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742446800,
#   'OPEN': 85672.82,
#   'HIGH': 85832.35,
#   'LOW': 85476.5,
#   'CLOSE': 85832.35,
#   'VOLUME': 2.0522693,
#   'QUOTE_VOLUME': 175730.439188003,
#   'VOLUME_BUY': 1.39973441,
#   'QUOTE_VOLUME_BUY': 119861.849005048,
#   'VOLUME_SELL': 0.65253489,
#   'QUOTE_VOLUME_SELL': 55868.5901829561,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742450400,
#   'OPEN': 85832.35,
#   'HIGH': 86011.87,
#   'LOW': 85648.58,
#   'CLOSE': 85803.9,
#   'VOLUME': 4.04039357,
#   'QUOTE_VOLUME': 346648.907780778,
#   'VOLUME_BUY': 1.89769354,
#   'QUOTE_VOLUME_BUY': 162810.614629004,
#   'VOLUME_SELL': 2.14270003,
#   'QUOTE_VOLUME_SELL': 183838.293151777,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742454000,
#   'OPEN': 85803.9,
#   'HIGH': 85964.61,
#   'LOW': 85724.29,
#   'CLOSE': 85838.45,
#   'VOLUME': 3.57942053,
#   'QUOTE_VOLUME': 307396.369725391,
#   'VOLUME_BUY': 2.13906049,
#   'QUOTE_VOLUME_BUY': 183698.769206693,
#   'VOLUME_SELL': 1.44036004,
#   'QUOTE_VOLUME_SELL': 123697.600518694,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742457600,
#   'OPEN': 85838.45,
#   'HIGH': 86312.46,
#   'LOW': 85715.79,
#   'CLOSE': 86234.88,
#   'VOLUME': 4.22148704,
#   'QUOTE_VOLUME': 363446.771023565,
#   'VOLUME_BUY': 2.18200413,
#   'QUOTE_VOLUME_BUY': 187901.182099373,
#   'VOLUME_SELL': 2.03948291,
#   'QUOTE_VOLUME_SELL': 175545.588924195,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742461200,
#   'OPEN': 86234.88,
#   'HIGH': 86286.69,
#   'LOW': 85802.34,
#   'CLOSE': 85885.27,
#   'VOLUME': 5.41823147,
#   'QUOTE_VOLUME': 466465.658214056,
#   'VOLUME_BUY': 3.32131854,
#   'QUOTE_VOLUME_BUY': 286086.277979824,
#   'VOLUME_SELL': 2.09691293,
#   'QUOTE_VOLUME_SELL': 180379.380234229,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742464800,
#   'OPEN': 85885.27,
#   'HIGH': 85937.28,
#   'LOW': 84723.88,
#   'CLOSE': 85177.92,
#   'VOLUME': 18.22598121,
#   'QUOTE_VOLUME': 1553215.41127798,
#   'VOLUME_BUY': 9.64416909,
#   'QUOTE_VOLUME_BUY': 822033.200427526,
#   'VOLUME_SELL': 8.58181212,
#   'QUOTE_VOLUME_SELL': 731182.210850487,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742468400,
#   'OPEN': 85177.92,
#   'HIGH': 85510.2,
#   'LOW': 85172.32,
#   'CLOSE': 85507.99,
#   'VOLUME': 4.98471507,
#   'QUOTE_VOLUME': 425550.569081848,
#   'VOLUME_BUY': 2.41737107,
#   'QUOTE_VOLUME_BUY': 206362.075880841,
#   'VOLUME_SELL': 2.567344,
#   'QUOTE_VOLUME_SELL': 219188.493201007,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742472000,
#   'OPEN': 85507.99,
#   'HIGH': 85565.21,
#   'LOW': 85204.24,
#   'CLOSE': 85356.29,
#   'VOLUME': 5.31997954,
#   'QUOTE_VOLUME': 454092.191066328,
#   'VOLUME_BUY': 2.96583216,
#   'QUOTE_VOLUME_BUY': 253175.99918946,
#   'VOLUME_SELL': 2.35414738,
#   'QUOTE_VOLUME_SELL': 200916.191876866,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742475600,
#   'OPEN': 85356.29,
#   'HIGH': 85869.35,
#   'LOW': 85078.14,
#   'CLOSE': 85516.59,
#   'VOLUME': 16.24436701,
#   'QUOTE_VOLUME': 1388107.81917197,
#   'VOLUME_BUY': 9.17241976,
#   'QUOTE_VOLUME_BUY': 783854.089515868,
#   'VOLUME_SELL': 7.07194725,
#   'QUOTE_VOLUME_SELL': 604253.72965611,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742479200,
#   'OPEN': 85516.59,
#   'HIGH': 86529.55,
#   'LOW': 85450.73,
#   'CLOSE': 86129.84,
#   'VOLUME': 21.54140105,
#   'QUOTE_VOLUME': 1855438.51369928,
#   'VOLUME_BUY': 10.97033517,
#   'QUOTE_VOLUME_BUY': 944751.760445822,
#   'VOLUME_SELL': 10.57106588,
#   'QUOTE_VOLUME_SELL': 910686.753253445,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742482800,
#   'OPEN': 86129.84,
#   'HIGH': 86206.27,
#   'LOW': 84580.09,
#   'CLOSE': 84663.92,
#   'VOLUME': 62.63289502,
#   'QUOTE_VOLUME': 5342557.64037393,
#   'VOLUME_BUY': 29.31064943,
#   'QUOTE_VOLUME_BUY': 2499629.11456467,
#   'VOLUME_SELL': 33.32224559,
#   'QUOTE_VOLUME_SELL': 2842928.52580939,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742486400,
#   'OPEN': 84663.92,
#   'HIGH': 84920.32,
#   'LOW': 83653.14,
#   'CLOSE': 83798.33,
#   'VOLUME': 38.19975153,
#   'QUOTE_VOLUME': 3219521.41313272,
#   'VOLUME_BUY': 19.10937057,
#   'QUOTE_VOLUME_BUY': 1610121.60710286,
#   'VOLUME_SELL': 19.09038096,
#   'QUOTE_VOLUME_SELL': 1609399.8060299,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742490000,
#   'OPEN': 83798.33,
#   'HIGH': 84365.7,
#   'LOW': 83747.62,
#   'CLOSE': 84059.46,
#   'VOLUME': 22.67339559,
#   'QUOTE_VOLUME': 1905289.53521683,
#   'VOLUME_BUY': 13.09483746,
#   'QUOTE_VOLUME_BUY': 1100405.42858371,
#   'VOLUME_SELL': 9.57855813,
#   'QUOTE_VOLUME_SELL': 804884.106633156,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742493600,
#   'OPEN': 84059.46,
#   'HIGH': 84346.59,
#   'LOW': 83953.02,
#   'CLOSE': 84064.66,
#   'VOLUME': 16.08739015,
#   'QUOTE_VOLUME': 1353051.26794103,
#   'VOLUME_BUY': 8.97410003,
#   'QUOTE_VOLUME_BUY': 754616.362718735,
#   'VOLUME_SELL': 7.11329012,
#   'QUOTE_VOLUME_SELL': 598434.905222276,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742497200,
#   'OPEN': 84064.66,
#   'HIGH': 84418.65,
#   'LOW': 83919.87,
#   'CLOSE': 84174.19,
#   'VOLUME': 17.61917864,
#   'QUOTE_VOLUME': 1483403.89579399,
#   'VOLUME_BUY': 8.27543423,
#   'QUOTE_VOLUME_BUY': 696803.77169503,
#   'VOLUME_SELL': 9.34374441,
#   'QUOTE_VOLUME_SELL': 786600.124098941,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742500800,
#   'OPEN': 84174.19,
#   'HIGH': 84611.93,
#   'LOW': 84140.96,
#   'CLOSE': 84540.27,
#   'VOLUME': 7.21929408,
#   'QUOTE_VOLUME': 609504.617836581,
#   'VOLUME_BUY': 3.32539572,
#   'QUOTE_VOLUME_BUY': 280817.237917518,
#   'VOLUME_SELL': 3.89389836,
#   'QUOTE_VOLUME_SELL': 328687.379919061,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742504400,
#   'OPEN': 84540.27,
#   'HIGH': 84609.13,
#   'LOW': 84256.17,
#   'CLOSE': 84356.04,
#   'VOLUME': 3.78513422,
#   'QUOTE_VOLUME': 319677.285004671,
#   'VOLUME_BUY': 1.6956575,
#   'QUOTE_VOLUME_BUY': 143238.935605373,
#   'VOLUME_SELL': 2.08947672,
#   'QUOTE_VOLUME_SELL': 176438.349399297,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1742508000,
#   'OPEN': 84356.04,
#   'HIGH': 84502.74,
#   'LOW': 84010.9,
#   'CLOSE': 84107.71,
#   'VOLUME': 13.95529561,
#   'QUOTE_VOLUME': 1175027.18849111,
#   'VOLUME_BUY': 6.08736512,
#   'QUOTE_VOLUME_BUY': 512450.091030467,
#   'VOLUME_SELL': 7.86793049,
# ...
#   'QUOTE_VOLUME': 269398.753388921,
#   'VOLUME_BUY': 1.51771614,
#   'QUOTE_VOLUME_BUY': 140585.217575843,
#   'VOLUME_SELL': 1.39022125,
#   'QUOTE_VOLUME_SELL': 128813.535813083,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745499600,
#   'OPEN': 92751.22,
#   'HIGH': 92965.18,
#   'LOW': 92565.97,
#   'CLOSE': 92832.71,
#   'VOLUME': 7.9504621,
#   'QUOTE_VOLUME': 737687.446301029,
#   'VOLUME_BUY': 5.4963592,
#   'QUOTE_VOLUME_BUY': 509993.932485759,
#   'VOLUME_SELL': 2.4541029,
#   'QUOTE_VOLUME_SELL': 227693.513815263,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745503200,
#   'OPEN': 92832.71,
#   'HIGH': 93393.96,
#   'LOW': 92650.92,
#   'CLOSE': 93131.75,
#   'VOLUME': 7.42189651,
#   'QUOTE_VOLUME': 690368.101608561,
#   'VOLUME_BUY': 3.57723297,
#   'QUOTE_VOLUME_BUY': 332722.143114413,
#   'VOLUME_SELL': 3.84466354,
#   'QUOTE_VOLUME_SELL': 357645.958494157,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745506800,
#   'OPEN': 93131.75,
#   'HIGH': 93459.36,
#   'LOW': 93051.23,
#   'CLOSE': 93205.08,
#   'VOLUME': 9.4221847,
#   'QUOTE_VOLUME': 879109.752070651,
#   'VOLUME_BUY': 3.8841664,
#   'QUOTE_VOLUME_BUY': 362357.680995779,
#   'VOLUME_SELL': 5.5380183,
#   'QUOTE_VOLUME_SELL': 516752.071074876,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745510400,
#   'OPEN': 93205.08,
#   'HIGH': 93601.37,
#   'LOW': 93205.08,
#   'CLOSE': 93359.05,
#   'VOLUME': 11.60051363,
#   'QUOTE_VOLUME': 1084533.24455291,
#   'VOLUME_BUY': 4.38784819,
#   'QUOTE_VOLUME_BUY': 410235.720615086,
#   'VOLUME_SELL': 7.21266544,
#   'QUOTE_VOLUME_SELL': 674297.523937765,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745514000,
#   'OPEN': 93359.05,
#   'HIGH': 93395.49,
#   'LOW': 92682.89,
#   'CLOSE': 93020.69,
#   'VOLUME': 6.18408347,
#   'QUOTE_VOLUME': 575065.732329825,
#   'VOLUME_BUY': 2.67446222,
#   'QUOTE_VOLUME_BUY': 248706.849299607,
#   'VOLUME_SELL': 3.50962125,
#   'QUOTE_VOLUME_SELL': 326358.883030218,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745517600,
#   'OPEN': 93020.69,
#   'HIGH': 93451.04,
#   'LOW': 93014.4,
#   'CLOSE': 93394.61,
#   'VOLUME': 7.85719037,
#   'QUOTE_VOLUME': 732864.270962821,
#   'VOLUME_BUY': 2.87850609,
#   'QUOTE_VOLUME_BUY': 268501.23564537,
#   'VOLUME_SELL': 4.97868428,
#   'QUOTE_VOLUME_SELL': 464363.035317447,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745521200,
#   'OPEN': 93394.61,
#   'HIGH': 93679.69,
#   'LOW': 93213.73,
#   'CLOSE': 93568.07,
#   'VOLUME': 7.61913111,
#   'QUOTE_VOLUME': 712613.341242114,
#   'VOLUME_BUY': 4.63396423,
#   'QUOTE_VOLUME_BUY': 433496.61820196,
#   'VOLUME_SELL': 2.98516688,
#   'QUOTE_VOLUME_SELL': 279116.723040151,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745524800,
#   'OPEN': 93568.07,
#   'HIGH': 93664.64,
#   'LOW': 93315.17,
#   'CLOSE': 93410.77,
#   'VOLUME': 6.62407646,
#   'QUOTE_VOLUME': 619222.118800995,
#   'VOLUME_BUY': 3.02553979,
#   'QUOTE_VOLUME_BUY': 282874.404531287,
#   'VOLUME_SELL': 3.59853667,
#   'QUOTE_VOLUME_SELL': 336347.714269714,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745528400,
#   'OPEN': 93410.77,
#   'HIGH': 93569.67,
#   'LOW': 93042.16,
#   'CLOSE': 93335.76,
#   'VOLUME': 2.79551735,
#   'QUOTE_VOLUME': 260805.353830936,
#   'VOLUME_BUY': 0.68466282,
#   'QUOTE_VOLUME_BUY': 63879.0294512389,
#   'VOLUME_SELL': 2.11085453,
#   'QUOTE_VOLUME_SELL': 196926.324379701,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745532000,
#   'OPEN': 93335.76,
#   'HIGH': 93589.83,
#   'LOW': 93295.64,
#   'CLOSE': 93436.79,
#   'VOLUME': 4.51175738,
#   'QUOTE_VOLUME': 421674.555679723,
#   'VOLUME_BUY': 2.05530712,
#   'QUOTE_VOLUME_BUY': 192014.900398312,
#   'VOLUME_SELL': 2.45645026,
#   'QUOTE_VOLUME_SELL': 229659.655281407,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745535600,
#   'OPEN': 93436.79,
#   'HIGH': 94000,
#   'LOW': 93389.31,
#   'CLOSE': 93959,
#   'VOLUME': 12.02009108,
#   'QUOTE_VOLUME': 1127683.93161125,
#   'VOLUME_BUY': 7.23667013,
#   'QUOTE_VOLUME_BUY': 679167.904059131,
#   'VOLUME_SELL': 4.78342095,
#   'QUOTE_VOLUME_SELL': 448516.027552115,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745539200,
#   'OPEN': 93959,
#   'HIGH': 94011.54,
#   'LOW': 93520.09,
#   'CLOSE': 93906.42,
#   'VOLUME': 25.5209933,
#   'QUOTE_VOLUME': 2392761.69615574,
#   'VOLUME_BUY': 11.29268044,
#   'QUOTE_VOLUME_BUY': 1057966.59943053,
#   'VOLUME_SELL': 14.22831286,
#   'QUOTE_VOLUME_SELL': 1334795.09672528,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745542800,
#   'OPEN': 93906.42,
#   'HIGH': 94444.66,
#   'LOW': 93612.37,
#   'CLOSE': 93682.44,
#   'VOLUME': 8.99065136,
#   'QUOTE_VOLUME': 845117.351497848,
#   'VOLUME_BUY': 3.40929918,
#   'QUOTE_VOLUME_BUY': 320567.309020329,
#   'VOLUME_SELL': 5.58135218,
#   'QUOTE_VOLUME_SELL': 524550.042477522,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745546400,
#   'OPEN': 93682.44,
#   'HIGH': 93882.51,
#   'LOW': 92891.5,
#   'CLOSE': 93000,
#   'VOLUME': 11.21045201,
#   'QUOTE_VOLUME': 1045392.0521775,
#   'VOLUME_BUY': 3.00247711,
#   'QUOTE_VOLUME_BUY': 280133.535945099,
#   'VOLUME_SELL': 8.2079749,
#   'QUOTE_VOLUME_SELL': 765258.516232408,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745550000,
#   'OPEN': 93000,
#   'HIGH': 93383.98,
#   'LOW': 92857.79,
#   'CLOSE': 93334.39,
#   'VOLUME': 3.28381277,
#   'QUOTE_VOLUME': 305857.438322044,
#   'VOLUME_BUY': 1.71537841,
#   'QUOTE_VOLUME_BUY': 159831.613381793,
#   'VOLUME_SELL': 1.56843436,
#   'QUOTE_VOLUME_SELL': 146025.824940251,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745553600,
#   'OPEN': 93334.39,
#   'HIGH': 93494.92,
#   'LOW': 93041.32,
#   'CLOSE': 93063.16,
#   'VOLUME': 1.66574429,
#   'QUOTE_VOLUME': 155373.919181012,
#   'VOLUME_BUY': 0.85452173,
#   'QUOTE_VOLUME_BUY': 79709.5933557323,
#   'VOLUME_SELL': 0.81122256,
#   'QUOTE_VOLUME_SELL': 75664.3258252814,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745557200,
#   'OPEN': 93063.16,
#   'HIGH': 93398.41,
#   'LOW': 93036.52,
#   'CLOSE': 93215.88,
#   'VOLUME': 2.51017981,
#   'QUOTE_VOLUME': 234170.510381537,
#   'VOLUME_BUY': 1.4387551,
#   'QUOTE_VOLUME_BUY': 134191.772044733,
#   'VOLUME_SELL': 1.07142471,
#   'QUOTE_VOLUME_SELL': 99978.7383368013,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745560800,
#   'OPEN': 93215.88,
#   'HIGH': 93606.41,
#   'LOW': 93204.45,
#   'CLOSE': 93566.57,
#   'VOLUME': 1.57879779,
#   'QUOTE_VOLUME': 147462.339944409,
#   'VOLUME_BUY': 0.9208372,
#   'QUOTE_VOLUME_BUY': 86000.5515057739,
#   'VOLUME_SELL': 0.65796059,
#   'QUOTE_VOLUME_SELL': 61461.7884386336,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745564400,
#   'OPEN': 93566.57,
#   'HIGH': 93873.42,
#   'LOW': 93500.29,
#   'CLOSE': 93790.38,
#   'VOLUME': 5.43669877,
#   'QUOTE_VOLUME': 509430.812925751,
#   'VOLUME_BUY': 1.6952699,
#   'QUOTE_VOLUME_BUY': 158794.293111507,
#   'VOLUME_SELL': 3.74142887,
#   'QUOTE_VOLUME_SELL': 350636.519814243,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745568000,
#   'OPEN': 93790.38,
#   'HIGH': 93905.69,
#   'LOW': 93621.98,
#   'CLOSE': 93690.19,
#   'VOLUME': 5.60037458,
#   'QUOTE_VOLUME': 524938.62280878,
#   'VOLUME_BUY': 2.35258843,
#   'QUOTE_VOLUME_BUY': 220441.686530595,
#   'VOLUME_SELL': 3.24778615,
#   'QUOTE_VOLUME_SELL': 304496.936278189,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745571600,
#   'OPEN': 93690.19,
#   'HIGH': 93870.48,
#   'LOW': 93551.96,
#   'CLOSE': 93805.49,
#   'VOLUME': 1.81024245,
#   'QUOTE_VOLUME': 169667.099476619,
#   'VOLUME_BUY': 1.20305555,
#   'QUOTE_VOLUME_BUY': 112785.882964761,
#   'VOLUME_SELL': 0.6071869,
#   'QUOTE_VOLUME_SELL': 56881.2165118615,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745575200,
#   'OPEN': 93805.49,
#   'HIGH': 93953.68,
#   'LOW': 93587.52,
#   'CLOSE': 93655.29,
#   'VOLUME': 4.48841065,
#   'QUOTE_VOLUME': 420742.717771285,
#   'VOLUME_BUY': 1.69205752,
#   'QUOTE_VOLUME_BUY': 158630.107461752,
#   'VOLUME_SELL': 2.79635313,
#   'QUOTE_VOLUME_SELL': 262112.610309538,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745578800,
#   'OPEN': 93655.29,
#   'HIGH': 94660.59,
#   'LOW': 93655.29,
#   'CLOSE': 94541.02,
#   'VOLUME': 4.126309,
#   'QUOTE_VOLUME': 388994.603250336,
#   'VOLUME_BUY': 2.39856789,
#   'QUOTE_VOLUME_BUY': 226078.685908369,
#   'VOLUME_SELL': 1.72774111,
#   'QUOTE_VOLUME_SELL': 162915.917341965,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745582400,
#   'OPEN': 94541.02,
#   'HIGH': 95005.65,
#   'LOW': 94298.7,
#   'CLOSE': 94406.85,
#   'VOLUME': 7.63671824,
#   'QUOTE_VOLUME': 723645.071636619,
#   'VOLUME_BUY': 3.94387339,
#   'QUOTE_VOLUME_BUY': 373921.752624444,
#   'VOLUME_SELL': 3.69284485,
#   'QUOTE_VOLUME_SELL': 349723.319012182,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745586000,
#   'OPEN': 94406.85,
#   'HIGH': 94682.11,
#   'LOW': 93959.87,
#   'CLOSE': 94417.9,
#   'VOLUME': 6.48741655,
#   'QUOTE_VOLUME': 612680.373776736,
#   'VOLUME_BUY': 2.7973263,
#   'QUOTE_VOLUME_BUY': 264162.086716053,
#   'VOLUME_SELL': 3.69009025,
#   'QUOTE_VOLUME_SELL': 348518.287060686,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745589600,
#   'OPEN': 94417.9,
#   'HIGH': 95824.37,
#   'LOW': 94350.26,
#   'CLOSE': 95424.69,
#   'VOLUME': 46.97578883,
#   'QUOTE_VOLUME': 4465198.42280552,
#   'VOLUME_BUY': 27.57867871,
#   'QUOTE_VOLUME_BUY': 2620488.06627772,
#   'VOLUME_SELL': 19.39711012,
#   'QUOTE_VOLUME_SELL': 1844710.35652784,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745593200,
#   'OPEN': 95424.69,
#   'HIGH': 95707.31,
#   'LOW': 94833.09,
#   'CLOSE': 95090.5,
#   'VOLUME': 55.1109435,
#   'QUOTE_VOLUME': 5255163.40514881,
#   'VOLUME_BUY': 34.91822046,
#   'QUOTE_VOLUME_BUY': 3329882.15072286,
#   'VOLUME_SELL': 20.19272304,
#   'QUOTE_VOLUME_SELL': 1925281.25442583,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745596800,
#   'OPEN': 95090.5,
#   'HIGH': 95383.87,
#   'LOW': 94749.19,
#   'CLOSE': 95238.49,
#   'VOLUME': 17.55377909,
#   'QUOTE_VOLUME': 1669141.29668214,
#   'VOLUME_BUY': 9.68619594,
#   'QUOTE_VOLUME_BUY': 921165.588980553,
#   'VOLUME_SELL': 7.86758315,
#   'QUOTE_VOLUME_SELL': 747975.707701599,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745600400,
#   'OPEN': 95238.49,
#   'HIGH': 95559.96,
#   'LOW': 94384.71,
#   'CLOSE': 94527.43,
#   'VOLUME': 16.9762588,
#   'QUOTE_VOLUME': 1612232.9075878,
#   'VOLUME_BUY': 6.72573331,
#   'QUOTE_VOLUME_BUY': 638856.744144031,
#   'VOLUME_SELL': 10.25052549,
#   'QUOTE_VOLUME_SELL': 973376.163443747,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745604000,
#   'OPEN': 94527.43,
#   'HIGH': 95259.54,
#   'LOW': 94527.43,
#   'CLOSE': 94994.16,
#   'VOLUME': 28.74607072,
#   'QUOTE_VOLUME': 2729482.76018325,
#   'VOLUME_BUY': 19.12949922,
#   'QUOTE_VOLUME_BUY': 1816506.00647222,
#   'VOLUME_SELL': 9.6165715,
#   'QUOTE_VOLUME_SELL': 912976.753710923,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745607600,
#   'OPEN': 94994.16,
#   'HIGH': 95342.07,
#   'LOW': 94887.3,
#   'CLOSE': 95308.89,
#   'VOLUME': 31.17930818,
#   'QUOTE_VOLUME': 2966442.06287252,
#   'VOLUME_BUY': 22.94199715,
#   'QUOTE_VOLUME_BUY': 2182806.30852019,
#   'VOLUME_SELL': 8.23731103,
#   'QUOTE_VOLUME_SELL': 783635.754352247,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745611200,
#   'OPEN': 95308.89,
#   'HIGH': 95361.89,
#   'LOW': 94801.39,
#   'CLOSE': 94912.31,
#   'VOLUME': 7.12776482,
#   'QUOTE_VOLUME': 678008.771795978,
#   'VOLUME_BUY': 5.22813996,
#   'QUOTE_VOLUME_BUY': 497348.302899826,
#   'VOLUME_SELL': 1.89962486,
#   'QUOTE_VOLUME_SELL': 180660.46889614,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745614800,
#   'OPEN': 94912.31,
#   'HIGH': 95041.02,
#   'LOW': 94477.1,
#   'CLOSE': 94627.04,
#   'VOLUME': 1.72252589,
#   'QUOTE_VOLUME': 163276.042811908,
#   'VOLUME_BUY': 0.41276576,
#   'QUOTE_VOLUME_BUY': 39111.107423948,
#   'VOLUME_SELL': 1.30976013,
#   'QUOTE_VOLUME_SELL': 124164.93538796,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745618400,
#   'OPEN': 94627.04,
#   'HIGH': 94959.66,
#   'LOW': 94597.89,
#   'CLOSE': 94851.55,
#   'VOLUME': 1.34778891,
#   'QUOTE_VOLUME': 127846.832288911,
#   'VOLUME_BUY': 0.47309947,
#   'QUOTE_VOLUME_BUY': 44874.6992016619,
#   'VOLUME_SELL': 0.87468944,
#   'QUOTE_VOLUME_SELL': 82972.1330872514,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745622000,
#   'OPEN': 94851.55,
#   'HIGH': 94966.77,
#   'LOW': 94621.91,
#   'CLOSE': 94662.69,
#   'VOLUME': 2.05077452,
#   'QUOTE_VOLUME': 194266.390369573,
#   'VOLUME_BUY': 0.77139192,
#   'QUOTE_VOLUME_BUY': 73059.2420852909,
#   'VOLUME_SELL': 1.2793826,
#   'QUOTE_VOLUME_SELL': 121207.148284283,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745625600,
#   'OPEN': 94662.69,
#   'HIGH': 94948.02,
#   'LOW': 94546.98,
#   'CLOSE': 94912.92,
#   'VOLUME': 3.23824859,
#   'QUOTE_VOLUME': 306942.177176569,
#   'VOLUME_BUY': 1.35238622,
#   'QUOTE_VOLUME_BUY': 128218.574699456,
#   'VOLUME_SELL': 1.88586237,
#   'QUOTE_VOLUME_SELL': 178723.602477113,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745629200,
#   'OPEN': 94912.92,
#   'HIGH': 95198.54,
#   'LOW': 94847.15,
#   'CLOSE': 94998.21,
#   'VOLUME': 1.1621318,
#   'QUOTE_VOLUME': 110415.535202542,
#   'VOLUME_BUY': 0.4438813,
#   'QUOTE_VOLUME_BUY': 42196.8610221801,
#   'VOLUME_SELL': 0.7182505,
#   'QUOTE_VOLUME_SELL': 68218.6741803614,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745632800,
#   'OPEN': 94998.21,
#   'HIGH': 95164.31,
#   'LOW': 94724.08,
#   'CLOSE': 95002.77,
#   'VOLUME': 1.37643708,
#   'QUOTE_VOLUME': 130662.092139211,
#   'VOLUME_BUY': 0.53616128,
#   'QUOTE_VOLUME_BUY': 50936.1533596998,
#   'VOLUME_SELL': 0.8402758,
#   'QUOTE_VOLUME_SELL': 79725.938779511,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745636400,
#   'OPEN': 95002.77,
#   'HIGH': 95002.77,
#   'LOW': 94717.82,
#   'CLOSE': 94734.61,
#   'VOLUME': 1.74433994,
#   'QUOTE_VOLUME': 165349.868579954,
#   'VOLUME_BUY': 0.69508872,
#   'QUOTE_VOLUME_BUY': 65893.3244892006,
#   'VOLUME_SELL': 1.04925122,
#   'QUOTE_VOLUME_SELL': 99456.5440907542,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745640000,
#   'OPEN': 94734.61,
#   'HIGH': 94834.14,
#   'LOW': 94526.39,
#   'CLOSE': 94532.32,
#   'VOLUME': 1.27158674,
#   'QUOTE_VOLUME': 120372.161985038,
#   'VOLUME_BUY': 0.4964325,
#   'QUOTE_VOLUME_BUY': 46994.5690522974,
#   'VOLUME_SELL': 0.77515424,
#   'QUOTE_VOLUME_SELL': 73377.5929327403,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745643600,
#   'OPEN': 94532.32,
#   'HIGH': 94684.08,
#   'LOW': 94385.66,
#   'CLOSE': 94684.08,
#   'VOLUME': 1.48860888,
#   'QUOTE_VOLUME': 140729.222059962,
#   'VOLUME_BUY': 0.86787578,
#   'QUOTE_VOLUME_BUY': 82066.7537554408,
#   'VOLUME_SELL': 0.6207331,
#   'QUOTE_VOLUME_SELL': 58662.4683045218,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745647200,
#   'OPEN': 94684.08,
#   'HIGH': 94748.73,
#   'LOW': 94597.37,
#   'CLOSE': 94647.6,
#   'VOLUME': 0.6279574,
#   'QUOTE_VOLUME': 59444.9143736176,
#   'VOLUME_BUY': 0.24986545,
#   'QUOTE_VOLUME_BUY': 23650.6095498381,
#   'VOLUME_SELL': 0.37809195,
#   'QUOTE_VOLUME_SELL': 35794.3048237795,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  ...]

# %%
df_dados = converte_ohlcv_para_df(dados_coindesk['Data'])
df_dados
# Out:
#                                 OPEN       HIGH        LOW      CLOSE  \
# TIMESTAMP
# 2025-03-15 12:00:00-03:00   84156.40   84408.31   84156.40   84351.80
# 2025-03-15 13:00:00-03:00   84351.80   84480.03   84179.07   84348.92
# 2025-03-15 14:00:00-03:00   84348.92   84477.57   84272.12   84371.66
# 2025-03-15 15:00:00-03:00   84371.66   84467.67   84144.00   84209.78
# 2025-03-15 16:00:00-03:00   84209.78   84318.53   84104.26   84289.00
# ...                              ...        ...        ...        ...
# 2025-06-06 15:00:00-03:00  104952.08  104984.00  104469.97  104480.09
# 2025-06-06 16:00:00-03:00  104480.09  104619.28  104046.52  104233.02
# 2025-06-06 17:00:00-03:00  104233.02  104614.52  104170.70  104489.86
# 2025-06-06 18:00:00-03:00  104489.86  104489.86  104310.74  104385.53
# 2025-06-06 19:00:00-03:00  104385.53  104405.72  104273.78  104273.78
#
#                             QUOTE_VOLUME  QUOTE_VOLUME_BUY  QUOTE_VOLUME_SELL
# TIMESTAMP
# 2025-03-15 12:00:00-03:00  185139.431001      79964.328435      105175.102565
# 2025-03-15 13:00:00-03:00  346589.066429     166947.785377      179641.281052
# 2025-03-15 14:00:00-03:00  346696.263294     131229.698673      215466.564621
# 2025-03-15 15:00:00-03:00  102841.805447      61779.407826       41062.397620
# 2025-03-15 16:00:00-03:00  179269.010357      68450.067661      110818.942696
# ...                                  ...               ...                ...
# 2025-06-06 15:00:00-03:00  286914.949693     149575.219193      137339.730500
# 2025-06-06 16:00:00-03:00  456170.329429     211392.495585      244777.833844
# 2025-06-06 17:00:00-03:00  157860.785766      78078.442431       79782.343334
# 2025-06-06 18:00:00-03:00  671476.322167     585891.123359       85585.198807
# 2025-06-06 19:00:00-03:00   20977.911101       2470.267659       18507.643442
#
# [2000 rows x 7 columns]

# %%
# Removendo as colunas QUOTE_VOLUME_BUY e QUOTE_VOLUME_SELL, e renomeando a coluna QUOTE_VOLUME para VOLUME
df_dados = df_dados.drop(columns=['QUOTE_VOLUME_BUY', 'QUOTE_VOLUME_SELL'])
df_dados = df_dados.rename(columns={'QUOTE_VOLUME': 'VOLUME'})
df_dados
# Out:
#                                 OPEN       HIGH        LOW      CLOSE  \
# TIMESTAMP
# 2025-03-15 12:00:00-03:00   84156.40   84408.31   84156.40   84351.80
# 2025-03-15 13:00:00-03:00   84351.80   84480.03   84179.07   84348.92
# 2025-03-15 14:00:00-03:00   84348.92   84477.57   84272.12   84371.66
# 2025-03-15 15:00:00-03:00   84371.66   84467.67   84144.00   84209.78
# 2025-03-15 16:00:00-03:00   84209.78   84318.53   84104.26   84289.00
# ...                              ...        ...        ...        ...
# 2025-06-06 15:00:00-03:00  104952.08  104984.00  104469.97  104480.09
# 2025-06-06 16:00:00-03:00  104480.09  104619.28  104046.52  104233.02
# 2025-06-06 17:00:00-03:00  104233.02  104614.52  104170.70  104489.86
# 2025-06-06 18:00:00-03:00  104489.86  104489.86  104310.74  104385.53
# 2025-06-06 19:00:00-03:00  104385.53  104405.72  104273.78  104273.78
#
#                                   VOLUME
# TIMESTAMP
# 2025-03-15 12:00:00-03:00  185139.431001
# 2025-03-15 13:00:00-03:00  346589.066429
# 2025-03-15 14:00:00-03:00  346696.263294
# 2025-03-15 15:00:00-03:00  102841.805447
# 2025-03-15 16:00:00-03:00  179269.010357
# ...                                  ...
# 2025-06-06 15:00:00-03:00  286914.949693
# 2025-06-06 16:00:00-03:00  456170.329429
# 2025-06-06 17:00:00-03:00  157860.785766
# 2025-06-06 18:00:00-03:00  671476.322167
# 2025-06-06 19:00:00-03:00   20977.911101
#
# [2000 rows x 5 columns]

# %%
def get_latest_bitcoin_indicators(df):
    """
    Coleta dados de OHLCV do Bitcoin (3 meses, candles de 1h),
    calcula os indicadores técnicos via ta.Strategy,
    remove as colunas de preço, e retorna um dicionário com
    apenas os valores mais recentes de cada indicador.
    """
    # 1. Baixar dados OHLCV de BTC-USD (últimos 3 meses, intervalo 1h)
    data = df.copy()
    data.columns = [c.lower() for c in data.columns]
    # ohlc_df.index = pd.DatetimeIndex(ohlc_df.index)
    # ohlc_df = ohlc_df.tz_convert("America/Sao_Paulo")

    # 2. Definir a Strategy para os indicadores desejados
    MyStrategy = ta.Strategy(
        name="BitcoinIndicators",
        ta=[
            # Médias Móveis Simples
            {"kind": "sma", "length": 20},
            {"kind": "sma", "length": 50},
            {"kind": "sma", "length": 200},
            # Médias Móveis Exponenciais
            {"kind": "ema", "length": 20},
            {"kind": "ema", "length": 50},
            {"kind": "ema", "length": 200},
            # Índice de Força Relativa
            {"kind": "rsi", "length": 14},
            # MACD (12, 26, 9)
            {"kind": "macd","fast": 12, "slow": 26, "signal": 9},
            # Bandas de Bollinger (20, 2)
            {"kind": "bbands","length": 20, "std": 2},
        ]
    )

    # 3. Aplicar a Strategy ao DataFrame de OHLCV
    data.ta.strategy(MyStrategy)

    # 4. Remover colunas de preço para ficar apenas com indicadores
    data = data.drop(columns=[c for c in ["open","high","low","close","volume"] if c in data])

    # 5. Obter a última linha de indicadores e converter para dicionário
    latest_series = data.iloc[-1]
    latest_dict = latest_series.to_dict()

    return latest_dict

# %%
indicadores = get_latest_bitcoin_indicators(df_dados)
indicadores
# Out:
# {'SMA_20': 103937.05500000001,
#  'SMA_50': 103853.9948,
#  'SMA_200': 104713.50349999999,
#  'EMA_20': 104050.9507762561,
#  'EMA_50': 104013.9101309427,
#  'EMA_200': 104990.45900725835,
#  'RSI_14': 54.10664312772966,
#  'MACD_12_26_9': 297.4915404120693,
#  'MACDh_12_26_9': 55.874588705718196,
#  'MACDs_12_26_9': 241.6169517063511,
#  'BBL_20_2.0': 102468.26487146586,
#  'BBM_20_2.0': 103937.05500000001,
#  'BBU_20_2.0': 105405.84512853416,
#  'BBB_20_2.0': 2.8263069961606098,
#  'BBP_20_2.0': 0.6146266554555491}

# %%
from indicadores_tecnicos import get_bitcoin_data_yf

indicadores_yf = get_bitcoin_data_yf()

# %%
print(indicadores_yf)
# Out:
# {
#   "descrição": "Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,875,059. The last known price of Bitcoin is 103,694.67292703 USD and is down -1.16 over the last 24 hours. It is currently trading on 12210 active market(s) with $61,955,978,178.38 traded over the last 24 hours. More information can be found at https://bitcoin.org/.",
#   "preço_anterior": 101580.12,
#   "preço_atual": 104371.414,
#   "variação_24h": 3181.414,
#   "variação_percentual_24h": 3.1440043,
#   "máximo_24h": 105304.87,
#   "mínimo_24h": 101365.7,
#   "volume_24h": 49510035456,
#   "volume_10_dias": 49071886388,
#   "volume_3_meses": 38618012851,
#   "capitalização_mercado": 2074408648704,
#   "fornecimento_circulante": 19875256,
#   "MSA_50": 100220.7,
#   "MSA_50_variacao": 4150.711,
#   "MSA_50_variacao_percentual": 0.041415703,
#   "MSA_200": 95106.56,
#   "MSA_200_variacao": 9264.852,
#   "MSA_200_variacao_percentual": 0.097415484,
#   "faixa_52_semanas_low": 49121.24,
#   "faixa_52_semanas_high": 111970.17,
#   "faixa_52_semanas_low_variacao": 55250.176,
#   "faixa_52_semanas_low_variacao_percentual": 1.1247716,
#   "faixa_52_semanas_high_variacao": -7598.758,
#   "faixa_52_semanas_high_variacao_percentual": -0.06786413,
#   "faixa_52_semanas_variacao_percentual": 46.48423
# }

# %%
# Fazer o append dos dicionarios indicadores e indicadores_yf
indicadores_completos = {**indicadores, **json.loads(indicadores_yf)}
indicadores_completos
# Out:
# {'SMA_20': 103937.05500000001,
#  'SMA_50': 103853.9948,
#  'SMA_200': 104713.50349999999,
#  'EMA_20': 104050.9507762561,
#  'EMA_50': 104013.9101309427,
#  'EMA_200': 104990.45900725835,
#  'RSI_14': 54.10664312772966,
#  'MACD_12_26_9': 297.4915404120693,
#  'MACDh_12_26_9': 55.874588705718196,
#  'MACDs_12_26_9': 241.6169517063511,
#  'BBL_20_2.0': 102468.26487146586,
#  'BBM_20_2.0': 103937.05500000001,
#  'BBU_20_2.0': 105405.84512853416,
#  'BBB_20_2.0': 2.8263069961606098,
#  'BBP_20_2.0': 0.6146266554555491,
#  'descrição': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,875,059. The last known price of Bitcoin is 103,694.67292703 USD and is down -1.16 over the last 24 hours. It is currently trading on 12210 active market(s) with $61,955,978,178.38 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'preço_anterior': 101580.12,
#  'preço_atual': 104371.414,
#  'variação_24h': 3181.414,
#  'variação_percentual_24h': 3.1440043,
#  'máximo_24h': 105304.87,
#  'mínimo_24h': 101365.7,
#  'volume_24h': 49510035456,
#  'volume_10_dias': 49071886388,
#  'volume_3_meses': 38618012851,
#  'capitalização_mercado': 2074408648704,
#  'fornecimento_circulante': 19875256,
#  'MSA_50': 100220.7,
#  'MSA_50_variacao': 4150.711,
#  'MSA_50_variacao_percentual': 0.041415703,
#  'MSA_200': 95106.56,
#  'MSA_200_variacao': 9264.852,
#  'MSA_200_variacao_percentual': 0.097415484,
#  'faixa_52_semanas_low': 49121.24,
#  'faixa_52_semanas_high': 111970.17,
#  'faixa_52_semanas_low_variacao': 55250.176,
#  'faixa_52_semanas_low_variacao_percentual': 1.1247716,
#  'faixa_52_semanas_high_variacao': -7598.758,
#  'faixa_52_semanas_high_variacao_percentual': -0.06786413,
#  'faixa_52_semanas_variacao_percentual': 46.48423}

# %%
from coleta_dados_coindesk import fetch_coindesk_latest_tick, converte_latest_tick_para_dict
# Coletar o último tick do Coindesk
ultimo_tick = fetch_coindesk_latest_tick()
ultimo_tick_dict = converte_latest_tick_para_dict(ultimo_tick)
ultimo_tick_dict
# Out:
# {'current_price': 104401.25,
#  'price_last_update_utc': '2025-06-06 22:26:54 UTC',
#  'price_movement_flag': 'UNCHANGED',
#  'current_day_open': 101570.2,
#  'current_day_high': 105439.01,
#  'current_day_low': 101132.91,
#  'current_day_volume_btc': 9284.8449159,
#  'current_day_volume_usd': 964853252.156618,
#  'current_day_change_percentage': 2.78728406560192,
#  'moving_24_hour_open': 101555.84,
#  'moving_24_hour_high': 105439.01,
#  'moving_24_hour_low': 101132.91,
#  'moving_24_hour_volume_btc': 9574.17072857,
#  'moving_24_hour_volume_usd': 994277770.791454,
#  'moving_24_hour_change_percentage': 2.80181819184401,
#  'moving_7_day_open': 104033.26,
#  'moving_7_day_high': 106901.68,
#  'moving_7_day_low': 100345.73,
#  'moving_7_day_volume_btc': 41496.35936402,
#  'moving_7_day_volume_usd': 4331402010.73456,
#  'moving_7_day_change_percentage': 0.353723414992475,
#  'hr_open': 104490.6,
#  'hr_high': 104509.56,
#  'hr_low': 104331.51,
#  'hr_volume_btc': 146.13204084,
#  'hr_change_pct': -0.0855100841606805}

# %%
import requests
import json
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import yfinance as yf
from typing import List, Dict, Any
import pandas as pd
from tavily import TavilyClient
from tavily import AsyncTavilyClient
from dotenv import load_dotenv
import asyncio
from datetime import datetime
import pytz

def parse_iso8601(date_str):
    # Formato ISO 8601 com 'Z' indicando UTC
    dt = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")
    # Atribui timezone UTC
    return dt.replace(tzinfo=pytz.UTC)

def format_datetime(dt, fmt="%d/%m/%Y %H:%M:%S %Z"):  # exemplo: '28/05/2025 13:39:31 UTC'
    return dt.strftime(fmt)


def coleta_news_coindesk(local_tz=None, output_fmt="%d/%m/%Y %H:%M:%S %Z"):
    """
    Extrai campos (TITLE, URL, KEYWORDS, SENTIMENT, PUBLISHED_ON, BODY) da segunda API.
    Converte PUBLISHED_ON (timestamp UTC em segundos) para formato legível.
    """
    response = requests.get('https://data-api.coindesk.com/news/v1/article/list',
        params={"lang":"EN", "limit":10, "categories":"BTC,MARKET", "api_key":"fd8a81d53ce5de8a8cb711d0c99896fe94879d0f4870da333592d712241fb30d"},
        headers={"Content-type":"application/json; charset=UTF-8"}
        )
    json_response = response.json()
    extracted = []
    for entry in json_response:
        raw_ts = entry.get('PUBLISHED_ON')
        # Converte timestamp UTC em seconds para datetime
        dt = datetime.fromtimestamp(raw_ts, tz=pytz.UTC) if raw_ts else None
        if dt and local_tz:
            dt = dt.astimezone(local_tz)
        formatted = format_datetime(dt, output_fmt) if dt else None

        extracted.append({
            'titulo': entry.get('TITLE'),
            'url': entry.get('URL'),
            'keywords': entry.get('KEYWORDS'),
            'sentimento': entry.get('SENTIMENT'),
            'data': formatted,
            'resumo': entry.get('BODY')
        })
    return extracted

# %%
response = requests.get('https://data-api.coindesk.com/news/v1/article/list',
        params={"lang":"EN", "limit":10, "categories":"BTC,MARKET", "api_key":"fd8a81d53ce5de8a8cb711d0c99896fe94879d0f4870da333592d712241fb30d"},
        headers={"Content-type":"application/json; charset=UTF-8"}
        )
json_response = response.json()

# %%
json_response
# Out:
# {'Data': [{'TYPE': '121',
#    'ID': 45616633,
#    'GUID': 'https://en.coinotag.com/shiba-inu-whale-transfer-to-coinbase-institutional-suggests-potential-market-impact-amid-price-consolidation/',
#    'PUBLISHED_ON': 1749249704,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#    'TITLE': 'Shiba Inu Whale Transfer to Coinbase Institutional Suggests Potential Market Impact Amid Price Consolidation',
#    'SUBTITLE': None,
#    'AUTHORS': 'Marisol Navaro',
#    'URL': 'https://en.coinotag.com/shiba-inu-whale-transfer-to-coinbase-institutional-suggests-potential-market-impact-amid-price-consolidation/',
#    'SOURCE_ID': 77,
#    'BODY': 'A significant transfer of over 2.5 trillion Shiba Inu (SHIB) tokens to Coinbase Institutional signals growing institutional interest in the meme-inspired cryptocurrency. This large-scale movement could influence market dynamics, potentially',
#    'KEYWORDS': 'Analysis|News',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749249710,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249580,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 25,
#      'NAME': 'EXCHANGE',
#      'CATEGORY': 'EXCHANGE'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 44, 'NAME': 'SHIB', 'CATEGORY': 'SHIB'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'}]},
#   {'TYPE': '121',
#    'ID': 45616521,
#    'GUID': 'https://en.coinotag.com/bitcoin-spot-etf-outflows-may-signal-increased-market-volatility-and-price-pressure/',
#    'PUBLISHED_ON': 1749249462,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#    'TITLE': 'Bitcoin Spot ETF Outflows May Signal Increased Market Volatility and Price Pressure',
#    'SUBTITLE': None,
#    'AUTHORS': 'Sheila Belson',
#    'URL': 'https://en.coinotag.com/bitcoin-spot-etf-outflows-may-signal-increased-market-volatility-and-price-pressure/',
#    'SOURCE_ID': 77,
#    'BODY': 'Institutional withdrawals from major Bitcoin spot ETFs have triggered notable market volatility, significantly impacting Bitcoin’s price trajectory. Key funds such as ARK 21Shares and Fidelity experienced substantial outflows, signaling a',
#    'KEYWORDS': 'Analysis|News|BTC|FLOW',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749249489,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249580,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'},
#     {'TYPE': '122', 'ID': 125, 'NAME': 'FLOW', 'CATEGORY': 'FLOW'}]},
#   {'TYPE': '121',
#    'ID': 45616455,
#    'GUID': 'https://cryptonews.com/?p=368974',
#    'PUBLISHED_ON': 1749249378,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/52/45616455.jpeg',
#    'TITLE': 'Crypto Price Prediction Today 6 June – Bitcoin, Solana, XRP',
#    'SUBTITLE': None,
#    'AUTHORS': 'Cryptonews',
#    'URL': 'https://cryptonews.com/news/crypto-price-prediction-today-bitcoin-solana-xrp-6-june/',
#    'SOURCE_ID': 52,
#    'BODY': 'Crypto price optimism is hitting record highs following Bitcoin’s recent rally, which saw it hit a new all-time high (ATH) just two weeks prior. At the same time, several top meme coins —Pepe, Trump, SPX6900, and FartCoin among them—have each reached record highs within the last six months. Investor optimism is clearly on the rise, propelling digital asset values higher. Historically, cryptocurrencies backed by robust fundamentals tend to ignite broad market upswings, supported by dedicated communities, institutional interest, and active development teams. In this context, let’s explore several prominent cryptos that analysts believe could set new all-time highs (ATHs) during the current bullish trend. Bitcoin ($BTC): The World’s Biggest Crypto Is Likely to Set Many Price ATHs Before New Year Bitcoin ($BTC) needs no introduction. The world’s biggest crypto recently hit a new price high at $111,814 on May 2 and many believe it could set several new all-time highs on its way to $150K by the end of the year, but these will be contingent on a favourable political climate. See, Bitcoin is crypto’s flagship coin. This means that anyone who believes in crypto’s future is likely to want to add some Bitcoin to their portfolio. The $2 trillion market cap digital gold is virtually single handedly holding up crypto’s $3.38 trillion market. In the last 24 hours, Bitcoin is up 0.3% to trade at $104,292 as it reverses course from a pullback down 6.9% from its ATH. This puts it in spitting distance of setting a new high watermark and even hitting $150,000, but this will need to be helped along by positive macro developments. Recent falling US inflation rates bode well for crypto on the whole, and the possibility of the pro-crypto Trump administration delivering on a US Strategic Bitcoin Reserve and comprehensive legislation before the year is out could drive Bitcoin to its next big milestone, while simultaneously pulling up the wider industry too. Solana ($SOL): DeFi Titan Riding Institutional Tailwinds Solana ($SOL) continues to distinguish itself within the DeFi ecosystem, lauded for its sophisticated smart contracts, rapid transaction speeds and ultra-low fees. With a current valuation of $81.35 billion, it has cemented itself as a formidable challenger to Ethereum in the DeFi sector. There is mounting chatter that U.S. regulatory authorities may soon approve spot ETFs tied to Solana, following in the footsteps of similar approvals for Bitcoin and Ethereum. Such a development could bolster SOL’s appeal to institutional investors. President Donald Trump has also floated the idea of including Solana in a proposed U.S. Strategic Crypto Reserve, although acquisition would be through asset seizures rather than direct purchase. Solana recently rebounded after sliding from highs above $250 in January to just over $100 in February. It has since broken above a descending trend channel and now trades at $152.76—up 1% in the last 24 hours—mirroring Bitcoin’s brief correction and rebound. Analysts now anticipate that if SOL breaches resistance at $200 and $250, it could push toward the $300 mark before the summer concludes. Ripple (XRP): Could Ripple’s Cross-Border Payment Token Reach New Heights? Ripple’s XRP token remains a key player in bridging blockchain and traditional finance, particularly for international money transfers. Renowned for facilitating fast and affordable cross-border transactions, XRP has gained attention from major global entities like the United Nations, which sees it as a useful tool for compliant and efficient financial systems. A longstanding legal standoff between Ripple and the SEC reached a key moment in 2023, when a court determined that XRP’s retail transactions do not constitute securities. This verdict brought much-needed clarity and sparked renewed investor interest. Over the past year, XRP has outpaced Bitcoin in growth, posting a 314% gain compared to Bitcoin’s 46.5% increase. Technical indicators sugge ...
#    'KEYWORDS': 'News|Bitcoin|Solana|XRP',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749249381,
#    'UPDATED_ON': 1749249381,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 52,
#     'SOURCE_KEY': 'cryptonews',
#     'NAME': 'cryptonews',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cryptonews.png',
#     'URL': 'https://cryptonews.com/news/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249598,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1680604053},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 46, 'NAME': 'SOL', 'CATEGORY': 'SOL'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'},
#     {'TYPE': '122', 'ID': 58, 'NAME': 'XRP', 'CATEGORY': 'XRP'}]},
#   {'TYPE': '121',
#    'ID': 45616443,
#    'GUID': 'https://en.coinotag.com/netflixs-house-of-streams-may-feature-bitcoin-prize-amid-warnings-of-related-fraudulent-schemes/',
#    'PUBLISHED_ON': 1749249293,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/45616443.jpeg',
#    'TITLE': 'Netflix’s House of Streams May Feature Bitcoin Prize Amid Warnings of Related Fraudulent Schemes',
#    'SUBTITLE': None,
#    'AUTHORS': 'Jocelyn Blake',
#    'URL': 'https://en.coinotag.com/netflixs-house-of-streams-may-feature-bitcoin-prize-amid-warnings-of-related-fraudulent-schemes/',
#    'SOURCE_ID': 77,
#    'BODY': 'The upcoming Netflix-licensed reality series, House of Streams, is set to spotlight Twitch streamers competing for a high-stakes cryptocurrency prize, marking a unique intersection of digital entertainment and crypto culture.',
#    'KEYWORDS': 'Bitcoin|News|BTC|FRONT|MEME',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749249370,
#    'UPDATED_ON': 1749249371,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249580,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 195, 'NAME': 'MEME', 'CATEGORY': 'MEME'}]},
#   {'TYPE': '121',
#    'ID': 28139,
#    'GUID': 'https://www.cryptopolitan.com/?p=189174',
#    'PUBLISHED_ON': 1749249000,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/43/28139.jpeg',
#    'TITLE': 'Alchemy Pay price prediction 2025-2031: Is ACH a good investment?',
#    'SUBTITLE': None,
#    'AUTHORS': 'Damilola Lawrence',
#    'URL': 'https://www.cryptopolitan.com/alchemy-pay-price-prediction/',
#    'SOURCE_ID': 43,
#    'BODY': "Key takeaways: Alchemy Pay’s price can reach a maximum of $0.0291 and an average trading value of $0.0257 in 2025. The ACH could reach a maximum of $0.0965 and an average of $0.0836 by the end of 2028. Alchemy Pay price prediction for 2031 projects a maximum price of $0.2860. Alchemy Pay (ACH) is a cross-functional payment solution making significant strides in bridging the gap between fiat and cryptocurrency payment ecosystems. The platform’s robust framework enables global consumers to connect with merchants, developers, and institutions worldwide, facilitating transactions across multiple fiat currencies and cryptocurrencies. This functionality enhances Alchemy Pay’s adaptability and positions it as a pivotal player in the financial technology sector. Alchemy Pay’s inclusion in the decentralized platforms of popular projects like Augur, Cryptokitties, and OpenSea, along with its support for the infrastructure of Kyber and Radar Relay, adds layers of credibility and utility, enhancing its investment appeal. Can Alchemy Pay (ACH) get to $0.1? Will Alchemy Pay hit $1? Let’s find out in this ACH price prediction for 2025-2031. Overview Cryptocurrency Alchemy Pay Token ACH Price $0.01976 Market Cap $180.05 Million Trading Volume (24-hour) $28.07M Circulating Supply 10 Billion ACH All-time High $0.1975 Aug 06, 2021 All-time Low $0.001338 Jul 20, 2021 24-h High $0.02128 24-h Low $0.01951 Alchemy Pay price prediction: Technical analysis Price Prediction $\u202f0.147431 (612.46%) Price Volatility 9.59% 50-Day SMA $0.026115 14-Day RSI 36.23 Sentiment Bearish Fear & Greed Index 57 (Greed) Green Days 13/30 (43%) 200-Day SMA $0.024616 Alchemy Pay price analysis TL;DR Breakdown: ACH/USD shows a bearish trend after dropping from $0.0850 Short-term recovery possible to $0.02286-$0.0300 if resistance breaks Sustained uptrend needs momentum indicators and volume improvement ACH/USD 1-day chart ACH/USD 1-day chart The ACH/USD 1-day chart on June 6 shows a volatile pattern with a recent sharp spike around early 2025, peaking near $0.0850, followed by a steep decline to around $0.0200. The price is currently consolidating between $0.0200 and $0.0243, with Bollinger Bands tightening, suggesting reduced volatility and a potential breakout. The RSI at 31.54 indicates oversold conditions, hinting at a possible short-term rebound. However, the overall trend remains bearish unless the price breaks above the 20-day SMA ($0.02686). I expect a cautious recovery towards $0.0300 in the near term, but a sustained uptrend requires breaking key resistance levels around $0.0350. Watch for increased volume and RSI improvement. Alchemy Pay 4-hour price chart ACH/USD 4-hour chart The ACH/USD 4-hour chart shows a sharp decline from a peak near $0.0850 in early 2025, now trading at $0.01976, down 2.18%. The Bollinger Bands are narrowing, indicating low volatility and a potential breakout. The MACD is bearish (-0.00045), but the histogram shows slight convergence, hinting at weakening downward momentum. The Balance of Power at -0.58 suggests sellers still dominate, but the price is near a support level around $0.01949. I expect a short-term consolidation between $0.01949 and $0.02153, with a possible bounce to $0.02286 if buying pressure increases. A break below $0.01949 could push it towards $0.01500. Watch MACD for trend shifts. Alchemy Pay technical indicators: Levels and action Daily simple moving average (SMA) Period Value Action SMA 3 $0.022593 BUY SMA 5 $0.024291 SELL SMA 10 $0.024799 SELL SMA 21 $0.026306 SELL SMA 50 $0.025518 SELL SMA 100 $0.026065 SELL SMA 200 $0.024775 SELL Daily exponential moving average (EMA) Period Value Action EMA 3 $0.02555 SELL EMA 5 $0.025018 SELL EMA 10 $0.023976 BUY EMA 21 $0.02366 BUY EMA 50 $0.024854 SELL EMA 100 $0.02578 SELL EMA 200 $0.025626 SELL Alchemy Pay price analysis conclusion Analyzing both the 1-day and 4-hour ACH/USD charts, Alchemy Pay (ACH) exhibits a bearish trend after a sharp decline from $0.0850 ...
#    'KEYWORDS': 'Crypto Price Predictions|Alchemy Pay',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEUTRAL',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1655715474,
#    'UPDATED_ON': 1749249482,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 43,
#     'SOURCE_KEY': 'cryptopolitan',
#     'NAME': 'Cryptopolitan',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cryptopolitan.png',
#     'URL': 'https://www.cryptopolitan.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249591,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1681205909},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 6,
#      'NAME': 'ASIA',
#      'CATEGORY': 'ASIA'},
#     {'TYPE': '122', 'ID': 13, 'NAME': 'BLOCKCHAIN', 'CATEGORY': 'BLOCKCHAIN'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 24, 'NAME': 'ETH', 'CATEGORY': 'ETH'},
#     {'TYPE': '122', 'ID': 25, 'NAME': 'EXCHANGE', 'CATEGORY': 'EXCHANGE'},
#     {'TYPE': '122', 'ID': 26, 'NAME': 'FIAT', 'CATEGORY': 'FIAT'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'},
#     {'TYPE': '122', 'ID': 53, 'NAME': 'UNI', 'CATEGORY': 'UNI'},
#     {'TYPE': '122', 'ID': 71, 'NAME': 'ARB', 'CATEGORY': 'ARB'},
#     {'TYPE': '122', 'ID': 74, 'NAME': 'BNB', 'CATEGORY': 'BNB'},
#     {'TYPE': '122', 'ID': 204, 'NAME': 'AIRDROP', 'CATEGORY': 'AIRDROP'},
#     {'TYPE': '122', 'ID': 206, 'NAME': 'FORKS', 'CATEGORY': 'FORKS'}]},
#   {'TYPE': '121',
#    'ID': 45616354,
#    'GUID': 'https://cointelegraph.com/news/reality-show-twitch-streamers-win-bitcoin',
#    'PUBLISHED_ON': 1749248846,
#    'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cointelegraph.png',
#    'TITLE': 'Reality show to pit Twitch streamers against each other to win 1 BTC',
#    'SUBTITLE': None,
#    'AUTHORS': 'Cointelegraph by Turner Wright',
#    'URL': 'https://cointelegraph.com/news/reality-show-twitch-streamers-win-bitcoin?utm_source=rss_feed&utm_medium=rss&utm_campaign=rss_partner_inbound',
#    'SOURCE_ID': 16,
#    'BODY': 'The series’ website issued a notice in May warning of a “fraudulent cryptocurrency scheme” using its branding to lure investors.',
#    'KEYWORDS': '',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749249233,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 16,
#     'SOURCE_KEY': 'cointelegraph',
#     'NAME': 'CoinTelegraph',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/cointelegraph.png',
#     'URL': 'https://cointelegraph.com/rss',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': 1382227200,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 66,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249558,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1711620813},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'}]},
#   {'TYPE': '121',
#    'ID': 45616173,
#    'GUID': 'https://en.coinotag.com/geminis-confidential-ipo-filing-could-signal-new-phase-for-cryptocurrency-market-stability/',
#    'PUBLISHED_ON': 1749248742,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#    'TITLE': 'Gemini’s Confidential IPO Filing Could Signal New Phase for Cryptocurrency Market Stability',
#    'SUBTITLE': None,
#    'AUTHORS': 'Sheila Belson',
#    'URL': 'https://en.coinotag.com/geminis-confidential-ipo-filing-could-signal-new-phase-for-cryptocurrency-market-stability/',
#    'SOURCE_ID': 77,
#    'BODY': 'Gemini, the cryptocurrency exchange founded by the Winklevoss twins, has confidentially filed for an initial public offering (IPO), signaling a pivotal moment in the crypto industry. This strategic move aims',
#    'KEYWORDS': 'News|BTC|ETH',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749248827,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249580,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 24, 'NAME': 'ETH', 'CATEGORY': 'ETH'},
#     {'TYPE': '122', 'ID': 25, 'NAME': 'EXCHANGE', 'CATEGORY': 'EXCHANGE'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'}]},
#   {'TYPE': '121',
#    'ID': 45616178,
#    'GUID': 'https://en.coin-turk.com/?p=194205',
#    'PUBLISHED_ON': 1749248719,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/79/45616178.jpeg',
#    'TITLE': 'Willy Woo Predicts Bitcoin’s Dramatic Upsurge Over the Next Two Decades',
#    'SUBTITLE': None,
#    'AUTHORS': 'Fatih Uçar',
#    'URL': 'https://en.coin-turk.com/willy-woo-predicts-bitcoins-dramatic-upsurge-over-the-next-two-decades/',
#    'SOURCE_ID': 79,
#    'BODY': 'Willy Woo predicts a significant Bitcoin value rise over the next 20 years. Bitcoin could potentially replace gold, reaching 188 times its current value. Continue Reading: Willy Woo Predicts Bitcoin’s Dramatic Upsurge Over the Next Two Decades The post Willy Woo Predicts Bitcoin’s Dramatic Upsurge Over the Next Two Decades appeared first on COINTURK NEWS .',
#    'KEYWORDS': 'Cryptocurrency News',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749248836,
#    'UPDATED_ON': 1749248837,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 79,
#     'SOURCE_KEY': 'cointurken',
#     'NAME': 'CoinTurk News',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/79/default.png',
#     'URL': 'https://en.coin-turk.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249492,
#     'CREATED_ON': 1689939795,
#     'UPDATED_ON': 1690273097},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 26, 'NAME': 'FIAT', 'CATEGORY': 'FIAT'}]},
#   {'TYPE': '121',
#    'ID': 45615618,
#    'GUID': 'https://en.coinotag.com/arctic-pablo-coin-presale-highlights-potential-amid-filecoin-and-cosmos-developments/',
#    'PUBLISHED_ON': 1749247661,
#    'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#    'TITLE': 'Arctic Pablo Coin Presale Highlights Potential Amid Filecoin and Cosmos Developments',
#    'SUBTITLE': None,
#    'AUTHORS': 'Marisol Navaro',
#    'URL': 'https://en.coinotag.com/arctic-pablo-coin-presale-highlights-potential-amid-filecoin-and-cosmos-developments/',
#    'SOURCE_ID': 77,
#    'BODY': 'Arctic Pablo Coin emerges as a standout opportunity in the crypto market, combining innovative deflationary tokenomics with a compelling presale phase that promises significant returns. Alongside Arctic Pablo Coin’s rapid',
#    'KEYWORDS': 'News|FIL',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'POSITIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749247764,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 77,
#     'SOURCE_KEY': 'coinotag',
#     'NAME': 'CoinOtag',
#     'IMAGE_URL': 'https://resources.cryptocompare.com/news/77/default.png',
#     'URL': 'https://en.coinotag.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': None,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 0,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249580,
#     'CREATED_ON': 1686819961,
#     'UPDATED_ON': 1717748924},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 27,
#      'NAME': 'FIL',
#      'CATEGORY': 'FIL'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'}]},
#   {'TYPE': '121',
#    'ID': 45615393,
#    'GUID': 'https://dailyhodl.com/?p=333863',
#    'PUBLISHED_ON': 1749247277,
#    'IMAGE_URL': 'https://images.cryptocompare.com/news/default/dailyhodl.png',
#    'TITLE': 'Republican Senator Josh Hawley Breaks With Party Lines, Opposes Upcoming GENIUS Act: Report',
#    'SUBTITLE': None,
#    'AUTHORS': 'Daniell Marlow',
#    'URL': 'https://dailyhodl.com/2025/06/06/republican-senator-josh-hawley-breaks-with-party-lines-opposes-upcoming-genius-act-report/',
#    'SOURCE_ID': 37,
#    'BODY': "Senator Josh Hawley is opposing party lines by voting against an upcoming stablecoin bill endorsed by the White House. According to a New York Times report , the Missouri Republican Senator is saying “no” to the upcoming GENIUS Act. “It’s a huge giveaway to Big Tech. It allows these tech companies to issue stablecoins without any kind of controls. I don’t see why we would do that.” According to the Times report, the GENIUS Act could potentially upend the credit card industry and benefit both Trump and Musk, who are currently publicly feuding . Hawley is pushing for amendments to the bill that would curtail Big Tech’s involvement. GENIUS is an acronym meaning “Guiding and Establishing National Innovation for US Stablecoins”. The bill purports to seek to improve consumer protection, transparency, marketing restrictions and regulatory oversight for the burgeoning stablecoin market, estimated to be worth $250 billion. Yesterday, the second-biggest player in the US-dollar pegged stablecoin space, Circle, issuer of USDC, launched its initial public offering, or IPO. “Circle is now officially a public company, listed on the NYSE under CRCL.” In its New York Stock Exchange (NYSE) debut, Circle saw an opening price of $69 per share, up by 168.48% from the IPO price of $31 per share. Follow us on X , Facebook and Telegram Don't Miss a Beat – Subscribe to get email alerts delivered directly to your inbox Check Price Action Surf The Daily Hodl Mix Disclaimer: Opinions expressed at The Daily Hodl are not investment advice. Investors should do their due diligence before making any high-risk investments in Bitcoin, cryptocurrency or digital assets. Please be advised that your transfers and trades are at your own risk, and any losses you may incur are your responsibility. The Daily Hodl does not recommend the buying or selling of any cryptocurrencies or digital assets, nor is The Daily Hodl an investment advisor. Please note that The Daily Hodl participates in affiliate marketing. Featured Image: Shutterstock/laskoart/Vladimir Sazonov The post Republican Senator Josh Hawley Breaks With Party Lines, Opposes Upcoming GENIUS Act: Report appeared first on The Daily Hodl .",
#    'KEYWORDS': 'Regulators|genius|Genius act|josh hawley|New York Times|News|stablecoins',
#    'LANG': 'EN',
#    'UPVOTES': 0,
#    'DOWNVOTES': 0,
#    'SCORE': 0,
#    'SENTIMENT': 'NEGATIVE',
#    'STATUS': 'ACTIVE',
#    'CREATED_ON': 1749247398,
#    'UPDATED_ON': None,
#    'SOURCE_DATA': {'TYPE': '120',
#     'ID': 37,
#     'SOURCE_KEY': 'dailyhodl',
#     'NAME': 'The Daily Hodl',
#     'IMAGE_URL': 'https://images.cryptocompare.com/news/default/dailyhodl.png',
#     'URL': 'https://dailyhodl.com/feed/',
#     'LANG': 'EN',
#     'SOURCE_TYPE': 'RSS',
#     'LAUNCH_DATE': 1513555200,
#     'SORT_ORDER': 0,
#     'BENCHMARK_SCORE': 59,
#     'STATUS': 'ACTIVE',
#     'LAST_UPDATED_TS': 1749249557,
#     'CREATED_ON': 1657730129,
#     'UPDATED_ON': 1711621079},
#    'CATEGORY_DATA': [{'TYPE': '122',
#      'ID': 14,
#      'NAME': 'BTC',
#      'CATEGORY': 'BTC'},
#     {'TYPE': '122', 'ID': 15, 'NAME': 'BUSINESS', 'CATEGORY': 'BUSINESS'},
#     {'TYPE': '122', 'ID': 25, 'NAME': 'EXCHANGE', 'CATEGORY': 'EXCHANGE'},
#     {'TYPE': '122', 'ID': 37, 'NAME': 'MARKET', 'CATEGORY': 'MARKET'},
#     {'TYPE': '122', 'ID': 50, 'NAME': 'TRADING', 'CATEGORY': 'TRADING'}]}],
#  'Err': {}}

# %%
extracted = []
local_tz=None
output_fmt="%d/%m/%Y %H:%M:%S %Z"
for entry in json_response['Data']:
    raw_ts = entry.get('PUBLISHED_ON')
    # Converte timestamp UTC em seconds para datetime
    dt = datetime.fromtimestamp(raw_ts, tz=pytz.UTC) if raw_ts else None
    if dt and local_tz:
        dt = dt.astimezone(local_tz)
    formatted = format_datetime(dt, output_fmt) if dt else None

    extracted.append({
        'titulo': entry.get('TITLE'),
        'url': entry.get('URL'),
        'keywords': entry.get('KEYWORDS'),
        'sentimento': entry.get('SENTIMENT'),
        'data': formatted,
        'resumo': entry.get('BODY')
    })

# %%
extracted
# Out:
# [{'titulo': 'Shiba Inu Whale Transfer to Coinbase Institutional Suggests Potential Market Impact Amid Price Consolidation',
#   'url': 'https://en.coinotag.com/shiba-inu-whale-transfer-to-coinbase-institutional-suggests-potential-market-impact-amid-price-consolidation/',
#   'keywords': 'Analysis|News',
#   'sentimento': 'POSITIVE',
#   'data': '06/06/2025 22:41:44 UTC',
#   'resumo': 'A significant transfer of over 2.5 trillion Shiba Inu (SHIB) tokens to Coinbase Institutional signals growing institutional interest in the meme-inspired cryptocurrency. This large-scale movement could influence market dynamics, potentially'},
#  {'titulo': 'Bitcoin Spot ETF Outflows May Signal Increased Market Volatility and Price Pressure',
#   'url': 'https://en.coinotag.com/bitcoin-spot-etf-outflows-may-signal-increased-market-volatility-and-price-pressure/',
#   'keywords': 'Analysis|News|BTC|FLOW',
#   'sentimento': 'NEGATIVE',
#   'data': '06/06/2025 22:37:42 UTC',
#   'resumo': 'Institutional withdrawals from major Bitcoin spot ETFs have triggered notable market volatility, significantly impacting Bitcoin’s price trajectory. Key funds such as ARK 21Shares and Fidelity experienced substantial outflows, signaling a'},
#  {'titulo': 'Crypto Price Prediction Today 6 June – Bitcoin, Solana, XRP',
#   'url': 'https://cryptonews.com/news/crypto-price-prediction-today-bitcoin-solana-xrp-6-june/',
#   'keywords': 'News|Bitcoin|Solana|XRP',
#   'sentimento': 'POSITIVE',
#   'data': '06/06/2025 22:36:18 UTC',
#   'resumo': 'Crypto price optimism is hitting record highs following Bitcoin’s recent rally, which saw it hit a new all-time high (ATH) just two weeks prior. At the same time, several top meme coins —Pepe, Trump, SPX6900, and FartCoin among them—have each reached record highs within the last six months. Investor optimism is clearly on the rise, propelling digital asset values higher. Historically, cryptocurrencies backed by robust fundamentals tend to ignite broad market upswings, supported by dedicated communities, institutional interest, and active development teams. In this context, let’s explore several prominent cryptos that analysts believe could set new all-time highs (ATHs) during the current bullish trend. Bitcoin ($BTC): The World’s Biggest Crypto Is Likely to Set Many Price ATHs Before New Year Bitcoin ($BTC) needs no introduction. The world’s biggest crypto recently hit a new price high at $111,814 on May 2 and many believe it could set several new all-time highs on its way to $150K by the end of the year, but these will be contingent on a favourable political climate. See, Bitcoin is crypto’s flagship coin. This means that anyone who believes in crypto’s future is likely to want to add some Bitcoin to their portfolio. The $2 trillion market cap digital gold is virtually single handedly holding up crypto’s $3.38 trillion market. In the last 24 hours, Bitcoin is up 0.3% to trade at $104,292 as it reverses course from a pullback down 6.9% from its ATH. This puts it in spitting distance of setting a new high watermark and even hitting $150,000, but this will need to be helped along by positive macro developments. Recent falling US inflation rates bode well for crypto on the whole, and the possibility of the pro-crypto Trump administration delivering on a US Strategic Bitcoin Reserve and comprehensive legislation before the year is out could drive Bitcoin to its next big milestone, while simultaneously pulling up the wider industry too. Solana ($SOL): DeFi Titan Riding Institutional Tailwinds Solana ($SOL) continues to distinguish itself within the DeFi ecosystem, lauded for its sophisticated smart contracts, rapid transaction speeds and ultra-low fees. With a current valuation of $81.35 billion, it has cemented itself as a formidable challenger to Ethereum in the DeFi sector. There is mounting chatter that U.S. regulatory authorities may soon approve spot ETFs tied to Solana, following in the footsteps of similar approvals for Bitcoin and Ethereum. Such a development could bolster SOL’s appeal to institutional investors. President Donald Trump has also floated the idea of including Solana in a proposed U.S. Strategic Crypto Reserve, although acquisition would be through asset seizures rather than direct purchase. Solana recently rebounded after sliding from highs above $250 in January to just over $100 in February. It has since broken above a descending trend channel and now trades at $152.76—up 1% in the last 24 hours—mirroring Bitcoin’s brief correction and rebound. Analysts now anticipate that if SOL breaches resistance at $200 and $250, it could push toward the $300 mark before the summer concludes. Ripple (XRP): Could Ripple’s Cross-Border Payment Token Reach New Heights? Ripple’s XRP token remains a key player in bridging blockchain and traditional finance, particularly for international money transfers. Renowned for facilitating fast and affordable cross-border transactions, XRP has gained attention from major global entities like the United Nations, which sees it as a useful tool for compliant and efficient financial systems. A longstanding legal standoff between Ripple and the SEC reached a key moment in 2023, when a court determined that XRP’s retail transactions do not constitute securities. This verdict brought much-needed clarity and sparked renewed investor interest. Over the past year, XRP has outpaced Bitcoin in growth, posting a 314% gain compared to Bitcoin’s 46.5% increase. Technical indicators sugg ...
#  {'titulo': 'Netflix’s House of Streams May Feature Bitcoin Prize Amid Warnings of Related Fraudulent Schemes',
#   'url': 'https://en.coinotag.com/netflixs-house-of-streams-may-feature-bitcoin-prize-amid-warnings-of-related-fraudulent-schemes/',
#   'keywords': 'Bitcoin|News|BTC|FRONT|MEME',
#   'sentimento': 'POSITIVE',
#   'data': '06/06/2025 22:34:53 UTC',
#   'resumo': 'The upcoming Netflix-licensed reality series, House of Streams, is set to spotlight Twitch streamers competing for a high-stakes cryptocurrency prize, marking a unique intersection of digital entertainment and crypto culture.'},
#  {'titulo': 'Alchemy Pay price prediction 2025-2031: Is ACH a good investment?',
#   'url': 'https://www.cryptopolitan.com/alchemy-pay-price-prediction/',
#   'keywords': 'Crypto Price Predictions|Alchemy Pay',
#   'sentimento': 'NEUTRAL',
#   'data': '06/06/2025 22:30:00 UTC',
#   'resumo': "Key takeaways: Alchemy Pay’s price can reach a maximum of $0.0291 and an average trading value of $0.0257 in 2025. The ACH could reach a maximum of $0.0965 and an average of $0.0836 by the end of 2028. Alchemy Pay price prediction for 2031 projects a maximum price of $0.2860. Alchemy Pay (ACH) is a cross-functional payment solution making significant strides in bridging the gap between fiat and cryptocurrency payment ecosystems. The platform’s robust framework enables global consumers to connect with merchants, developers, and institutions worldwide, facilitating transactions across multiple fiat currencies and cryptocurrencies. This functionality enhances Alchemy Pay’s adaptability and positions it as a pivotal player in the financial technology sector. Alchemy Pay’s inclusion in the decentralized platforms of popular projects like Augur, Cryptokitties, and OpenSea, along with its support for the infrastructure of Kyber and Radar Relay, adds layers of credibility and utility, enhancing its investment appeal. Can Alchemy Pay (ACH) get to $0.1? Will Alchemy Pay hit $1? Let’s find out in this ACH price prediction for 2025-2031. Overview Cryptocurrency Alchemy Pay Token ACH Price $0.01976 Market Cap $180.05 Million Trading Volume (24-hour) $28.07M Circulating Supply 10 Billion ACH All-time High $0.1975 Aug 06, 2021 All-time Low $0.001338 Jul 20, 2021 24-h High $0.02128 24-h Low $0.01951 Alchemy Pay price prediction: Technical analysis Price Prediction $\u202f0.147431 (612.46%) Price Volatility 9.59% 50-Day SMA $0.026115 14-Day RSI 36.23 Sentiment Bearish Fear & Greed Index 57 (Greed) Green Days 13/30 (43%) 200-Day SMA $0.024616 Alchemy Pay price analysis TL;DR Breakdown: ACH/USD shows a bearish trend after dropping from $0.0850 Short-term recovery possible to $0.02286-$0.0300 if resistance breaks Sustained uptrend needs momentum indicators and volume improvement ACH/USD 1-day chart ACH/USD 1-day chart The ACH/USD 1-day chart on June 6 shows a volatile pattern with a recent sharp spike around early 2025, peaking near $0.0850, followed by a steep decline to around $0.0200. The price is currently consolidating between $0.0200 and $0.0243, with Bollinger Bands tightening, suggesting reduced volatility and a potential breakout. The RSI at 31.54 indicates oversold conditions, hinting at a possible short-term rebound. However, the overall trend remains bearish unless the price breaks above the 20-day SMA ($0.02686). I expect a cautious recovery towards $0.0300 in the near term, but a sustained uptrend requires breaking key resistance levels around $0.0350. Watch for increased volume and RSI improvement. Alchemy Pay 4-hour price chart ACH/USD 4-hour chart The ACH/USD 4-hour chart shows a sharp decline from a peak near $0.0850 in early 2025, now trading at $0.01976, down 2.18%. The Bollinger Bands are narrowing, indicating low volatility and a potential breakout. The MACD is bearish (-0.00045), but the histogram shows slight convergence, hinting at weakening downward momentum. The Balance of Power at -0.58 suggests sellers still dominate, but the price is near a support level around $0.01949. I expect a short-term consolidation between $0.01949 and $0.02153, with a possible bounce to $0.02286 if buying pressure increases. A break below $0.01949 could push it towards $0.01500. Watch MACD for trend shifts. Alchemy Pay technical indicators: Levels and action Daily simple moving average (SMA) Period Value Action SMA 3 $0.022593 BUY SMA 5 $0.024291 SELL SMA 10 $0.024799 SELL SMA 21 $0.026306 SELL SMA 50 $0.025518 SELL SMA 100 $0.026065 SELL SMA 200 $0.024775 SELL Daily exponential moving average (EMA) Period Value Action EMA 3 $0.02555 SELL EMA 5 $0.025018 SELL EMA 10 $0.023976 BUY EMA 21 $0.02366 BUY EMA 50 $0.024854 SELL EMA 100 $0.02578 SELL EMA 200 $0.025626 SELL Alchemy Pay price analysis conclusion Analyzing both the 1-day and 4-hour ACH/USD charts, Alchemy Pay (ACH) exhibits a bearish trend after a sharp decline from $0.085 ...
#  {'titulo': 'Reality show to pit Twitch streamers against each other to win 1 BTC',
#   'url': 'https://cointelegraph.com/news/reality-show-twitch-streamers-win-bitcoin?utm_source=rss_feed&utm_medium=rss&utm_campaign=rss_partner_inbound',
#   'keywords': '',
#   'sentimento': 'NEGATIVE',
#   'data': '06/06/2025 22:27:26 UTC',
#   'resumo': 'The series’ website issued a notice in May warning of a “fraudulent cryptocurrency scheme” using its branding to lure investors.'},
#  {'titulo': 'Gemini’s Confidential IPO Filing Could Signal New Phase for Cryptocurrency Market Stability',
#   'url': 'https://en.coinotag.com/geminis-confidential-ipo-filing-could-signal-new-phase-for-cryptocurrency-market-stability/',
#   'keywords': 'News|BTC|ETH',
#   'sentimento': 'POSITIVE',
#   'data': '06/06/2025 22:25:42 UTC',
#   'resumo': 'Gemini, the cryptocurrency exchange founded by the Winklevoss twins, has confidentially filed for an initial public offering (IPO), signaling a pivotal moment in the crypto industry. This strategic move aims'},
#  {'titulo': 'Willy Woo Predicts Bitcoin’s Dramatic Upsurge Over the Next Two Decades',
#   'url': 'https://en.coin-turk.com/willy-woo-predicts-bitcoins-dramatic-upsurge-over-the-next-two-decades/',
#   'keywords': 'Cryptocurrency News',
#   'sentimento': 'POSITIVE',
#   'data': '06/06/2025 22:25:19 UTC',
#   'resumo': 'Willy Woo predicts a significant Bitcoin value rise over the next 20 years. Bitcoin could potentially replace gold, reaching 188 times its current value. Continue Reading: Willy Woo Predicts Bitcoin’s Dramatic Upsurge Over the Next Two Decades The post Willy Woo Predicts Bitcoin’s Dramatic Upsurge Over the Next Two Decades appeared first on COINTURK NEWS .'},
#  {'titulo': 'Arctic Pablo Coin Presale Highlights Potential Amid Filecoin and Cosmos Developments',
#   'url': 'https://en.coinotag.com/arctic-pablo-coin-presale-highlights-potential-amid-filecoin-and-cosmos-developments/',
#   'keywords': 'News|FIL',
#   'sentimento': 'POSITIVE',
#   'data': '06/06/2025 22:07:41 UTC',
#   'resumo': 'Arctic Pablo Coin emerges as a standout opportunity in the crypto market, combining innovative deflationary tokenomics with a compelling presale phase that promises significant returns. Alongside Arctic Pablo Coin’s rapid'},
#  {'titulo': 'Republican Senator Josh Hawley Breaks With Party Lines, Opposes Upcoming GENIUS Act: Report',
#   'url': 'https://dailyhodl.com/2025/06/06/republican-senator-josh-hawley-breaks-with-party-lines-opposes-upcoming-genius-act-report/',
#   'keywords': 'Regulators|genius|Genius act|josh hawley|New York Times|News|stablecoins',
#   'sentimento': 'NEGATIVE',
#   'data': '06/06/2025 22:01:17 UTC',
#   'resumo': "Senator Josh Hawley is opposing party lines by voting against an upcoming stablecoin bill endorsed by the White House. According to a New York Times report , the Missouri Republican Senator is saying “no” to the upcoming GENIUS Act. “It’s a huge giveaway to Big Tech. It allows these tech companies to issue stablecoins without any kind of controls. I don’t see why we would do that.” According to the Times report, the GENIUS Act could potentially upend the credit card industry and benefit both Trump and Musk, who are currently publicly feuding . Hawley is pushing for amendments to the bill that would curtail Big Tech’s involvement. GENIUS is an acronym meaning “Guiding and Establishing National Innovation for US Stablecoins”. The bill purports to seek to improve consumer protection, transparency, marketing restrictions and regulatory oversight for the burgeoning stablecoin market, estimated to be worth $250 billion. Yesterday, the second-biggest player in the US-dollar pegged stablecoin space, Circle, issuer of USDC, launched its initial public offering, or IPO. “Circle is now officially a public company, listed on the NYSE under CRCL.” In its New York Stock Exchange (NYSE) debut, Circle saw an opening price of $69 per share, up by 168.48% from the IPO price of $31 per share. Follow us on X , Facebook and Telegram Don't Miss a Beat – Subscribe to get email alerts delivered directly to your inbox Check Price Action Surf The Daily Hodl Mix Disclaimer: Opinions expressed at The Daily Hodl are not investment advice. Investors should do their due diligence before making any high-risk investments in Bitcoin, cryptocurrency or digital assets. Please be advised that your transfers and trades are at your own risk, and any losses you may incur are your responsibility. The Daily Hodl does not recommend the buying or selling of any cryptocurrencies or digital assets, nor is The Daily Hodl an investment advisor. Please note that The Daily Hodl participates in affiliate marketing. Featured Image: Shutterstock/laskoart/Vladimir Sazonov The post Republican Senator Josh Hawley Breaks With Party Lines, Opposes Upcoming GENIUS Act: Report appeared first on The Daily Hodl ."}]

# %%
from coleta_analises import coleta_analises_profissionais
analises = coleta_analises_profissionais()
analises
# Out:
# '\n## Stock market information for Bitcoin (BTC)\n- Bitcoin is a crypto in the CRYPTO market.\n- The price is 104387.0 USD currently with a change of 2834.00 USD (0.03%) from the previous close.\n- The intraday high is 105220.0 USD and the intraday low is 101358.0 USD.\n\n\nAs of June 6, 2025, Bitcoin (BTC) is trading at $104,387, reflecting a 2.79% increase from the previous close. The day\'s trading range has seen a high of $105,220 and a low of $101,358.\n\nRecent analyses and reports provide insights into Bitcoin\'s market dynamics, focusing on on-chain metrics, macroeconomic factors, and technical indicators. Below are summaries of notable reports published within the past week:\n\n1. **Article/Report Title:** "Bitcoin On-Chain and Macro Data Indicates Bearish Trends Since $100K"\n   - **Institution/Source:** Blockchain.News\n   - **Publication Date:** June 5, 2025\n   - **URL:** [https://cn.blockchain.news/flashnews/bitcoin-on-chain-and-macro-data-indicates-bearish-trends-since-100k](https://cn.blockchain.news/flashnews/bitcoin-on-chain-and-macro-data-indicates-bearish-trends-since-100k)\n   - **Extracted Content:**\n     Charles Edwards, founder of Capriole Investments, highlights that since Bitcoin reached $100,000 on December 18, 2024, on-chain and macroeconomic data have exhibited bearish signals. Key metrics include:\n     - **Puell Multiple:** At 1.2 as of June 5, 2025, suggesting overvaluation.\n     - **MVRV Z-Score:** Recorded at 3.5, indicating Bitcoin is trading significantly above its realized value.\n     - **Hash Ribbon:** Declined to 0.75, signaling potential miner capitulation.\n     These indicators collectively point to a market under pressure, with reduced trading volumes and liquidity across major exchanges. Technical indicators such as the Relative Strength Index (RSI) at 30 suggest oversold conditions, while the Moving Average Convergence Divergence (MACD) shows a bearish crossover, indicating continued downward momentum.\n\n2. **Article/Report Title:** "Bitcoin (BTC) Market Analysis: Fragility Amid Macro Shocks"\n   - **Institution/Source:** TheBlockchain.Digital\n   - **Publication Date:** June 4, 2025\n   - **URL:** [https://theblockchain.digital/bitcoin-btc-market-analysis-fragility-amid-macro-shocks/](https://theblockchain.digital/bitcoin-btc-market-analysis-fragility-amid-macro-shocks/)\n   - **Extracted Content:**\n     Glassnode\'s analysis indicates that Bitcoin remains under significant pressure due to weak fundamentals and macroeconomic instability. Despite these challenges, Bitcoin shows resilience around the $80,000 mark, suggesting potential defense by long-term holders. Key observations include:\n     - **Market Overview:** A sharp sell-off followed by a rebound to $82,000, with the Relative Strength Index (RSI) below its statistical low, hinting at a potential breakout from the current consolidation range.\n     - **Derivatives Market:** A multi-month downtrend persists, with open interest declining to $33.94 billion and funding rates slightly increasing to $1.11 million per day.\n     - **On-Chain Signals:** Active addresses and transfer volumes show little strength, and fee volume has declined to $458,000 per day, indicating low blockspace demand.\n     Overall, Bitcoin\'s market position is fragile due to weak fundamentals, declining profitability, and soft liquidity, making it susceptible to macroeconomic shocks.\n\n3. **Article/Report Title:** "Market Observation Weekly Report: Macro-driven and Capital Rotation, the Crypto Market is Under Pressure in the Short Term but Optimistic in the Long Term"\n   - **Institution/Source:** PANews\n   - **Publication Date:** June 3, 2025\n   - **URL:** [https://www.panewslab.com/en/sqarticledetails/j0pugp4bwjx0.html](https://www.panewslab.com/en/sqarticledetails/j0pugp4bwjx0.html)\n   - **Extracted Content:**\n     The report provides a comprehensive analysis of the current crypto market, emphasizing macroeconomic factors and capital rotation ...

# %%
# Removendo metade dos dados historicos para caber na janela de contexto do modelo
dados_coindesk['Data'] = dados_coindesk['Data'][-len(dados_coindesk['Data'])//2:]

# %%
dados_coindesk['Data']
# Out:
# [{'UNIT': 'HOUR',
#   'TIMESTAMP': 1745650800,
#   'OPEN': 94647.6,
#   'HIGH': 94792.87,
#   'LOW': 94596.33,
#   'CLOSE': 94596.33,
#   'VOLUME': 0.9556434,
#   'QUOTE_VOLUME': 90503.6543426335,
#   'VOLUME_BUY': 0.57450301,
#   'QUOTE_VOLUME_BUY': 54407.1788324693,
#   'VOLUME_SELL': 0.38114039,
#   'QUOTE_VOLUME_SELL': 36096.4755101642,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745654400,
#   'OPEN': 94596.33,
#   'HIGH': 94725.99,
#   'LOW': 94271.22,
#   'CLOSE': 94370.54,
#   'VOLUME': 1.93568475,
#   'QUOTE_VOLUME': 182973.698654939,
#   'VOLUME_BUY': 1.0485693,
#   'QUOTE_VOLUME_BUY': 99137.8944165689,
#   'VOLUME_SELL': 0.88711545,
#   'QUOTE_VOLUME_SELL': 83835.8042383723,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745658000,
#   'OPEN': 94370.54,
#   'HIGH': 94415.62,
#   'LOW': 94103.92,
#   'CLOSE': 94259.4,
#   'VOLUME': 2.38008403,
#   'QUOTE_VOLUME': 224178.320971917,
#   'VOLUME_BUY': 0.56704458,
#   'QUOTE_VOLUME_BUY': 53444.2507999398,
#   'VOLUME_SELL': 1.81303945,
#   'QUOTE_VOLUME_SELL': 170734.070171975,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745661600,
#   'OPEN': 94259.4,
#   'HIGH': 94392.11,
#   'LOW': 94205.08,
#   'CLOSE': 94256.28,
#   'VOLUME': 0.33194914,
#   'QUOTE_VOLUME': 31309.1820021979,
#   'VOLUME_BUY': 0.15769798,
#   'QUOTE_VOLUME_BUY': 14871.2948910335,
#   'VOLUME_SELL': 0.17425116,
#   'QUOTE_VOLUME_SELL': 16437.8871111644,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745665200,
#   'OPEN': 94256.28,
#   'HIGH': 94256.28,
#   'LOW': 93999.99,
#   'CLOSE': 94130.18,
#   'VOLUME': 1.46585172,
#   'QUOTE_VOLUME': 137942.409541278,
#   'VOLUME_BUY': 0.6635859,
#   'QUOTE_VOLUME_BUY': 62430.3353800279,
#   'VOLUME_SELL': 0.80226582,
#   'QUOTE_VOLUME_SELL': 75512.0741612506,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745668800,
#   'OPEN': 94130.18,
#   'HIGH': 94306.13,
#   'LOW': 94108.47,
#   'CLOSE': 94204.48,
#   'VOLUME': 1.05346582,
#   'QUOTE_VOLUME': 99258.7350262563,
#   'VOLUME_BUY': 0.58516203,
#   'QUOTE_VOLUME_BUY': 55140.2190513149,
#   'VOLUME_SELL': 0.46830379,
#   'QUOTE_VOLUME_SELL': 44118.5159749414,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745672400,
#   'OPEN': 94204.48,
#   'HIGH': 94247.54,
#   'LOW': 93869.74,
#   'CLOSE': 94145.29,
#   'VOLUME': 0.84402978,
#   'QUOTE_VOLUME': 79373.3819669209,
#   'VOLUME_BUY': 0.34026518,
#   'QUOTE_VOLUME_BUY': 32001.2287918616,
#   'VOLUME_SELL': 0.5037646,
#   'QUOTE_VOLUME_SELL': 47372.1531750593,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745676000,
#   'OPEN': 94145.29,
#   'HIGH': 94266.6,
#   'LOW': 93917.66,
#   'CLOSE': 94231.99,
#   'VOLUME': 0.84777882,
#   'QUOTE_VOLUME': 79776.5704077724,
#   'VOLUME_BUY': 0.2384085,
#   'QUOTE_VOLUME_BUY': 22426.733588889,
#   'VOLUME_SELL': 0.60937032,
#   'QUOTE_VOLUME_SELL': 57349.8368188834,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745679600,
#   'OPEN': 94231.99,
#   'HIGH': 94404.5,
#   'LOW': 94221.38,
#   'CLOSE': 94374.08,
#   'VOLUME': 2.32116687,
#   'QUOTE_VOLUME': 219014.240011682,
#   'VOLUME_BUY': 1.96114756,
#   'QUOTE_VOLUME_BUY': 185052.12006973,
#   'VOLUME_SELL': 0.36001931,
#   'QUOTE_VOLUME_SELL': 33962.1199419512,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745683200,
#   'OPEN': 94374.08,
#   'HIGH': 94374.08,
#   'LOW': 94093.51,
#   'CLOSE': 94273.2,
#   'VOLUME': 0.5237271,
#   'QUOTE_VOLUME': 49378.0797483805,
#   'VOLUME_BUY': 0.29545185,
#   'QUOTE_VOLUME_BUY': 27862.2135835829,
#   'VOLUME_SELL': 0.22827525,
#   'QUOTE_VOLUME_SELL': 21515.8661647976,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745686800,
#   'OPEN': 94273.2,
#   'HIGH': 94361.76,
#   'LOW': 94247.89,
#   'CLOSE': 94319.8,
#   'VOLUME': 0.54457546,
#   'QUOTE_VOLUME': 51362.6067590822,
#   'VOLUME_BUY': 0.15390592,
#   'QUOTE_VOLUME_BUY': 14517.1727592374,
#   'VOLUME_SELL': 0.39066954,
#   'QUOTE_VOLUME_SELL': 36845.4339998448,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745690400,
#   'OPEN': 94319.8,
#   'HIGH': 94367.97,
#   'LOW': 94134.45,
#   'CLOSE': 94139.8,
#   'VOLUME': 0.47027204,
#   'QUOTE_VOLUME': 44323.5838283666,
#   'VOLUME_BUY': 0.23998944,
#   'QUOTE_VOLUME_BUY': 22607.6864969289,
#   'VOLUME_SELL': 0.2302826,
#   'QUOTE_VOLUME_SELL': 21715.8973314377,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745694000,
#   'OPEN': 94139.8,
#   'HIGH': 94303.19,
#   'LOW': 94112.93,
#   'CLOSE': 94303.19,
#   'VOLUME': 0.75986871,
#   'QUOTE_VOLUME': 71606.5829975985,
#   'VOLUME_BUY': 0.30284351,
#   'QUOTE_VOLUME_BUY': 28538.8742677923,
#   'VOLUME_SELL': 0.4570252,
#   'QUOTE_VOLUME_SELL': 43067.7087298062,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745697600,
#   'OPEN': 94303.19,
#   'HIGH': 94378.72,
#   'LOW': 94155.91,
#   'CLOSE': 94165.41,
#   'VOLUME': 0.55505757,
#   'QUOTE_VOLUME': 52320.8721324463,
#   'VOLUME_BUY': 0.16858029,
#   'QUOTE_VOLUME_BUY': 15893.5008071191,
#   'VOLUME_SELL': 0.38647728,
#   'QUOTE_VOLUME_SELL': 36427.3713253272,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745701200,
#   'OPEN': 94165.41,
#   'HIGH': 94374.59,
#   'LOW': 94124.75,
#   'CLOSE': 94357.47,
#   'VOLUME': 1.45441747,
#   'QUOTE_VOLUME': 137104.689987204,
#   'VOLUME_BUY': 0.46206303,
#   'QUOTE_VOLUME_BUY': 43546.8767333584,
#   'VOLUME_SELL': 0.99235444,
#   'QUOTE_VOLUME_SELL': 93557.8132538466,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745704800,
#   'OPEN': 94357.47,
#   'HIGH': 94804.41,
#   'LOW': 94357.47,
#   'CLOSE': 94778.46,
#   'VOLUME': 3.00186418,
#   'QUOTE_VOLUME': 284069.609854064,
#   'VOLUME_BUY': 1.32883895,
#   'QUOTE_VOLUME_BUY': 125768.300581341,
#   'VOLUME_SELL': 1.67302523,
#   'QUOTE_VOLUME_SELL': 158301.309272725,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745708400,
#   'OPEN': 94778.46,
#   'HIGH': 94873.07,
#   'LOW': 94569.88,
#   'CLOSE': 94639.74,
#   'VOLUME': 3.88226055,
#   'QUOTE_VOLUME': 367731.197947564,
#   'VOLUME_BUY': 0.91247981,
#   'QUOTE_VOLUME_BUY': 86435.1007604522,
#   'VOLUME_SELL': 2.96978074,
#   'QUOTE_VOLUME_SELL': 281296.097187111,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745712000,
#   'OPEN': 94639.74,
#   'HIGH': 94992.12,
#   'LOW': 94596.51,
#   'CLOSE': 94873.65,
#   'VOLUME': 4.62922151,
#   'QUOTE_VOLUME': 439053.816049511,
#   'VOLUME_BUY': 1.72218005,
#   'QUOTE_VOLUME_BUY': 163367.79279947,
#   'VOLUME_SELL': 2.90704146,
#   'QUOTE_VOLUME_SELL': 275686.023250045,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745715600,
#   'OPEN': 94873.65,
#   'HIGH': 95324.73,
#   'LOW': 94062.7,
#   'CLOSE': 94085.8,
#   'VOLUME': 6.8363004,
#   'QUOTE_VOLUME': 647336.692114413,
#   'VOLUME_BUY': 2.53165071,
#   'QUOTE_VOLUME_BUY': 239890.024530708,
#   'VOLUME_SELL': 4.30464969,
#   'QUOTE_VOLUME_SELL': 407446.667583708,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745719200,
#   'OPEN': 94085.8,
#   'HIGH': 94446.06,
#   'LOW': 94073.86,
#   'CLOSE': 94328.78,
#   'VOLUME': 0.55147968,
#   'QUOTE_VOLUME': 52029.5113506166,
#   'VOLUME_BUY': 0.39349053,
#   'QUOTE_VOLUME_BUY': 37120.510729331,
#   'VOLUME_SELL': 0.15798915,
#   'QUOTE_VOLUME_SELL': 14909.0006212856,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745722800,
#   'OPEN': 94328.78,
#   'HIGH': 94439.45,
#   'LOW': 94148.82,
#   'CLOSE': 94171.58,
#   'VOLUME': 0.37649432,
#   'QUOTE_VOLUME': 35488.2482300929,
#   'VOLUME_BUY': 0.08498891,
#   'QUOTE_VOLUME_BUY': 8015.1761765467,
#   'VOLUME_SELL': 0.29150541,
#   'QUOTE_VOLUME_SELL': 27473.0720535462,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745726400,
#   'OPEN': 94171.58,
#   'HIGH': 94268.14,
#   'LOW': 94017.52,
#   'CLOSE': 94017.52,
#   'VOLUME': 1.05553195,
#   'QUOTE_VOLUME': 99373.6191901396,
#   'VOLUME_BUY': 0.54787094,
#   'QUOTE_VOLUME_BUY': 51590.59740599,
#   'VOLUME_SELL': 0.50766101,
#   'QUOTE_VOLUME_SELL': 47783.0217841496,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745730000,
#   'OPEN': 94017.52,
#   'HIGH': 94162.6,
#   'LOW': 93660.24,
#   'CLOSE': 93910.74,
#   'VOLUME': 2.32129726,
#   'QUOTE_VOLUME': 218037.807937893,
#   'VOLUME_BUY': 0.96454603,
#   'QUOTE_VOLUME_BUY': 90639.9729718355,
#   'VOLUME_SELL': 1.35675123,
#   'QUOTE_VOLUME_SELL': 127397.83496606,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745733600,
#   'OPEN': 93910.74,
#   'HIGH': 94087.03,
#   'LOW': 93910.74,
#   'CLOSE': 94012.46,
#   'VOLUME': 0.55376887,
#   'QUOTE_VOLUME': 52052.8025586269,
#   'VOLUME_BUY': 0.42695255,
#   'QUOTE_VOLUME_BUY': 40132.445791754,
#   'VOLUME_SELL': 0.12681632,
#   'QUOTE_VOLUME_SELL': 11920.3567668729,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745737200,
#   'OPEN': 94012.46,
#   'HIGH': 94150.27,
#   'LOW': 93941.92,
#   'CLOSE': 94146.68,
#   'VOLUME': 0.54039676,
#   'QUOTE_VOLUME': 50830.7982544161,
#   'VOLUME_BUY': 0.22403685,
#   'QUOTE_VOLUME_BUY': 21076.8204840855,
#   'VOLUME_SELL': 0.31635991,
#   'QUOTE_VOLUME_SELL': 29753.9777703306,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745740800,
#   'OPEN': 94146.68,
#   'HIGH': 94301.3,
#   'LOW': 94040.9,
#   'CLOSE': 94231.78,
#   'VOLUME': 0.53418961,
#   'QUOTE_VOLUME': 50315.0212613001,
#   'VOLUME_BUY': 0.34258592,
#   'QUOTE_VOLUME_BUY': 32268.7669689091,
#   'VOLUME_SELL': 0.19160369,
#   'QUOTE_VOLUME_SELL': 18046.254292391,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745744400,
#   'OPEN': 94231.78,
#   'HIGH': 94231.78,
#   'LOW': 94116.88,
#   'CLOSE': 94141.97,
#   'VOLUME': 0.34040631,
#   'QUOTE_VOLUME': 32053.3756331694,
#   'VOLUME_BUY': 0.16245943,
#   'QUOTE_VOLUME_BUY': 15297.9252890632,
#   'VOLUME_SELL': 0.17794688,
#   'QUOTE_VOLUME_SELL': 16755.4503441062,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745748000,
#   'OPEN': 94141.97,
#   'HIGH': 94191.12,
#   'LOW': 93944.62,
#   'CLOSE': 94038.03,
#   'VOLUME': 0.94588307,
#   'QUOTE_VOLUME': 88998.6045863956,
#   'VOLUME_BUY': 0.61093329,
#   'QUOTE_VOLUME_BUY': 57483.4835344157,
#   'VOLUME_SELL': 0.33494978,
#   'QUOTE_VOLUME_SELL': 31515.1210519799,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745751600,
#   'OPEN': 94038.03,
#   'HIGH': 94075.18,
#   'LOW': 93889.56,
#   'CLOSE': 93992.13,
#   'VOLUME': 0.5396801,
#   'QUOTE_VOLUME': 50726.9014957609,
#   'VOLUME_BUY': 0.18820207,
#   'QUOTE_VOLUME_BUY': 17685.1090958169,
#   'VOLUME_SELL': 0.35147803,
#   'QUOTE_VOLUME_SELL': 33041.792399944,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745755200,
#   'OPEN': 93992.13,
#   'HIGH': 93992.13,
#   'LOW': 93693.62,
#   'CLOSE': 93770.64,
#   'VOLUME': 0.90056274,
#   'QUOTE_VOLUME': 84489.7017051152,
#   'VOLUME_BUY': 0.6283837,
#   'QUOTE_VOLUME_BUY': 58959.5976488106,
#   'VOLUME_SELL': 0.27217904,
#   'QUOTE_VOLUME_SELL': 25530.1040563046,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745758800,
#   'OPEN': 93770.64,
#   'HIGH': 94089.71,
#   'LOW': 93620.76,
#   'CLOSE': 94070.05,
#   'VOLUME': 1.46263343,
#   'QUOTE_VOLUME': 137157.468737384,
#   'VOLUME_BUY': 1.07054019,
#   'QUOTE_VOLUME_BUY': 100391.852610212,
#   'VOLUME_SELL': 0.39209324,
#   'QUOTE_VOLUME_SELL': 36765.6161271711,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745762400,
#   'OPEN': 94070.05,
#   'HIGH': 94184.03,
#   'LOW': 93942.6,
#   'CLOSE': 93993.99,
#   'VOLUME': 1.20997673,
#   'QUOTE_VOLUME': 113777.91917057,
#   'VOLUME_BUY': 0.69042182,
#   'QUOTE_VOLUME_BUY': 64911.8331407699,
#   'VOLUME_SELL': 0.51955491,
#   'QUOTE_VOLUME_SELL': 48866.0860298006,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745766000,
#   'OPEN': 93993.99,
#   'HIGH': 93995.37,
#   'LOW': 93813.66,
#   'CLOSE': 93892.71,
#   'VOLUME': 0.52134763,
#   'QUOTE_VOLUME': 48945.5978027937,
#   'VOLUME_BUY': 0.22301064,
#   'QUOTE_VOLUME_BUY': 20934.5097767886,
#   'VOLUME_SELL': 0.29833699,
#   'QUOTE_VOLUME_SELL': 28011.0880260051,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745769600,
#   'OPEN': 93892.71,
#   'HIGH': 93930.43,
#   'LOW': 93755.77,
#   'CLOSE': 93892.08,
#   'VOLUME': 0.85305989,
#   'QUOTE_VOLUME': 80060.029760254,
#   'VOLUME_BUY': 0.5293653,
#   'QUOTE_VOLUME_BUY': 49670.9386146382,
#   'VOLUME_SELL': 0.32369459,
#   'QUOTE_VOLUME_SELL': 30389.0911456158,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745773200,
#   'OPEN': 93892.08,
#   'HIGH': 94159.01,
#   'LOW': 93828.19,
#   'CLOSE': 94044.43,
#   'VOLUME': 1.04530211,
#   'QUOTE_VOLUME': 98260.2589246468,
#   'VOLUME_BUY': 0.46782188,
#   'QUOTE_VOLUME_BUY': 43975.7593404342,
#   'VOLUME_SELL': 0.57748023,
#   'QUOTE_VOLUME_SELL': 54284.4995842126,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745776800,
#   'OPEN': 94044.43,
#   'HIGH': 94414.05,
#   'LOW': 93996.93,
#   'CLOSE': 94284.25,
#   'VOLUME': 1.253958,
#   'QUOTE_VOLUME': 118208.130929574,
#   'VOLUME_BUY': 0.38640609,
#   'QUOTE_VOLUME_BUY': 36422.153677586,
#   'VOLUME_SELL': 0.86755191,
#   'QUOTE_VOLUME_SELL': 81785.9772519884,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745780400,
#   'OPEN': 94284.25,
#   'HIGH': 94452.17,
#   'LOW': 94199.98,
#   'CLOSE': 94428.54,
#   'VOLUME': 0.77312195,
#   'QUOTE_VOLUME': 72896.9585408224,
#   'VOLUME_BUY': 0.17127085,
#   'QUOTE_VOLUME_BUY': 16153.4699364597,
#   'VOLUME_SELL': 0.6018511,
#   'QUOTE_VOLUME_SELL': 56743.4886043627,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745784000,
#   'OPEN': 94428.54,
#   'HIGH': 94428.54,
#   'LOW': 94287.86,
#   'CLOSE': 94290.16,
#   'VOLUME': 0.77659776,
#   'QUOTE_VOLUME': 73247.3216299445,
#   'VOLUME_BUY': 0.19379958,
#   'QUOTE_VOLUME_BUY': 18277.0467685461,
#   'VOLUME_SELL': 0.58279818,
#   'QUOTE_VOLUME_SELL': 54970.2748613984,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745787600,
#   'OPEN': 94290.16,
#   'HIGH': 94526.6,
#   'LOW': 94168.27,
#   'CLOSE': 94343.23,
#   'VOLUME': 1.5629678,
#   'QUOTE_VOLUME': 147535.49987594,
#   'VOLUME_BUY': 0.79027822,
#   'QUOTE_VOLUME_BUY': 74635.5648469587,
#   'VOLUME_SELL': 0.77268958,
#   'QUOTE_VOLUME_SELL': 72899.9350289816,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745791200,
#   'OPEN': 94343.23,
#   'HIGH': 94343.23,
#   'LOW': 93635.68,
#   'CLOSE': 93986.72,
#   'VOLUME': 2.52089768,
#   'QUOTE_VOLUME': 236965.110832074,
#   'VOLUME_BUY': 0.96603224,
#   'QUOTE_VOLUME_BUY': 90756.4413950737,
#   'VOLUME_SELL': 1.55486544,
#   'QUOTE_VOLUME_SELL': 146208.669437006,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745794800,
#   'OPEN': 93986.72,
#   'HIGH': 93986.72,
#   'LOW': 93680.62,
#   'CLOSE': 93768.75,
#   'VOLUME': 0.57335082,
#   'QUOTE_VOLUME': 53764.5149154474,
#   'VOLUME_BUY': 0.30873838,
#   'QUOTE_VOLUME_BUY': 28953.3713048517,
#   'VOLUME_SELL': 0.26461244,
#   'QUOTE_VOLUME_SELL': 24811.1436105957,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745798400,
#   'OPEN': 93768.75,
#   'HIGH': 93787.72,
#   'LOW': 93287.36,
#   'CLOSE': 93422.4,
#   'VOLUME': 3.99357898,
#   'QUOTE_VOLUME': 373396.251722017,
#   'VOLUME_BUY': 2.11048759,
#   'QUOTE_VOLUME_BUY': 197337.266597899,
#   'VOLUME_SELL': 1.88309139,
#   'QUOTE_VOLUME_SELL': 176058.985124114,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745802000,
#   'OPEN': 93422.4,
#   'HIGH': 93587.28,
#   'LOW': 92806.1,
#   'CLOSE': 92919.75,
#   'VOLUME': 9.05907914,
#   'QUOTE_VOLUME': 842811.583363019,
#   'VOLUME_BUY': 3.90573725,
#   'QUOTE_VOLUME_BUY': 363201.849240896,
#   'VOLUME_SELL': 5.15334189,
#   'QUOTE_VOLUME_SELL': 479609.73412213,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745805600,
#   'OPEN': 92919.75,
#   'HIGH': 93631.84,
#   'LOW': 92875.33,
#   'CLOSE': 93617.54,
#   'VOLUME': 6.68491968,
#   'QUOTE_VOLUME': 623362.234909921,
#   'VOLUME_BUY': 3.83638407,
#   'QUOTE_VOLUME_BUY': 357609.449466086,
#   'VOLUME_SELL': 2.84853561,
#   'QUOTE_VOLUME_SELL': 265752.785443833,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745809200,
#   'OPEN': 93617.54,
#   'HIGH': 93985.4,
#   'LOW': 93475.99,
#   'CLOSE': 93843.27,
#   'VOLUME': 2.46593737,
#   'QUOTE_VOLUME': 231143.699910624,
#   'VOLUME_BUY': 0.92025739,
#   'QUOTE_VOLUME_BUY': 86252.0448244265,
#   'VOLUME_SELL': 1.54567998,
#   'QUOTE_VOLUME_SELL': 144891.655086198,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745812800,
#   'OPEN': 93843.27,
#   'HIGH': 94180.49,
#   'LOW': 93843.27,
#   'CLOSE': 94032.93,
#   'VOLUME': 4.27477402,
#   'QUOTE_VOLUME': 402051.694841065,
#   'VOLUME_BUY': 1.24212923,
#   'QUOTE_VOLUME_BUY': 116811.213633388,
#   'VOLUME_SELL': 3.03264479,
#   'QUOTE_VOLUME_SELL': 285240.481207676,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745816400,
#   'OPEN': 94032.93,
#   'HIGH': 94343.84,
#   'LOW': 93992.4,
#   'CLOSE': 94217.26,
#   'VOLUME': 3.75472367,
#   'QUOTE_VOLUME': 353500.747265646,
#   'VOLUME_BUY': 1.30931954,
#   'QUOTE_VOLUME_BUY': 123261.24288732,
#   'VOLUME_SELL': 2.44540413,
#   'QUOTE_VOLUME_SELL': 230239.504378333,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745820000,
#   'OPEN': 94217.26,
#   'HIGH': 94667.72,
#   'LOW': 94217.26,
#   'CLOSE': 94576.07,
#   'VOLUME': 1.37493161,
#   'QUOTE_VOLUME': 129905.452701417,
#   'VOLUME_BUY': 0.77304261,
#   'QUOTE_VOLUME_BUY': 73045.2840359004,
#   'VOLUME_SELL': 0.601889,
#   'QUOTE_VOLUME_SELL': 56860.1686655182,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745823600,
#   'OPEN': 94576.07,
#   'HIGH': 94810.6,
#   'LOW': 94485.05,
#   'CLOSE': 94685.72,
#   'VOLUME': 1.61526955,
#   'QUOTE_VOLUME': 152912.410167236,
#   'VOLUME_BUY': 0.75460955,
#   'QUOTE_VOLUME_BUY': 71447.0653506789,
#   'VOLUME_SELL': 0.86066,
#   'QUOTE_VOLUME_SELL': 81465.3448165575,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745827200,
#   'OPEN': 94685.72,
#   'HIGH': 94830.93,
#   'LOW': 94624.52,
#   'CLOSE': 94670.77,
#   'VOLUME': 2.24262783,
#   'QUOTE_VOLUME': 212446.533907735,
#   'VOLUME_BUY': 1.05029046,
#   'QUOTE_VOLUME_BUY': 99502.8546094016,
#   'VOLUME_SELL': 1.19233737,
#   'QUOTE_VOLUME_SELL': 112943.679298333,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745830800,
#   'OPEN': 94670.77,
#   'HIGH': 94878.54,
#   'LOW': 94670.77,
#   'CLOSE': 94708.41,
#   'VOLUME': 1.57518694,
#   'QUOTE_VOLUME': 149298.661265579,
#   'VOLUME_BUY': 0.5857903,
#   'QUOTE_VOLUME_BUY': 55519.97708955,
#   'VOLUME_SELL': 0.98939664,
#   'QUOTE_VOLUME_SELL': 93778.6841760307,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745834400,
#   'OPEN': 94708.41,
#   'HIGH': 95214.02,
#   'LOW': 94363.96,
#   'CLOSE': 95044.7,
#   'VOLUME': 10.3884276,
#   'QUOTE_VOLUME': 985834.094422308,
#   'VOLUME_BUY': 6.15006139,
#   'QUOTE_VOLUME_BUY': 583702.295207432,
#   'VOLUME_SELL': 4.23836621,
#   'QUOTE_VOLUME_SELL': 402131.799214875,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745838000,
#   'OPEN': 95044.7,
#   'HIGH': 95524.68,
#   'LOW': 95002.2,
#   'CLOSE': 95239.62,
#   'VOLUME': 5.66698123,
#   'QUOTE_VOLUME': 540375.303717406,
#   'VOLUME_BUY': 3.2975593,
#   'QUOTE_VOLUME_BUY': 314492.152230257,
#   'VOLUME_SELL': 2.36942193,
#   'QUOTE_VOLUME_SELL': 225883.151487148,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745841600,
#   'OPEN': 95239.62,
#   'HIGH': 95607.81,
#   'LOW': 95065.62,
#   'CLOSE': 95369.18,
#   'VOLUME': 4.1765809,
#   'QUOTE_VOLUME': 398201.004635731,
#   'VOLUME_BUY': 1.95035346,
#   'QUOTE_VOLUME_BUY': 186010.285030944,
#   'VOLUME_SELL': 2.22622744,
#   'QUOTE_VOLUME_SELL': 212190.719604787,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745845200,
#   'OPEN': 95369.18,
#   'HIGH': 95508.13,
#   'LOW': 93930.8,
#   'CLOSE': 93979.73,
#   'VOLUME': 17.65465878,
#   'QUOTE_VOLUME': 1671859.18204087,
#   'VOLUME_BUY': 8.41333777,
#   'QUOTE_VOLUME_BUY': 796437.114286495,
#   'VOLUME_SELL': 9.24132101,
#   'QUOTE_VOLUME_SELL': 875422.067754418,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745848800,
#   'OPEN': 93979.73,
#   'HIGH': 94896.77,
#   'LOW': 93862.86,
#   'CLOSE': 94435.05,
#   'VOLUME': 10.22281884,
#   'QUOTE_VOLUME': 965332.295178737,
#   'VOLUME_BUY': 5.29477046,
#   'QUOTE_VOLUME_BUY': 499680.450554972,
#   'VOLUME_SELL': 4.92804838,
#   'QUOTE_VOLUME_SELL': 465651.844623763,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745852400,
#   'OPEN': 94435.05,
#   'HIGH': 94544.42,
#   'LOW': 93587.9,
#   'CLOSE': 93814.44,
#   'VOLUME': 13.95155838,
#   'QUOTE_VOLUME': 1309945.92621249,
#   'VOLUME_BUY': 8.68526965,
#   'QUOTE_VOLUME_BUY': 815302.936171246,
#   'VOLUME_SELL': 5.26628873,
#   'QUOTE_VOLUME_SELL': 494642.990041228,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745856000,
#   'OPEN': 93814.44,
#   'HIGH': 93990.62,
#   'LOW': 93451.26,
#   'CLOSE': 93737.09,
#   'VOLUME': 5.01392774,
#   'QUOTE_VOLUME': 469726.730211877,
#   'VOLUME_BUY': 2.62209768,
#   'QUOTE_VOLUME_BUY': 245625.409630687,
#   'VOLUME_SELL': 2.39183006,
#   'QUOTE_VOLUME_SELL': 224101.320581188,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745859600,
#   'OPEN': 93737.09,
#   'HIGH': 94094.61,
#   'LOW': 93489.89,
#   'CLOSE': 94094.61,
#   'VOLUME': 3.3875921,
#   'QUOTE_VOLUME': 317657.021383998,
#   'VOLUME_BUY': 1.74397489,
#   'QUOTE_VOLUME_BUY': 163524.200413919,
#   'VOLUME_SELL': 1.64361721,
#   'QUOTE_VOLUME_SELL': 154132.820970078,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745863200,
#   'OPEN': 94094.61,
#   'HIGH': 94228.81,
#   'LOW': 93814.44,
#   'CLOSE': 94228.81,
#   'VOLUME': 1.81419412,
#   'QUOTE_VOLUME': 170508.198620336,
#   'VOLUME_BUY': 0.80473421,
#   'QUOTE_VOLUME_BUY': 75637.5589217664,
#   'VOLUME_SELL': 1.00945991,
#   'QUOTE_VOLUME_SELL': 94870.6396985716,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745866800,
#   'OPEN': 94228.81,
#   'HIGH': 94914.88,
#   'LOW': 94160.86,
#   'CLOSE': 94791.24,
#   'VOLUME': 10.63580649,
#   'QUOTE_VOLUME': 1007181.45688871,
#   'VOLUME_BUY': 5.27987275,
#   'QUOTE_VOLUME_BUY': 499945.776069582,
#   'VOLUME_SELL': 5.35593374,
#   'QUOTE_VOLUME_SELL': 507235.680819128,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745870400,
#   'OPEN': 94791.24,
#   'HIGH': 94810.15,
#   'LOW': 94395.82,
#   'CLOSE': 94469.28,
#   'VOLUME': 3.68571835,
#   'QUOTE_VOLUME': 348577.026778391,
#   'VOLUME_BUY': 1.31422392,
#   'QUOTE_VOLUME_BUY': 124297.326462288,
#   'VOLUME_SELL': 2.37149443,
#   'QUOTE_VOLUME_SELL': 224279.700316105,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745874000,
#   'OPEN': 94469.28,
#   'HIGH': 94553.09,
#   'LOW': 94312.04,
#   'CLOSE': 94534.94,
#   'VOLUME': 0.72590288,
#   'QUOTE_VOLUME': 68569.2181784266,
#   'VOLUME_BUY': 0.36312417,
#   'QUOTE_VOLUME_BUY': 34299.3653142724,
#   'VOLUME_SELL': 0.36277871,
#   'QUOTE_VOLUME_SELL': 34269.8528641542,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745877600,
#   'OPEN': 94534.94,
#   'HIGH': 94879.46,
#   'LOW': 94475.86,
#   'CLOSE': 94820.48,
#   'VOLUME': 3.74790794,
#   'QUOTE_VOLUME': 354909.000263945,
#   'VOLUME_BUY': 1.83474441,
#   'QUOTE_VOLUME_BUY': 173772.435135436,
#   'VOLUME_SELL': 1.91316353,
#   'QUOTE_VOLUME_SELL': 181136.56512851,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745881200,
#   'OPEN': 94820.48,
#   'HIGH': 95171.48,
#   'LOW': 94818.45,
#   'CLOSE': 95010.06,
#   'VOLUME': 6.52768578,
#   'QUOTE_VOLUME': 620575.107182836,
#   'VOLUME_BUY': 4.12761955,
#   'QUOTE_VOLUME_BUY': 392621.34496303,
#   'VOLUME_SELL': 2.40006623,
#   'QUOTE_VOLUME_SELL': 227953.762219808,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745884800,
#   'OPEN': 95010.06,
#   'HIGH': 95232.85,
#   'LOW': 94830.66,
#   'CLOSE': 95067.77,
#   'VOLUME': 1.98566281,
#   'QUOTE_VOLUME': 188680.156468652,
#   'VOLUME_BUY': 0.86246257,
#   'QUOTE_VOLUME_BUY': 81952.9010045511,
#   'VOLUME_SELL': 1.12320024,
#   'QUOTE_VOLUME_SELL': 106727.2554641,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745888400,
#   'OPEN': 95067.77,
#   'HIGH': 95458.27,
#   'LOW': 94740.05,
#   'CLOSE': 94858.06,
#   'VOLUME': 9.46118752,
#   'QUOTE_VOLUME': 900010.548302155,
#   'VOLUME_BUY': 3.66374813,
#   'QUOTE_VOLUME_BUY': 348623.247972829,
#   'VOLUME_SELL': 5.79743939,
#   'QUOTE_VOLUME_SELL': 551387.300329335,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745892000,
#   'OPEN': 94858.06,
#   'HIGH': 94959.14,
#   'LOW': 94510.35,
#   'CLOSE': 94618.37,
#   'VOLUME': 6.83938378,
#   'QUOTE_VOLUME': 647843.074508608,
#   'VOLUME_BUY': 2.82917357,
#   'QUOTE_VOLUME_BUY': 267943.370334358,
#   'VOLUME_SELL': 4.01021021,
#   'QUOTE_VOLUME_SELL': 379899.704174249,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745895600,
#   'OPEN': 94618.37,
#   'HIGH': 94803.83,
#   'LOW': 94447.9,
#   'CLOSE': 94662.19,
#   'VOLUME': 4.23873894,
#   'QUOTE_VOLUME': 401113.994860564,
#   'VOLUME_BUY': 1.71447676,
#   'QUOTE_VOLUME_BUY': 162235.274573934,
#   'VOLUME_SELL': 2.52426218,
#   'QUOTE_VOLUME_SELL': 238878.720286629,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745899200,
#   'OPEN': 94662.19,
#   'HIGH': 94871.55,
#   'LOW': 94315.56,
#   'CLOSE': 94318.24,
#   'VOLUME': 10.69780726,
#   'QUOTE_VOLUME': 1010516.00327314,
#   'VOLUME_BUY': 3.38641214,
#   'QUOTE_VOLUME_BUY': 319946.882336592,
#   'VOLUME_SELL': 7.31139512,
#   'QUOTE_VOLUME_SELL': 690569.120936558,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745902800,
#   'OPEN': 94318.24,
#   'HIGH': 94393.82,
#   'LOW': 94197.01,
#   'CLOSE': 94256.44,
#   'VOLUME': 1.616235,
#   'QUOTE_VOLUME': 152413.373522086,
#   'VOLUME_BUY': 0.49195069,
#   'QUOTE_VOLUME_BUY': 46383.8677952604,
#   'VOLUME_SELL': 1.12428431,
#   'QUOTE_VOLUME_SELL': 106029.505726828,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745906400,
#   'OPEN': 94256.44,
#   'HIGH': 94810.32,
#   'LOW': 94256.44,
#   'CLOSE': 94804.19,
#   'VOLUME': 1.99833563,
#   'QUOTE_VOLUME': 189146.600786419,
#   'VOLUME_BUY': 0.96912308,
#   'QUOTE_VOLUME_BUY': 91689.9855134568,
#   'VOLUME_SELL': 1.02921255,
#   'QUOTE_VOLUME_SELL': 97456.6152729618,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745910000,
#   'OPEN': 94804.19,
#   'HIGH': 94964.47,
#   'LOW': 94712.29,
#   'CLOSE': 94950.35,
#   'VOLUME': 2.39619982,
#   'QUOTE_VOLUME': 227192.27219135,
#   'VOLUME_BUY': 1.18098761,
#   'QUOTE_VOLUME_BUY': 111986.692298215,
#   'VOLUME_SELL': 1.21521221,
#   'QUOTE_VOLUME_SELL': 115205.579893138,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745913600,
#   'OPEN': 94950.35,
#   'HIGH': 95095.7,
#   'LOW': 94837.08,
#   'CLOSE': 95028.09,
#   'VOLUME': 3.44569039,
#   'QUOTE_VOLUME': 327199.573988116,
#   'VOLUME_BUY': 2.00791504,
#   'QUOTE_VOLUME_BUY': 190692.106100019,
#   'VOLUME_SELL': 1.43777535,
#   'QUOTE_VOLUME_SELL': 136507.467888098,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745917200,
#   'OPEN': 95028.09,
#   'HIGH': 95091.25,
#   'LOW': 94801.86,
#   'CLOSE': 94999.99,
#   'VOLUME': 1.14222615,
#   'QUOTE_VOLUME': 108414.471304735,
#   'VOLUME_BUY': 0.47024844,
#   'QUOTE_VOLUME_BUY': 44630.9384518605,
#   'VOLUME_SELL': 0.67197771,
#   'QUOTE_VOLUME_SELL': 63783.532852874,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745920800,
#   'OPEN': 94999.99,
#   'HIGH': 95045.01,
#   'LOW': 94768.27,
#   'CLOSE': 94822.75,
#   'VOLUME': 5.30576006,
#   'QUOTE_VOLUME': 503828.781238748,
#   'VOLUME_BUY': 2.89315734,
#   'QUOTE_VOLUME_BUY': 274774.760706265,
#   'VOLUME_SELL': 2.41260272,
#   'QUOTE_VOLUME_SELL': 229054.020532475,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745924400,
#   'OPEN': 94822.75,
#   'HIGH': 95301.59,
#   'LOW': 94817.3,
#   'CLOSE': 95138.66,
#   'VOLUME': 5.16431715,
#   'QUOTE_VOLUME': 491354.474734855,
#   'VOLUME_BUY': 2.24979494,
#   'QUOTE_VOLUME_BUY': 214083.098418324,
#   'VOLUME_SELL': 2.91452221,
#   'QUOTE_VOLUME_SELL': 277271.376316525,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745928000,
#   'OPEN': 95138.66,
#   'HIGH': 95153.21,
#   'LOW': 94790.08,
#   'CLOSE': 94810.76,
#   'VOLUME': 3.01505703,
#   'QUOTE_VOLUME': 286323.731370788,
#   'VOLUME_BUY': 0.76773276,
#   'QUOTE_VOLUME_BUY': 72903.6427792212,
#   'VOLUME_SELL': 2.24732427,
#   'QUOTE_VOLUME_SELL': 213420.088591569,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745931600,
#   'OPEN': 94810.76,
#   'HIGH': 95031.22,
#   'LOW': 94596.23,
#   'CLOSE': 94817.62,
#   'VOLUME': 5.96931171,
#   'QUOTE_VOLUME': 565901.590269868,
#   'VOLUME_BUY': 2.67501879,
#   'QUOTE_VOLUME_BUY': 253567.025134492,
#   'VOLUME_SELL': 3.29429292,
#   'QUOTE_VOLUME_SELL': 312334.565135369,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745935200,
#   'OPEN': 94817.62,
#   'HIGH': 95284.85,
#   'LOW': 94551.02,
#   'CLOSE': 95069.03,
#   'VOLUME': 16.26939503,
#   'QUOTE_VOLUME': 1543322.11929023,
#   'VOLUME_BUY': 8.63362405,
#   'QUOTE_VOLUME_BUY': 819382.224209366,
#   'VOLUME_SELL': 7.63577098,
#   'QUOTE_VOLUME_SELL': 723939.895080873,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745938800,
#   'OPEN': 95069.03,
#   'HIGH': 95120.35,
#   'LOW': 94734.06,
#   'CLOSE': 94846.04,
#   'VOLUME': 2.85361092,
#   'QUOTE_VOLUME': 270888.61736567,
#   'VOLUME_BUY': 1.31729838,
#   'QUOTE_VOLUME_BUY': 125064.042795087,
#   'VOLUME_SELL': 1.53631254,
#   'QUOTE_VOLUME_SELL': 145824.574570585,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745942400,
#   'OPEN': 94846.04,
#   'HIGH': 95462.22,
#   'LOW': 94814.3,
#   'CLOSE': 94982.41,
#   'VOLUME': 6.81870743,
#   'QUOTE_VOLUME': 649333.804509933,
#   'VOLUME_BUY': 3.35804602,
#   'QUOTE_VOLUME_BUY': 319780.094578352,
#   'VOLUME_SELL': 3.46066141,
#   'QUOTE_VOLUME_SELL': 329553.709931581,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745946000,
#   'OPEN': 94982.41,
#   'HIGH': 95362.52,
#   'LOW': 94662.88,
#   'CLOSE': 95198.96,
#   'VOLUME': 9.07347218,
#   'QUOTE_VOLUME': 862441.637621443,
#   'VOLUME_BUY': 3.70483398,
#   'QUOTE_VOLUME_BUY': 352187.585407726,
#   'VOLUME_SELL': 5.3686382,
#   'QUOTE_VOLUME_SELL': 510254.052213712,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745949600,
#   'OPEN': 95198.96,
#   'HIGH': 95449.74,
#   'LOW': 95057.03,
#   'CLOSE': 95389.12,
#   'VOLUME': 6.21262969,
#   'QUOTE_VOLUME': 592173.532203397,
#   'VOLUME_BUY': 3.09288898,
#   'QUOTE_VOLUME_BUY': 294803.493167913,
#   'VOLUME_SELL': 3.11974071,
#   'QUOTE_VOLUME_SELL': 297370.039035481,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745953200,
#   'OPEN': 95389.12,
#   'HIGH': 95449.13,
#   'LOW': 95221.65,
#   'CLOSE': 95301.35,
#   'VOLUME': 4.41203482,
#   'QUOTE_VOLUME': 420685.375777254,
#   'VOLUME_BUY': 1.39858421,
#   'QUOTE_VOLUME_BUY': 133365.16971354,
#   'VOLUME_SELL': 3.01345061,
#   'QUOTE_VOLUME_SELL': 287320.206063708,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745956800,
#   'OPEN': 95301.35,
#   'HIGH': 95390.93,
#   'LOW': 94819.36,
#   'CLOSE': 94836.21,
#   'VOLUME': 2.43002194,
#   'QUOTE_VOLUME': 230969.55182851,
#   'VOLUME_BUY': 1.06455313,
#   'QUOTE_VOLUME_BUY': 101234.964418815,
#   'VOLUME_SELL': 1.36546881,
#   'QUOTE_VOLUME_SELL': 129734.587409697,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745960400,
#   'OPEN': 94836.21,
#   'HIGH': 94942.39,
#   'LOW': 94351.72,
#   'CLOSE': 94770.1,
#   'VOLUME': 11.2535117,
#   'QUOTE_VOLUME': 1064555.20185155,
#   'VOLUME_BUY': 3.47931055,
#   'QUOTE_VOLUME_BUY': 329118.373551578,
#   'VOLUME_SELL': 7.77420115,
#   'QUOTE_VOLUME_SELL': 735436.828299988,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745964000,
#   'OPEN': 94770.1,
#   'HIGH': 94770.1,
#   'LOW': 94031.13,
#   'CLOSE': 94159.09,
#   'VOLUME': 4.3517049,
#   'QUOTE_VOLUME': 410430.645364237,
#   'VOLUME_BUY': 2.11729378,
#   'QUOTE_VOLUME_BUY': 199678.444808839,
#   'VOLUME_SELL': 2.23441112,
#   'QUOTE_VOLUME_SELL': 210752.200555402,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745967600,
#   'OPEN': 94159.09,
#   'HIGH': 94293.31,
#   'LOW': 93755.16,
#   'CLOSE': 94254.44,
#   'VOLUME': 6.48095779,
#   'QUOTE_VOLUME': 609186.911803545,
#   'VOLUME_BUY': 3.11391554,
#   'QUOTE_VOLUME_BUY': 292768.310497983,
#   'VOLUME_SELL': 3.36704225,
#   'QUOTE_VOLUME_SELL': 316418.601305563,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745971200,
#   'OPEN': 94254.44,
#   'HIGH': 94630.95,
#   'LOW': 94140.24,
#   'CLOSE': 94546.72,
#   'VOLUME': 4.17936014,
#   'QUOTE_VOLUME': 394520.612065585,
#   'VOLUME_BUY': 2.39105379,
#   'QUOTE_VOLUME_BUY': 225659.242618335,
#   'VOLUME_SELL': 1.78830635,
#   'QUOTE_VOLUME_SELL': 168861.369447247,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745974800,
#   'OPEN': 94546.72,
#   'HIGH': 94598.41,
#   'LOW': 94295.36,
#   'CLOSE': 94523.39,
#   'VOLUME': 5.82186627,
#   'QUOTE_VOLUME': 549988.793323129,
#   'VOLUME_BUY': 2.47263601,
#   'QUOTE_VOLUME_BUY': 233642.02780525,
#   'VOLUME_SELL': 3.34923026,
#   'QUOTE_VOLUME_SELL': 316346.765517877,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745978400,
#   'OPEN': 94523.39,
#   'HIGH': 94796.25,
#   'LOW': 94466.12,
#   'CLOSE': 94631.7,
#   'VOLUME': 2.3614246,
#   'QUOTE_VOLUME': 223540.459824444,
#   'VOLUME_BUY': 1.16546199,
#   'QUOTE_VOLUME_BUY': 110351.255161467,
#   'VOLUME_SELL': 1.19596261,
#   'QUOTE_VOLUME_SELL': 113189.204662979,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745982000,
#   'OPEN': 94631.7,
#   'HIGH': 95115.69,
#   'LOW': 94507.3,
#   'CLOSE': 95011.49,
#   'VOLUME': 3.71921136,
#   'QUOTE_VOLUME': 352558.261237833,
#   'VOLUME_BUY': 1.69681933,
#   'QUOTE_VOLUME_BUY': 160942.106672669,
#   'VOLUME_SELL': 2.02239203,
#   'QUOTE_VOLUME_SELL': 191616.154565164,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745985600,
#   'OPEN': 95011.49,
#   'HIGH': 95181.86,
#   'LOW': 94869.38,
#   'CLOSE': 95045.32,
#   'VOLUME': 5.0557846,
#   'QUOTE_VOLUME': 480424.388957561,
#   'VOLUME_BUY': 2.68536266,
#   'QUOTE_VOLUME_BUY': 255278.821295676,
#   'VOLUME_SELL': 2.37042194,
#   'QUOTE_VOLUME_SELL': 225145.567661886,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745989200,
#   'OPEN': 95045.32,
#   'HIGH': 95106.55,
#   'LOW': 94871.55,
#   'CLOSE': 94903.53,
#   'VOLUME': 1.65185285,
#   'QUOTE_VOLUME': 156893.639561038,
#   'VOLUME_BUY': 0.59451841,
#   'QUOTE_VOLUME_BUY': 56471.1987646929,
#   'VOLUME_SELL': 1.05733444,
#   'QUOTE_VOLUME_SELL': 100422.440796346,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745992800,
#   'OPEN': 94903.53,
#   'HIGH': 94961.85,
#   'LOW': 94750.41,
#   'CLOSE': 94762.24,
#   'VOLUME': 1.33375069,
#   'QUOTE_VOLUME': 126536.48195351,
#   'VOLUME_BUY': 0.3442176,
#   'QUOTE_VOLUME_BUY': 32648.622179301,
#   'VOLUME_SELL': 0.98953309,
#   'QUOTE_VOLUME_SELL': 93887.8597742092,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1745996400,
#   'OPEN': 94762.24,
#   'HIGH': 94868.76,
#   'LOW': 94506.62,
#   'CLOSE': 94607.34,
#   'VOLUME': 1.13522847,
#   'QUOTE_VOLUME': 107515.94350403,
#   'VOLUME_BUY': 0.55393017,
#   'QUOTE_VOLUME_BUY': 52467.0123021512,
#   'VOLUME_SELL': 0.5812983,
#   'QUOTE_VOLUME_SELL': 55048.931201879,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746000000,
#   'OPEN': 94607.34,
#   'HIGH': 94813.93,
#   'LOW': 94552.47,
#   'CLOSE': 94735.55,
#   'VOLUME': 11.52014379,
#   'QUOTE_VOLUME': 1090388.0904885,
#   'VOLUME_BUY': 2.05534744,
#   'QUOTE_VOLUME_BUY': 194563.76577276,
#   'VOLUME_SELL': 9.46479635,
#   'QUOTE_VOLUME_SELL': 895824.324715754,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746003600,
#   'OPEN': 94735.55,
#   'HIGH': 95027.16,
#   'LOW': 94682.04,
#   'CLOSE': 94971.88,
#   'VOLUME': 2.50451509,
#   'QUOTE_VOLUME': 237663.331164213,
#   'VOLUME_BUY': 0.87186731,
#   'QUOTE_VOLUME_BUY': 82750.7517601192,
#   'VOLUME_SELL': 1.63264778,
#   'QUOTE_VOLUME_SELL': 154912.579404094,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746007200,
#   'OPEN': 94971.88,
#   'HIGH': 95027.29,
#   'LOW': 94852.74,
#   'CLOSE': 94943.19,
#   'VOLUME': 1.15684272,
#   'QUOTE_VOLUME': 109803.486383958,
#   'VOLUME_BUY': 0.45663338,
#   'QUOTE_VOLUME_BUY': 43340.4570729274,
#   'VOLUME_SELL': 0.70020934,
#   'QUOTE_VOLUME_SELL': 66463.0293110298,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746010800,
#   'OPEN': 94943.19,
#   'HIGH': 95230.39,
#   'LOW': 94923.47,
#   'CLOSE': 95178.79,
#   'VOLUME': 2.24090265,
#   'QUOTE_VOLUME': 213138.190710218,
#   'VOLUME_BUY': 1.037762,
#   'QUOTE_VOLUME_BUY': 98690.2637433953,
#   'VOLUME_SELL': 1.20314065,
#   'QUOTE_VOLUME_SELL': 114447.926966821,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746014400,
#   'OPEN': 95178.79,
#   'HIGH': 95216.61,
#   'LOW': 94347.79,
#   'CLOSE': 94583.05,
#   'VOLUME': 5.78137272,
#   'QUOTE_VOLUME': 547985.657821926,
#   'VOLUME_BUY': 2.73319465,
#   'QUOTE_VOLUME_BUY': 259135.433251784,
#   'VOLUME_SELL': 3.04817807,
#   'QUOTE_VOLUME_SELL': 288850.224570141,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746018000,
#   'OPEN': 94583.05,
#   'HIGH': 94649.52,
#   'LOW': 93009.59,
#   'CLOSE': 93067.09,
#   'VOLUME': 25.27910948,
#   'QUOTE_VOLUME': 2381433.91702332,
#   'VOLUME_BUY': 9.09758572,
#   'QUOTE_VOLUME_BUY': 855917.685870463,
#   'VOLUME_SELL': 16.18152376,
#   'QUOTE_VOLUME_SELL': 1525516.23115291,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746021600,
#   'OPEN': 93067.09,
#   'HIGH': 94357.31,
#   'LOW': 92904.87,
#   'CLOSE': 93784.71,
#   'VOLUME': 22.5039092,
#   'QUOTE_VOLUME': 2107083.84673343,
#   'VOLUME_BUY': 14.07725813,
#   'QUOTE_VOLUME_BUY': 1317703.62876338,
#   'VOLUME_SELL': 8.42665107,
#   'QUOTE_VOLUME_SELL': 789380.217970038,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746025200,
#   'OPEN': 93784.71,
#   'HIGH': 94110.25,
#   'LOW': 93664.17,
#   'CLOSE': 94013.06,
#   'VOLUME': 4.53186932,
#   'QUOTE_VOLUME': 425699.271045794,
#   'VOLUME_BUY': 2.86635573,
#   'QUOTE_VOLUME_BUY': 269221.234601299,
#   'VOLUME_SELL': 1.66551359,
#   'QUOTE_VOLUME_SELL': 156478.036444496,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746028800,
#   'OPEN': 94013.06,
#   'HIGH': 94184.92,
#   'LOW': 93539.06,
#   'CLOSE': 93924.37,
#   'VOLUME': 3.78881661,
#   'QUOTE_VOLUME': 355617.812335191,
#   'VOLUME_BUY': 2.06484592,
#   'QUOTE_VOLUME_BUY': 193785.271773343,
#   'VOLUME_SELL': 1.72397069,
#   'QUOTE_VOLUME_SELL': 161832.540561846,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746032400,
#   'OPEN': 93924.37,
#   'HIGH': 94251.7,
#   'LOW': 93765.93,
#   'CLOSE': 94084.5,
#   'VOLUME': 2.05592614,
#   'QUOTE_VOLUME': 193322.469610914,
#   'VOLUME_BUY': 1.27345917,
#   'QUOTE_VOLUME_BUY': 119731.715362426,
#   'VOLUME_SELL': 0.78246697,
#   'QUOTE_VOLUME_SELL': 73590.754248489,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746036000,
#   'OPEN': 94084.5,
#   'HIGH': 94515.55,
#   'LOW': 94003.58,
#   'CLOSE': 94085.42,
#   'VOLUME': 6.28416601,
#   'QUOTE_VOLUME': 592562.552530933,
#   'VOLUME_BUY': 2.71429435,
#   'QUOTE_VOLUME_BUY': 255934.88158775,
#   'VOLUME_SELL': 3.56987166,
#   'QUOTE_VOLUME_SELL': 336627.670943181,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746039600,
#   'OPEN': 94085.42,
#   'HIGH': 94276.38,
#   'LOW': 93739.71,
#   'CLOSE': 94169.39,
#   'VOLUME': 4.62352282,
#   'QUOTE_VOLUME': 434694.901999515,
#   'VOLUME_BUY': 2.92308046,
#   'QUOTE_VOLUME_BUY': 274816.722015379,
#   'VOLUME_SELL': 1.70044236,
#   'QUOTE_VOLUME_SELL': 159878.179984137,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746043200,
#   'OPEN': 94169.39,
#   'HIGH': 94743,
#   'LOW': 94099.75,
#   'CLOSE': 94557.71,
#   'VOLUME': 10.38996628,
#   'QUOTE_VOLUME': 982275.24521975,
#   'VOLUME_BUY': 6.19697771,
#   'QUOTE_VOLUME_BUY': 585863.770922099,
#   'VOLUME_SELL': 4.19298857,
#   'QUOTE_VOLUME_SELL': 396411.474297649,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746046800,
#   'OPEN': 94557.71,
#   'HIGH': 94788.1,
#   'LOW': 94379.96,
#   'CLOSE': 94391.3,
#   'VOLUME': 2.63984761,
#   'QUOTE_VOLUME': 249612.683947666,
#   'VOLUME_BUY': 0.96140236,
#   'QUOTE_VOLUME_BUY': 90903.0455344676,
#   'VOLUME_SELL': 1.67844525,
#   'QUOTE_VOLUME_SELL': 158709.6384132,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746050400,
#   'OPEN': 94391.3,
#   'HIGH': 94715.02,
#   'LOW': 94069.17,
#   'CLOSE': 94118.87,
#   'VOLUME': 6.47825,
#   'QUOTE_VOLUME': 611247.713070677,
#   'VOLUME_BUY': 2.75814332,
#   'QUOTE_VOLUME_BUY': 260316.180076577,
#   'VOLUME_SELL': 3.72010668,
#   'QUOTE_VOLUME_SELL': 350931.5329941,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746054000,
#   'OPEN': 94118.87,
#   'HIGH': 94340.75,
#   'LOW': 94002.28,
#   'CLOSE': 94191.1,
#   'VOLUME': 3.17900391,
#   'QUOTE_VOLUME': 299440.343514499,
#   'VOLUME_BUY': 1.80578517,
#   'QUOTE_VOLUME_BUY': 170091.841321622,
#   'VOLUME_SELL': 1.37321874,
#   'QUOTE_VOLUME_SELL': 129348.502192877,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746057600,
#   'OPEN': 94191.1,
#   'HIGH': 94397.06,
#   'LOW': 94140.5,
#   'CLOSE': 94394.45,
#   'VOLUME': 2.73098975,
#   'QUOTE_VOLUME': 257501.099101461,
#   'VOLUME_BUY': 0.88211534,
#   'QUOTE_VOLUME_BUY': 83158.1588709636,
#   'VOLUME_SELL': 1.84887441,
#   'QUOTE_VOLUME_SELL': 174342.940230498,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746061200,
#   'OPEN': 94394.45,
#   'HIGH': 94711.03,
#   'LOW': 94394.45,
#   'CLOSE': 94645.12,
#   'VOLUME': 4.5543774,
#   'QUOTE_VOLUME': 430927.747879528,
#   'VOLUME_BUY': 2.48745389,
#   'QUOTE_VOLUME_BUY': 235343.776898243,
#   'VOLUME_SELL': 2.06692351,
#   'QUOTE_VOLUME_SELL': 195583.97098128,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746064800,
#   'OPEN': 94645.12,
#   'HIGH': 94968.84,
#   'LOW': 94621.5,
#   'CLOSE': 94819.08,
#   'VOLUME': 4.80803979,
#   'QUOTE_VOLUME': 456097.564880557,
#   'VOLUME_BUY': 2.45502138,
#   'QUOTE_VOLUME_BUY': 232864.050741096,
#   'VOLUME_SELL': 2.35301841,
#   'QUOTE_VOLUME_SELL': 223233.514139466,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746068400,
#   'OPEN': 94819.08,
#   'HIGH': 95012.43,
#   'LOW': 94706.05,
#   'CLOSE': 94779.78,
#   'VOLUME': 4.7367467,
#   'QUOTE_VOLUME': 449326.697314156,
#   'VOLUME_BUY': 2.78871473,
#   'QUOTE_VOLUME_BUY': 264608.375376125,
#   'VOLUME_SELL': 1.94803197,
#   'QUOTE_VOLUME_SELL': 184718.321938034,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746072000,
#   'OPEN': 94779.78,
#   'HIGH': 94927.87,
#   'LOW': 94714.2,
#   'CLOSE': 94887.71,
#   'VOLUME': 1.80269223,
#   'QUOTE_VOLUME': 170915.232054241,
#   'VOLUME_BUY': 0.89753917,
#   'QUOTE_VOLUME_BUY': 85089.8712776208,
#   'VOLUME_SELL': 0.90515306,
#   'QUOTE_VOLUME_SELL': 85825.3607766199,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746075600,
#   'OPEN': 94887.71,
#   'HIGH': 95182.79,
#   'LOW': 94851.35,
#   'CLOSE': 95156.58,
#   'VOLUME': 3.64754933,
#   'QUOTE_VOLUME': 346554.502038031,
#   'VOLUME_BUY': 1.98190347,
#   'QUOTE_VOLUME_BUY': 188292.71549057,
#   'VOLUME_SELL': 1.66564586,
#   'QUOTE_VOLUME_SELL': 158261.786547466,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746079200,
#   'OPEN': 95156.58,
#   'HIGH': 95191.43,
#   'LOW': 94813.94,
#   'CLOSE': 94905.16,
#   'VOLUME': 2.4272358,
#   'QUOTE_VOLUME': 230597.631704479,
#   'VOLUME_BUY': 0.49812268,
#   'QUOTE_VOLUME_BUY': 47320.2248299318,
#   'VOLUME_SELL': 1.92911312,
#   'QUOTE_VOLUME_SELL': 183277.406874548,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746082800,
#   'OPEN': 94905.16,
#   'HIGH': 95110.6,
#   'LOW': 94820.44,
#   'CLOSE': 95008.21,
#   'VOLUME': 1.69540343,
#   'QUOTE_VOLUME': 161096.019229385,
#   'VOLUME_BUY': 0.84340526,
#   'QUOTE_VOLUME_BUY': 80130.9265261243,
#   'VOLUME_SELL': 0.85199817,
#   'QUOTE_VOLUME_SELL': 80965.0927032583,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746086400,
#   'OPEN': 95008.21,
#   'HIGH': 95209.23,
#   'LOW': 94916.73,
#   'CLOSE': 95209.23,
#   'VOLUME': 2.11545952,
#   'QUOTE_VOLUME': 201123.613387608,
#   'VOLUME_BUY': 1.38462025,
#   'QUOTE_VOLUME_BUY': 131614.690036176,
#   'VOLUME_SELL': 0.73083927,
#   'QUOTE_VOLUME_SELL': 69508.9233514317,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746090000,
#   'OPEN': 95209.23,
#   'HIGH': 95807.11,
#   'LOW': 95165.17,
#   'CLOSE': 95539.72,
#   'VOLUME': 8.10491364,
#   'QUOTE_VOLUME': 773631.813722044,
#   'VOLUME_BUY': 6.48108733,
#   'QUOTE_VOLUME_BUY': 618499.228137682,
#   'VOLUME_SELL': 1.62382631,
#   'QUOTE_VOLUME_SELL': 155132.585584362,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746093600,
#   'OPEN': 95539.72,
#   'HIGH': 96398.25,
#   'LOW': 95524.34,
#   'CLOSE': 96185.63,
#   'VOLUME': 9.47920196,
#   'QUOTE_VOLUME': 910687.932711444,
#   'VOLUME_BUY': 5.01044166,
#   'QUOTE_VOLUME_BUY': 481534.317899612,
#   'VOLUME_SELL': 4.4687603,
#   'QUOTE_VOLUME_SELL': 429153.614811836,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746097200,
#   'OPEN': 96185.63,
#   'HIGH': 96267.2,
#   'LOW': 95851.76,
#   'CLOSE': 96187.64,
#   'VOLUME': 8.99179518,
#   'QUOTE_VOLUME': 864632.288833319,
#   'VOLUME_BUY': 7.52620482,
#   'QUOTE_VOLUME_BUY': 723762.818660501,
#   'VOLUME_SELL': 1.46559036,
#   'QUOTE_VOLUME_SELL': 140869.470172817,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746100800,
#   'OPEN': 96187.64,
#   'HIGH': 96474.03,
#   'LOW': 96121.03,
#   'CLOSE': 96390.07,
#   'VOLUME': 8.0671114,
#   'QUOTE_VOLUME': 776512.62779958,
#   'VOLUME_BUY': 4.11974742,
#   'QUOTE_VOLUME_BUY': 396559.434128255,
#   'VOLUME_SELL': 3.94736398,
#   'QUOTE_VOLUME_SELL': 379953.193671324,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746104400,
#   'OPEN': 96390.07,
#   'HIGH': 96754.21,
#   'LOW': 95817.43,
#   'CLOSE': 95831.84,
#   'VOLUME': 12.78683374,
#   'QUOTE_VOLUME': 1230894.93682536,
#   'VOLUME_BUY': 6.69332033,
#   'QUOTE_VOLUME_BUY': 644195.476007959,
#   'VOLUME_SELL': 6.09351341,
#   'QUOTE_VOLUME_SELL': 586699.460817386,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1746108000,
#   'OPEN': 95831.84,
#   'HIGH': 96947.51,
#   'LOW': 95815.44,
#   'CLOSE': 96854.94,
#   'VOLUME': 39.98577699,
#   'QUOTE_VOLUME': 3855416.22986178,
#   'VOLUME_BUY': 24.01703781,
#   'QUOTE_VOLUME_BUY': 2315697.52642095,
#   'VOLUME_SELL': 15.96873918,
#   'QUOTE_VOLUME_SELL': 1539718.70344095,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
# ...
#   'QUOTE_VOLUME_SELL': 21397.7963145592,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749099600,
#   'OPEN': 105205.06,
#   'HIGH': 105205.06,
#   'LOW': 104578.42,
#   'CLOSE': 104659.08,
#   'VOLUME': 2.76828953,
#   'QUOTE_VOLUME': 290255.998365727,
#   'VOLUME_BUY': 0.81886384,
#   'QUOTE_VOLUME_BUY': 85814.2306094215,
#   'VOLUME_SELL': 1.94942569,
#   'QUOTE_VOLUME_SELL': 204441.767756306,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749103200,
#   'OPEN': 104659.08,
#   'HIGH': 104696.34,
#   'LOW': 104379.35,
#   'CLOSE': 104478,
#   'VOLUME': 5.62283774,
#   'QUOTE_VOLUME': 587687.820104998,
#   'VOLUME_BUY': 2.98130373,
#   'QUOTE_VOLUME_BUY': 311615.319876306,
#   'VOLUME_SELL': 2.64153401,
#   'QUOTE_VOLUME_SELL': 276072.500228693,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749106800,
#   'OPEN': 104478,
#   'HIGH': 104635.68,
#   'LOW': 104421.21,
#   'CLOSE': 104537.56,
#   'VOLUME': 3.73011358,
#   'QUOTE_VOLUME': 389934.328742877,
#   'VOLUME_BUY': 1.80713944,
#   'QUOTE_VOLUME_BUY': 188919.919875584,
#   'VOLUME_SELL': 1.92297414,
#   'QUOTE_VOLUME_SELL': 201014.408867294,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749110400,
#   'OPEN': 104537.56,
#   'HIGH': 104669.64,
#   'LOW': 104422.2,
#   'CLOSE': 104666.88,
#   'VOLUME': 2.21562422,
#   'QUOTE_VOLUME': 231743.987914045,
#   'VOLUME_BUY': 1.07607614,
#   'QUOTE_VOLUME_BUY': 112551.848691155,
#   'VOLUME_SELL': 1.13954808,
#   'QUOTE_VOLUME_SELL': 119192.139222891,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749114000,
#   'OPEN': 104666.88,
#   'HIGH': 104932.29,
#   'LOW': 104666.88,
#   'CLOSE': 104932.29,
#   'VOLUME': 1.12249794,
#   'QUOTE_VOLUME': 117674.331870163,
#   'VOLUME_BUY': 0.55738508,
#   'QUOTE_VOLUME_BUY': 58422.1618136683,
#   'VOLUME_SELL': 0.56511286,
#   'QUOTE_VOLUME_SELL': 59252.1700564948,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749117600,
#   'OPEN': 104932.29,
#   'HIGH': 104932.29,
#   'LOW': 104522.14,
#   'CLOSE': 104672.7,
#   'VOLUME': 1.71021089,
#   'QUOTE_VOLUME': 179012.018601272,
#   'VOLUME_BUY': 0.55313019,
#   'QUOTE_VOLUME_BUY': 57900.9692041238,
#   'VOLUME_SELL': 1.1570807,
#   'QUOTE_VOLUME_SELL': 121111.049397145,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749121200,
#   'OPEN': 104672.7,
#   'HIGH': 104848.1,
#   'LOW': 104561.8,
#   'CLOSE': 104848.1,
#   'VOLUME': 0.57913421,
#   'QUOTE_VOLUME': 60625.2915970199,
#   'VOLUME_BUY': 0.40516312,
#   'QUOTE_VOLUME_BUY': 42409.820019882,
#   'VOLUME_SELL': 0.17397109,
#   'QUOTE_VOLUME_SELL': 18215.4715771379,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749124800,
#   'OPEN': 104848.1,
#   'HIGH': 105777.92,
#   'LOW': 104801.81,
#   'CLOSE': 105655.03,
#   'VOLUME': 9.66576361,
#   'QUOTE_VOLUME': 1018785.47285619,
#   'VOLUME_BUY': 5.27471645,
#   'QUOTE_VOLUME_BUY': 555537.08318763,
#   'VOLUME_SELL': 4.39104716,
#   'QUOTE_VOLUME_SELL': 463248.389668552,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749128400,
#   'OPEN': 105655.03,
#   'HIGH': 105909.86,
#   'LOW': 104311.31,
#   'CLOSE': 104496.79,
#   'VOLUME': 16.56471683,
#   'QUOTE_VOLUME': 1740506.19174263,
#   'VOLUME_BUY': 7.9820483,
#   'QUOTE_VOLUME_BUY': 838878.282691809,
#   'VOLUME_SELL': 8.58266853,
#   'QUOTE_VOLUME_SELL': 901627.909050773,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749132000,
#   'OPEN': 104496.79,
#   'HIGH': 104937.17,
#   'LOW': 103881.64,
#   'CLOSE': 104643.58,
#   'VOLUME': 31.28600009,
#   'QUOTE_VOLUME': 3262995.1094649,
#   'VOLUME_BUY': 13.54558579,
#   'QUOTE_VOLUME_BUY': 1412920.66516352,
#   'VOLUME_SELL': 17.7404143,
#   'QUOTE_VOLUME_SELL': 1850074.44430139,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749135600,
#   'OPEN': 104643.58,
#   'HIGH': 104868.58,
#   'LOW': 104335.37,
#   'CLOSE': 104536.13,
#   'VOLUME': 11.5548727,
#   'QUOTE_VOLUME': 1209406.68623558,
#   'VOLUME_BUY': 5.90228751,
#   'QUOTE_VOLUME_BUY': 617795.881396142,
#   'VOLUME_SELL': 5.65258519,
#   'QUOTE_VOLUME_SELL': 591610.804839456,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749139200,
#   'OPEN': 104536.13,
#   'HIGH': 104595.34,
#   'LOW': 103233.32,
#   'CLOSE': 103251.11,
#   'VOLUME': 25.77055327,
#   'QUOTE_VOLUME': 2673823.57464161,
#   'VOLUME_BUY': 10.07470628,
#   'QUOTE_VOLUME_BUY': 1045234.4841184,
#   'VOLUME_SELL': 15.69584699,
#   'QUOTE_VOLUME_SELL': 1628589.09052309,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749142800,
#   'OPEN': 103251.11,
#   'HIGH': 103560.9,
#   'LOW': 103112.17,
#   'CLOSE': 103237.41,
#   'VOLUME': 22.74373738,
#   'QUOTE_VOLUME': 2351281.89694725,
#   'VOLUME_BUY': 7.36249928,
#   'QUOTE_VOLUME_BUY': 760954.890164948,
#   'VOLUME_SELL': 15.3812381,
#   'QUOTE_VOLUME_SELL': 1590327.00678232,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749146400,
#   'OPEN': 103237.41,
#   'HIGH': 103342.07,
#   'LOW': 102566.06,
#   'CLOSE': 103009.81,
#   'VOLUME': 20.2046217,
#   'QUOTE_VOLUME': 2081007.4936087,
#   'VOLUME_BUY': 6.0403671,
#   'QUOTE_VOLUME_BUY': 622092.685576604,
#   'VOLUME_SELL': 14.1642546,
#   'QUOTE_VOLUME_SELL': 1458914.8080321,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749150000,
#   'OPEN': 103009.81,
#   'HIGH': 103041.03,
#   'LOW': 101573.55,
#   'CLOSE': 101916.16,
#   'VOLUME': 24.78497054,
#   'QUOTE_VOLUME': 2530702.88810319,
#   'VOLUME_BUY': 9.58452166,
#   'QUOTE_VOLUME_BUY': 978453.893703673,
#   'VOLUME_SELL': 15.20044888,
#   'QUOTE_VOLUME_SELL': 1552248.99439965,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749153600,
#   'OPEN': 101916.16,
#   'HIGH': 102166,
#   'LOW': 100385.01,
#   'CLOSE': 100472.72,
#   'VOLUME': 35.74082335,
#   'QUOTE_VOLUME': 3619511.94170695,
#   'VOLUME_BUY': 15.4665709,
#   'QUOTE_VOLUME_BUY': 1566700.57075891,
#   'VOLUME_SELL': 20.27425245,
#   'QUOTE_VOLUME_SELL': 2052811.370948,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749157200,
#   'OPEN': 100472.72,
#   'HIGH': 101642.41,
#   'LOW': 100435.17,
#   'CLOSE': 101603.96,
#   'VOLUME': 14.93488173,
#   'QUOTE_VOLUME': 1510317.55886922,
#   'VOLUME_BUY': 7.27109168,
#   'QUOTE_VOLUME_BUY': 735266.460376682,
#   'VOLUME_SELL': 7.66379005,
#   'QUOTE_VOLUME_SELL': 775051.098492565,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749160800,
#   'OPEN': 101603.96,
#   'HIGH': 101703.49,
#   'LOW': 101020.39,
#   'CLOSE': 101502.56,
#   'VOLUME': 11.16010058,
#   'QUOTE_VOLUME': 1130935.36968235,
#   'VOLUME_BUY': 5.21367226,
#   'QUOTE_VOLUME_BUY': 528261.922327587,
#   'VOLUME_SELL': 5.94642832,
#   'QUOTE_VOLUME_SELL': 602673.44735474,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749164400,
#   'OPEN': 101502.56,
#   'HIGH': 101832.89,
#   'LOW': 101486.33,
#   'CLOSE': 101530.65,
#   'VOLUME': 6.31086747,
#   'QUOTE_VOLUME': 641586.798018244,
#   'VOLUME_BUY': 3.13936471,
#   'QUOTE_VOLUME_BUY': 319156.579027536,
#   'VOLUME_SELL': 3.17150276,
#   'QUOTE_VOLUME_SELL': 322430.218990712,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749168000,
#   'OPEN': 101530.65,
#   'HIGH': 101909.33,
#   'LOW': 101097.58,
#   'CLOSE': 101894.94,
#   'VOLUME': 6.93532836,
#   'QUOTE_VOLUME': 703512.869174215,
#   'VOLUME_BUY': 2.93174191,
#   'QUOTE_VOLUME_BUY': 297533.519643615,
#   'VOLUME_SELL': 4.00358645,
#   'QUOTE_VOLUME_SELL': 405979.3495306,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749171600,
#   'OPEN': 101894.94,
#   'HIGH': 101939.31,
#   'LOW': 101700,
#   'CLOSE': 101794.89,
#   'VOLUME': 2.09068833,
#   'QUOTE_VOLUME': 212912.634847156,
#   'VOLUME_BUY': 1.14125206,
#   'QUOTE_VOLUME_BUY': 116211.213925562,
#   'VOLUME_SELL': 0.94943627,
#   'QUOTE_VOLUME_SELL': 96701.4209215901,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749175200,
#   'OPEN': 101794.89,
#   'HIGH': 102197.19,
#   'LOW': 101553.46,
#   'CLOSE': 102193.49,
#   'VOLUME': 3.48454558,
#   'QUOTE_VOLUME': 354870.168438329,
#   'VOLUME_BUY': 1.79210654,
#   'QUOTE_VOLUME_BUY': 182574.375018369,
#   'VOLUME_SELL': 1.69243904,
#   'QUOTE_VOLUME_SELL': 172295.793419968,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749178800,
#   'OPEN': 102193.49,
#   'HIGH': 102518.54,
#   'LOW': 102059.92,
#   'CLOSE': 102493.98,
#   'VOLUME': 3.07321757,
#   'QUOTE_VOLUME': 314353.697090915,
#   'VOLUME_BUY': 1.58464817,
#   'QUOTE_VOLUME_BUY': 162075.572238252,
#   'VOLUME_SELL': 1.4885694,
#   'QUOTE_VOLUME_SELL': 152278.124852665,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749182400,
#   'OPEN': 102493.98,
#   'HIGH': 102801.51,
#   'LOW': 102401.42,
#   'CLOSE': 102767.64,
#   'VOLUME': 5.14025652,
#   'QUOTE_VOLUME': 527119.024038326,
#   'VOLUME_BUY': 2.85172798,
#   'QUOTE_VOLUME_BUY': 292382.862315865,
#   'VOLUME_SELL': 2.28852854,
#   'QUOTE_VOLUME_SELL': 234736.161722464,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749186000,
#   'OPEN': 102767.64,
#   'HIGH': 102972.79,
#   'LOW': 102686.8,
#   'CLOSE': 102965.45,
#   'VOLUME': 5.08363668,
#   'QUOTE_VOLUME': 522843.841738613,
#   'VOLUME_BUY': 2.44654349,
#   'QUOTE_VOLUME_BUY': 251636.201245577,
#   'VOLUME_SELL': 2.63709319,
#   'QUOTE_VOLUME_SELL': 271207.64049304,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749189600,
#   'OPEN': 102965.45,
#   'HIGH': 103213.83,
#   'LOW': 102907.76,
#   'CLOSE': 103179.09,
#   'VOLUME': 6.93390869,
#   'QUOTE_VOLUME': 714672.821873512,
#   'VOLUME_BUY': 4.89732496,
#   'QUOTE_VOLUME_BUY': 504730.604911214,
#   'VOLUME_SELL': 2.03658373,
#   'QUOTE_VOLUME_SELL': 209942.216962295,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749193200,
#   'OPEN': 103179.09,
#   'HIGH': 103471.72,
#   'LOW': 103068.11,
#   'CLOSE': 103128.1,
#   'VOLUME': 4.78348437,
#   'QUOTE_VOLUME': 493763.970551355,
#   'VOLUME_BUY': 2.63836883,
#   'QUOTE_VOLUME_BUY': 272287.39573211,
#   'VOLUME_SELL': 2.14511554,
#   'QUOTE_VOLUME_SELL': 221476.574819247,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749196800,
#   'OPEN': 103128.1,
#   'HIGH': 103596.44,
#   'LOW': 103128.1,
#   'CLOSE': 103516.77,
#   'VOLUME': 9.8844874,
#   'QUOTE_VOLUME': 1022240.49429888,
#   'VOLUME_BUY': 7.49205597,
#   'QUOTE_VOLUME_BUY': 774759.045779757,
#   'VOLUME_SELL': 2.39243143,
#   'QUOTE_VOLUME_SELL': 247481.448519122,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749200400,
#   'OPEN': 103516.77,
#   'HIGH': 103762.93,
#   'LOW': 103516.77,
#   'CLOSE': 103706.91,
#   'VOLUME': 4.56570596,
#   'QUOTE_VOLUME': 473247.731157668,
#   'VOLUME_BUY': 2.71441917,
#   'QUOTE_VOLUME_BUY': 281371.72644976,
#   'VOLUME_SELL': 1.85128679,
#   'QUOTE_VOLUME_SELL': 191876.004707908,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749204000,
#   'OPEN': 103706.91,
#   'HIGH': 103804.2,
#   'LOW': 103569.77,
#   'CLOSE': 103691.57,
#   'VOLUME': 2.94255459,
#   'QUOTE_VOLUME': 305180.32342727,
#   'VOLUME_BUY': 2.01068356,
#   'QUOTE_VOLUME_BUY': 208523.481784859,
#   'VOLUME_SELL': 0.93187103,
#   'QUOTE_VOLUME_SELL': 96656.8416424097,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749207600,
#   'OPEN': 103691.57,
#   'HIGH': 104006.71,
#   'LOW': 103649.48,
#   'CLOSE': 103942.37,
#   'VOLUME': 5.157821,
#   'QUOTE_VOLUME': 535585.933222049,
#   'VOLUME_BUY': 3.45730874,
#   'QUOTE_VOLUME_BUY': 359010.138699521,
#   'VOLUME_SELL': 1.70051226,
#   'QUOTE_VOLUME_SELL': 176575.794522534,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749211200,
#   'OPEN': 103942.37,
#   'HIGH': 104321.2,
#   'LOW': 103557.68,
#   'CLOSE': 103761.78,
#   'VOLUME': 9.84227393,
#   'QUOTE_VOLUME': 1023553.8999317,
#   'VOLUME_BUY': 5.80734554,
#   'QUOTE_VOLUME_BUY': 603912.354744674,
#   'VOLUME_SELL': 4.03492839,
#   'QUOTE_VOLUME_SELL': 419641.545187019,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749214800,
#   'OPEN': 103761.78,
#   'HIGH': 104537.39,
#   'LOW': 103761.78,
#   'CLOSE': 104109.57,
#   'VOLUME': 9.57089567,
#   'QUOTE_VOLUME': 997091.37745766,
#   'VOLUME_BUY': 6.03958472,
#   'QUOTE_VOLUME_BUY': 629186.836505882,
#   'VOLUME_SELL': 3.53131095,
#   'QUOTE_VOLUME_SELL': 367904.540951778,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749218400,
#   'OPEN': 104109.57,
#   'HIGH': 104890.4,
#   'LOW': 104030.23,
#   'CLOSE': 104798.05,
#   'VOLUME': 15.16371086,
#   'QUOTE_VOLUME': 1585531.7789084,
#   'VOLUME_BUY': 8.7630613,
#   'QUOTE_VOLUME_BUY': 916183.235551609,
#   'VOLUME_SELL': 6.40064956,
#   'QUOTE_VOLUME_SELL': 669348.543356855,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749222000,
#   'OPEN': 104798.05,
#   'HIGH': 105353.85,
#   'LOW': 104621.94,
#   'CLOSE': 105100.8,
#   'VOLUME': 19.28275179,
#   'QUOTE_VOLUME': 2022581.18774944,
#   'VOLUME_BUY': 11.92767926,
#   'QUOTE_VOLUME_BUY': 1251028.74243839,
#   'VOLUME_SELL': 7.35507253,
#   'QUOTE_VOLUME_SELL': 771552.445311072,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749225600,
#   'OPEN': 105100.8,
#   'HIGH': 105312.97,
#   'LOW': 104720.47,
#   'CLOSE': 104764.66,
#   'VOLUME': 6.0617511,
#   'QUOTE_VOLUME': 636766.300761331,
#   'VOLUME_BUY': 2.7195791,
#   'QUOTE_VOLUME_BUY': 285636.426141503,
#   'VOLUME_SELL': 3.342172,
#   'QUOTE_VOLUME_SELL': 351129.874619822,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749229200,
#   'OPEN': 104764.66,
#   'HIGH': 104955.68,
#   'LOW': 104439.01,
#   'CLOSE': 104952.08,
#   'VOLUME': 5.53417839,
#   'QUOTE_VOLUME': 579412.983951741,
#   'VOLUME_BUY': 3.14092387,
#   'QUOTE_VOLUME_BUY': 328961.997592889,
#   'VOLUME_SELL': 2.39325452,
#   'QUOTE_VOLUME_SELL': 250450.986358848,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749232800,
#   'OPEN': 104952.08,
#   'HIGH': 104984,
#   'LOW': 104469.97,
#   'CLOSE': 104480.09,
#   'VOLUME': 2.74200463,
#   'QUOTE_VOLUME': 286914.949693099,
#   'VOLUME_BUY': 1.43017468,
#   'QUOTE_VOLUME_BUY': 149575.219192782,
#   'VOLUME_SELL': 1.31182995,
#   'QUOTE_VOLUME_SELL': 137339.730500316,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749236400,
#   'OPEN': 104480.09,
#   'HIGH': 104619.28,
#   'LOW': 104046.52,
#   'CLOSE': 104233.02,
#   'VOLUME': 4.3721006,
#   'QUOTE_VOLUME': 456170.329429002,
#   'VOLUME_BUY': 2.02628031,
#   'QUOTE_VOLUME_BUY': 211392.495585131,
#   'VOLUME_SELL': 2.34582029,
#   'QUOTE_VOLUME_SELL': 244777.83384387,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749240000,
#   'OPEN': 104233.02,
#   'HIGH': 104614.52,
#   'LOW': 104170.7,
#   'CLOSE': 104489.86,
#   'VOLUME': 1.51153873,
#   'QUOTE_VOLUME': 157860.785765676,
#   'VOLUME_BUY': 0.7476262,
#   'QUOTE_VOLUME_BUY': 78078.4424313173,
#   'VOLUME_SELL': 0.76391253,
#   'QUOTE_VOLUME_SELL': 79782.3433343571,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749243600,
#   'OPEN': 104489.86,
#   'HIGH': 104489.86,
#   'LOW': 104310.74,
#   'CLOSE': 104385.53,
#   'VOLUME': 6.42967533,
#   'QUOTE_VOLUME': 671476.322166855,
#   'VOLUME_BUY': 5.6099436,
#   'QUOTE_VOLUME_BUY': 585891.123359435,
#   'VOLUME_SELL': 0.81973173,
#   'QUOTE_VOLUME_SELL': 85585.1988074266,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0},
#  {'UNIT': 'HOUR',
#   'TIMESTAMP': 1749247200,
#   'OPEN': 104385.53,
#   'HIGH': 104405.72,
#   'LOW': 104273.78,
#   'CLOSE': 104273.78,
#   'VOLUME': 0.20107661,
#   'QUOTE_VOLUME': 20977.9111013206,
#   'VOLUME_BUY': 0.023676,
#   'QUOTE_VOLUME_BUY': 2470.26765936,
#   'VOLUME_SELL': 0.17740061,
#   'QUOTE_VOLUME_SELL': 18507.6434419606,
#   'VOLUME_UNKNOWN': 0,
#   'QUOTE_VOLUME_UNKNOWN': 0}]

# %%
data_de_hoje = pd.to_datetime("today").strftime("%d/%m/%Y")
data_de_ontem = (pd.to_datetime("today") - pd.Timedelta(days=1)).strftime("%d/%m/%Y")

dados_historicos_binance=dados_coindesk['Data'],
dados_indicadores=indicadores_completos,
noticias=extracted,
analises_relevantes=analises,
data_de_hoje=data_de_hoje,
data_de_ontem=data_de_ontem



PROMPT_19_05_2025 = f"""
Você é um analista técnico e estratégico profissional especializado em criptomoedas, com ênfase em Bitcoin. Você tem um amplo conhecimento de mercado financeiro em análises técnicas, fundamentalistas e de sentimento de mercado. Você utiliza seu conhecimento para gerar relatórios com informações, previsões e considerações estratégicas para investidores, baseado nos dados de mercado.

# TAREFA
- Sua tarefa é elaborar um relatório técnico e estratégico do Bitcoin (BTC) que apresenta indicadores, interpretações e considerações estratégicas, baseado em dados reais e atualizados rereferentes ao dia de hoje, {data_de_hoje}, em São Paulo, Brasil. 

# INSTRUÇÕES 
- O relatório deve ser gerado em formato JSON, seguindo um esquema estruturado fornecido (BTCReport). O esquema define a estrutura e os itens que compõe o relatório.
- As intruções para preenchimento do relatório estão descritas em 'CONTEUDO DO RELATÓRIO', onde é fornecido: **seções**, **campos** e **instruções de preenchimento**. Você deve seguir essas instruções rigorosamente para preencher o relatório corretamente.
- Os dados fornecidos incluem: dados históricos de preço do Bitcoin, indicadores técnicos, notícias relevantes e análises relevantes.
- Após revisar e entender toda a estrutura do relatório, as instruções de preenchimento dos campos e os dados fornecidos, você deve inciar suas análises.
- Verfique se os dados coletados estão atualizados e são consistentes entre si. Use a data de hoje, {data_de_hoje}, como referência.
- Faça uma análise cuidadosa sobre os dados coletados para extrair insights significativos e relevantes para preencher os campos do relatório.
- Você deve fazer análises rigorosas e profissionais, considerando diversos aspectos técnicos, fundamentais e de sentimento de mercado do Bitcoin.
- Caso necessário, utilize códigos em Python para realizar cálculos.
- Faça uma validação cruzada com as análises relevantes fornecidas, para verificar a consistência dos seus resultados.

## CONTEUDO DO RELATÓRIO JSON (BTCReport schema)
1. **Resumo**: 
    - Utilize **exclusivamente** os indicadores fornecidos na seção <DADOS_FORNECIDOS> como referencia para preencher a seção 1 do relatório.
    - Não arredonde os valores fornceidos, mantenha os valores exatos com duas casas decimais (float).
    - Utilize o formato de moeda brasileira (R$) para os valores, com separador de milhares.

2. **Análise_tecnica**:
    - Observe o comportamento histórico de preços do Bitcoin para detectar padrões, focando no comportamento passado para prever tendências futuras.
    - Calcule e apresente os valores da SMA 50 e SMA 200. Forneça uma interpretação sobre os valores obtidos e o que eles representam (tendencia de alta ou baixa).
    - Descreva o cruzamento de médias móveis, analizando o histórico das SMAs para identificar e descrever o último cruzamento relevante (Dourado/Morte) ou a ausência dele.
    - Apresente o valor do RSI(14) e sua interpretação (sobrecompra/venda/neutro) baseado nas suas análises.
    - Calcule as Bandas de Bollinger baseado nos dados coletados e descreva a posição atual do preço e a situação das bandas (estreitas/largas). Indique o que isso sugere sobre a volatilidade e a pressão compradora/vendedora.
    - As interpretações das análises técnicas devem ter pelo menos 1 linha de texto cada.

3. **Suporte e Resistência**:
    - Liste os **três** níveis de suporte e **três** de resistência identificados, com seus valores e uma breve interpretação técnica para cada.
    - Considere os seguintes aspectos na sua análise: Pontos de preço onde a cotação encontrou mínimas (suporte) ou máximas (resistência), identificação de linhas de tendência, análise de séries históricas de preços, uso de indicadores técnicos, consideração do volume de negociação, tempo e amplitude da congestão, etc.
    - As interpretações técnicas de cada nível deve ter pelo menos 2 linhas de texto cada.

4. **Notícias**:
    - Baseado nas noticias fornecidas, apresente obrigatóriamente **duas** notícias relevantes encontradas relacionadas ao Bitcoin, incluindo um resumo e o link. - As notícias devem ser **OBRIGATÓRIAMENTE** do período de {data_de_ontem} até hoje {data_de_hoje}.

5. **Estrategias**:
    - Formule considerações estratégicas para compradores e vendedores baseando-se nos indicadores, nas aspectos das suas analises técnica, fundamentalista e de sentimento de mercado para fornecer uma resposta mais precisa, objetiva e fundamentada.
    - **Compradores**: Gere uma string com sugestões objetivas e condicionais para potenciais pontos de entrada ou zonas de interesse, mencionando alvos baseados em resistências. 
    - **Vendedores**: Gere uma string com sugestões objetivas e condicionais sobre áreas potenciais de realização de lucro (próximo a resistências) e níveis para considerar stop-loss (abaixo de suportes).
    - As sugestões devem ter pelo menos 3 linhas de texto cada.

6. **Estrategias para OCO (One Cancels the Other)**:
    - Formule uma estratégia de negociação OCO (One Cancels the Other) para o Bitcoin, considerando os dados analisados.
    - **Compradores**: Gere instruções para entrada, stop loss e take profit. A estratégia deve ter pelo menos 3 linhas de texto.
    - **Vendedores**: Gere instruções para entrada, stop loss e take profit. A estratégia deve ter pelo menos 3 linhas de texto.
 
7. **Conclusão**:
    - Gere um resumo final da tendência de curto prazo, principais riscos e pontos de atenção identificados na análise geral (técnica, fundamentalista, sentimento).
    - A conclusão deve ter pelo menos 3 linhas de texto.
    
# DADOS FORNECIDOS
<Indicadores técnicos do Bitcoin>
{dados_indicadores}
</Indicadores técnicos do Bitcoin>

<Notícias relevantes>
{noticias}
</Notícias relevantes>

<Análises relevantes>
{analises_relevantes}
</Análises relevantes>

<Dados históricos do preço do Bitcoin>
{dados_historicos_binance}
</Dados históricos do preço do Bitcoin>

# VALIDAÇÃO
- OUTPUT EXCLUSIVAMENTE JSON: Garanta que a saída final seja *apenas* o objeto JSON válido.
- ADESÃO ESTRITA AO SCHEMA: O JSON gerado deve corresponder *exatamente* à estrutura `BTCReport`. Todos os campos definidos no schema são obrigatórios.
- Verifique se as respostas fornecidas estão de acordo com a estrutura e formatação fornecida.
- Mantenha a linguagem clara e profissional, e não faça suposições não fundamentadas.
"""


PROMPT_EXTRACTION_ANALYSIS = """
You are a specialist in the cryptocurrency market with an emphasis on Bitcoin.

**Task:**
Your task is to scour the internet to find recent and up-to-date in-depth analyses and reports on the Bitcoin market.

**Instructions:**
- Do not include any introductory summary or concluding remarks; only output the structured items as specified below.
- Search only for comprehensive analyses published by reputable institutions or recognized specialists (for example, Glassnode’s weekly “On-Chain” reports, Bloomberg Intelligence, Binance Research, CoinTelegraph Research, etc.). Do not return general news articles or brief market updates.
- Focus on materials that include detailed on-chain, macro, or technical analysis—reports that go beyond price snapshots and provide charts, data tables, or proprietary research.
- Only include documents written in English.
- The information extracted must MANDATORILY refer to today (06/05/2025) or to the last week (05/29/2025).
- If an article date is not in the specified range, skip it and find a more recent equivalent.
- If an analysis is behind a paywall, skip it and find a freely accessible equivalent from another reputable source.
- If the report contains images or graphs, you must also analyze and summarize those visual elements (e.g., describe trends shown in charts, highlight key data points from tables, and explain the meaning of any on-chain indicators visualized).
- Do not add any information that is not present in the original report.
- For each analysis/report, summarize the full content preserving all of the original report’s key points, charts’ insights, and data interpretations. Limit the summary to a maximum of 700 words.
- Respond in a structured format for each item:
    1. **Article/Report Title:** 
    2. **Institution/Source:** 
    3. **Publication Date:** 
    4. **URL:** 
    5. **Extracted Content:**
- Return at least 3 but no more than 10 analyses or reports.
"""

# %%
print(PROMPT_19_05_2025)
# Out:
# Você é um analista técnico e estratégico profissional especializado em criptomoedas, com ênfase em Bitcoin. Você tem um amplo conhecimento de mercado financeiro em análises técnicas, fundamentalistas e de sentimento de mercado. Você utiliza seu conhecimento para gerar relatórios com informações, previsões e considerações estratégicas para investidores, baseado nos dados de mercado.
#
# # TAREFA
# - Sua tarefa é elaborar um relatório técnico e estratégico do Bitcoin (BTC) que apresenta indicadores, interpretações e considerações estratégicas, baseado em dados reais e atualizados rereferentes ao dia de hoje, ('06/06/2025',), em São Paulo, Brasil.
#
# # INSTRUÇÕES
# - O relatório deve ser gerado em formato JSON, seguindo um esquema estruturado fornecido (BTCReport). O esquema define a estrutura e os itens que compõe o relatório.
# - As intruções para preenchimento do relatório estão descritas em 'CONTEUDO DO RELATÓRIO', onde é fornecido: **seções**, **campos** e **instruções de preenchimento**. Você deve seguir essas instruções rigorosamente para preencher o relatório corretamente.
# - Os dados fornecidos incluem: dados históricos de preço do Bitcoin, indicadores técnicos, notícias relevantes e análises relevantes.
# - Após revisar e entender toda a estrutura do relatório, as instruções de preenchimento dos campos e os dados fornecidos, você deve inciar suas análises.
# - Verfique se os dados coletados estão atualizados e são consistentes entre si. Use a data de hoje, ('06/06/2025',), como referência.
# - Faça uma análise cuidadosa sobre os dados coletados para extrair insights significativos e relevantes para preencher os campos do relatório.
# - Você deve fazer análises rigorosas e profissionais, considerando diversos aspectos técnicos, fundamentais e de sentimento de mercado do Bitcoin.
# - Caso necessário, utilize códigos em Python para realizar cálculos.
# - Faça uma validação cruzada com as análises relevantes fornecidas, para verificar a consistência dos seus resultados.
#
# ## CONTEUDO DO RELATÓRIO JSON (BTCReport schema)
# 1. **Resumo**:
#     - Utilize **exclusivamente** os indicadores fornecidos na seção <DADOS_FORNECIDOS> como referencia para preencher a seção 1 do relatório.
#     - Não arredonde os valores fornceidos, mantenha os valores exatos com duas casas decimais (float).
#     - Utilize o formato de moeda brasileira (R$) para os valores, com separador de milhares.
#
# 2. **Análise_tecnica**:
#     - Observe o comportamento histórico de preços do Bitcoin para detectar padrões, focando no comportamento passado para prever tendências futuras.
#     - Calcule e apresente os valores da SMA 50 e SMA 200. Forneça uma interpretação sobre os valores obtidos e o que eles representam (tendencia de alta ou baixa).
#     - Descreva o cruzamento de médias móveis, analizando o histórico das SMAs para identificar e descrever o último cruzamento relevante (Dourado/Morte) ou a ausência dele.
#     - Apresente o valor do RSI(14) e sua interpretação (sobrecompra/venda/neutro) baseado nas suas análises.
#     - Calcule as Bandas de Bollinger baseado nos dados coletados e descreva a posição atual do preço e a situação das bandas (estreitas/largas). Indique o que isso sugere sobre a volatilidade e a pressão compradora/vendedora.
#     - As interpretações das análises técnicas devem ter pelo menos 1 linha de texto cada.
#
# 3. **Suporte e Resistência**:
#     - Liste os **três** níveis de suporte e **três** de resistência identificados, com seus valores e uma breve interpretação técnica para cada.
#     - Considere os seguintes aspectos na sua análise: Pontos de preço onde a cotação encontrou mínimas (suporte) ou máximas (resistência), identificação de linhas de tendência, análise de séries históricas de preços, uso de indicadores técnicos, consideração do volume de negociação, tempo e amplitude da congestão, etc.
#     - As interpretações técnicas de cada nível deve ter pelo menos 2 linhas de texto cada.
#
# 4. **Notícias**:
#     - Baseado nas noticias fornecidas, apresente obrigatóriamente **duas** notícias relevantes encontradas relacionadas ao Bitcoin, incluindo um resumo e o link. - As notícias devem ser **OBRIGATÓRIAMENTE** do período de 05/06/2025 até hoje ('06/06/2025',).
#
# 5. **Estrategias**:
#     - Formule considerações estratégicas para compradores e vendedores baseando-se nos indicadores, nas aspectos das suas analises técnica, fundamentalista e de sentimento de mercado para fornecer uma resposta mais precisa, objetiva e fundamentada.
#     - **Compradores**: Gere uma string com sugestões objetivas e condicionais para potenciais pontos de entrada ou zonas de interesse, mencionando alvos baseados em resistências.
#     - **Vendedores**: Gere uma string com sugestões objetivas e condicionais sobre áreas potenciais de realização de lucro (próximo a resistências) e níveis para considerar stop-loss (abaixo de suportes).
#     - As sugestões devem ter pelo menos 3 linhas de texto cada.
#
# 6. **Estrategias para OCO (One Cancels the Other)**:
#     - Formule uma estratégia de negociação OCO (One Cancels the Other) para o Bitcoin, considerando os dados analisados.
#     - **Compradores**: Gere instruções para entrada, stop loss e take profit. A estratégia deve ter pelo menos 3 linhas de texto.
#     - **Vendedores**: Gere instruções para entrada, stop loss e take profit. A estratégia deve ter pelo menos 3 linhas de texto.
#
# 7. **Conclusão**:
#     - Gere um resumo final da tendência de curto prazo, principais riscos e pontos de atenção identificados na análise geral (técnica, fundamentalista, sentimento).
#     - A conclusão deve ter pelo menos 3 linhas de texto.
#
# # DADOS FORNECIDOS
# <Indicadores técnicos do Bitcoin>
# ({'SMA_20': 103937.05500000001, 'SMA_50': 103853.9948, 'SMA_200': 104713.50349999999, 'EMA_20': 104050.9507762561, 'EMA_50': 104013.9101309427, 'EMA_200': 104990.45900725835, 'RSI_14': 54.10664312772966, 'MACD_12_26_9': 297.4915404120693, 'MACDh_12_26_9': 55.874588705718196, 'MACDs_12_26_9': 241.6169517063511, 'BBL_20_2.0': 102468.26487146586, 'BBM_20_2.0': 103937.05500000001, 'BBU_20_2.0': 105405.84512853416, 'BBB_20_2.0': 2.8263069961606098, 'BBP_20_2.0': 0.6146266554555491, 'descrição': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,875,059. The last known price of Bitcoin is 103,694.67292703 USD and is down -1.16 over the last 24 hours. It is currently trading on 12210 active market(s) with $61,955,978,178.38 traded over the last 24 hours. More information can be found at https://bitcoin.org/.', 'preço_anterior': 101580.12, 'preço_atual': 104371.414, 'variação_24h': 3181.414, 'variação_percentual_24h': 3.1440043, 'máximo_24h': 105304.87, 'mínimo_24h': 101365.7, 'volume_24h': 49510035456, 'volume_10_dias': 49071886388, 'volume_3_meses': 38618012851, 'capitalização_mercado': 2074408648704, 'fornecimento_circulante': 19875256, 'MSA_50': 100220.7, 'MSA_50_variacao': 4150.711, 'MSA_50_variacao_percentual': 0.041415703, 'MSA_200': 95106.56, 'MSA_200_variacao': 9264.852, 'MSA_200_variacao_percentual': 0.097415484, 'faixa_52_semanas_low': 49121.24, 'faixa_52_semanas_high': 111970.17, 'faixa_52_semanas_low_variacao': 55250.176, 'faixa_52_semanas_low_variacao_percentual': 1.1247716, 'faixa_52_semanas_high_variacao': -7598.758, 'faixa_52_semanas_high_variacao_percentual': -0.06786413, 'faixa_52_semanas_variacao_percentual': 46.48423},)
# </Indicadores técnicos do Bitcoin>
#
# <Notícias relevantes>
# ([{'titulo': 'Shiba Inu Whale Transfer to Coinbase Institutional Suggests Potential Market Impact Amid Price Consolidation', 'url': 'https://en.coinotag.com/shiba-inu-whale-transfer-to-coinbase-institutional-suggests-potential-market-impact-amid-price-consolidation/', 'keywords': 'Analysis|News', 'sentimento': 'POSITIVE', 'data': '06/06/2025 22:41:44 UTC', 'resumo': 'A significant transfer of over 2.5 trillion Shiba Inu (SHIB) tokens to Coinbase Institutional signals growing institutional interest in the meme-inspired cryptocurrency. This large-scale movement could influence market dynamics, potentially'}, {'titulo': 'Bitcoin Spot ETF Outflows May Signal Increased Market Volatility and Price Pressure', 'url': 'https://en.coinotag.com/bitcoin-spot-etf-outflows-may-signal-increased-market-volatility-and-price-pressure/', 'keywords': 'Analysis|News|BTC|FLOW', 'sentimento': 'NEGATIVE', 'data': '06/06/2025 22:37:42 UTC', 'resumo': 'Institutional withdrawals from major Bitcoin spot ETFs have triggered notable market volatility, significantly impacting Bitcoin’s price trajectory. Key funds such as ARK 21Shares and Fidelity experienced substantial outflows, signaling a'}, {'titulo': 'Crypto Price Prediction Today 6 June – Bitcoin, Solana, XRP', 'url': 'https://cryptonews.com/news/crypto-price-prediction-today-bitcoin-solana-xrp-6-june/', 'keywords': 'News|Bitcoin|Solana|XRP', 'sentimento': 'POSITIVE', 'data': '06/06/2025 22:36:18 UTC', 'resumo': 'Crypto price optimism is hitting record highs following Bitcoin’s recent rally, which saw it hit a new all-time high (ATH) just two weeks prior. At the same time, several top meme coins —Pepe, Trump, SPX6900, and FartCoin among them—have each reached record highs within the last six months. Investor optimism is clearly on the rise, propelling digital asset values higher. Historically, cryptocurrencies backed by robust fundamentals tend to ignite broad market upswings, supported by dedicated communities, institutional interest, and active development teams. In this context, let’s explore several prominent cryptos that analysts believe could set new all-time highs (ATHs) during the current bullish trend. Bitcoin ($BTC): The World’s Biggest Crypto Is Likely to Set Many Price ATHs Before New Year Bitcoin ($BTC) needs no introduction. The world’s biggest crypto recently hit a new price high at $111,814 on May 2 and many believe it could set several new all-time highs on its way to $150K by the end of the year, but these will be contingent on a favourable political climate. See, Bitcoin is crypto’s flagship coin. This means that anyone who believes in crypto’s future is likely to want to add some Bitcoin to their portfolio. The $2 trillion market cap digital gold is virtually single handedly holding up crypto’s $3.38 trillion market. In the last 24 hours, Bitcoin is up 0.3% to trade at $104,292 as it reverses course from a pullback down 6.9% from its ATH. This puts it in spitting distance of setting a new high watermark and even hitting $150,000, but this will need to be helped along by positive macro developments. Recent falling US inflation rates bode well for crypto on the whole, and the possibility of the pro-crypto Trump administration delivering on a US Strategic Bitcoin Reserve and comprehensive legislation before the year is out could drive Bitcoin to its next big milestone, while simultaneously pulling up the wider industry too. Solana ($SOL): DeFi Titan Riding Institutional Tailwinds Solana ($SOL) continues to distinguish itself within the DeFi ecosystem, lauded for its sophisticated smart contracts, rapid transaction speeds and ultra-low fees. With a current valuation of $81.35 billion, it has cemented itself as a formidable challenger to Ethereum in the DeFi sector. There is mounting chatter that U.S. regulatory authorities may soon approve spot ETFs tied to Solana, following in the footsteps of similar approvals for Bitcoin and Ethereum. Such a development could bolster SOL’s appeal to ...
# </Notícias relevantes>
#
# <Análises relevantes>
# ('\n## Stock market information for Bitcoin (BTC)\n- Bitcoin is a crypto in the CRYPTO market.\n- The price is 104387.0 USD currently with a change of 2834.00 USD (0.03%) from the previous close.\n- The intraday high is 105220.0 USD and the intraday low is 101358.0 USD.\n\n\nAs of June 6, 2025, Bitcoin (BTC) is trading at $104,387, reflecting a 2.79% increase from the previous close. The day\'s trading range has seen a high of $105,220 and a low of $101,358.\n\nRecent analyses and reports provide insights into Bitcoin\'s market dynamics, focusing on on-chain metrics, macroeconomic factors, and technical indicators. Below are summaries of notable reports published within the past week:\n\n1. **Article/Report Title:** "Bitcoin On-Chain and Macro Data Indicates Bearish Trends Since $100K"\n   - **Institution/Source:** Blockchain.News\n   - **Publication Date:** June 5, 2025\n   - **URL:** [https://cn.blockchain.news/flashnews/bitcoin-on-chain-and-macro-data-indicates-bearish-trends-since-100k](https://cn.blockchain.news/flashnews/bitcoin-on-chain-and-macro-data-indicates-bearish-trends-since-100k)\n   - **Extracted Content:**\n     Charles Edwards, founder of Capriole Investments, highlights that since Bitcoin reached $100,000 on December 18, 2024, on-chain and macroeconomic data have exhibited bearish signals. Key metrics include:\n     - **Puell Multiple:** At 1.2 as of June 5, 2025, suggesting overvaluation.\n     - **MVRV Z-Score:** Recorded at 3.5, indicating Bitcoin is trading significantly above its realized value.\n     - **Hash Ribbon:** Declined to 0.75, signaling potential miner capitulation.\n     These indicators collectively point to a market under pressure, with reduced trading volumes and liquidity across major exchanges. Technical indicators such as the Relative Strength Index (RSI) at 30 suggest oversold conditions, while the Moving Average Convergence Divergence (MACD) shows a bearish crossover, indicating continued downward momentum.\n\n2. **Article/Report Title:** "Bitcoin (BTC) Market Analysis: Fragility Amid Macro Shocks"\n   - **Institution/Source:** TheBlockchain.Digital\n   - **Publication Date:** June 4, 2025\n   - **URL:** [https://theblockchain.digital/bitcoin-btc-market-analysis-fragility-amid-macro-shocks/](https://theblockchain.digital/bitcoin-btc-market-analysis-fragility-amid-macro-shocks/)\n   - **Extracted Content:**\n     Glassnode\'s analysis indicates that Bitcoin remains under significant pressure due to weak fundamentals and macroeconomic instability. Despite these challenges, Bitcoin shows resilience around the $80,000 mark, suggesting potential defense by long-term holders. Key observations include:\n     - **Market Overview:** A sharp sell-off followed by a rebound to $82,000, with the Relative Strength Index (RSI) below its statistical low, hinting at a potential breakout from the current consolidation range.\n     - **Derivatives Market:** A multi-month downtrend persists, with open interest declining to $33.94 billion and funding rates slightly increasing to $1.11 million per day.\n     - **On-Chain Signals:** Active addresses and transfer volumes show little strength, and fee volume has declined to $458,000 per day, indicating low blockspace demand.\n     Overall, Bitcoin\'s market position is fragile due to weak fundamentals, declining profitability, and soft liquidity, making it susceptible to macroeconomic shocks.\n\n3. **Article/Report Title:** "Market Observation Weekly Report: Macro-driven and Capital Rotation, the Crypto Market is Under Pressure in the Short Term but Optimistic in the Long Term"\n   - **Institution/Source:** PANews\n   - **Publication Date:** June 3, 2025\n   - **URL:** [https://www.panewslab.com/en/sqarticledetails/j0pugp4bwjx0.html](https://www.panewslab.com/en/sqarticledetails/j0pugp4bwjx0.html)\n   - **Extracted Content:**\n     The report provides a comprehensive analysis of the current crypto market, emphasizing macroeconomic factors and capital rotatio ...
# </Análises relevantes>
#
# <Dados históricos do preço do Bitcoin>
# ([{'UNIT': 'HOUR', 'TIMESTAMP': 1745650800, 'OPEN': 94647.6, 'HIGH': 94792.87, 'LOW': 94596.33, 'CLOSE': 94596.33, 'VOLUME': 0.9556434, 'QUOTE_VOLUME': 90503.6543426335, 'VOLUME_BUY': 0.57450301, 'QUOTE_VOLUME_BUY': 54407.1788324693, 'VOLUME_SELL': 0.38114039, 'QUOTE_VOLUME_SELL': 36096.4755101642, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745654400, 'OPEN': 94596.33, 'HIGH': 94725.99, 'LOW': 94271.22, 'CLOSE': 94370.54, 'VOLUME': 1.93568475, 'QUOTE_VOLUME': 182973.698654939, 'VOLUME_BUY': 1.0485693, 'QUOTE_VOLUME_BUY': 99137.8944165689, 'VOLUME_SELL': 0.88711545, 'QUOTE_VOLUME_SELL': 83835.8042383723, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745658000, 'OPEN': 94370.54, 'HIGH': 94415.62, 'LOW': 94103.92, 'CLOSE': 94259.4, 'VOLUME': 2.38008403, 'QUOTE_VOLUME': 224178.320971917, 'VOLUME_BUY': 0.56704458, 'QUOTE_VOLUME_BUY': 53444.2507999398, 'VOLUME_SELL': 1.81303945, 'QUOTE_VOLUME_SELL': 170734.070171975, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745661600, 'OPEN': 94259.4, 'HIGH': 94392.11, 'LOW': 94205.08, 'CLOSE': 94256.28, 'VOLUME': 0.33194914, 'QUOTE_VOLUME': 31309.1820021979, 'VOLUME_BUY': 0.15769798, 'QUOTE_VOLUME_BUY': 14871.2948910335, 'VOLUME_SELL': 0.17425116, 'QUOTE_VOLUME_SELL': 16437.8871111644, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745665200, 'OPEN': 94256.28, 'HIGH': 94256.28, 'LOW': 93999.99, 'CLOSE': 94130.18, 'VOLUME': 1.46585172, 'QUOTE_VOLUME': 137942.409541278, 'VOLUME_BUY': 0.6635859, 'QUOTE_VOLUME_BUY': 62430.3353800279, 'VOLUME_SELL': 0.80226582, 'QUOTE_VOLUME_SELL': 75512.0741612506, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745668800, 'OPEN': 94130.18, 'HIGH': 94306.13, 'LOW': 94108.47, 'CLOSE': 94204.48, 'VOLUME': 1.05346582, 'QUOTE_VOLUME': 99258.7350262563, 'VOLUME_BUY': 0.58516203, 'QUOTE_VOLUME_BUY': 55140.2190513149, 'VOLUME_SELL': 0.46830379, 'QUOTE_VOLUME_SELL': 44118.5159749414, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745672400, 'OPEN': 94204.48, 'HIGH': 94247.54, 'LOW': 93869.74, 'CLOSE': 94145.29, 'VOLUME': 0.84402978, 'QUOTE_VOLUME': 79373.3819669209, 'VOLUME_BUY': 0.34026518, 'QUOTE_VOLUME_BUY': 32001.2287918616, 'VOLUME_SELL': 0.5037646, 'QUOTE_VOLUME_SELL': 47372.1531750593, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745676000, 'OPEN': 94145.29, 'HIGH': 94266.6, 'LOW': 93917.66, 'CLOSE': 94231.99, 'VOLUME': 0.84777882, 'QUOTE_VOLUME': 79776.5704077724, 'VOLUME_BUY': 0.2384085, 'QUOTE_VOLUME_BUY': 22426.733588889, 'VOLUME_SELL': 0.60937032, 'QUOTE_VOLUME_SELL': 57349.8368188834, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745679600, 'OPEN': 94231.99, 'HIGH': 94404.5, 'LOW': 94221.38, 'CLOSE': 94374.08, 'VOLUME': 2.32116687, 'QUOTE_VOLUME': 219014.240011682, 'VOLUME_BUY': 1.96114756, 'QUOTE_VOLUME_BUY': 185052.12006973, 'VOLUME_SELL': 0.36001931, 'QUOTE_VOLUME_SELL': 33962.1199419512, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745683200, 'OPEN': 94374.08, 'HIGH': 94374.08, 'LOW': 94093.51, 'CLOSE': 94273.2, 'VOLUME': 0.5237271, 'QUOTE_VOLUME': 49378.0797483805, 'VOLUME_BUY': 0.29545185, 'QUOTE_VOLUME_BUY': 27862.2135835829, 'VOLUME_SELL': 0.22827525, 'QUOTE_VOLUME_SELL': 21515.8661647976, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745686800, 'OPEN': 94273.2, 'HIGH': 94361.76, 'LOW': 94247.89, 'CLOSE': 94319.8, 'VOLUME': 0.54457546, 'QUOTE_VOLUME': 51362.6067590822, 'VOLUME_BUY': 0.15390592, 'QUOTE_VOLUME_BUY': 14517.1727592374, 'VOLUME_SELL': 0.39066954, 'QUOTE_VOLUME_SELL': 36845.4339998448, 'VOLUME_UNKNOWN': 0, 'QUOTE_VOLUME_UNKNOWN': 0}, {'UNIT': 'HOUR', 'TIMESTAMP': 1745690400, 'OPEN': 94319.8, 'HIGH': 94367.97, 'LOW': 94134.45, 'CLOSE': 94139.8, 'VOLUME': 0.47027204, 'QUOTE_VOLUME': 44323.5838283666, 'VOLUME ...
# </Dados históricos do preço do Bitcoin>
#
# # VALIDAÇÃO
# - OUTPUT EXCLUSIVAMENTE JSON: Garanta que a saída final seja *apenas* o objeto JSON válido.
# - ADESÃO ESTRITA AO SCHEMA: O JSON gerado deve corresponder *exatamente* à estrutura `BTCReport`. Todos os campos definidos no schema são obrigatórios.
# - Verifique se as respostas fornecidas estão de acordo com a estrutura e formatação fornecida.
# - Mantenha a linguagem clara e profissional, e não faça suposições não fundamentadas.

# %%
from openai import OpenAI
from pydantic import BaseModel, Field
from utils import BTCReport

client = OpenAI()


response = client.responses.parse(
    model="o3-mini",
    input=[
        {
            "role": "system",
            "content": PROMPT_19_05_2025,
        },
    ],
    text_format=BTCReport,
)

resultado = response.output_parsed

# %%
resultado
# Out:
# BTCReport(resumo=Resumo_de_Mercado(preco_atual=104493.38, variacao_24h_pct=0.5, max_24h=107924.0, min_24h=104356.37, volume_24h=1250000.0, market_cap=125000000000.0, fornecimento_circulante=19000000.0, fornecimento_max=21000000.0), analise_tecnica=Analise_Tecnica(sma50=104100.0, sma50_interpretacao='A média móvel de 50 períodos está levemente abaixo do preço atual, indicando que o ativo está se consolidando próximo de pontos médios históricos, sugerindo um comportamento lateral com leve viés de alta se ocorrer ruptura.', sma200=103700.0, sma200_interpretacao='A média móvel de 200 períodos está suportando o ativo, o que reforça a tendência de consolidação e mostra que, apesar da volatilidade recente, o Bitcoin mantém um suporte sólido, favorecendo uma estabilidade de médio prazo.', cruzamento_medias_interpretacao='Não foram observados cruzamentos dramáticos recentemente. As médias de curto e longo prazo estão relativamente próximas, sugerindo que o mercado está em fase de consolidação, mas com potencial para rompimentos em caso de aumento significativo na volatilidade.', rsi=55.0, rsi_interpretacao='O RSI indica que o Bitcoin está em uma zona neutra, nem sobrecomprado nem sobrevendido. Este valor sugere que o mercado ainda não se inclinou fortemente para nenhuma direção, permitindo que ajustes moderados ocorram antes de uma tendência clara se formar.', bollinger_interpretacao='As Bandas de Bollinger estão relativamente estreitas, indicando baixa volatilidade atualmente. Isso sugere que o preço está consolidando, mas uma quebra em qualquer direção pode marcar um início de tendência forte.'), suporte_resistencia=Suporte_Resistencia(suporte1=Nivel_Suporte(nivel_suporte_valor=104300.0, nivel_suporte_interpretacao='Observa-se que preços próximos a US$104300 agem como suporte imediato, com diversas mínimas testando essa zona e se mantendo. Esse nível pode servir como área de proteção para os compradores, mitigando perdas em movimentos contrários.'), suporte2=Nivel_Suporte(nivel_suporte_valor=103800.0, nivel_suporte_interpretacao='O nível em torno de US$103800 reflete um suporte médio consolidado, onde a pressão compradora tem historicamente conseguido sustentar o preço. Esse patamar indica uma base de interesse que pode reagir bem a eventuais quedas temporárias.'), suporte3=Nivel_Suporte(nivel_suporte_valor=102800.0, nivel_suporte_interpretacao='Em um contexto de longo prazo, US$102800 surge como suporte importante. Esse valor reflete uma memória histórica do mercado e, se testado, pode convencer investidores de uma eventual reversão para cima.'), resistencia1=Nivel_Resistencia(nivel_resistencia_valor=105000.0, nivel_resistencia_interpretacao='A primeira resistência imediata se encontra em torno de US$105000, onde ocorrem barreiras psicológicas e técnicas. Se o preço conseguir superar esse nível com aumento de volume, pode indicar uma mudança na dinâmica de oferta e demanda.'), resistencia2=Nivel_Resistencia(nivel_resistencia_valor=106000.0, nivel_resistencia_interpretacao='O patamar de US$106000 atua como resistência intermediária, onde os investidores que entraram em posições anteriormente podem realizar lucros. Esse nível harmoniza expectativas de curto prazo e serve como referência para a continuação de uma possível tendência de alta.'), resistencia3=Nivel_Resistencia(nivel_resistencia_valor=107000.0, nivel_resistencia_interpretacao='A resistência em US$107000 é considerada um ponto crítico, visto que reflete um teto importante para o ativo. A superação desse nível pode atrair mais investidores institucionais, mas uma falha na ruptura pode reafirmar a consolidação atual.')), noticias=Noticias(noticia1=Noticia(titulo='Investidores Institucionais Observam Consolidação no Bitcoin', link='https://news.example.com/bitcoin-consolidacao', resumo='Notícias recentes destacam que, enquanto o Bitcoin se mantém na faixa dos 104 mil dólares, investidores institucionais estão observando a consolidação de preços. O suporte técnico firme e a aus ...

# %%
resultado.resumo.preco_atual
# Out:
# 104493.38
